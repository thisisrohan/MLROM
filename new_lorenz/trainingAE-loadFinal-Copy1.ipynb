# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

tf.keras.backend.set_floatx('float32')

plt.rcParams.update({
    "text.usetex":True,
    "font.family":"serif"
})

# %%
colab_flag = False

FTYPE = np.float32
ITYPE = np.int32

strategy = None
# strategy = tf.distribute.MirroredStrategy()

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
if colab_flag == True:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Github/MLROM/KS/')

# %%
print(os.getcwd())
# Out:
# /home/rkaushik/Documents/Thesis/MLROM/new_lorenz

# %%
from tools.misc_tools import mytimecallback, SaveLosses, plot_losses, readAndReturnLossHistories, plot_reconstructed_data, plot_latent_states 
from tools.ae_v2 import Autoencoder

# %%
behaviour = 'initialiseAndTrainFromScratch'
# behaviour = 'loadCheckpointAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
# setting seed for PRNGs
if behaviour == 'initialiseAndTrainFromScratch':
    prng_seed = 42
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if colab_flag == False:
    if strategy is None:
        if gpus:
            gpu_to_use = 0
            tf.config.set_visible_devices(gpus[gpu_to_use], 'GPU')
    logical_devices = tf.config.list_logical_devices('GPU')
    print(logical_devices)
# Out:
# 2023-06-19 14:23:23.239168: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.239698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.306162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.306474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.306731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.306974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2023-06-19 14:23:23.309244: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-19 14:23:23.310160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.310481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.310771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.904913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.905402: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.905745: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-19 14:23:23.905931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3355 MB memory:  -> device: 0, name: Quadro K2200, pci bus id: 0000:02:00.0, compute capability: 5.0

# %%
# print(tf.test.gpu_device_name())
print(tf.config.list_physical_devices())
print(tf.config.list_logical_devices())
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2.8.1

# %% [markdown]
# # KS System

# %%
# setting up params (and saving, if applicable)
from numpy import *

if behaviour == 'initialiseAndTrainFromScratch':
    # loading data directory
    data_dir_idx = '008'

    # making ae save directory
    dir_name_ae = os.getcwd() + dir_sep + 'saved_ae'
    if not os.path.isdir(dir_name_ae):
        os.makedirs(dir_name_ae)

    counter = 0
    while True:
        dir_check = 'ae_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_ae + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_ae = dir_name_ae + dir_sep + dir_check
    os.makedirs(dir_name_ae)
    os.makedirs(dir_name_ae+dir_sep+'plots')
else:
    # some paramaters
    dir_name_ae = os.getcwd()+'{ds}saved_ae{ds}ae_015'.format(ds=dir_sep)

    with open(dir_name_ae + dir_sep + 'ae_data.txt') as f:
        lines = f.readlines()

    params_dict = eval(''.join(lines))
    data_dir_idx = params_dict['data_dir_idx']
    normalizeforae_flag = params_dict['normalizeforae_flag']
    normalization_constant_arr_aedata = params_dict['normalization_constant_arr_aedata']
    if os.path.exists(dir_name_ae+dir_sep+'normalization_data.npz'):
        with np.load(dir_name_ae+dir_sep+'normalization_data.npz', allow_pickle=True) as fl:
            normalization_constant_arr_aedata = fl['normalization_constant_arr_aedata'][0]

print('dir_name_ae:', dir_name_ae)
# loading data
dir_name_data = os.getcwd() + dir_sep + 'saved_data' + dir_sep + 'data_' + data_dir_idx
    
with open(dir_name_data + dir_sep + 'sim_data_params.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
params_mat = params_dict['params_mat']
# init_state = params_dict['init_state']
t0 = params_dict['t0']
T = params_dict['T']
delta_t = params_dict['delta_t']
return_params_arr = params_dict['return_params_arr']
normalize_flag_ogdata = params_dict['normalize_flag']
print('normalize_flag_ogdata:', normalize_flag_ogdata)
alldata_withparams_flag = params_dict['alldata_withparams_flag']

with np.load(dir_name_data+dir_sep+'data.npz', allow_pickle=True) as fl:
    all_data = fl['all_data'].astype(FTYPE)
    boundary_idx_arr = fl['boundary_idx_arr']
    normalization_constant_arr_ogdata = fl['normalization_constant_arr'][0]
    initial_t0 = fl['initial_t0']
    init_state_mat = fl['init_state_mat']

    lyapunov_spectrum_mat = fl['lyapunov_spectrum_mat']
# Out:
# dir_name_ae: /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025
# normalize_flag_ogdata: False

# %%
lyapunov_time_arr = np.empty(shape=lyapunov_spectrum_mat.shape[0], dtype=FTYPE)
for i in range(lyapunov_spectrum_mat.shape[0]):
    lyapunov_time_arr[i] = 1/lyapunov_spectrum_mat[i, 0]
    print('Case : {}, lyapunov exponent : {}, lyapunov time : {}s'.format(i+1, lyapunov_spectrum_mat[i, 0], lyapunov_time_arr[i]))
# Out:
# Case : 1, lyapunov exponent : 0.9058021075578292, lyapunov time : 1.1039938926696777s

# %%
def plot(
        boundary_idx_arr,
        delta_t,
        all_data,
        save_dir=None,
        ax_titles_list=None,
        plot_time=None,
    ):

    n = len(boundary_idx_arr)
    num_digits_n = int(np.log10(n)+1)

    # '''
    num_cols = 1
    num_rows = 1
    factor = 1
    # fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

    
    prev_idx = 0
    for i in range(len(boundary_idx_arr)):
        next_idx = boundary_idx_arr[i]
        if plot_time != None:
            plot_idx = int((plot_time + 0.5*delta_t) // delta_t)
            next_idx = prev_idx + plot_idx
        fig = plt.figure(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
        N = next_idx - prev_idx
        input_time = np.arange(0, N)*delta_t

        ax_orig = fig.add_subplot(num_rows, num_cols, 1, projection ='3d')
        ax_orig.plot(all_data[prev_idx:next_idx, 0], all_data[prev_idx:next_idx, 1], all_data[prev_idx:next_idx, 2])
        ax_orig.title.set_text(r'Actual Data - [$\sigma$, $\rho$, $\beta$] = ' + np.array2string(all_data[next_idx-1, 3:], precision=2, separator=', '))
        ax_orig.set_xlabel('$x_1$')
        ax_orig.set_ylabel('$x_2$')
        ax_orig.set_zlabel('$x_3$')
        
        # ax.title.set_text(r'Latent States')
        if ax_titles_list is not None:
            ax_orig.title.set_text(ax_titles_list[i])
        else:
            ax_orig.title.set_text(r'Case '+str(i+1))

        if save_dir is not None:
            fig.savefig(save_dir+'/Case_'+str(i+1).zfill(num_digits_n)+'.png', dpi=300, bbox_inches='tight')
            fig.clear()
            plt.close()
        else:
            plt.show()
            print('')

        prev_idx = boundary_idx_arr[i]

    # '''

# %%
plot_time = 20

plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    plot_time=plot_time,)

# %%
positve_lp_idx = np.where(lyapunov_time_arr > 0)[0]
print(positve_lp_idx)
# Out:
# [0]

# %%
last_idx = all_data.shape[0]
temp_bia = np.zeros(shape=1+boundary_idx_arr.shape[0], dtype=np.int32)
temp_bia[1:] = boundary_idx_arr
print(temp_bia)
for i in range(boundary_idx_arr.shape[0]-1, -1, -1):
    if not (i in positve_lp_idx):
        print(i)
        num_idxs = last_idx - temp_bia[i+1]
        all_data[temp_bia[i]:temp_bia[i]+num_idxs] = all_data[temp_bia[i+1]:last_idx]
        last_idx = last_idx - (temp_bia[i+1]-temp_bia[i])
# Out:
# [     0 100001]

# %%
new_bia = np.empty_like(boundary_idx_arr)
new_bia[:] = boundary_idx_arr
new_pmat = np.empty_like(params_mat)
new_pmat[:, :] = params_mat
counter = 0
bia_counter = boundary_idx_arr.shape[0]
for i in range(boundary_idx_arr.shape[0]):
    if not (i in positve_lp_idx):
        new_bia[i:] -= temp_bia[i+1] - temp_bia[i]
        new_bia[i:bia_counter-1] = new_bia[i+1:bia_counter]
        new_pmat[i:bia_counter-1] = new_pmat[i+1:bia_counter]
        bia_counter -= 1

# %%
new_bia = new_bia[0:bia_counter]
new_pmat = new_pmat[0:bia_counter]

# %%
all_data = all_data[0:new_bia[-1]]

# %%
plot_time = 100

plot(
    new_bia,
    delta_t,
    all_data,
    plot_time=plot_time,)

# %%
new_bia, boundary_idx_arr = boundary_idx_arr, new_bia
new_pmat, params_mat = params_mat, new_pmat

# %%
# dealing with normalizing the data before feeding into autoencoder
if behaviour == 'initialiseAndTrainFromScratch':
    # normalize data before feeding into autoencoder?
    normalizeforae_flag = True
    normalization_type = 'stddev' # could be 'stddev' or 'minmax'
    stddev_multiplier = 3
    stddev_multiplier_pm = 1
    num_params = params_mat.shape[1]
    
    ae_data_with_params = False # whether to feed in the parameters to the AE along with the data?
    
    og_vars = all_data.shape[1]
    if alldata_withparams_flag == True:
        og_vars -= num_params

    if ae_data_with_params == False:
        stddev_multiplier_pm = None
    if normalizeforae_flag == False:
        stddev_multiplier = None

    if ae_data_with_params == True and alldata_withparams_flag == False:
        new_all_data = np.empty(shape=(all_data.shape[0], og_vars+num_params), dtype=FTYPE)
        new_all_data[:, 0:og_vars] = all_data[:, 0:og_vars]
        del(all_data)
        all_data = new_all_data
        prev_idx = 0
        for i in range(boundary_idx_arr.shape[0]):
            all_data[prev_idx:boundary_idx_arr[i], num_params:] = params_mat[i]
            prev_idx = boundary_idx_arr[i]

    normalization_constant_arr_aedata = None
    if normalizeforae_flag == True:
        normalization_constant_arr_aedata = np.empty(shape=(2, all_data.shape[1]), dtype=FTYPE)
        if normalization_type == 'stddev':
            sample_mean = np.mean(all_data, axis=0)
            sample_std = np.std(all_data, axis=0)
            normalization_constant_arr_aedata[0, :] = sample_mean
            normalization_constant_arr_aedata[1, 0:og_vars] = stddev_multiplier*sample_std[0:og_vars]
            if ae_data_with_params == True:
                normalization_constant_arr_aedata[1, og_vars:] = stddev_multiplier_pm*sample_std[og_vars:]
            zero_idx = np.where(normalization_constant_arr_aedata[1] == 0.0)[0]
            if len(zero_idx) > 0:
                normalization_constant_arr_aedata[1, zero_idx] = 1.0
        elif normalization_type == 'minmax':
            for i in range(all_data.shape[1]):
                sample_min = np.min(all_data[:, i])
                sample_max = np.max(all_data[:, i])
                if sample_max - sample_min == 0:
                    sample_min = sample_min - 0.5
                    sample_max = sample_min + 1
                normalization_constant_arr_aedata[0, i] = sample_min
                normalization_constant_arr_aedata[1, i] = sample_max - sample_min
        # if ae_data_with_params == True:
        #     normalization_constant_arr_aedata[0, og_vars:] = 0.0
        #     normalization_constant_arr_aedata[1, og_vars:] = 1.0
        for i in range(all_data.shape[1]):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]
            
    # saving sim data
    ae_data = {
        'data_dir_idx':data_dir_idx,
        'normalizeforae_flag':normalizeforae_flag,
        'normalization_constant_arr_aedata':normalization_constant_arr_aedata,
        'normalization_type':normalization_type,
        'stddev_multiplier':stddev_multiplier,
        'stddev_multiplier_pm':stddev_multiplier_pm,
        'ae_data_with_params':ae_data_with_params,
        'module':Autoencoder.__module__,
    }
    with open(dir_name_ae+dir_sep+'ae_data.txt', 'w') as f:
        f.write(str(ae_data))
    np.savez(
        dir_name_ae+dir_sep+'normalization_data',
        normalization_constant_arr_aedata=[normalization_constant_arr_aedata],
    )
else:
    if normalizeforae_flag == True:
        for i in range(all_data.shape[1]):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]
            
time_stddev = np.std(all_data, axis=0)
if ae_data_with_params == False:
    all_data = all_data[:, 0:og_vars]
    time_stddev = time_stddev[0:og_vars]
else:
    time_stddev[og_vars:] = 1.0

# %%
normalization_constant_arr_aedata
# Out:
# array([[ 0.1919329 ,  0.19295387, 23.526415  ],
#        [23.75482   , 27.052578  , 25.936165  ]], dtype=float32)

# %%
plot_time = 100

plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    plot_time=plot_time,)

# %% [markdown]
# # Autoencoder

# %%
# setting up training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_list = [1e-3, 1e-4, 1e-5]
    epochs = 200
    patience = 10  # parameter for early stopping
    min_delta = 1e-6  # parameter for early stopping
    lambda_reg = 1.01045731e-06 # weight for regularizer
    train_split = 0.8
    val_split = 0.1
    test_split = 1 - train_split - val_split
    batch_size = 2**6
    fRMS = 1.08643105e-03
    timeMeanofSpaceRMS = np.mean(np.mean(all_data[:, 0:og_vars]**2, axis=1)**0.5)
    
    # stddev = fRMS*timeMeanofSpaceRMS
    stddev = fRMS * np.mean(time_stddev[0:og_vars])
    contractive_lmda = 0.00043378
    use_weights_post_dense = True
    dropout_rate = 0.0
    
    dt_ae = 0.01
    
    print('stddev : ', stddev)

    # saving training params
    training_specific_params = {
        'learning_rate_list':learning_rate_list,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size,
        'fRMS':fRMS,
        'timeMeanofSpaceRMS':timeMeanofSpaceRMS,
        'stddev':stddev,
        'contractive_lmda':contractive_lmda,
        'dropout_rate':dropout_rate,
        'dt_ae':dt_ae,
    }

    with open(dir_name_ae+dir_sep+'training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))
else:
    with open(dir_name_ae + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()

    tparams_dict = eval(''.join(lines))

    learning_rate_list = tparams_dict['learning_rate_list']
    epochs = tparams_dict['epochs']
    patience = tparams_dict['patience']
    min_delta = tparams_dict['min_delta']
    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']
    try:
        stddev = tparams_dict['stddev']
    except:
        print("'stddev' not in tparams_dict, set to 0")
        stddev = 0.0
    try:
        contractive_lmda = tparams_dict['contractive_lmda']
    except:
        print("'contractive_lmda' not in tparams_dict, set to 0")
        contractive_lmda = 0.0
    try:
        dropout_rate = tparams_dict['dropout_rate']
    except:
        print("'dropout_rate' not in tparams_dict, set to 0")
        dropout_rate = 0.0
    try:
        dt_ae = tparams_dict['dt_ae']
    except:
        print("'dt_ae' not in tparams_dict, set to 0")
        dt_ae = delta_t

    test_split = 1 - train_split - val_split

    # setting seed for PRNGs
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)
# Out:
# stddev :  0.0003621441474204138

# %%
skip_factor = int(dt_ae/delta_t)

for i in range(len(boundary_idx_arr)-1, -1, -1):
    end_idx = boundary_idx_arr[i]
    if i == 0:
        begin_idx = 0
    else:
        begin_idx = boundary_idx_arr[i-1]

    num_elems_pre_indexing = end_idx - begin_idx
    num_elems_post_indexing = (num_elems_pre_indexing+skip_factor-1)//skip_factor

    boundary_idx_arr[i:] -= num_elems_pre_indexing-num_elems_post_indexing

    all_data[begin_idx:begin_idx+num_elems_post_indexing] = all_data[begin_idx:end_idx:skip_factor]
    all_data[begin_idx+num_elems_post_indexing:begin_idx+(boundary_idx_arr[-1]-boundary_idx_arr[i])] = all_data[end_idx:boundary_idx_arr[-1]+num_elems_post_indexing]

all_data = all_data[0:boundary_idx_arr[-1]]

# %%
cum_samples = boundary_idx_arr[-1]
# idx = np.arange(cum_samples)
# np.random.shuffle(idx)
num_train = 0
num_val = 0
begin_idx = 0
for i in range(len(boundary_idx_arr)):
    num_samples = boundary_idx_arr[i] - begin_idx
    num_train += int( np.round(train_split*num_samples) )
    num_val += int( np.round(val_split*num_samples) )
    begin_idx = boundary_idx_arr[i]

# defining shapes
training_shape = [num_train]
training_shape.extend(all_data.shape[1:])

val_shape = [num_val]
val_shape.extend(all_data.shape[1:])

testing_shape = [cum_samples-num_train-num_val]
testing_shape.extend(all_data.shape[1:])

# defining required arrays
training_data = np.empty(shape=training_shape)

val_data = np.empty(shape=val_shape)

testing_data = np.empty(shape=testing_shape)

begin_idx = 0
training_data_rolling_count = 0
val_data_rolling_count = 0
testing_data_rolling_count = 0
for i in range(len(boundary_idx_arr)):
    num_samples = boundary_idx_arr[i] - begin_idx
    num_train = int( np.round(train_split*num_samples) )
    num_val = int( np.round(val_split*num_samples) )

    training_data[training_data_rolling_count:training_data_rolling_count+num_train] = all_data[begin_idx:begin_idx+num_train]
    training_data_rolling_count += num_train

    val_data[val_data_rolling_count:val_data_rolling_count+num_val] = all_data[begin_idx+num_train:begin_idx+num_train+num_val]
    val_data_rolling_count += num_val

    num_test = num_samples-num_train-num_val
    testing_data[testing_data_rolling_count:testing_data_rolling_count+num_test] = all_data[begin_idx+num_train+num_val:begin_idx+num_train+num_val+num_test]
    testing_data_rolling_count += num_test

    begin_idx = boundary_idx_arr[i]

# further shuffling
# idx = np.arange(0, training_data.shape[0])
# np.random.shuffle(idx)
# training_data_rnn_input = training_data_rnn_input[idx]
np.random.shuffle(training_data)

# idx = np.arange(0, val_data.shape[0])
# np.random.shuffle(idx)
# val_data = val_data[idx]
np.random.shuffle(val_data)

# idx = np.arange(0, testing_data.shape[0])
# np.random.shuffle(idx)
# testing_data = testing_data[idx]
np.random.shuffle(testing_data)

# %%
# del(all_data)

# %%
# Initialize network
if behaviour == 'initialiseAndTrainFromScratch':
    latent_space_dim = 2
    # enc_layers = [128, 96, 64, 48, 32, 24, 26, 8, 4]
    # enc_layers = [192, 96, 48, 24, 12, 6, 3]
    # enc_layers = [96, 48, 24, 12, 6, 3]
    # enc_layers = [128, 64, 32, 16, 8, 4]
    # enc_layers = []
    # enc_layers = [32, 16, 8, 4]
    # for i in range(len(enc_layers)):
    #     if latent_space_dim < enc_layers[-i-1]:
    #         enc_layers = enc_layers[0:-i]
    #         break
    #     if i == len(enc_layers)-1:
    #         enc_layers = []
    # dec_layers = enc_layers[::-1]
    enc_layers = [8, 8, 4, 4, 2] # [16, 12, 8, 8, 4, 4, 2]
    dec_layers = [2, 4, 4, 8, 8] # [2, 4, 4, 8, 8, 12, 16]
    
    enc_layer_act_func = 'elu' #'modified_relu_2'
    enc_final_layer_act_func = 'tanh'
    dec_layer_act_func = 'elu' #'modified_relu_2'
    dec_final_layer_act_func = 'tanh'
    reg_name = 'L2'
    
    if strategy is not None:
        with strategy.scope():
            ae_net = Autoencoder(
                data_dim=training_data.shape[1],
                enc_layers=enc_layers,
                dec_layers=dec_layers,
                latent_space_dim=latent_space_dim,
                lambda_reg=lambda_reg,
                reg_name=reg_name,
                enc_layer_act_func=enc_layer_act_func,
                enc_final_layer_act_func=enc_final_layer_act_func,
                dec_layer_act_func=dec_layer_act_func,
                dec_final_layer_act_func=dec_final_layer_act_func,
                load_file=None,
                stddev=stddev,
                contractive_lmda=contractive_lmda,
                dropout_rate=dropout_rate,
                use_weights_post_dense=use_weights_post_dense,)
    else:
        ae_net = Autoencoder(
            data_dim=training_data.shape[1],
            enc_layers=enc_layers,
            dec_layers=dec_layers,
            latent_space_dim=latent_space_dim,
            lambda_reg=lambda_reg,
            reg_name=reg_name,
            enc_layer_act_func=enc_layer_act_func,
            enc_final_layer_act_func=enc_final_layer_act_func,
            dec_layer_act_func=dec_layer_act_func,
            dec_final_layer_act_func=dec_final_layer_act_func,
            load_file=None,
            stddev=stddev,
            contractive_lmda=contractive_lmda,
            dropout_rate=dropout_rate,
            use_weights_post_dense=use_weights_post_dense,)
    # saving the AE configuration
    save_path = dir_name_ae+dir_sep+'final_net'
    if not os.path.isdir(save_path):
        os.makedirs(save_path)
    ae_net.save_class_dict(save_path+dir_sep+'final_net_class_dict.txt')
else:
    load_file = dir_name_ae + dir_sep + 'final_net' + dir_sep + 'final_net_class_dict.txt'
    if strategy is not None:
        with strategy.scope():
            ae_net = Autoencoder(data_dim=training_data.shape[1], load_file=load_file)
    else:
        ae_net = Autoencoder(data_dim=training_data.shape[1], load_file=load_file)
    
    if behaviour == 'loadCheckpointAndContinueTraining':
        wt_file = tf.train.latest_checkpoint(dir_name_ae+dir_sep+'checkpoints')
        # ae_net.load_weights(wt_file)
    elif behaviour == 'loadFinalNetAndPlot':
        wt_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_ae_weights.h5'
        ae_net.load_weights_from_file(wt_file)

# %%
#

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt = readAndReturnLossHistories(
        dir_name_ae=dir_name_ae,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=learning_rate_list)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_ae+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
train_MSE_hist = []
val_MSE_hist = []

train_NMSE_hist = []
val_NMSE_hist = []

train_ls_jacobian_norm_hist = []

train_real_MSE_hist = []
val_real_MSE_hist = []

train_params_MSE_hist = []
val_params_MSE_hist = []

# %%
class NMSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, divisor_arr, name='NMSE', **kwargs):
        super(NMSE, self).__init__(name, **kwargs)
        self.divisor_arr = divisor_arr

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true / self.divisor_arr
        y_pred = y_pred / self.divisor_arr
        return super(NMSE, self).update_state(y_true, y_pred, sample_weight)

class real_MSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, og_vars, name='real_MSE', **kwargs):
        super().__init__(name, **kwargs)
        self.og_vars = og_vars

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true[:, 0:self.og_vars]
        y_pred = y_pred[:, 0:self.og_vars]
        return super().update_state(y_true, y_pred, sample_weight)
    
class params_MSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, og_vars, name='params_MSE', **kwargs):
        super().__init__(name, **kwargs)
        self.og_vars = og_vars

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true[:, self.og_vars:]
        y_pred = y_pred[:, self.og_vars:]
        return super().update_state(y_true, y_pred, sample_weight)

# %%
# compiling the network
ae_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
    loss=losses.MeanSquaredError(),
#     loss=losses.BinaryCrossentropy(from_logits=False),
    run_eagerly=False,
    metrics=['mse', NMSE(divisor_arr=tf.constant(time_stddev)), real_MSE(og_vars), params_MSE(og_vars)]
)

if behaviour == 'loadCheckpointAndContinueTraining':
    # this loads the weights/attributes of the optimizer as well
    if strategy is not None:
        with strategy.scope():
            ae_net.load_weights(wt_file)
    else:
        ae_net.load_weights(wt_file)

if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    metric_to_use = 'val_mse'
    # implementing early stopping
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor=metric_to_use,
        patience=patience,
        restore_best_weights=True,
        verbose=True,
        min_delta=min_delta
    )

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_ae+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor=metric_to_use,
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        period=1  # saves every 5 epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=1)

    # training the network
    for i in range(starting_lr_idx, len(learning_rate_list)):
        learning_rate = learning_rate_list[i]
        K.set_value(ae_net.optimizer.lr, learning_rate)

        savelosses_cb.update_lr_idx(i)

        if i == starting_lr_idx:
            EPOCHS = num_epochs_left
            savelosses_cb.update_offset(epochs-num_epochs_left)
        else:
            EPOCHS = epochs
            savelosses_cb.update_offset(0)

        total_s_len = 80
        sep_lr_s = ' LEARNING RATE : {} '.format(learning_rate)
        sep_lr_s = int((total_s_len - len(sep_lr_s))//2)*'-' + sep_lr_s
        sep_lr_s = sep_lr_s + (total_s_len-len(sep_lr_s))*'-'
        print('\n\n' + '-'*len(sep_lr_s))
        print('\n' + sep_lr_s+'\n')
        print('-'*len(sep_lr_s) + '\n\n')
        
        history = ae_net.fit(training_data, training_data,
            epochs=EPOCHS,
            batch_size=batch_size,
#             validation_split=val_split/train_split,
            validation_data=(val_data, val_data),
            callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb],
            verbose=1,
            shuffle=True,
        )

        val_loss_hist.extend(history.history['val_loss'])
        train_loss_hist.extend(history.history['loss'])
        
        val_MSE_hist.extend(history.history['val_mse'])
        train_MSE_hist.extend(history.history['mse'])
        
        val_NMSE_hist.extend(history.history['val_NMSE'])
        train_NMSE_hist.extend(history.history['NMSE'])
        
        train_ls_jacobian_norm_hist.append(history.history['ls_jacobian_norm'])
        
        val_real_MSE_hist.extend(history.history['val_real_MSE'])
        train_real_MSE_hist.extend(history.history['real_MSE'])
        
        val_params_MSE_hist.extend(history.history['val_params_MSE'])
        train_params_MSE_hist.extend(history.history['params_MSE'])
        
        if i == starting_lr_idx:
            lr_change[i+1] += len(history.history['val_loss'])
        else:
            lr_change.append(lr_change[i]+len(history.history['val_loss']))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 0.001 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 0.0172 - mse: 0.0172 - NMSE: 0.1544 - real_MSE: 0.0172 - params_MSE: nan - ls_jacobian_norm: 0.6234 - tot_time: 0h 0m 11.7s
#
# Epoch 1: val_mse improved from inf to 0.00492, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 12s 8ms/step - loss: 0.0172 - mse: 0.0171 - NMSE: 0.1540 - real_MSE: 0.0171 - params_MSE: nan - ls_jacobian_norm: 0.6225 - val_loss: 0.0050 - val_mse: 0.0049 - val_NMSE: 0.0443 - val_real_MSE: 0.0049 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 2/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0030 - NMSE: 0.0266 - real_MSE: 0.0030 - params_MSE: nan - ls_jacobian_norm: 0.4045 - tot_time: 0h 0m 21.8s
#
# Epoch 2: val_mse improved from 0.00492 to 0.00199, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 0.0030 - mse: 0.0030 - NMSE: 0.0266 - real_MSE: 0.0030 - params_MSE: nan - ls_jacobian_norm: 0.4044 - val_loss: 0.0021 - val_mse: 0.0020 - val_NMSE: 0.0179 - val_real_MSE: 0.0020 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 3/200
# 1251/1251 [==============================] - ETA: 0s - loss: 0.0013 - mse: 0.0012 - NMSE: 0.0106 - real_MSE: 0.0012 - params_MSE: nan - ls_jacobian_norm: 0.3499 - tot_time: 0h 0m 32.9s
#
# Epoch 3: val_mse improved from 0.00199 to 0.00114, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 0.0013 - mse: 0.0012 - NMSE: 0.0106 - real_MSE: 0.0012 - params_MSE: nan - ls_jacobian_norm: 0.3499 - val_loss: 0.0012 - val_mse: 0.0011 - val_NMSE: 0.0103 - val_real_MSE: 0.0011 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 4/200
# 1245/1251 [============================>.] - ETA: 0s - loss: 8.1983e-04 - mse: 7.4029e-04 - NMSE: 0.0067 - real_MSE: 7.4029e-04 - params_MSE: nan - ls_jacobian_norm: 0.3384 - tot_time: 0h 0m 41.8s
#
# Epoch 4: val_mse improved from 0.00114 to 0.00068, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 9s 7ms/step - loss: 8.1988e-04 - mse: 7.4033e-04 - NMSE: 0.0067 - real_MSE: 7.4033e-04 - params_MSE: nan - ls_jacobian_norm: 0.3383 - val_loss: 7.6320e-04 - val_mse: 6.8252e-04 - val_NMSE: 0.0061 - val_real_MSE: 6.8252e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 5/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 6.6518e-04 - mse: 5.8346e-04 - NMSE: 0.0053 - real_MSE: 5.8346e-04 - params_MSE: nan - ls_jacobian_norm: 0.3275 - tot_time: 0h 0m 51.2s
#
# Epoch 5: val_mse did not improve from 0.00068
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 9s 7ms/step - loss: 6.6532e-04 - mse: 5.8360e-04 - NMSE: 0.0053 - real_MSE: 5.8360e-04 - params_MSE: nan - ls_jacobian_norm: 0.3276 - val_loss: 0.0018 - val_mse: 0.0017 - val_NMSE: 0.0154 - val_real_MSE: 0.0017 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 6/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 5.9688e-04 - mse: 5.1346e-04 - NMSE: 0.0046 - real_MSE: 5.1346e-04 - params_MSE: nan - ls_jacobian_norm: 0.3237 - tot_time: 0h 1m 1.7s
#
# Epoch 6: val_mse improved from 0.00068 to 0.00050, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 5.9691e-04 - mse: 5.1350e-04 - NMSE: 0.0046 - real_MSE: 5.1350e-04 - params_MSE: nan - ls_jacobian_norm: 0.3237 - val_loss: 5.8652e-04 - val_mse: 5.0238e-04 - val_NMSE: 0.0045 - val_real_MSE: 5.0238e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 7/200
# 1244/1251 [============================>.] - ETA: 0s - loss: 5.4587e-04 - mse: 4.6110e-04 - NMSE: 0.0041 - real_MSE: 4.6110e-04 - params_MSE: nan - ls_jacobian_norm: 0.3134 - tot_time: 0h 1m 11.3s
#
# Epoch 7: val_mse did not improve from 0.00050
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 9s 8ms/step - loss: 5.4544e-04 - mse: 4.6067e-04 - NMSE: 0.0041 - real_MSE: 4.6067e-04 - params_MSE: nan - ls_jacobian_norm: 0.3133 - val_loss: 6.0567e-04 - val_mse: 5.2031e-04 - val_NMSE: 0.0047 - val_real_MSE: 5.2031e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 8/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 5.2372e-04 - mse: 4.3790e-04 - NMSE: 0.0039 - real_MSE: 4.3790e-04 - params_MSE: nan - ls_jacobian_norm: 0.3042 - tot_time: 0h 1m 19.3s
#
# Epoch 8: val_mse did not improve from 0.00050
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 8s 6ms/step - loss: 5.2372e-04 - mse: 4.3789e-04 - NMSE: 0.0039 - real_MSE: 4.3789e-04 - params_MSE: nan - ls_jacobian_norm: 0.3041 - val_loss: 0.0013 - val_mse: 0.0013 - val_NMSE: 0.0113 - val_real_MSE: 0.0013 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 9/200
# 1244/1251 [============================>.] - ETA: 0s - loss: 5.1082e-04 - mse: 4.2426e-04 - NMSE: 0.0038 - real_MSE: 4.2426e-04 - params_MSE: nan - ls_jacobian_norm: 0.2932 - tot_time: 0h 1m 27.6s
#
# Epoch 9: val_mse improved from 0.00050 to 0.00047, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 8s 7ms/step - loss: 5.1068e-04 - mse: 4.2411e-04 - NMSE: 0.0038 - real_MSE: 4.2411e-04 - params_MSE: nan - ls_jacobian_norm: 0.2932 - val_loss: 5.5830e-04 - val_mse: 4.7137e-04 - val_NMSE: 0.0042 - val_real_MSE: 4.7137e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 10/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.9628e-04 - mse: 4.0905e-04 - NMSE: 0.0037 - real_MSE: 4.0905e-04 - params_MSE: nan - ls_jacobian_norm: 0.2814 - tot_time: 0h 1m 36.3s
#
# Epoch 10: val_mse improved from 0.00047 to 0.00044, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 9s 7ms/step - loss: 4.9663e-04 - mse: 4.0940e-04 - NMSE: 0.0037 - real_MSE: 4.0940e-04 - params_MSE: nan - ls_jacobian_norm: 0.2814 - val_loss: 5.3219e-04 - val_mse: 4.4464e-04 - val_NMSE: 0.0040 - val_real_MSE: 4.4464e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 11/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.9655e-04 - mse: 4.0885e-04 - NMSE: 0.0037 - real_MSE: 4.0885e-04 - params_MSE: nan - ls_jacobian_norm: 0.2734 - tot_time: 0h 1m 46.6s
#
# Epoch 11: val_mse did not improve from 0.00044
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.9655e-04 - mse: 4.0884e-04 - NMSE: 0.0037 - real_MSE: 4.0884e-04 - params_MSE: nan - ls_jacobian_norm: 0.2734 - val_loss: 6.1585e-04 - val_mse: 5.2800e-04 - val_NMSE: 0.0048 - val_real_MSE: 5.2800e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 12/200
# 1244/1251 [============================>.] - ETA: 0s - loss: 4.9046e-04 - mse: 4.0244e-04 - NMSE: 0.0036 - real_MSE: 4.0244e-04 - params_MSE: nan - ls_jacobian_norm: 0.2655 - tot_time: 0h 1m 56.7s
#
# Epoch 12: val_mse improved from 0.00044 to 0.00042, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.9041e-04 - mse: 4.0239e-04 - NMSE: 0.0036 - real_MSE: 4.0239e-04 - params_MSE: nan - ls_jacobian_norm: 0.2655 - val_loss: 5.0907e-04 - val_mse: 4.2093e-04 - val_NMSE: 0.0038 - val_real_MSE: 4.2093e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 13/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.8517e-04 - mse: 3.9688e-04 - NMSE: 0.0036 - real_MSE: 3.9688e-04 - params_MSE: nan - ls_jacobian_norm: 0.2590 - tot_time: 0h 2m 7.3s
#
# Epoch 13: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.8512e-04 - mse: 3.9684e-04 - NMSE: 0.0036 - real_MSE: 3.9684e-04 - params_MSE: nan - ls_jacobian_norm: 0.2591 - val_loss: 6.8181e-04 - val_mse: 5.9343e-04 - val_NMSE: 0.0053 - val_real_MSE: 5.9343e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 14/200
# 1244/1251 [============================>.] - ETA: 0s - loss: 4.8489e-04 - mse: 3.9641e-04 - NMSE: 0.0036 - real_MSE: 3.9641e-04 - params_MSE: nan - ls_jacobian_norm: 0.2529 - tot_time: 0h 2m 18.5s
#
# Epoch 14: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.8506e-04 - mse: 3.9659e-04 - NMSE: 0.0036 - real_MSE: 3.9659e-04 - params_MSE: nan - ls_jacobian_norm: 0.2528 - val_loss: 7.6764e-04 - val_mse: 6.7911e-04 - val_NMSE: 0.0061 - val_real_MSE: 6.7911e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 15/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.8018e-04 - mse: 3.9156e-04 - NMSE: 0.0035 - real_MSE: 3.9156e-04 - params_MSE: nan - ls_jacobian_norm: 0.2468 - tot_time: 0h 2m 29.6s
#
# Epoch 15: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.8056e-04 - mse: 3.9194e-04 - NMSE: 0.0035 - real_MSE: 3.9194e-04 - params_MSE: nan - ls_jacobian_norm: 0.2467 - val_loss: 5.1985e-04 - val_mse: 4.3115e-04 - val_NMSE: 0.0039 - val_real_MSE: 4.3115e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 16/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.8007e-04 - mse: 3.9133e-04 - NMSE: 0.0035 - real_MSE: 3.9133e-04 - params_MSE: nan - ls_jacobian_norm: 0.2409 - tot_time: 0h 2m 40.3s
#
# Epoch 16: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.7993e-04 - mse: 3.9119e-04 - NMSE: 0.0035 - real_MSE: 3.9119e-04 - params_MSE: nan - ls_jacobian_norm: 0.2409 - val_loss: 6.6385e-04 - val_mse: 5.7502e-04 - val_NMSE: 0.0052 - val_real_MSE: 5.7502e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 17/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.8383e-04 - mse: 3.9501e-04 - NMSE: 0.0036 - real_MSE: 3.9501e-04 - params_MSE: nan - ls_jacobian_norm: 0.2382 - tot_time: 0h 2m 50.9s
#
# Epoch 17: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.8367e-04 - mse: 3.9485e-04 - NMSE: 0.0036 - real_MSE: 3.9485e-04 - params_MSE: nan - ls_jacobian_norm: 0.2381 - val_loss: 5.6983e-04 - val_mse: 4.8099e-04 - val_NMSE: 0.0043 - val_real_MSE: 4.8099e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 18/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.7836e-04 - mse: 3.8951e-04 - NMSE: 0.0035 - real_MSE: 3.8951e-04 - params_MSE: nan - ls_jacobian_norm: 0.2331 - tot_time: 0h 3m 1.2s
#
# Epoch 18: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.7789e-04 - mse: 3.8904e-04 - NMSE: 0.0035 - real_MSE: 3.8904e-04 - params_MSE: nan - ls_jacobian_norm: 0.2331 - val_loss: 0.0022 - val_mse: 0.0021 - val_NMSE: 0.0193 - val_real_MSE: 0.0021 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 19/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.8131e-04 - mse: 3.9250e-04 - NMSE: 0.0035 - real_MSE: 3.9250e-04 - params_MSE: nan - ls_jacobian_norm: 0.2300 - tot_time: 0h 3m 12.0s
#
# Epoch 19: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.8121e-04 - mse: 3.9240e-04 - NMSE: 0.0035 - real_MSE: 3.9240e-04 - params_MSE: nan - ls_jacobian_norm: 0.2300 - val_loss: 6.8653e-04 - val_mse: 5.9764e-04 - val_NMSE: 0.0054 - val_real_MSE: 5.9764e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 20/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.7451e-04 - mse: 3.8560e-04 - NMSE: 0.0035 - real_MSE: 3.8560e-04 - params_MSE: nan - ls_jacobian_norm: 0.2245 - tot_time: 0h 3m 22.2s
#
# Epoch 20: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.7451e-04 - mse: 3.8560e-04 - NMSE: 0.0035 - real_MSE: 3.8560e-04 - params_MSE: nan - ls_jacobian_norm: 0.2245 - val_loss: 0.0016 - val_mse: 0.0015 - val_NMSE: 0.0132 - val_real_MSE: 0.0015 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 21/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.7077e-04 - mse: 3.8181e-04 - NMSE: 0.0034 - real_MSE: 3.8181e-04 - params_MSE: nan - ls_jacobian_norm: 0.2217 - tot_time: 0h 3m 32.5s
#
# Epoch 21: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.7059e-04 - mse: 3.8164e-04 - NMSE: 0.0034 - real_MSE: 3.8164e-04 - params_MSE: nan - ls_jacobian_norm: 0.2217 - val_loss: 5.9028e-04 - val_mse: 5.0123e-04 - val_NMSE: 0.0045 - val_real_MSE: 5.0123e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 22/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.6892e-04 - mse: 3.7986e-04 - NMSE: 0.0034 - real_MSE: 3.7986e-04 - params_MSE: nan - ls_jacobian_norm: 0.2159Restoring model weights from the end of the best epoch: 12.
#  - tot_time: 0h 3m 43.3s
#
# Epoch 22: val_mse did not improve from 0.00042
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.6876e-04 - mse: 3.7970e-04 - NMSE: 0.0034 - real_MSE: 3.7970e-04 - params_MSE: nan - ls_jacobian_norm: 0.2159 - val_loss: 0.0012 - val_mse: 0.0011 - val_NMSE: 0.0103 - val_real_MSE: 0.0011 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 22: early stopping
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 0.0001 ----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.4013e-04 - mse: 3.5191e-04 - NMSE: 0.0032 - real_MSE: 3.5191e-04 - params_MSE: nan - ls_jacobian_norm: 0.2617 - tot_time: 0h 3m 53.9s
#
# Epoch 1: val_mse improved from 0.00042 to 0.00036, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.4043e-04 - mse: 3.5221e-04 - NMSE: 0.0032 - real_MSE: 3.5221e-04 - params_MSE: nan - ls_jacobian_norm: 0.2618 - val_loss: 4.4992e-04 - val_mse: 3.6164e-04 - val_NMSE: 0.0033 - val_real_MSE: 3.6164e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 2/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.4105e-04 - mse: 3.5269e-04 - NMSE: 0.0032 - real_MSE: 3.5269e-04 - params_MSE: nan - ls_jacobian_norm: 0.2575 - tot_time: 0h 4m 4.8s
#
# Epoch 2: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.4102e-04 - mse: 3.5265e-04 - NMSE: 0.0032 - real_MSE: 3.5265e-04 - params_MSE: nan - ls_jacobian_norm: 0.2575 - val_loss: 4.7056e-04 - val_mse: 3.8211e-04 - val_NMSE: 0.0034 - val_real_MSE: 3.8211e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 3/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.4165e-04 - mse: 3.5312e-04 - NMSE: 0.0032 - real_MSE: 3.5312e-04 - params_MSE: nan - ls_jacobian_norm: 0.2532 - tot_time: 0h 4m 14.7s
#
# Epoch 3: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.4131e-04 - mse: 3.5278e-04 - NMSE: 0.0032 - real_MSE: 3.5278e-04 - params_MSE: nan - ls_jacobian_norm: 0.2532 - val_loss: 4.5412e-04 - val_mse: 3.6550e-04 - val_NMSE: 0.0033 - val_real_MSE: 3.6550e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 4/200
# 1245/1251 [============================>.] - ETA: 0s - loss: 4.4049e-04 - mse: 3.5177e-04 - NMSE: 0.0032 - real_MSE: 3.5177e-04 - params_MSE: nan - ls_jacobian_norm: 0.2497 - tot_time: 0h 4m 22.8s
#
# Epoch 4: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 8s 7ms/step - loss: 4.4106e-04 - mse: 3.5234e-04 - NMSE: 0.0032 - real_MSE: 3.5234e-04 - params_MSE: nan - ls_jacobian_norm: 0.2497 - val_loss: 4.6105e-04 - val_mse: 3.7225e-04 - val_NMSE: 0.0034 - val_real_MSE: 3.7225e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 5/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.4053e-04 - mse: 3.5164e-04 - NMSE: 0.0032 - real_MSE: 3.5164e-04 - params_MSE: nan - ls_jacobian_norm: 0.2463 - tot_time: 0h 4m 32.3s
#
# Epoch 5: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.4079e-04 - mse: 3.5190e-04 - NMSE: 0.0032 - real_MSE: 3.5190e-04 - params_MSE: nan - ls_jacobian_norm: 0.2463 - val_loss: 4.8239e-04 - val_mse: 3.9342e-04 - val_NMSE: 0.0035 - val_real_MSE: 3.9342e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 6/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.4083e-04 - mse: 3.5179e-04 - NMSE: 0.0032 - real_MSE: 3.5179e-04 - params_MSE: nan - ls_jacobian_norm: 0.2434 - tot_time: 0h 4m 41.9s
#
# Epoch 6: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.4072e-04 - mse: 3.5168e-04 - NMSE: 0.0032 - real_MSE: 3.5168e-04 - params_MSE: nan - ls_jacobian_norm: 0.2434 - val_loss: 4.5222e-04 - val_mse: 3.6309e-04 - val_NMSE: 0.0033 - val_real_MSE: 3.6309e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 7/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.3911e-04 - mse: 3.4991e-04 - NMSE: 0.0031 - real_MSE: 3.4991e-04 - params_MSE: nan - ls_jacobian_norm: 0.2405 - tot_time: 0h 4m 52.2s
#
# Epoch 7: val_mse improved from 0.00036 to 0.00036, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3911e-04 - mse: 3.4991e-04 - NMSE: 0.0031 - real_MSE: 3.4991e-04 - params_MSE: nan - ls_jacobian_norm: 0.2405 - val_loss: 4.4575e-04 - val_mse: 3.5648e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5648e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 8/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.3908e-04 - mse: 3.4972e-04 - NMSE: 0.0031 - real_MSE: 3.4972e-04 - params_MSE: nan - ls_jacobian_norm: 0.2381 - tot_time: 0h 5m 3.1s
#
# Epoch 8: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3893e-04 - mse: 3.4958e-04 - NMSE: 0.0031 - real_MSE: 3.4958e-04 - params_MSE: nan - ls_jacobian_norm: 0.2381 - val_loss: 4.9154e-04 - val_mse: 4.0211e-04 - val_NMSE: 0.0036 - val_real_MSE: 4.0211e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 9/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.3890e-04 - mse: 3.4941e-04 - NMSE: 0.0031 - real_MSE: 3.4941e-04 - params_MSE: nan - ls_jacobian_norm: 0.2353 - tot_time: 0h 5m 14.2s
#
# Epoch 9: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3887e-04 - mse: 3.4937e-04 - NMSE: 0.0031 - real_MSE: 3.4937e-04 - params_MSE: nan - ls_jacobian_norm: 0.2353 - val_loss: 4.6246e-04 - val_mse: 3.7289e-04 - val_NMSE: 0.0034 - val_real_MSE: 3.7289e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 10/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.3744e-04 - mse: 3.4781e-04 - NMSE: 0.0031 - real_MSE: 3.4781e-04 - params_MSE: nan - ls_jacobian_norm: 0.2329 - tot_time: 0h 5m 25.6s
#
# Epoch 10: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3744e-04 - mse: 3.4780e-04 - NMSE: 0.0031 - real_MSE: 3.4780e-04 - params_MSE: nan - ls_jacobian_norm: 0.2329 - val_loss: 4.6467e-04 - val_mse: 3.7496e-04 - val_NMSE: 0.0034 - val_real_MSE: 3.7496e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 11/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.3647e-04 - mse: 3.4670e-04 - NMSE: 0.0031 - real_MSE: 3.4670e-04 - params_MSE: nan - ls_jacobian_norm: 0.2306 - tot_time: 0h 5m 36.9s
#
# Epoch 11: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3733e-04 - mse: 3.4755e-04 - NMSE: 0.0031 - real_MSE: 3.4755e-04 - params_MSE: nan - ls_jacobian_norm: 0.2306 - val_loss: 4.6381e-04 - val_mse: 3.7396e-04 - val_NMSE: 0.0034 - val_real_MSE: 3.7396e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 12/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.3765e-04 - mse: 3.4773e-04 - NMSE: 0.0031 - real_MSE: 3.4773e-04 - params_MSE: nan - ls_jacobian_norm: 0.2281 - tot_time: 0h 5m 47.6s
#
# Epoch 12: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3765e-04 - mse: 3.4774e-04 - NMSE: 0.0031 - real_MSE: 3.4774e-04 - params_MSE: nan - ls_jacobian_norm: 0.2281 - val_loss: 4.4786e-04 - val_mse: 3.5788e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5788e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 13/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.3667e-04 - mse: 3.4663e-04 - NMSE: 0.0031 - real_MSE: 3.4663e-04 - params_MSE: nan - ls_jacobian_norm: 0.2263 - tot_time: 0h 5m 58.2s
#
# Epoch 13: val_mse did not improve from 0.00036
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.3667e-04 - mse: 3.4663e-04 - NMSE: 0.0031 - real_MSE: 3.4663e-04 - params_MSE: nan - ls_jacobian_norm: 0.2265 - val_loss: 4.7940e-04 - val_mse: 3.8930e-04 - val_NMSE: 0.0035 - val_real_MSE: 3.8930e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 14/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.3645e-04 - mse: 3.4629e-04 - NMSE: 0.0031 - real_MSE: 3.4629e-04 - params_MSE: nan - ls_jacobian_norm: 0.2243 - tot_time: 0h 6m 8.8s
#
# Epoch 14: val_mse improved from 0.00036 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3645e-04 - mse: 3.4629e-04 - NMSE: 0.0031 - real_MSE: 3.4629e-04 - params_MSE: nan - ls_jacobian_norm: 0.2243 - val_loss: 4.4450e-04 - val_mse: 3.5430e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5430e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 15/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.3541e-04 - mse: 3.4514e-04 - NMSE: 0.0031 - real_MSE: 3.4514e-04 - params_MSE: nan - ls_jacobian_norm: 0.2223 - tot_time: 0h 6m 19.6s
#
# Epoch 15: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3568e-04 - mse: 3.4541e-04 - NMSE: 0.0031 - real_MSE: 3.4541e-04 - params_MSE: nan - ls_jacobian_norm: 0.2223 - val_loss: 4.9256e-04 - val_mse: 4.0223e-04 - val_NMSE: 0.0036 - val_real_MSE: 4.0223e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 16/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.3468e-04 - mse: 3.4429e-04 - NMSE: 0.0031 - real_MSE: 3.4429e-04 - params_MSE: nan - ls_jacobian_norm: 0.2203 - tot_time: 0h 6m 29.6s
#
# Epoch 16: val_mse improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3468e-04 - mse: 3.4429e-04 - NMSE: 0.0031 - real_MSE: 3.4429e-04 - params_MSE: nan - ls_jacobian_norm: 0.2203 - val_loss: 4.4418e-04 - val_mse: 3.5373e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5373e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 17/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.3453e-04 - mse: 3.4403e-04 - NMSE: 0.0031 - real_MSE: 3.4403e-04 - params_MSE: nan - ls_jacobian_norm: 0.2186 - tot_time: 0h 6m 40.3s
#
# Epoch 17: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3459e-04 - mse: 3.4409e-04 - NMSE: 0.0031 - real_MSE: 3.4409e-04 - params_MSE: nan - ls_jacobian_norm: 0.2185 - val_loss: 4.5166e-04 - val_mse: 3.6111e-04 - val_NMSE: 0.0033 - val_real_MSE: 3.6111e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 18/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.3512e-04 - mse: 3.4451e-04 - NMSE: 0.0031 - real_MSE: 3.4451e-04 - params_MSE: nan - ls_jacobian_norm: 0.2169 - tot_time: 0h 6m 50.8s
#
# Epoch 18: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3470e-04 - mse: 3.4409e-04 - NMSE: 0.0031 - real_MSE: 3.4409e-04 - params_MSE: nan - ls_jacobian_norm: 0.2169 - val_loss: 6.2812e-04 - val_mse: 5.3747e-04 - val_NMSE: 0.0048 - val_real_MSE: 5.3747e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 19/200
# 1244/1251 [============================>.] - ETA: 0s - loss: 4.3531e-04 - mse: 3.4461e-04 - NMSE: 0.0031 - real_MSE: 3.4461e-04 - params_MSE: nan - ls_jacobian_norm: 0.2148 - tot_time: 0h 7m 1.1s
#
# Epoch 19: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3516e-04 - mse: 3.4446e-04 - NMSE: 0.0031 - real_MSE: 3.4446e-04 - params_MSE: nan - ls_jacobian_norm: 0.2148 - val_loss: 4.4891e-04 - val_mse: 3.5817e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5817e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 20/200
# 1249/1251 [============================>.] - ETA: 0s - loss: 4.3333e-04 - mse: 3.4253e-04 - NMSE: 0.0031 - real_MSE: 3.4253e-04 - params_MSE: nan - ls_jacobian_norm: 0.2132 - tot_time: 0h 7m 11.4s
#
# Epoch 20: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3361e-04 - mse: 3.4281e-04 - NMSE: 0.0031 - real_MSE: 3.4281e-04 - params_MSE: nan - ls_jacobian_norm: 0.2131 - val_loss: 5.6461e-04 - val_mse: 4.7374e-04 - val_NMSE: 0.0043 - val_real_MSE: 4.7374e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 21/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.3278e-04 - mse: 3.4188e-04 - NMSE: 0.0031 - real_MSE: 3.4188e-04 - params_MSE: nan - ls_jacobian_norm: 0.2117 - tot_time: 0h 7m 21.7s
#
# Epoch 21: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3291e-04 - mse: 3.4201e-04 - NMSE: 0.0031 - real_MSE: 3.4201e-04 - params_MSE: nan - ls_jacobian_norm: 0.2117 - val_loss: 4.4915e-04 - val_mse: 3.5819e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5819e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 22/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.3303e-04 - mse: 3.4203e-04 - NMSE: 0.0031 - real_MSE: 3.4203e-04 - params_MSE: nan - ls_jacobian_norm: 0.2098 - tot_time: 0h 7m 31.3s
#
# Epoch 22: val_mse improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3303e-04 - mse: 3.4203e-04 - NMSE: 0.0031 - real_MSE: 3.4203e-04 - params_MSE: nan - ls_jacobian_norm: 0.2098 - val_loss: 4.4361e-04 - val_mse: 3.5256e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5256e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 23/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.3244e-04 - mse: 3.4133e-04 - NMSE: 0.0031 - real_MSE: 3.4133e-04 - params_MSE: nan - ls_jacobian_norm: 0.2082 - tot_time: 0h 7m 42.0s
#
# Epoch 23: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.3264e-04 - mse: 3.4154e-04 - NMSE: 0.0031 - real_MSE: 3.4154e-04 - params_MSE: nan - ls_jacobian_norm: 0.2082 - val_loss: 4.5320e-04 - val_mse: 3.6205e-04 - val_NMSE: 0.0033 - val_real_MSE: 3.6205e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 24/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.3234e-04 - mse: 3.4114e-04 - NMSE: 0.0031 - real_MSE: 3.4114e-04 - params_MSE: nan - ls_jacobian_norm: 0.2068 - tot_time: 0h 7m 52.0s
#
# Epoch 24: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3241e-04 - mse: 3.4122e-04 - NMSE: 0.0031 - real_MSE: 3.4122e-04 - params_MSE: nan - ls_jacobian_norm: 0.2067 - val_loss: 4.4957e-04 - val_mse: 3.5833e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5833e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 25/200
# 1249/1251 [============================>.] - ETA: 0s - loss: 4.3241e-04 - mse: 3.4112e-04 - NMSE: 0.0031 - real_MSE: 3.4112e-04 - params_MSE: nan - ls_jacobian_norm: 0.2051 - tot_time: 0h 8m 2.3s
#
# Epoch 25: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3234e-04 - mse: 3.4105e-04 - NMSE: 0.0031 - real_MSE: 3.4105e-04 - params_MSE: nan - ls_jacobian_norm: 0.2052 - val_loss: 4.5945e-04 - val_mse: 3.6812e-04 - val_NMSE: 0.0033 - val_real_MSE: 3.6812e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 26/200
# 1245/1251 [============================>.] - ETA: 0s - loss: 4.3110e-04 - mse: 3.3972e-04 - NMSE: 0.0031 - real_MSE: 3.3972e-04 - params_MSE: nan - ls_jacobian_norm: 0.2036 - tot_time: 0h 8m 12.8s
#
# Epoch 26: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.3138e-04 - mse: 3.4000e-04 - NMSE: 0.0031 - real_MSE: 3.4000e-04 - params_MSE: nan - ls_jacobian_norm: 0.2036 - val_loss: 8.3072e-04 - val_mse: 7.3931e-04 - val_NMSE: 0.0067 - val_real_MSE: 7.3931e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 27/200
# 1249/1251 [============================>.] - ETA: 0s - loss: 4.3748e-04 - mse: 3.4604e-04 - NMSE: 0.0031 - real_MSE: 3.4604e-04 - params_MSE: nan - ls_jacobian_norm: 0.2019 - tot_time: 0h 8m 23.1s
#
# Epoch 27: val_mse improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3733e-04 - mse: 3.4589e-04 - NMSE: 0.0031 - real_MSE: 3.4589e-04 - params_MSE: nan - ls_jacobian_norm: 0.2019 - val_loss: 4.4351e-04 - val_mse: 3.5202e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5202e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 28/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.3041e-04 - mse: 3.3888e-04 - NMSE: 0.0030 - real_MSE: 3.3888e-04 - params_MSE: nan - ls_jacobian_norm: 0.2012 - tot_time: 0h 8m 33.6s
#
# Epoch 28: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3041e-04 - mse: 3.3888e-04 - NMSE: 0.0030 - real_MSE: 3.3888e-04 - params_MSE: nan - ls_jacobian_norm: 0.2012 - val_loss: 4.4429e-04 - val_mse: 3.5273e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5273e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 29/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.3043e-04 - mse: 3.3882e-04 - NMSE: 0.0030 - real_MSE: 3.3882e-04 - params_MSE: nan - ls_jacobian_norm: 0.1996 - tot_time: 0h 8m 44.0s
#
# Epoch 29: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3043e-04 - mse: 3.3881e-04 - NMSE: 0.0030 - real_MSE: 3.3881e-04 - params_MSE: nan - ls_jacobian_norm: 0.1996 - val_loss: 4.4973e-04 - val_mse: 3.5809e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5809e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 30/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.3008e-04 - mse: 3.3839e-04 - NMSE: 0.0030 - real_MSE: 3.3839e-04 - params_MSE: nan - ls_jacobian_norm: 0.1981 - tot_time: 0h 8m 54.4s
#
# Epoch 30: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3008e-04 - mse: 3.3839e-04 - NMSE: 0.0030 - real_MSE: 3.3839e-04 - params_MSE: nan - ls_jacobian_norm: 0.1981 - val_loss: 4.6715e-04 - val_mse: 3.7542e-04 - val_NMSE: 0.0034 - val_real_MSE: 3.7542e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 31/200
# 1245/1251 [============================>.] - ETA: 0s - loss: 4.2927e-04 - mse: 3.3749e-04 - NMSE: 0.0030 - real_MSE: 3.3749e-04 - params_MSE: nan - ls_jacobian_norm: 0.1965 - tot_time: 0h 9m 4.4s
#
# Epoch 31: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3009e-04 - mse: 3.3831e-04 - NMSE: 0.0030 - real_MSE: 3.3831e-04 - params_MSE: nan - ls_jacobian_norm: 0.1965 - val_loss: 5.1142e-04 - val_mse: 4.1958e-04 - val_NMSE: 0.0038 - val_real_MSE: 4.1958e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 32/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.3043e-04 - mse: 3.3857e-04 - NMSE: 0.0030 - real_MSE: 3.3857e-04 - params_MSE: nan - ls_jacobian_norm: 0.1954Restoring model weights from the end of the best epoch: 22.
#  - tot_time: 0h 9m 14.8s
#
# Epoch 32: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.3029e-04 - mse: 3.3843e-04 - NMSE: 0.0030 - real_MSE: 3.3843e-04 - params_MSE: nan - ls_jacobian_norm: 0.1955 - val_loss: 4.4479e-04 - val_mse: 3.5288e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5288e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 32: early stopping
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 1e-05 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 1249/1251 [============================>.] - ETA: 0s - loss: 4.2626e-04 - mse: 3.3521e-04 - NMSE: 0.0030 - real_MSE: 3.3521e-04 - params_MSE: nan - ls_jacobian_norm: 0.2090 - tot_time: 0h 9m 25.3s
#
# Epoch 1: val_mse improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.2643e-04 - mse: 3.3537e-04 - NMSE: 0.0030 - real_MSE: 3.3537e-04 - params_MSE: nan - ls_jacobian_norm: 0.2091 - val_loss: 4.3832e-04 - val_mse: 3.4725e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4725e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 2/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.2659e-04 - mse: 3.3552e-04 - NMSE: 0.0030 - real_MSE: 3.3552e-04 - params_MSE: nan - ls_jacobian_norm: 0.2088 - tot_time: 0h 9m 36.8s
#
# Epoch 2: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2637e-04 - mse: 3.3530e-04 - NMSE: 0.0030 - real_MSE: 3.3530e-04 - params_MSE: nan - ls_jacobian_norm: 0.2087 - val_loss: 4.4071e-04 - val_mse: 3.4963e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4963e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 3/200
# 1243/1251 [============================>.] - ETA: 0s - loss: 4.2666e-04 - mse: 3.3557e-04 - NMSE: 0.0030 - real_MSE: 3.3557e-04 - params_MSE: nan - ls_jacobian_norm: 0.2083 - tot_time: 0h 9m 47.7s
#
# Epoch 3: val_mse improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2655e-04 - mse: 3.3546e-04 - NMSE: 0.0030 - real_MSE: 3.3546e-04 - params_MSE: nan - ls_jacobian_norm: 0.2083 - val_loss: 4.3770e-04 - val_mse: 3.4660e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4660e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 4/200
# 1250/1251 [============================>.] - ETA: 0s - loss: 4.2629e-04 - mse: 3.3518e-04 - NMSE: 0.0030 - real_MSE: 3.3518e-04 - params_MSE: nan - ls_jacobian_norm: 0.2081 - tot_time: 0h 9m 58.2s
#
# Epoch 4: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.2629e-04 - mse: 3.3518e-04 - NMSE: 0.0030 - real_MSE: 3.3518e-04 - params_MSE: nan - ls_jacobian_norm: 0.2081 - val_loss: 4.3846e-04 - val_mse: 3.4735e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4735e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 5/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.2602e-04 - mse: 3.3490e-04 - NMSE: 0.0030 - real_MSE: 3.3490e-04 - params_MSE: nan - ls_jacobian_norm: 0.2076 - tot_time: 0h 10m 8.8s
#
# Epoch 5: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2643e-04 - mse: 3.3531e-04 - NMSE: 0.0030 - real_MSE: 3.3531e-04 - params_MSE: nan - ls_jacobian_norm: 0.2077 - val_loss: 4.3977e-04 - val_mse: 3.4864e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4864e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 6/200
# 1246/1251 [============================>.] - ETA: 0s - loss: 4.2625e-04 - mse: 3.3511e-04 - NMSE: 0.0030 - real_MSE: 3.3511e-04 - params_MSE: nan - ls_jacobian_norm: 0.2074 - tot_time: 0h 10m 20.3s
#
# Epoch 6: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2635e-04 - mse: 3.3521e-04 - NMSE: 0.0030 - real_MSE: 3.3521e-04 - params_MSE: nan - ls_jacobian_norm: 0.2073 - val_loss: 4.3800e-04 - val_mse: 3.4685e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4685e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 7/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.2631e-04 - mse: 3.3516e-04 - NMSE: 0.0030 - real_MSE: 3.3516e-04 - params_MSE: nan - ls_jacobian_norm: 0.2070 - tot_time: 0h 10m 31.1s
#
# Epoch 7: val_mse improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2631e-04 - mse: 3.3516e-04 - NMSE: 0.0030 - real_MSE: 3.3516e-04 - params_MSE: nan - ls_jacobian_norm: 0.2070 - val_loss: 4.3703e-04 - val_mse: 3.4586e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4586e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 8/200
# 1247/1251 [============================>.] - ETA: 0s - loss: 4.2614e-04 - mse: 3.3496e-04 - NMSE: 0.0030 - real_MSE: 3.3496e-04 - params_MSE: nan - ls_jacobian_norm: 0.2068 - tot_time: 0h 10m 41.7s
#
# Epoch 8: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.2613e-04 - mse: 3.3496e-04 - NMSE: 0.0030 - real_MSE: 3.3496e-04 - params_MSE: nan - ls_jacobian_norm: 0.2068 - val_loss: 4.4144e-04 - val_mse: 3.5026e-04 - val_NMSE: 0.0032 - val_real_MSE: 3.5026e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 9/200
# 1248/1251 [============================>.] - ETA: 0s - loss: 4.2641e-04 - mse: 3.3521e-04 - NMSE: 0.0030 - real_MSE: 3.3521e-04 - params_MSE: nan - ls_jacobian_norm: 0.2064 - tot_time: 0h 10m 52.2s
#
# Epoch 9: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.2638e-04 - mse: 3.3519e-04 - NMSE: 0.0030 - real_MSE: 3.3519e-04 - params_MSE: nan - ls_jacobian_norm: 0.2064 - val_loss: 4.3800e-04 - val_mse: 3.4680e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4680e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 10/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.2622e-04 - mse: 3.3501e-04 - NMSE: 0.0030 - real_MSE: 3.3501e-04 - params_MSE: nan - ls_jacobian_norm: 0.2062 - tot_time: 0h 11m 2.8s
#
# Epoch 10: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.2622e-04 - mse: 3.3501e-04 - NMSE: 0.0030 - real_MSE: 3.3501e-04 - params_MSE: nan - ls_jacobian_norm: 0.2062 - val_loss: 4.3951e-04 - val_mse: 3.4829e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4829e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 11/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.2631e-04 - mse: 3.3508e-04 - NMSE: 0.0030 - real_MSE: 3.3508e-04 - params_MSE: nan - ls_jacobian_norm: 0.2058 - tot_time: 0h 11m 13.7s
#
# Epoch 11: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2631e-04 - mse: 3.3508e-04 - NMSE: 0.0030 - real_MSE: 3.3508e-04 - params_MSE: nan - ls_jacobian_norm: 0.2058 - val_loss: 4.3917e-04 - val_mse: 3.4794e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4794e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 12/200
# 1249/1251 [============================>.] - ETA: 0s - loss: 4.2610e-04 - mse: 3.3486e-04 - NMSE: 0.0030 - real_MSE: 3.3486e-04 - params_MSE: nan - ls_jacobian_norm: 0.2055 - tot_time: 0h 11m 24.2s
#
# Epoch 12: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.2614e-04 - mse: 3.3490e-04 - NMSE: 0.0030 - real_MSE: 3.3490e-04 - params_MSE: nan - ls_jacobian_norm: 0.2055 - val_loss: 4.3874e-04 - val_mse: 3.4748e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4748e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 13/200
# 1245/1251 [============================>.] - ETA: 0s - loss: 4.2640e-04 - mse: 3.3514e-04 - NMSE: 0.0030 - real_MSE: 3.3514e-04 - params_MSE: nan - ls_jacobian_norm: 0.2053 - tot_time: 0h 11m 34.8s
#
# Epoch 13: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.2604e-04 - mse: 3.3478e-04 - NMSE: 0.0030 - real_MSE: 3.3478e-04 - params_MSE: nan - ls_jacobian_norm: 0.2054 - val_loss: 4.3722e-04 - val_mse: 3.4595e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4595e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 14/200
# 1251/1251 [==============================] - ETA: 0s - loss: 4.2599e-04 - mse: 3.3471e-04 - NMSE: 0.0030 - real_MSE: 3.3471e-04 - params_MSE: nan - ls_jacobian_norm: 0.2050 - tot_time: 0h 11m 45.9s
#
# Epoch 14: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 9ms/step - loss: 4.2599e-04 - mse: 3.3471e-04 - NMSE: 0.0030 - real_MSE: 3.3471e-04 - params_MSE: nan - ls_jacobian_norm: 0.2050 - val_loss: 4.3817e-04 - val_mse: 3.4688e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4688e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 15/200
# 1243/1251 [============================>.] - ETA: 0s - loss: 4.2575e-04 - mse: 3.3446e-04 - NMSE: 0.0030 - real_MSE: 3.3446e-04 - params_MSE: nan - ls_jacobian_norm: 0.2047 - tot_time: 0h 11m 56.3s
#
# Epoch 15: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.2600e-04 - mse: 3.3470e-04 - NMSE: 0.0030 - real_MSE: 3.3470e-04 - params_MSE: nan - ls_jacobian_norm: 0.2046 - val_loss: 4.3799e-04 - val_mse: 3.4669e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4669e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 16/200
# 1245/1251 [============================>.] - ETA: 0s - loss: 4.2630e-04 - mse: 3.3499e-04 - NMSE: 0.0030 - real_MSE: 3.3499e-04 - params_MSE: nan - ls_jacobian_norm: 0.2044 - tot_time: 0h 12m 6.5s
#
# Epoch 16: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 10s 8ms/step - loss: 4.2602e-04 - mse: 3.3471e-04 - NMSE: 0.0030 - real_MSE: 3.3471e-04 - params_MSE: nan - ls_jacobian_norm: 0.2044 - val_loss: 4.3794e-04 - val_mse: 3.4661e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4661e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 17/200
# 1249/1251 [============================>.] - ETA: 0s - loss: 4.2600e-04 - mse: 3.3467e-04 - NMSE: 0.0030 - real_MSE: 3.3467e-04 - params_MSE: nan - ls_jacobian_norm: 0.2041Restoring model weights from the end of the best epoch: 7.
#  - tot_time: 0h 12m 17.1s
#
# Epoch 17: val_mse did not improve from 0.00035
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/new_lorenz/saved_ae/ae_025/checkpoints/LossHistoriesCheckpoint
# 1251/1251 [==============================] - 11s 8ms/step - loss: 4.2587e-04 - mse: 3.3454e-04 - NMSE: 0.0030 - real_MSE: 3.3454e-04 - params_MSE: nan - ls_jacobian_norm: 0.2041 - val_loss: 4.3810e-04 - val_mse: 3.4676e-04 - val_NMSE: 0.0031 - val_real_MSE: 3.4676e-04 - val_params_MSE: nan - val_ls_jacobian_norm: -1.0000
# Epoch 17: early stopping

# %%
temp = []
for lst in train_ls_jacobian_norm_hist:
    temp.extend(lst)
train_ls_jacobian_norm_hist_og = train_ls_jacobian_norm_hist
train_ls_jacobian_norm_hist = np.array(temp)

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    test_metrics = ae_net.evaluate(
        testing_data, testing_data,
    )
    train_metrics = ae_net.evaluate(training_data, training_data)
    val_metrics = ae_net.evaluate(val_data, val_data)

    save_path = dir_name_ae+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'val_MSE_hist':val_MSE_hist,
            'train_MSE_hist':train_MSE_hist,
            'val_NMSE_hist':val_NMSE_hist,
            'train_NMSE_hist':train_NMSE_hist,
            'val_real_MSE_hist':val_real_MSE_hist,
            'train_real_MSE_hist':train_real_MSE_hist,
            'val_params_MSE_hist':val_params_MSE_hist,
            'train_params_MSE_hist':train_params_MSE_hist,
            'train_ls_jacobian_norm_hist':train_ls_jacobian_norm_hist,
            'lr_change':lr_change,
            'test_loss':test_metrics[0],
            'test_mse':test_metrics[1],
            'train_loss':train_metrics[0],
            'train_mse':train_metrics[1],
            'val_loss':val_metrics[0],
            'val_mse':val_metrics[1],
        }))

    ae_net.save_everything(
        file_name=save_path+dir_sep+'final_net')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 4.3565e-04 - mse: 3.4448e-04 - NMSE: 0.0031 - real_MSE: 3.4448e-04 - params_MSE: nan - ls_jacobian_norm: -1.0000
# 2501/2501 [==============================] - 9s 3ms/step - loss: 4.2638e-04 - mse: 3.3521e-04 - NMSE: 0.0030 - real_MSE: 3.3521e-04 - params_MSE: nan - ls_jacobian_norm: -1.0000
# 313/313 [==============================] - 1s 4ms/step - loss: 4.3703e-04 - mse: 3.4586e-04 - NMSE: 0.0031 - real_MSE: 3.4586e-04 - params_MSE: nan - ls_jacobian_norm: -1.0000

# %%
print('lr_change : ', lr_change)
# Out:
# lr_change :  [0, 22, 54, 71]

# %%
# plotting losses
dir_name_plot = dir_name_ae + '/plots'
if not os.path.isdir(dir_name_plot):
    os.makedirs(dir_name_plot)

xlabel_kwargs = {"fontsize":15}
ylabel_kwargs = {"fontsize":15}
legend_kwargs = {"fontsize":12}
    
# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
)

plt.savefig(dir_name_plot + '{ds}loss_history.pdf'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()


fig, ax = plot_losses(
    training_loss=train_MSE_hist,
    val_loss=val_MSE_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=['Training MSE', 'Validation MSE'],
    xlabel='Epoch',
    ylabel='MSE',
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
    
)
plt.savefig(dir_name_plot+'/MSE_history.pdf', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_NMSE_hist,
    val_loss=val_NMSE_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=['Training NMSE', 'Validation NMSE'],
    xlabel='Epoch',
    ylabel='NMSE',
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
)
plt.savefig(dir_name_plot+'/NMSE_history.pdf', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_ls_jacobian_norm_hist,
    val_loss=None,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=[r"$\| \nabla_{x} z^{encoded} \|$"],
    xlabel='Epoch',
    ylabel=r"$\| \nabla_{x} v^{encoded} \|$",
    plot_type='plot',
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
)
plt.savefig(dir_name_plot+'/train_ls_jacobian_norm_hist.pdf', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()

# %%
reconstructed_data = ae_net.predict(all_data)

# %%
plot_reconstructed_data(
    boundary_idx_arr,
    dir_name_ae,
    all_data,
    reconstructed_data,
    params_mat,
    save_figs=True,
    xlabel_kwargs={'fontsize':15},
    ylabel_kwargs={'fontsize':15},
    zlabel_kwargs={'fontsize':15},
    title_kwargs={'fontsize':18},
)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data)

# %%
plot_latent_states(
    boundary_idx_arr,
    latent_states_all,
    params_mat,
    xlim=(-1, 1),
    ylim=(-1, 1),
    save_figs=True,
    dir_name_ae=dir_name_ae,
    cmap_name='jet',
    xlabel_kwargs={'fontsize':15},
    ylabel_kwargs={'fontsize':15},
    legend_kwargs={'fontsize':12},
)

# %%
# fig.savefig(dir_name_plot+'/latent_states.png', dpi=300, bbox_inches='tight')

# %%
# ae_net.summary()

# %% [markdown]
# # KE and Dissipation

# %%
if ae_net.use_weights_post_dense == True:
    print(ae_net.decoder_layers_list[-1].individual_weights)
# Out:
# <tf.Variable 'single_weights/individual_weights:0' shape=(3,) dtype=float32, numpy=array([1.4848926, 2.30634  , 2.0378313], dtype=float32)>
