# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

tf.keras.backend.set_floatx('float32')
plt.rcParams.update({
    "text.usetex":True,
    "font.family":"serif",
}) # enable tex rendering in matplotlib

# %%
colab_flag = False

FTYPE = np.float32
ITYPE = np.int32

strategy = None
# strategy = tf.distribute.MirroredStrategy()

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
if colab_flag == True:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Github/MLROM/KS/')

# %%
print(os.getcwd())
# Out:
# /home/rkaushik/Documents/Thesis/MLROM/new_cdv

# %%
from tools.misc_tools import mytimecallback, SaveLosses, plot_losses, readAndReturnLossHistories, plot_reconstructed_data_cdv, plot_latent_states_cdv
from tools.ae_v2 import Autoencoder

# %%
behaviour = 'initialiseAndTrainFromScratch'
# behaviour = 'loadCheckpointAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
# setting seed for PRNGs
if behaviour == 'initialiseAndTrainFromScratch':
    prng_seed = 42
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if colab_flag == False:
    if strategy is None:
        if gpus:
            gpu_to_use = 0
            tf.config.set_visible_devices(gpus[gpu_to_use], 'GPU')
    logical_devices = tf.config.list_logical_devices('GPU')
    print(logical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2023-07-28 15:22:26.143349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.182099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.182340: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.183545: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-28 15:22:26.184143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.184328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.184494: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.594228: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.594414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.594567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-28 15:22:26.594685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 23657 MB memory:  -> device: 0, name: Tesla P40, pci bus id: 0000:03:00.0, compute capability: 6.1

# %%
# print(tf.test.gpu_device_name())
print(tf.config.list_physical_devices())
print(tf.config.list_logical_devices())
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2.8.1

# %% [markdown]
# # KS System

# %%
# setting up params (and saving, if applicable)
from numpy import *

if behaviour == 'initialiseAndTrainFromScratch':
    # loading data directory
    data_dir_idx = '005'

    # making ae save directory
    dir_name_ae = os.getcwd() + dir_sep + 'saved_ae'
    if not os.path.isdir(dir_name_ae):
        os.makedirs(dir_name_ae)

    counter = 0
    while True:
        dir_check = 'ae_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_ae + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_ae = dir_name_ae + dir_sep + dir_check
    os.makedirs(dir_name_ae)
    os.makedirs(dir_name_ae+dir_sep+'plots')
else:
    # some paramaters
    dir_name_ae = os.getcwd()+'{ds}saved_ae{ds}ae_015'.format(ds=dir_sep)

    with open(dir_name_ae + dir_sep + 'ae_data.txt') as f:
        lines = f.readlines()

    params_dict = eval(''.join(lines))
    data_dir_idx = params_dict['data_dir_idx']
    normalizeforae_flag = params_dict['normalizeforae_flag']
    normalization_constant_arr_aedata = params_dict['normalization_constant_arr_aedata']
    if os.path.exists(dir_name_ae+dir_sep+'normalization_data.npz'):
        with np.load(dir_name_ae+dir_sep+'normalization_data.npz', allow_pickle=True) as fl:
            normalization_constant_arr_aedata = fl['normalization_constant_arr_aedata'][0]

print('dir_name_ae:', dir_name_ae)
# loading data
dir_name_data = os.getcwd() + dir_sep + 'saved_data' + dir_sep + 'data_' + data_dir_idx
    
with open(dir_name_data + dir_sep + 'sim_data_params.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
params_mat = params_dict['params_mat']
# init_state = params_dict['init_state']
t0 = params_dict['t0']
T = params_dict['T']
delta_t = params_dict['delta_t']
return_params_arr = params_dict['return_params_arr']
normalize_flag_ogdata = params_dict['normalize_flag']
print('normalize_flag_ogdata:', normalize_flag_ogdata)
alldata_withparams_flag = params_dict['alldata_withparams_flag']

with np.load(dir_name_data+dir_sep+'data.npz', allow_pickle=True) as fl:
    all_data = fl['all_data'].astype(FTYPE)
    boundary_idx_arr = fl['boundary_idx_arr']
    normalization_constant_arr_ogdata = fl['normalization_constant_arr'][0]
    initial_t0 = fl['initial_t0']
    init_state_mat = fl['init_state_mat']

    lyapunov_spectrum_mat = fl['lyapunov_spectrum_mat']
# Out:
# dir_name_ae: /home/rkaushik/Documents/Thesis/MLROM/new_cdv/saved_ae/ae_010
# normalize_flag_ogdata: False

# %%
lyapunov_time_arr = np.empty(shape=lyapunov_spectrum_mat.shape[0], dtype=FTYPE)
for i in range(lyapunov_spectrum_mat.shape[0]):
    lyapunov_time_arr[i] = 1/lyapunov_spectrum_mat[i, 0]
    print('Case : {}, lyapunov exponent : {}, lyapunov time : {}s'.format(i+1, lyapunov_spectrum_mat[i, 0], lyapunov_time_arr[i]))
# Out:
# Case : 1, lyapunov exponent : 0.03617107029869905, lyapunov time : 27.646404266357422s
# Case : 2, lyapunov exponent : 0.0003053088584026513, lyapunov time : 3275.371826171875s

# %%
positve_lp_idx = np.where(lyapunov_time_arr > 0)[0]
print(positve_lp_idx)
# Out:
# [0 1]

# %%
last_idx = all_data.shape[0]
temp_bia = np.zeros(shape=1+boundary_idx_arr.shape[0], dtype=np.int32)
temp_bia[1:] = boundary_idx_arr
print(temp_bia)
for i in range(boundary_idx_arr.shape[0]-1, -1, -1):
    if not (i in positve_lp_idx):
        print(i)
        num_idxs = last_idx - temp_bia[i+1]
        all_data[temp_bia[i]:temp_bia[i]+num_idxs] = all_data[temp_bia[i+1]:last_idx]
        last_idx = last_idx - (temp_bia[i+1]-temp_bia[i])
# Out:
# [     0 200001 400002]

# %%
new_bia = np.empty_like(boundary_idx_arr)
new_bia[:] = boundary_idx_arr
new_pmat = np.empty_like(params_mat)
new_pmat[:, :] = params_mat
counter = 0
bia_counter = boundary_idx_arr.shape[0]
for i in range(boundary_idx_arr.shape[0]):
    if not (i in positve_lp_idx):
        new_bia[i:] -= temp_bia[i+1] - temp_bia[i]
        new_bia[i:bia_counter-1] = new_bia[i+1:bia_counter]
        new_pmat[i:bia_counter-1] = new_pmat[i+1:bia_counter]
        bia_counter -= 1

# %%
new_bia = new_bia[0:bia_counter]
new_pmat = new_pmat[0:bia_counter]

# %%
all_data = all_data[0:new_bia[-1]]

# %%
new_bia, boundary_idx_arr = boundary_idx_arr, new_bia
new_pmat, params_mat = params_mat, new_pmat

# %%
# dealing with normalizing the data before feeding into autoencoder
if behaviour == 'initialiseAndTrainFromScratch':
    # normalize data before feeding into autoencoder?
    normalizeforae_flag = True
    normalization_type = 'stddev' # could be 'stddev' or 'minmax'
    stddev_multiplier = 3
    stddev_multiplier_pm = 1
    num_params = params_mat.shape[1]

    ae_data_with_params = True # whether to feed in the parameters to the AE along with the data?

    og_vars = all_data.shape[1]
    if alldata_withparams_flag == True:
        og_vars -= num_params

    if ae_data_with_params == False:
        stddev_multiplier_pm = None
    if normalizeforae_flag == False:
        stddev_multiplier = None

    if ae_data_with_params == True and alldata_withparams_flag == False:
        new_all_data = np.empty(shape=(all_data.shape[0], og_vars+num_params), dtype=FTYPE)
        new_all_data[:, 0:og_vars] = all_data[:, 0:og_vars]
        del(all_data)
        all_data = new_all_data
        prev_idx = 0
        for i in range(boundary_idx_arr.shape[0]):
            all_data[prev_idx:boundary_idx_arr[i], num_params:] = params_mat[i]
            prev_idx = boundary_idx_arr[i]

    normalization_constant_arr_aedata = None
    if normalizeforae_flag == True:
        normalization_constant_arr_aedata = np.empty(shape=(2, all_data.shape[1]), dtype=FTYPE)
        if normalization_type == 'stddev':
            sample_mean = np.mean(all_data, axis=0)
            sample_std = np.std(all_data, axis=0)
            normalization_constant_arr_aedata[0, :] = sample_mean
            normalization_constant_arr_aedata[1, 0:og_vars] = stddev_multiplier*sample_std[0:og_vars]
            if ae_data_with_params == True:
                normalization_constant_arr_aedata[1, og_vars:] = stddev_multiplier_pm*sample_std[og_vars:]
            zero_idx = np.where(normalization_constant_arr_aedata[1] == 0.0)[0]
            if len(zero_idx) > 0:
                normalization_constant_arr_aedata[1, zero_idx] = 1.0
        elif normalization_type == 'minmax':
            for i in range(all_data.shape[1]):
                sample_min = np.min(all_data[:, i])
                sample_max = np.max(all_data[:, i])
                if sample_max - sample_min == 0:
                    sample_min = sample_min - 0.5
                    sample_max = sample_min + 1
                normalization_constant_arr_aedata[0, i] = sample_min
                normalization_constant_arr_aedata[1, i] = sample_max - sample_min
        # if ae_data_with_params == True:
        #     normalization_constant_arr_aedata[0, og_vars:] = 0.0
        #     normalization_constant_arr_aedata[1, og_vars:] = 1.0
        for i in range(all_data.shape[1]):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]

    # saving sim data
    ae_data = {
        'data_dir_idx':data_dir_idx,
        'normalizeforae_flag':normalizeforae_flag,
        'normalization_constant_arr_aedata':normalization_constant_arr_aedata,
        'normalization_type':normalization_type,
        'stddev_multiplier':stddev_multiplier,
        'stddev_multiplier_pm':stddev_multiplier_pm,
        'ae_data_with_params':ae_data_with_params,
        'module':Autoencoder.__module__,
    }
    with open(dir_name_ae+dir_sep+'ae_data.txt', 'w') as f:
        f.write(str(ae_data))
    np.savez(
        dir_name_ae+dir_sep+'normalization_data',
        normalization_constant_arr_aedata=[normalization_constant_arr_aedata],
    )
else:
    if normalizeforae_flag == True:
        for i in range(all_data.shape[1]):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]
            
time_stddev = np.std(all_data, axis=0)
if ae_data_with_params == False:
    all_data = all_data[:, 0:og_vars]
    time_stddev = time_stddev[0:og_vars]
else:
    time_stddev[og_vars:] = 1.0

# %%
normalization_constant_arr_aedata
# Out:
# array([[ 8.78527462e-01,  2.08814368e-01, -1.52773619e-01,
#         -4.88473952e-01, -1.98383078e-01,  1.79238826e-01,
#          9.73079979e-01, -7.76253045e-01,  1.00052126e-01,
#          1.25000000e+00,  2.00104252e-01,  5.00000000e-01],
#        [ 1.84339583e-01,  2.56379038e-01,  3.87972355e-01,
#          3.46734434e-01,  3.89936328e-01,  4.55800384e-01,
#          2.02917401e-02,  1.60472151e-02,  5.21465772e-05,
#          1.00000000e+00,  1.04293154e-04,  1.00000000e+00]], dtype=float32)

# %% [markdown]
# # Autoencoder

# %%
# setting up training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_list = [1e-3, 1e-4, 1e-5]
    epochs = 200
    patience = 10  # parameter for early stopping
    min_delta = 1e-6  # parameter for early stopping
    lambda_reg = 1.99491662e-06 # weight for regularizer
    train_split = 0.8
    val_split = 0.1
    test_split = 1 - train_split - val_split
    batch_size = 2**6
    fRMS = 7.79229715e-03
    timeMeanofSpaceRMS = np.mean(np.mean(all_data[:, 0:og_vars]**2, axis=1)**0.5)
    
    dt_ae = 0.1
    
    # stddev = fRMS*timeMeanofSpaceRMS
    stddev = fRMS * np.mean(time_stddev[0:og_vars])
    contractive_lmda = 0.0#1.68130427e-06
    use_weights_post_dense = True
    dropout_rate = 0.0
    
    print('stddev : ', stddev)

    # saving training params
    training_specific_params = {
        'learning_rate_list':learning_rate_list,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size,
        'fRMS':fRMS,
        'timeMeanofSpaceRMS':timeMeanofSpaceRMS,
        'stddev':stddev,
        'contractive_lmda':contractive_lmda,
        'dropout_rate':dropout_rate,
        'dt_ae':dt_ae,
    }

    with open(dir_name_ae+dir_sep+'training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))
else:
    with open(dir_name_ae + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()

    tparams_dict = eval(''.join(lines))

    learning_rate_list = tparams_dict['learning_rate_list']
    epochs = tparams_dict['epochs']
    patience = tparams_dict['patience']
    min_delta = tparams_dict['min_delta']
    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']
    try:
        stddev = tparams_dict['stddev']
    except:
        print("'stddev' not in tparams_dict, set to 0")
        stddev = 0.0
    try:
        contractive_lmda = tparams_dict['contractive_lmda']
    except:
        print("'contractive_lmda' not in tparams_dict, set to 0")
        contractive_lmda = 0.0
    try:
        dropout_rate = tparams_dict['dropout_rate']
    except:
        print("'dropout_rate' not in tparams_dict, set to 0")
        dropout_rate = 0.0

    test_split = 1 - train_split - val_split

    # setting seed for PRNGs
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)
# Out:
# stddev :  0.0025974450010846483

# %%
# all_data = all_data[0:370001]
# boundary_idx_arr[0] = 370001

# %%
skip_factor = int(dt_ae/delta_t)

if dt_ae != delta_t:
    for i in range(len(boundary_idx_arr)-1, -1, -1):
        end_idx = boundary_idx_arr[i]
        if i == 0:
            begin_idx = 0
        else:
            begin_idx = boundary_idx_arr[i-1]

        num_elems_pre_indexing = end_idx - begin_idx
        num_elems_post_indexing = (num_elems_pre_indexing+skip_factor-1)//skip_factor

        temp_ = num_elems_pre_indexing-num_elems_post_indexing
        boundary_idx_arr[i:] -= temp_

        all_data[begin_idx:begin_idx+num_elems_post_indexing] = all_data[begin_idx:end_idx:skip_factor]
        if i < len(boundary_idx_arr)-1:
            all_data[begin_idx+num_elems_post_indexing:boundary_idx_arr[-1]] = all_data[end_idx:boundary_idx_arr[-1]+temp_]

    all_data = all_data[0:boundary_idx_arr[-1]]

# %%
boundary_idx_arr
# Out:
# array([200001, 400002])

# %%
all_data.shape
# Out:
# (400002, 12)

# %%
# # setting up data
# idx = np.arange(all_data.shape[0])
# np.random.shuffle(idx)
# boundary = int(np.round((1-test_split)*all_data.shape[0]))
# training_data = all_data[idx[0:boundary], :]
# testing_data = all_data[idx[boundary:], :]

# %%
cum_samples = boundary_idx_arr[-1]
# idx = np.arange(cum_samples)
# np.random.shuffle(idx)
num_train = 0
num_val = 0
begin_idx = 0
for i in range(len(boundary_idx_arr)):
    num_samples = boundary_idx_arr[i] - begin_idx
    num_train += int( np.round(train_split*num_samples) )
    num_val += int( np.round(val_split*num_samples) )
    begin_idx = boundary_idx_arr[i]

# defining shapes
training_shape = [num_train]
training_shape.extend(all_data.shape[1:])

val_shape = [num_val]
val_shape.extend(all_data.shape[1:])

testing_shape = [cum_samples-num_train-num_val]
testing_shape.extend(all_data.shape[1:])

# defining required arrays
training_data = np.empty(shape=training_shape)

val_data = np.empty(shape=val_shape)

testing_data = np.empty(shape=testing_shape)

begin_idx = 0
training_data_rolling_count = 0
val_data_rolling_count = 0
testing_data_rolling_count = 0
for i in range(len(boundary_idx_arr)):
    num_samples = boundary_idx_arr[i] - begin_idx
    num_train = int( np.round(train_split*num_samples) )
    num_val = int( np.round(val_split*num_samples) )

    training_data[training_data_rolling_count:training_data_rolling_count+num_train] = all_data[begin_idx:begin_idx+num_train]
    training_data_rolling_count += num_train

    val_data[val_data_rolling_count:val_data_rolling_count+num_val] = all_data[begin_idx+num_train:begin_idx+num_train+num_val]
    val_data_rolling_count += num_val

    num_test = num_samples-num_train-num_val
    testing_data[testing_data_rolling_count:testing_data_rolling_count+num_test] = all_data[begin_idx+num_train+num_val:begin_idx+num_train+num_val+num_test]
    testing_data_rolling_count += num_test

    begin_idx = boundary_idx_arr[i]

# further shuffling
# idx = np.arange(0, training_data.shape[0])
# np.random.shuffle(idx)
# training_data_rnn_input = training_data_rnn_input[idx]
np.random.shuffle(training_data)

# idx = np.arange(0, val_data.shape[0])
# np.random.shuffle(idx)
# val_data = val_data[idx]
np.random.shuffle(val_data)

# idx = np.arange(0, testing_data.shape[0])
# np.random.shuffle(idx)
# testing_data = testing_data[idx]
np.random.shuffle(testing_data)

# %%
#

# %%
# Initialize network
if behaviour == 'initialiseAndTrainFromScratch':
    latent_space_dim = 5
    # enc_layers = [128, 96, 64, 48, 32, 24, 26, 8, 4]
    # enc_layers = [192, 96, 48, 24, 12, 6, 3]
    # enc_layers = [96, 48, 24, 12, 6, 3]
    # enc_layers = [128, 64, 32, 16, 8, 4]
    # enc_layers = []
    # enc_layers = [32, 16, 8, 4]
    # for i in range(len(enc_layers)):
    #     if latent_space_dim < enc_layers[-i-1]:
    #         enc_layers = enc_layers[0:-i]
    #         break
    #     if i == len(enc_layers)-1:
    #         enc_layers = []
    # dec_layers = enc_layers[::-1]
    enc_layers = [16, 8, 8]
    dec_layers = [8, 8, 16]
    
    enc_layer_act_func = 'elu'
    enc_final_layer_act_func = 'tanh'
    dec_layer_act_func = 'elu'
    dec_final_layer_act_func = 'tanh'
    reg_name = 'L2'
    
    if strategy is not None:
        with strategy.scope():
            ae_net = Autoencoder(
                data_dim=all_data.shape[1],
                enc_layers=enc_layers,
                dec_layers=dec_layers,
                latent_space_dim=latent_space_dim,
                lambda_reg=lambda_reg,
                reg_name=reg_name,
                enc_layer_act_func=enc_layer_act_func,
                enc_final_layer_act_func=enc_final_layer_act_func,
                dec_layer_act_func=dec_layer_act_func,
                dec_final_layer_act_func=dec_final_layer_act_func,
                load_file=None,
                stddev=stddev,
                contractive_lmda=contractive_lmda,
                dropout_rate=dropout_rate,
                use_weights_post_dense=use_weights_post_dense,)
    else:
        ae_net = Autoencoder(
            data_dim=all_data.shape[1],
            enc_layers=enc_layers,
            dec_layers=dec_layers,
            latent_space_dim=latent_space_dim,
            lambda_reg=lambda_reg,
            reg_name=reg_name,
            enc_layer_act_func=enc_layer_act_func,
            enc_final_layer_act_func=enc_final_layer_act_func,
            dec_layer_act_func=dec_layer_act_func,
            dec_final_layer_act_func=dec_final_layer_act_func,
            load_file=None,
            stddev=stddev,
            contractive_lmda=contractive_lmda,
            dropout_rate=dropout_rate,
            use_weights_post_dense=use_weights_post_dense,)
    # saving the AE configuration
    save_path = dir_name_ae+dir_sep+'final_net'
    if not os.path.isdir(save_path):
        os.makedirs(save_path)
    ae_net.save_class_dict(save_path+dir_sep+'final_net_class_dict.txt')
else:
    load_file = dir_name_ae + dir_sep + 'final_net' + dir_sep + 'final_net_class_dict.txt'
    if strategy is not None:
        with strategy.scope():
            ae_net = Autoencoder(data_dim=all_data.shape[1], load_file=load_file)
    else:
        ae_net = Autoencoder(data_dim=all_data.shape[1], load_file=load_file)
    
    if behaviour == 'loadCheckpointAndContinueTraining':
        wt_file = tf.train.latest_checkpoint(dir_name_ae+dir_sep+'checkpoints')
        # ae_net.load_weights(wt_file)
    elif behaviour == 'loadFinalNetAndPlot':
        wt_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_ae_weights.h5'
        ae_net.load_weights_from_file(wt_file)

# %%
#

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt = readAndReturnLossHistories(
        dir_name_ae=dir_name_ae,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=learning_rate_list)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_ae+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
train_MSE_hist = []
val_MSE_hist = []

train_NMSE_hist = []
val_NMSE_hist = []

train_ls_jacobian_norm_hist = []

train_real_MSE_hist = []
val_real_MSE_hist = []

train_params_MSE_hist = []
val_params_MSE_hist = []

# %%
class NMSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, divisor_arr, name='NMSE', **kwargs):
        super(NMSE, self).__init__(name, **kwargs)
        self.divisor_arr = divisor_arr

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true / self.divisor_arr
        y_pred = y_pred / self.divisor_arr
        return super(NMSE, self).update_state(y_true, y_pred, sample_weight)

class real_MSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, og_vars, name='real_MSE', **kwargs):
        super().__init__(name, **kwargs)
        self.og_vars = og_vars

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true[:, 0:self.og_vars]
        y_pred = y_pred[:, 0:self.og_vars]
        return super().update_state(y_true, y_pred, sample_weight)
    
class params_MSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, og_vars, name='params_MSE', **kwargs):
        super().__init__(name, **kwargs)
        self.og_vars = og_vars

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true[:, self.og_vars:]
        y_pred = y_pred[:, self.og_vars:]
        return super().update_state(y_true, y_pred, sample_weight)

# %%
# compiling the network
ae_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
    loss=losses.MeanSquaredError(),
#     loss=losses.BinaryCrossentropy(from_logits=False),
    run_eagerly=False,
    metrics=['mse', NMSE(divisor_arr=tf.constant(time_stddev)), real_MSE(og_vars), params_MSE(og_vars)]
)

if behaviour == 'loadCheckpointAndContinueTraining':
    # this loads the weights/attributes of the optimizer as well
    if strategy is not None:
        with strategy.scope():
            ae_net.load_weights(wt_file)
    else:
        ae_net.load_weights(wt_file)

if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    metric_to_use = 'val_NMSE'
    # implementing early stopping
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor=metric_to_use,
        patience=patience,
        restore_best_weights=True,
        verbose=True,
        min_delta=min_delta
    )

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_ae+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor=metric_to_use,
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        period=1  # saves every 5 epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=1)

    # training the network
    for i in range(starting_lr_idx, len(learning_rate_list)):
        learning_rate = learning_rate_list[i]
        K.set_value(ae_net.optimizer.lr, learning_rate)

        savelosses_cb.update_lr_idx(i)

        if i == starting_lr_idx:
            EPOCHS = num_epochs_left
            savelosses_cb.update_offset(epochs-num_epochs_left)
        else:
            EPOCHS = epochs
            savelosses_cb.update_offset(0)

        total_s_len = 80
        sep_lr_s = ' LEARNING RATE : {} '.format(learning_rate)
        sep_lr_s = int((total_s_len - len(sep_lr_s))//2)*'-' + sep_lr_s
        sep_lr_s = sep_lr_s + (total_s_len-len(sep_lr_s))*'-'
        print('\n\n' + '-'*len(sep_lr_s))
        print('\n' + sep_lr_s+'\n')
        print('-'*len(sep_lr_s) + '\n\n')
        
        history = ae_net.fit(training_data, training_data,
            epochs=EPOCHS,
            batch_size=batch_size,
#             validation_split=val_split/train_split,
            validation_data=(val_data, val_data),
            callbacks=[
                early_stopping_cb,
                timekeeper_cb,
                # checkpoint_cb,
                # savelosses_cb,
            ],
            verbose=1,
            shuffle=True,
        )

        val_loss_hist.extend(history.history['val_loss'])
        train_loss_hist.extend(history.history['loss'])
        
        val_MSE_hist.extend(history.history['val_mse'])
        train_MSE_hist.extend(history.history['mse'])
        
        val_NMSE_hist.extend(history.history['val_NMSE'])
        train_NMSE_hist.extend(history.history['NMSE'])
        
        train_ls_jacobian_norm_hist.append(history.history['ls_jacobian_norm'])
        
        if i == starting_lr_idx:
            lr_change[i+1] += len(history.history['val_loss'])
        else:
            lr_change.append(lr_change[i]+len(history.history['val_loss']))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 0.001 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 0.0085 - mse: 0.0083 - NMSE: 0.0530 - real_MSE: 0.0112 - params_MSE: 0.0055 - ls_jacobian_norm: 1.4399 - tot_time: 0h 0m 33.1s
# 5001/5001 [==============================] - 33s 6ms/step - loss: 0.0085 - mse: 0.0083 - NMSE: 0.0530 - real_MSE: 0.0112 - params_MSE: 0.0055 - ls_jacobian_norm: 1.4398 - val_loss: 8.6558e-04 - val_mse: 6.3914e-04 - val_NMSE: 0.0053 - val_real_MSE: 0.0012 - val_params_MSE: 1.0497e-04 - val_ls_jacobian_norm: -1.0000
# Epoch 2/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 5.6666e-04 - mse: 3.4268e-04 - NMSE: 0.0029 - real_MSE: 6.4381e-04 - params_MSE: 4.1548e-05 - ls_jacobian_norm: 1.3353 - tot_time: 0h 1m 5.8s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 5.6664e-04 - mse: 3.4266e-04 - NMSE: 0.0029 - real_MSE: 6.4379e-04 - params_MSE: 4.1542e-05 - ls_jacobian_norm: 1.3352 - val_loss: 6.5976e-04 - val_mse: 4.3942e-04 - val_NMSE: 0.0039 - val_real_MSE: 8.5703e-04 - val_params_MSE: 2.1805e-05 - val_ls_jacobian_norm: -1.0000
# Epoch 3/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 4.3569e-04 - mse: 2.1753e-04 - NMSE: 0.0019 - real_MSE: 4.2096e-04 - params_MSE: 1.4092e-05 - ls_jacobian_norm: 1.2565 - tot_time: 0h 1m 38.1s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 4.3567e-04 - mse: 2.1751e-04 - NMSE: 0.0019 - real_MSE: 4.2093e-04 - params_MSE: 1.4089e-05 - ls_jacobian_norm: 1.2565 - val_loss: 4.4261e-04 - val_mse: 2.2587e-04 - val_NMSE: 0.0020 - val_real_MSE: 4.4048e-04 - val_params_MSE: 1.1256e-05 - val_ls_jacobian_norm: -1.0000
# Epoch 4/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 3.6690e-04 - mse: 1.5203e-04 - NMSE: 0.0013 - real_MSE: 2.9482e-04 - params_MSE: 9.2510e-06 - ls_jacobian_norm: 1.2506 - tot_time: 0h 2m 10.3s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 3.6689e-04 - mse: 1.5202e-04 - NMSE: 0.0013 - real_MSE: 2.9480e-04 - params_MSE: 9.2501e-06 - ls_jacobian_norm: 1.2506 - val_loss: 3.6724e-04 - val_mse: 1.5456e-04 - val_NMSE: 0.0014 - val_real_MSE: 3.0033e-04 - val_params_MSE: 8.7841e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 5/200
# 4996/5001 [============================>.] - ETA: 0s - loss: 3.3180e-04 - mse: 1.2146e-04 - NMSE: 0.0011 - real_MSE: 2.3489e-04 - params_MSE: 8.0213e-06 - ls_jacobian_norm: 1.2639 - tot_time: 0h 2m 42.2s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 3.3177e-04 - mse: 1.2143e-04 - NMSE: 0.0011 - real_MSE: 2.3484e-04 - params_MSE: 8.0203e-06 - ls_jacobian_norm: 1.2639 - val_loss: 3.4247e-04 - val_mse: 1.3442e-04 - val_NMSE: 0.0012 - val_real_MSE: 2.6074e-04 - val_params_MSE: 8.0998e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 6/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 3.0591e-04 - mse: 1.0041e-04 - NMSE: 8.7559e-04 - real_MSE: 1.9379e-04 - params_MSE: 7.0293e-06 - ls_jacobian_norm: 1.2878 - tot_time: 0h 3m 15.0s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 3.0591e-04 - mse: 1.0041e-04 - NMSE: 8.7558e-04 - real_MSE: 1.9379e-04 - params_MSE: 7.0293e-06 - ls_jacobian_norm: 1.2878 - val_loss: 3.3009e-04 - val_mse: 1.2700e-04 - val_NMSE: 0.0011 - val_real_MSE: 2.4608e-04 - val_params_MSE: 7.9286e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 7/200
# 4993/5001 [============================>.] - ETA: 0s - loss: 2.8775e-04 - mse: 8.6711e-05 - NMSE: 7.5408e-04 - real_MSE: 1.6684e-04 - params_MSE: 6.5790e-06 - ls_jacobian_norm: 1.2952 - tot_time: 0h 3m 46.7s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.8775e-04 - mse: 8.6718e-05 - NMSE: 7.5414e-04 - real_MSE: 1.6686e-04 - params_MSE: 6.5780e-06 - ls_jacobian_norm: 1.2952 - val_loss: 3.2680e-04 - val_mse: 1.2757e-04 - val_NMSE: 0.0011 - val_real_MSE: 2.4703e-04 - val_params_MSE: 8.1093e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 8/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 2.7472e-04 - mse: 7.7139e-05 - NMSE: 6.6958e-04 - real_MSE: 1.4811e-04 - params_MSE: 6.1678e-06 - ls_jacobian_norm: 1.3009 - tot_time: 0h 4m 18.4s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.7470e-04 - mse: 7.7127e-05 - NMSE: 6.6947e-04 - real_MSE: 1.4809e-04 - params_MSE: 6.1675e-06 - ls_jacobian_norm: 1.3009 - val_loss: 2.7188e-04 - val_mse: 7.5766e-05 - val_NMSE: 6.5455e-04 - val_real_MSE: 1.4470e-04 - val_params_MSE: 6.8348e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 9/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 2.6449e-04 - mse: 6.9688e-05 - NMSE: 6.0391e-04 - real_MSE: 1.3356e-04 - params_MSE: 5.8191e-06 - ls_jacobian_norm: 1.3188 - tot_time: 0h 4m 50.7s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.6449e-04 - mse: 6.9688e-05 - NMSE: 6.0391e-04 - real_MSE: 1.3356e-04 - params_MSE: 5.8192e-06 - ls_jacobian_norm: 1.3189 - val_loss: 3.8820e-04 - val_mse: 1.9462e-04 - val_NMSE: 0.0017 - val_real_MSE: 3.8214e-04 - val_params_MSE: 7.1056e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 10/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.5628e-04 - mse: 6.3692e-05 - NMSE: 5.5116e-04 - real_MSE: 1.2187e-04 - params_MSE: 5.5173e-06 - ls_jacobian_norm: 1.3463 - tot_time: 0h 5m 22.6s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.5628e-04 - mse: 6.3692e-05 - NMSE: 5.5116e-04 - real_MSE: 1.2187e-04 - params_MSE: 5.5173e-06 - ls_jacobian_norm: 1.3463 - val_loss: 2.7749e-04 - val_mse: 8.5984e-05 - val_NMSE: 7.5197e-04 - val_real_MSE: 1.6650e-04 - val_params_MSE: 5.4718e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 11/200
# 4992/5001 [============================>.] - ETA: 0s - loss: 2.4970e-04 - mse: 5.8922e-05 - NMSE: 5.0906e-04 - real_MSE: 1.1253e-04 - params_MSE: 5.3100e-06 - ls_jacobian_norm: 1.3783 - tot_time: 0h 5m 54.9s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.4969e-04 - mse: 5.8918e-05 - NMSE: 5.0902e-04 - real_MSE: 1.1253e-04 - params_MSE: 5.3088e-06 - ls_jacobian_norm: 1.3783 - val_loss: 5.1759e-04 - val_mse: 3.2753e-04 - val_NMSE: 0.0029 - val_real_MSE: 6.4790e-04 - val_params_MSE: 7.1666e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 12/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.4444e-04 - mse: 5.5014e-05 - NMSE: 4.7449e-04 - real_MSE: 1.0487e-04 - params_MSE: 5.1592e-06 - ls_jacobian_norm: 1.4107 - tot_time: 0h 6m 26.4s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.4444e-04 - mse: 5.5014e-05 - NMSE: 4.7449e-04 - real_MSE: 1.0487e-04 - params_MSE: 5.1592e-06 - ls_jacobian_norm: 1.4107 - val_loss: 2.5296e-04 - val_mse: 6.4043e-05 - val_NMSE: 5.5562e-04 - val_real_MSE: 1.2289e-04 - val_params_MSE: 5.1925e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 13/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 2.3926e-04 - mse: 5.0853e-05 - NMSE: 4.3759e-04 - real_MSE: 9.6684e-05 - params_MSE: 5.0218e-06 - ls_jacobian_norm: 1.4386 - tot_time: 0h 6m 58.3s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.3925e-04 - mse: 5.0849e-05 - NMSE: 4.3756e-04 - real_MSE: 9.6677e-05 - params_MSE: 5.0213e-06 - ls_jacobian_norm: 1.4386 - val_loss: 2.6418e-04 - val_mse: 7.6217e-05 - val_NMSE: 6.6270e-04 - val_real_MSE: 1.4662e-04 - val_params_MSE: 5.8130e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 14/200
# 4996/5001 [============================>.] - ETA: 0s - loss: 2.3546e-04 - mse: 4.7974e-05 - NMSE: 4.1186e-04 - real_MSE: 9.0973e-05 - params_MSE: 4.9752e-06 - ls_jacobian_norm: 1.4635 - tot_time: 0h 7m 30.1s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.3545e-04 - mse: 4.7971e-05 - NMSE: 4.1183e-04 - real_MSE: 9.0966e-05 - params_MSE: 4.9754e-06 - ls_jacobian_norm: 1.4635 - val_loss: 2.4931e-04 - val_mse: 6.2213e-05 - val_NMSE: 5.3912e-04 - val_real_MSE: 1.1923e-04 - val_params_MSE: 5.1973e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 15/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.3231e-04 - mse: 4.5623e-05 - NMSE: 3.9092e-04 - real_MSE: 8.6326e-05 - params_MSE: 4.9208e-06 - ls_jacobian_norm: 1.4844 - tot_time: 0h 8m 2.9s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.3231e-04 - mse: 4.5623e-05 - NMSE: 3.9092e-04 - real_MSE: 8.6326e-05 - params_MSE: 4.9208e-06 - ls_jacobian_norm: 1.4844 - val_loss: 2.5838e-04 - val_mse: 7.2060e-05 - val_NMSE: 6.2567e-04 - val_real_MSE: 1.3841e-04 - val_params_MSE: 5.7157e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 16/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 2.2965e-04 - mse: 4.3681e-05 - NMSE: 3.7343e-04 - real_MSE: 8.2439e-05 - params_MSE: 4.9222e-06 - ls_jacobian_norm: 1.5025 - tot_time: 0h 8m 35.6s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.2966e-04 - mse: 4.3687e-05 - NMSE: 3.7349e-04 - real_MSE: 8.2451e-05 - params_MSE: 4.9225e-06 - ls_jacobian_norm: 1.5024 - val_loss: 2.5878e-04 - val_mse: 7.3040e-05 - val_NMSE: 6.3562e-04 - val_real_MSE: 1.4065e-04 - val_params_MSE: 5.4321e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 17/200
# 4996/5001 [============================>.] - ETA: 0s - loss: 2.2701e-04 - mse: 4.1652e-05 - NMSE: 3.5535e-04 - real_MSE: 7.8425e-05 - params_MSE: 4.8794e-06 - ls_jacobian_norm: 1.5159 - tot_time: 0h 9m 8.4s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.2701e-04 - mse: 4.1654e-05 - NMSE: 3.5536e-04 - real_MSE: 7.8427e-05 - params_MSE: 4.8806e-06 - ls_jacobian_norm: 1.5160 - val_loss: 2.8162e-04 - val_mse: 9.6530e-05 - val_NMSE: 8.4625e-04 - val_real_MSE: 1.8743e-04 - val_params_MSE: 5.6307e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 18/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 2.2483e-04 - mse: 4.0073e-05 - NMSE: 3.4119e-04 - real_MSE: 7.5281e-05 - params_MSE: 4.8652e-06 - ls_jacobian_norm: 1.5251 - tot_time: 0h 9m 40.5s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.2483e-04 - mse: 4.0073e-05 - NMSE: 3.4119e-04 - real_MSE: 7.5281e-05 - params_MSE: 4.8652e-06 - ls_jacobian_norm: 1.5251 - val_loss: 3.2384e-04 - val_mse: 1.3941e-04 - val_NMSE: 0.0012 - val_real_MSE: 2.7390e-04 - val_params_MSE: 4.9098e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 19/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 2.2258e-04 - mse: 3.8419e-05 - NMSE: 3.2634e-04 - real_MSE: 7.1980e-05 - params_MSE: 4.8572e-06 - ls_jacobian_norm: 1.5328 - tot_time: 0h 10m 13.0s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.2258e-04 - mse: 3.8418e-05 - NMSE: 3.2633e-04 - real_MSE: 7.1978e-05 - params_MSE: 4.8582e-06 - ls_jacobian_norm: 1.5328 - val_loss: 2.5268e-04 - val_mse: 6.8898e-05 - val_NMSE: 5.9721e-04 - val_real_MSE: 1.3208e-04 - val_params_MSE: 5.7158e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 20/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 2.2058e-04 - mse: 3.6949e-05 - NMSE: 3.1327e-04 - real_MSE: 6.9082e-05 - params_MSE: 4.8155e-06 - ls_jacobian_norm: 1.5378 - tot_time: 0h 10m 45.9s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.2058e-04 - mse: 3.6948e-05 - NMSE: 3.1327e-04 - real_MSE: 6.9081e-05 - params_MSE: 4.8156e-06 - ls_jacobian_norm: 1.5378 - val_loss: 2.3651e-04 - val_mse: 5.3216e-05 - val_NMSE: 4.5939e-04 - val_real_MSE: 1.0154e-04 - val_params_MSE: 4.8905e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 21/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.1878e-04 - mse: 3.5682e-05 - NMSE: 3.0191e-04 - real_MSE: 6.6557e-05 - params_MSE: 4.8072e-06 - ls_jacobian_norm: 1.5418 - tot_time: 0h 11m 18.9s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.1878e-04 - mse: 3.5682e-05 - NMSE: 3.0191e-04 - real_MSE: 6.6557e-05 - params_MSE: 4.8072e-06 - ls_jacobian_norm: 1.5418 - val_loss: 2.5501e-04 - val_mse: 7.2201e-05 - val_NMSE: 6.2892e-04 - val_real_MSE: 1.3918e-04 - val_params_MSE: 5.2216e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 22/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 2.1710e-04 - mse: 3.4463e-05 - NMSE: 2.9097e-04 - real_MSE: 6.4127e-05 - params_MSE: 4.7987e-06 - ls_jacobian_norm: 1.5435 - tot_time: 0h 11m 51.4s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.1710e-04 - mse: 3.4462e-05 - NMSE: 2.9096e-04 - real_MSE: 6.4126e-05 - params_MSE: 4.7986e-06 - ls_jacobian_norm: 1.5435 - val_loss: 2.3781e-04 - val_mse: 5.5488e-05 - val_NMSE: 4.7854e-04 - val_real_MSE: 1.0576e-04 - val_params_MSE: 5.2115e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 23/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 2.1553e-04 - mse: 3.3401e-05 - NMSE: 2.8138e-04 - real_MSE: 6.1995e-05 - params_MSE: 4.8073e-06 - ls_jacobian_norm: 1.5449 - tot_time: 0h 12m 24.0s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.1553e-04 - mse: 3.3401e-05 - NMSE: 2.8138e-04 - real_MSE: 6.1995e-05 - params_MSE: 4.8073e-06 - ls_jacobian_norm: 1.5449 - val_loss: 2.6725e-04 - val_mse: 8.5354e-05 - val_NMSE: 7.4509e-04 - val_real_MSE: 1.6494e-04 - val_params_MSE: 5.7727e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 24/200
# 4991/5001 [============================>.] - ETA: 0s - loss: 2.1428e-04 - mse: 3.2606e-05 - NMSE: 2.7450e-04 - real_MSE: 6.0474e-05 - params_MSE: 4.7372e-06 - ls_jacobian_norm: 1.5457 - tot_time: 0h 12m 56.5s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.1428e-04 - mse: 3.2607e-05 - NMSE: 2.7451e-04 - real_MSE: 6.0476e-05 - params_MSE: 4.7367e-06 - ls_jacobian_norm: 1.5457 - val_loss: 2.2360e-04 - val_mse: 4.2145e-05 - val_NMSE: 3.5806e-04 - val_real_MSE: 7.8978e-05 - val_params_MSE: 5.3111e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 25/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 2.1295e-04 - mse: 3.1753e-05 - NMSE: 2.6695e-04 - real_MSE: 5.8801e-05 - params_MSE: 4.7063e-06 - ls_jacobian_norm: 1.5473 - tot_time: 0h 13m 30.4s
# 5001/5001 [==============================] - 34s 7ms/step - loss: 2.1295e-04 - mse: 3.1753e-05 - NMSE: 2.6696e-04 - real_MSE: 5.8802e-05 - params_MSE: 4.7051e-06 - ls_jacobian_norm: 1.5473 - val_loss: 2.5076e-04 - val_mse: 6.9743e-05 - val_NMSE: 6.0874e-04 - val_real_MSE: 1.3475e-04 - val_params_MSE: 4.7350e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 26/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 2.1212e-04 - mse: 3.1342e-05 - NMSE: 2.6346e-04 - real_MSE: 5.8031e-05 - params_MSE: 4.6524e-06 - ls_jacobian_norm: 1.5503 - tot_time: 0h 14m 3.0s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.1212e-04 - mse: 3.1340e-05 - NMSE: 2.6345e-04 - real_MSE: 5.8027e-05 - params_MSE: 4.6528e-06 - ls_jacobian_norm: 1.5503 - val_loss: 2.5275e-04 - val_mse: 7.2205e-05 - val_NMSE: 6.2739e-04 - val_real_MSE: 1.3880e-04 - val_params_MSE: 5.6141e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 27/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 2.1134e-04 - mse: 3.0978e-05 - NMSE: 2.6035e-04 - real_MSE: 5.7345e-05 - params_MSE: 4.6110e-06 - ls_jacobian_norm: 1.5546 - tot_time: 0h 14m 35.3s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.1134e-04 - mse: 3.0978e-05 - NMSE: 2.6035e-04 - real_MSE: 5.7345e-05 - params_MSE: 4.6110e-06 - ls_jacobian_norm: 1.5546 - val_loss: 2.2901e-04 - val_mse: 4.8818e-05 - val_NMSE: 4.1430e-04 - val_real_MSE: 9.1372e-05 - val_params_MSE: 6.2645e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 28/200
# 4992/5001 [============================>.] - ETA: 0s - loss: 2.0999e-04 - mse: 3.0027e-05 - NMSE: 2.5205e-04 - real_MSE: 5.5506e-05 - params_MSE: 4.5482e-06 - ls_jacobian_norm: 1.5576 - tot_time: 0h 15m 7.6s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.0999e-04 - mse: 3.0023e-05 - NMSE: 2.5202e-04 - real_MSE: 5.5499e-05 - params_MSE: 4.5466e-06 - ls_jacobian_norm: 1.5576 - val_loss: 2.1993e-04 - val_mse: 4.0223e-05 - val_NMSE: 3.4186e-04 - val_real_MSE: 7.5409e-05 - val_params_MSE: 5.0371e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 29/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 2.0949e-04 - mse: 2.9933e-05 - NMSE: 2.5127e-04 - real_MSE: 5.5334e-05 - params_MSE: 4.5327e-06 - ls_jacobian_norm: 1.5619 - tot_time: 0h 15m 39.5s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.0949e-04 - mse: 2.9934e-05 - NMSE: 2.5127e-04 - real_MSE: 5.5335e-05 - params_MSE: 4.5328e-06 - ls_jacobian_norm: 1.5619 - val_loss: 2.3136e-04 - val_mse: 5.1957e-05 - val_NMSE: 4.4822e-04 - val_real_MSE: 9.9069e-05 - val_params_MSE: 4.8446e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 30/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.0873e-04 - mse: 2.9545e-05 - NMSE: 2.4800e-04 - real_MSE: 5.4615e-05 - params_MSE: 4.4760e-06 - ls_jacobian_norm: 1.5668 - tot_time: 0h 16m 13.3s
# 5001/5001 [==============================] - 34s 7ms/step - loss: 2.0873e-04 - mse: 2.9545e-05 - NMSE: 2.4800e-04 - real_MSE: 5.4615e-05 - params_MSE: 4.4760e-06 - ls_jacobian_norm: 1.5668 - val_loss: 2.7314e-04 - val_mse: 9.4122e-05 - val_NMSE: 8.2163e-04 - val_real_MSE: 1.8188e-04 - val_params_MSE: 6.3664e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 31/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 2.0818e-04 - mse: 2.9355e-05 - NMSE: 2.4638e-04 - real_MSE: 5.4256e-05 - params_MSE: 4.4540e-06 - ls_jacobian_norm: 1.5709 - tot_time: 0h 16m 46.7s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0818e-04 - mse: 2.9354e-05 - NMSE: 2.4636e-04 - real_MSE: 5.4253e-05 - params_MSE: 4.4544e-06 - ls_jacobian_norm: 1.5708 - val_loss: 2.2225e-04 - val_mse: 4.3593e-05 - val_NMSE: 3.7456e-04 - val_real_MSE: 8.2743e-05 - val_params_MSE: 4.4434e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 32/200
# 4996/5001 [============================>.] - ETA: 0s - loss: 2.0760e-04 - mse: 2.9149e-05 - NMSE: 2.4470e-04 - real_MSE: 5.3888e-05 - params_MSE: 4.4099e-06 - ls_jacobian_norm: 1.5765 - tot_time: 0h 17m 19.8s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0760e-04 - mse: 2.9151e-05 - NMSE: 2.4472e-04 - real_MSE: 5.3893e-05 - params_MSE: 4.4101e-06 - ls_jacobian_norm: 1.5765 - val_loss: 2.2006e-04 - val_mse: 4.1713e-05 - val_NMSE: 3.5612e-04 - val_real_MSE: 7.8602e-05 - val_params_MSE: 4.8231e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 33/200
# 4996/5001 [============================>.] - ETA: 0s - loss: 2.0698e-04 - mse: 2.8855e-05 - NMSE: 2.4218e-04 - real_MSE: 5.3331e-05 - params_MSE: 4.3793e-06 - ls_jacobian_norm: 1.5811 - tot_time: 0h 17m 53.8s
# 5001/5001 [==============================] - 34s 7ms/step - loss: 2.0698e-04 - mse: 2.8856e-05 - NMSE: 2.4218e-04 - real_MSE: 5.3331e-05 - params_MSE: 4.3800e-06 - ls_jacobian_norm: 1.5811 - val_loss: 3.0544e-04 - val_mse: 1.2748e-04 - val_NMSE: 0.0011 - val_real_MSE: 2.4987e-04 - val_params_MSE: 5.0902e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 34/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.0657e-04 - mse: 2.8795e-05 - NMSE: 2.4177e-04 - real_MSE: 5.3243e-05 - params_MSE: 4.3474e-06 - ls_jacobian_norm: 1.5867 - tot_time: 0h 18m 27.5s
# 5001/5001 [==============================] - 34s 7ms/step - loss: 2.0657e-04 - mse: 2.8795e-05 - NMSE: 2.4177e-04 - real_MSE: 5.3243e-05 - params_MSE: 4.3474e-06 - ls_jacobian_norm: 1.5867 - val_loss: 2.6933e-04 - val_mse: 9.1765e-05 - val_NMSE: 8.0828e-04 - val_real_MSE: 1.7914e-04 - val_params_MSE: 4.3945e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 35/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 2.0597e-04 - mse: 2.8530e-05 - NMSE: 2.3947e-04 - real_MSE: 5.2736e-05 - params_MSE: 4.3236e-06 - ls_jacobian_norm: 1.5925 - tot_time: 0h 19m 0.1s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0597e-04 - mse: 2.8532e-05 - NMSE: 2.3948e-04 - real_MSE: 5.2739e-05 - params_MSE: 4.3242e-06 - ls_jacobian_norm: 1.5925 - val_loss: 2.0823e-04 - val_mse: 3.0998e-05 - val_NMSE: 2.6152e-04 - val_real_MSE: 5.7633e-05 - val_params_MSE: 4.3640e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 36/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 2.0536e-04 - mse: 2.8246e-05 - NMSE: 2.3702e-04 - real_MSE: 5.2194e-05 - params_MSE: 4.2986e-06 - ls_jacobian_norm: 1.5975 - tot_time: 0h 19m 33.5s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0537e-04 - mse: 2.8251e-05 - NMSE: 2.3705e-04 - real_MSE: 5.2201e-05 - params_MSE: 4.3000e-06 - ls_jacobian_norm: 1.5975 - val_loss: 2.2468e-04 - val_mse: 4.7655e-05 - val_NMSE: 4.1099e-04 - val_real_MSE: 9.0834e-05 - val_params_MSE: 4.4762e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 37/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 2.0498e-04 - mse: 2.8163e-05 - NMSE: 2.3644e-04 - real_MSE: 5.2069e-05 - params_MSE: 4.2561e-06 - ls_jacobian_norm: 1.6040 - tot_time: 0h 20m 6.2s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0498e-04 - mse: 2.8162e-05 - NMSE: 2.3644e-04 - real_MSE: 5.2069e-05 - params_MSE: 4.2557e-06 - ls_jacobian_norm: 1.6040 - val_loss: 2.2542e-04 - val_mse: 4.8771e-05 - val_NMSE: 4.2081e-04 - val_real_MSE: 9.3011e-05 - val_params_MSE: 4.5310e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 38/200
# 5001/5001 [==============================] - ETA: 0s - loss: 2.0450e-04 - mse: 2.7986e-05 - NMSE: 2.3490e-04 - real_MSE: 5.1730e-05 - params_MSE: 4.2412e-06 - ls_jacobian_norm: 1.6100 - tot_time: 0h 20m 39.2s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0450e-04 - mse: 2.7986e-05 - NMSE: 2.3490e-04 - real_MSE: 5.1730e-05 - params_MSE: 4.2412e-06 - ls_jacobian_norm: 1.6100 - val_loss: 2.1409e-04 - val_mse: 3.7763e-05 - val_NMSE: 3.2250e-04 - val_real_MSE: 7.1185e-05 - val_params_MSE: 4.3410e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 39/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 2.0391e-04 - mse: 2.7726e-05 - NMSE: 2.3270e-04 - real_MSE: 5.1245e-05 - params_MSE: 4.2071e-06 - ls_jacobian_norm: 1.6162 - tot_time: 0h 21m 11.9s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0391e-04 - mse: 2.7728e-05 - NMSE: 2.3273e-04 - real_MSE: 5.1251e-05 - params_MSE: 4.2060e-06 - ls_jacobian_norm: 1.6162 - val_loss: 3.7370e-04 - val_mse: 1.9753e-04 - val_NMSE: 0.0018 - val_real_MSE: 3.8950e-04 - val_params_MSE: 5.5540e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 40/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 2.0362e-04 - mse: 2.7707e-05 - NMSE: 2.3261e-04 - real_MSE: 5.1226e-05 - params_MSE: 4.1876e-06 - ls_jacobian_norm: 1.6254 - tot_time: 0h 21m 43.7s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.0362e-04 - mse: 2.7706e-05 - NMSE: 2.3260e-04 - real_MSE: 5.1225e-05 - params_MSE: 4.1875e-06 - ls_jacobian_norm: 1.6254 - val_loss: 2.0956e-04 - val_mse: 3.3795e-05 - val_NMSE: 2.8695e-04 - val_real_MSE: 6.3290e-05 - val_params_MSE: 4.2990e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 41/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 2.0299e-04 - mse: 2.7359e-05 - NMSE: 2.2958e-04 - real_MSE: 5.0555e-05 - params_MSE: 4.1638e-06 - ls_jacobian_norm: 1.6314 - tot_time: 0h 22m 15.9s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.0298e-04 - mse: 2.7358e-05 - NMSE: 2.2957e-04 - real_MSE: 5.0553e-05 - params_MSE: 4.1635e-06 - ls_jacobian_norm: 1.6314 - val_loss: 2.4148e-04 - val_mse: 6.6097e-05 - val_NMSE: 5.7167e-04 - val_real_MSE: 1.2639e-04 - val_params_MSE: 5.7994e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 42/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 2.0259e-04 - mse: 2.7239e-05 - NMSE: 2.2853e-04 - real_MSE: 5.0323e-05 - params_MSE: 4.1546e-06 - ls_jacobian_norm: 1.6386 - tot_time: 0h 22m 48.0s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 2.0259e-04 - mse: 2.7241e-05 - NMSE: 2.2855e-04 - real_MSE: 5.0327e-05 - params_MSE: 4.1556e-06 - ls_jacobian_norm: 1.6386 - val_loss: 2.1564e-04 - val_mse: 4.0438e-05 - val_NMSE: 3.4536e-04 - val_real_MSE: 7.6232e-05 - val_params_MSE: 4.6451e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 43/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 2.0213e-04 - mse: 2.7029e-05 - NMSE: 2.2675e-04 - real_MSE: 4.9932e-05 - params_MSE: 4.1261e-06 - ls_jacobian_norm: 1.6451 - tot_time: 0h 23m 19.4s
# 5001/5001 [==============================] - 31s 6ms/step - loss: 2.0213e-04 - mse: 2.7029e-05 - NMSE: 2.2675e-04 - real_MSE: 4.9932e-05 - params_MSE: 4.1260e-06 - ls_jacobian_norm: 1.6451 - val_loss: 2.1422e-04 - val_mse: 3.9353e-05 - val_NMSE: 3.3656e-04 - val_real_MSE: 7.4302e-05 - val_params_MSE: 4.4035e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 44/200
# 4992/5001 [============================>.] - ETA: 0s - loss: 2.0156e-04 - mse: 2.6721e-05 - NMSE: 2.2397e-04 - real_MSE: 4.9313e-05 - params_MSE: 4.1302e-06 - ls_jacobian_norm: 1.6518 - tot_time: 0h 23m 51.9s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0156e-04 - mse: 2.6722e-05 - NMSE: 2.2397e-04 - real_MSE: 4.9314e-05 - params_MSE: 4.1299e-06 - ls_jacobian_norm: 1.6519 - val_loss: 2.1093e-04 - val_mse: 3.6217e-05 - val_NMSE: 3.0797e-04 - val_real_MSE: 6.7941e-05 - val_params_MSE: 4.4920e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 45/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 2.0153e-04 - mse: 2.6955e-05 - NMSE: 2.2604e-04 - real_MSE: 4.9772e-05 - params_MSE: 4.1370e-06 - ls_jacobian_norm: 1.6598Restoring model weights from the end of the best epoch: 35.
#  - tot_time: 0h 24m 24.5s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 2.0153e-04 - mse: 2.6957e-05 - NMSE: 2.2606e-04 - real_MSE: 4.9777e-05 - params_MSE: 4.1374e-06 - ls_jacobian_norm: 1.6598 - val_loss: 2.2834e-04 - val_mse: 5.3867e-05 - val_NMSE: 4.6733e-04 - val_real_MSE: 1.0337e-04 - val_params_MSE: 4.3666e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 45: early stopping
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 0.0001 ----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9855e-04 - mse: 2.1154e-05 - NMSE: 1.7460e-04 - real_MSE: 3.8362e-05 - params_MSE: 3.9455e-06 - ls_jacobian_norm: 1.5907 - tot_time: 0h 24m 57.9s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9855e-04 - mse: 2.1152e-05 - NMSE: 1.7458e-04 - real_MSE: 3.8359e-05 - params_MSE: 3.9448e-06 - ls_jacobian_norm: 1.5907 - val_loss: 1.9630e-04 - val_mse: 1.8823e-05 - val_NMSE: 1.5325e-04 - val_real_MSE: 3.3608e-05 - val_params_MSE: 4.0385e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 2/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 1.9847e-04 - mse: 2.0979e-05 - NMSE: 1.7344e-04 - real_MSE: 3.8117e-05 - params_MSE: 3.8410e-06 - ls_jacobian_norm: 1.5824 - tot_time: 0h 25m 31.0s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9847e-04 - mse: 2.0979e-05 - NMSE: 1.7344e-04 - real_MSE: 3.8117e-05 - params_MSE: 3.8410e-06 - ls_jacobian_norm: 1.5824 - val_loss: 1.9895e-04 - val_mse: 2.1445e-05 - val_NMSE: 1.7715e-04 - val_real_MSE: 3.8928e-05 - val_params_MSE: 3.9621e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 3/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 1.9832e-04 - mse: 2.0826e-05 - NMSE: 1.7218e-04 - real_MSE: 3.7839e-05 - params_MSE: 3.8130e-06 - ls_jacobian_norm: 1.5764 - tot_time: 0h 26m 4.5s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9832e-04 - mse: 2.0826e-05 - NMSE: 1.7218e-04 - real_MSE: 3.7839e-05 - params_MSE: 3.8130e-06 - ls_jacobian_norm: 1.5764 - val_loss: 1.9586e-04 - val_mse: 1.8382e-05 - val_NMSE: 1.4984e-04 - val_real_MSE: 3.2864e-05 - val_params_MSE: 3.8990e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 4/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 1.9816e-04 - mse: 2.0700e-05 - NMSE: 1.7113e-04 - real_MSE: 3.7607e-05 - params_MSE: 3.7922e-06 - ls_jacobian_norm: 1.5723 - tot_time: 0h 26m 37.5s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9816e-04 - mse: 2.0700e-05 - NMSE: 1.7113e-04 - real_MSE: 3.7607e-05 - params_MSE: 3.7919e-06 - ls_jacobian_norm: 1.5723 - val_loss: 1.9557e-04 - val_mse: 1.8116e-05 - val_NMSE: 1.4771e-04 - val_real_MSE: 3.2398e-05 - val_params_MSE: 3.8335e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 5/200
# 4993/5001 [============================>.] - ETA: 0s - loss: 1.9803e-04 - mse: 2.0612e-05 - NMSE: 1.7037e-04 - real_MSE: 3.7439e-05 - params_MSE: 3.7843e-06 - ls_jacobian_norm: 1.5694 - tot_time: 0h 27m 10.3s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9803e-04 - mse: 2.0611e-05 - NMSE: 1.7036e-04 - real_MSE: 3.7437e-05 - params_MSE: 3.7848e-06 - ls_jacobian_norm: 1.5694 - val_loss: 1.9658e-04 - val_mse: 1.9124e-05 - val_NMSE: 1.5648e-04 - val_real_MSE: 3.4340e-05 - val_params_MSE: 3.9081e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 6/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9793e-04 - mse: 2.0556e-05 - NMSE: 1.6995e-04 - real_MSE: 3.7348e-05 - params_MSE: 3.7646e-06 - ls_jacobian_norm: 1.5669 - tot_time: 0h 27m 42.1s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 1.9793e-04 - mse: 2.0557e-05 - NMSE: 1.6995e-04 - real_MSE: 3.7348e-05 - params_MSE: 3.7660e-06 - ls_jacobian_norm: 1.5668 - val_loss: 1.9461e-04 - val_mse: 1.7262e-05 - val_NMSE: 1.4003e-04 - val_real_MSE: 3.0692e-05 - val_params_MSE: 3.8329e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 7/200
# 5001/5001 [==============================] - ETA: 0s - loss: 1.9775e-04 - mse: 2.0429e-05 - NMSE: 1.6884e-04 - real_MSE: 3.7104e-05 - params_MSE: 3.7542e-06 - ls_jacobian_norm: 1.5646 - tot_time: 0h 28m 15.1s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9775e-04 - mse: 2.0429e-05 - NMSE: 1.6884e-04 - real_MSE: 3.7104e-05 - params_MSE: 3.7542e-06 - ls_jacobian_norm: 1.5645 - val_loss: 1.9576e-04 - val_mse: 1.8450e-05 - val_NMSE: 1.5057e-04 - val_real_MSE: 3.3030e-05 - val_params_MSE: 3.8704e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 8/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 1.9764e-04 - mse: 2.0367e-05 - NMSE: 1.6830e-04 - real_MSE: 3.6985e-05 - params_MSE: 3.7492e-06 - ls_jacobian_norm: 1.5632 - tot_time: 0h 28m 47.6s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9763e-04 - mse: 2.0363e-05 - NMSE: 1.6827e-04 - real_MSE: 3.6978e-05 - params_MSE: 3.7489e-06 - ls_jacobian_norm: 1.5632 - val_loss: 1.9455e-04 - val_mse: 1.7303e-05 - val_NMSE: 1.4012e-04 - val_real_MSE: 3.0706e-05 - val_params_MSE: 3.9007e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 9/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 1.9751e-04 - mse: 2.0286e-05 - NMSE: 1.6762e-04 - real_MSE: 3.6835e-05 - params_MSE: 3.7363e-06 - ls_jacobian_norm: 1.5618 - tot_time: 0h 29m 19.7s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 1.9750e-04 - mse: 2.0284e-05 - NMSE: 1.6761e-04 - real_MSE: 3.6832e-05 - params_MSE: 3.7362e-06 - ls_jacobian_norm: 1.5618 - val_loss: 1.9410e-04 - val_mse: 1.6906e-05 - val_NMSE: 1.3649e-04 - val_real_MSE: 2.9896e-05 - val_params_MSE: 3.9170e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 10/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 1.9743e-04 - mse: 2.0265e-05 - NMSE: 1.6747e-04 - real_MSE: 3.6802e-05 - params_MSE: 3.7285e-06 - ls_jacobian_norm: 1.5604 - tot_time: 0h 29m 52.1s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 1.9743e-04 - mse: 2.0265e-05 - NMSE: 1.6747e-04 - real_MSE: 3.6802e-05 - params_MSE: 3.7285e-06 - ls_jacobian_norm: 1.5604 - val_loss: 1.9490e-04 - val_mse: 1.7784e-05 - val_NMSE: 1.4469e-04 - val_real_MSE: 3.1726e-05 - val_params_MSE: 3.8428e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 11/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 1.9731e-04 - mse: 2.0224e-05 - NMSE: 1.6711e-04 - real_MSE: 3.6721e-05 - params_MSE: 3.7270e-06 - ls_jacobian_norm: 1.5597 - tot_time: 0h 30m 24.1s
# 5001/5001 [==============================] - 32s 6ms/step - loss: 1.9731e-04 - mse: 2.0224e-05 - NMSE: 1.6711e-04 - real_MSE: 3.6722e-05 - params_MSE: 3.7263e-06 - ls_jacobian_norm: 1.5597 - val_loss: 1.9603e-04 - val_mse: 1.8972e-05 - val_NMSE: 1.5553e-04 - val_real_MSE: 3.4140e-05 - val_params_MSE: 3.8032e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 12/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9718e-04 - mse: 2.0146e-05 - NMSE: 1.6645e-04 - real_MSE: 3.6577e-05 - params_MSE: 3.7156e-06 - ls_jacobian_norm: 1.5590 - tot_time: 0h 30m 56.7s
# 5001/5001 [==============================] - 33s 7ms/step - loss: 1.9718e-04 - mse: 2.0147e-05 - NMSE: 1.6646e-04 - real_MSE: 3.6579e-05 - params_MSE: 3.7153e-06 - ls_jacobian_norm: 1.5590 - val_loss: 1.9513e-04 - val_mse: 1.8140e-05 - val_NMSE: 1.4780e-04 - val_real_MSE: 3.2415e-05 - val_params_MSE: 3.8659e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 13/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 1.9708e-04 - mse: 2.0102e-05 - NMSE: 1.6611e-04 - real_MSE: 3.6503e-05 - params_MSE: 3.7003e-06 - ls_jacobian_norm: 1.5584 - tot_time: 0h 31m 32.4s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9708e-04 - mse: 2.0102e-05 - NMSE: 1.6611e-04 - real_MSE: 3.6503e-05 - params_MSE: 3.7003e-06 - ls_jacobian_norm: 1.5584 - val_loss: 1.9452e-04 - val_mse: 1.7559e-05 - val_NMSE: 1.4266e-04 - val_real_MSE: 3.1275e-05 - val_params_MSE: 3.8425e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 14/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 1.9698e-04 - mse: 2.0064e-05 - NMSE: 1.6576e-04 - real_MSE: 3.6423e-05 - params_MSE: 3.7044e-06 - ls_jacobian_norm: 1.5582 - tot_time: 0h 32m 8.2s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9698e-04 - mse: 2.0066e-05 - NMSE: 1.6576e-04 - real_MSE: 3.6425e-05 - params_MSE: 3.7060e-06 - ls_jacobian_norm: 1.5582 - val_loss: 1.9355e-04 - val_mse: 1.6661e-05 - val_NMSE: 1.3489e-04 - val_real_MSE: 2.9557e-05 - val_params_MSE: 3.7654e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 15/200
# 4992/5001 [============================>.] - ETA: 0s - loss: 1.9687e-04 - mse: 2.0009e-05 - NMSE: 1.6527e-04 - real_MSE: 3.6316e-05 - params_MSE: 3.7026e-06 - ls_jacobian_norm: 1.5578 - tot_time: 0h 32m 43.9s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9687e-04 - mse: 2.0011e-05 - NMSE: 1.6528e-04 - real_MSE: 3.6319e-05 - params_MSE: 3.7025e-06 - ls_jacobian_norm: 1.5578 - val_loss: 1.9630e-04 - val_mse: 1.9460e-05 - val_NMSE: 1.6013e-04 - val_real_MSE: 3.5167e-05 - val_params_MSE: 3.7532e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 16/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9679e-04 - mse: 1.9999e-05 - NMSE: 1.6521e-04 - real_MSE: 3.6302e-05 - params_MSE: 3.6954e-06 - ls_jacobian_norm: 1.5579 - tot_time: 0h 33m 19.6s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9679e-04 - mse: 2.0001e-05 - NMSE: 1.6522e-04 - real_MSE: 3.6306e-05 - params_MSE: 3.6954e-06 - ls_jacobian_norm: 1.5578 - val_loss: 1.9486e-04 - val_mse: 1.8057e-05 - val_NMSE: 1.4745e-04 - val_real_MSE: 3.2350e-05 - val_params_MSE: 3.7643e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 17/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 1.9665e-04 - mse: 1.9898e-05 - NMSE: 1.6437e-04 - real_MSE: 3.6118e-05 - params_MSE: 3.6788e-06 - ls_jacobian_norm: 1.5580 - tot_time: 0h 33m 55.4s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9665e-04 - mse: 1.9900e-05 - NMSE: 1.6438e-04 - real_MSE: 3.6121e-05 - params_MSE: 3.6797e-06 - ls_jacobian_norm: 1.5579 - val_loss: 1.9344e-04 - val_mse: 1.6719e-05 - val_NMSE: 1.3525e-04 - val_real_MSE: 2.9634e-05 - val_params_MSE: 3.8034e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 18/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 1.9659e-04 - mse: 1.9908e-05 - NMSE: 1.6440e-04 - real_MSE: 3.6124e-05 - params_MSE: 3.6932e-06 - ls_jacobian_norm: 1.5579 - tot_time: 0h 34m 30.9s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9659e-04 - mse: 1.9909e-05 - NMSE: 1.6440e-04 - real_MSE: 3.6124e-05 - params_MSE: 3.6930e-06 - ls_jacobian_norm: 1.5578 - val_loss: 1.9473e-04 - val_mse: 1.8065e-05 - val_NMSE: 1.4750e-04 - val_real_MSE: 3.2358e-05 - val_params_MSE: 3.7725e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 19/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9652e-04 - mse: 1.9888e-05 - NMSE: 1.6428e-04 - real_MSE: 3.6098e-05 - params_MSE: 3.6771e-06 - ls_jacobian_norm: 1.5577 - tot_time: 0h 35m 6.4s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9652e-04 - mse: 1.9889e-05 - NMSE: 1.6429e-04 - real_MSE: 3.6100e-05 - params_MSE: 3.6781e-06 - ls_jacobian_norm: 1.5576 - val_loss: 1.9280e-04 - val_mse: 1.6227e-05 - val_NMSE: 1.3074e-04 - val_real_MSE: 2.8629e-05 - val_params_MSE: 3.8246e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 20/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9640e-04 - mse: 1.9826e-05 - NMSE: 1.6374e-04 - real_MSE: 3.5979e-05 - params_MSE: 3.6727e-06 - ls_jacobian_norm: 1.5582 - tot_time: 0h 35m 41.9s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9640e-04 - mse: 1.9828e-05 - NMSE: 1.6376e-04 - real_MSE: 3.5983e-05 - params_MSE: 3.6728e-06 - ls_jacobian_norm: 1.5582 - val_loss: 1.9475e-04 - val_mse: 1.8213e-05 - val_NMSE: 1.4855e-04 - val_real_MSE: 3.2585e-05 - val_params_MSE: 3.8401e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 21/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 1.9631e-04 - mse: 1.9801e-05 - NMSE: 1.6353e-04 - real_MSE: 3.5932e-05 - params_MSE: 3.6689e-06 - ls_jacobian_norm: 1.5583 - tot_time: 0h 36m 17.8s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9631e-04 - mse: 1.9802e-05 - NMSE: 1.6355e-04 - real_MSE: 3.5936e-05 - params_MSE: 3.6685e-06 - ls_jacobian_norm: 1.5583 - val_loss: 1.9493e-04 - val_mse: 1.8454e-05 - val_NMSE: 1.5089e-04 - val_real_MSE: 3.3109e-05 - val_params_MSE: 3.7986e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 22/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 1.9624e-04 - mse: 1.9780e-05 - NMSE: 1.6338e-04 - real_MSE: 3.5900e-05 - params_MSE: 3.6597e-06 - ls_jacobian_norm: 1.5585 - tot_time: 0h 36m 53.6s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9624e-04 - mse: 1.9780e-05 - NMSE: 1.6338e-04 - real_MSE: 3.5900e-05 - params_MSE: 3.6595e-06 - ls_jacobian_norm: 1.5585 - val_loss: 1.9394e-04 - val_mse: 1.7532e-05 - val_NMSE: 1.4255e-04 - val_real_MSE: 3.1256e-05 - val_params_MSE: 3.8074e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 23/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 1.9617e-04 - mse: 1.9780e-05 - NMSE: 1.6330e-04 - real_MSE: 3.5881e-05 - params_MSE: 3.6778e-06 - ls_jacobian_norm: 1.5590 - tot_time: 0h 37m 28.9s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9617e-04 - mse: 1.9781e-05 - NMSE: 1.6332e-04 - real_MSE: 3.5885e-05 - params_MSE: 3.6775e-06 - ls_jacobian_norm: 1.5590 - val_loss: 1.9553e-04 - val_mse: 1.9155e-05 - val_NMSE: 1.5709e-04 - val_real_MSE: 3.4485e-05 - val_params_MSE: 3.8249e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 24/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 1.9606e-04 - mse: 1.9713e-05 - NMSE: 1.6281e-04 - real_MSE: 3.5774e-05 - params_MSE: 3.6531e-06 - ls_jacobian_norm: 1.5591 - tot_time: 0h 38m 4.0s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9606e-04 - mse: 1.9713e-05 - NMSE: 1.6281e-04 - real_MSE: 3.5774e-05 - params_MSE: 3.6531e-06 - ls_jacobian_norm: 1.5591 - val_loss: 1.9320e-04 - val_mse: 1.6888e-05 - val_NMSE: 1.3698e-04 - val_real_MSE: 3.0024e-05 - val_params_MSE: 3.7516e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 25/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 1.9595e-04 - mse: 1.9679e-05 - NMSE: 1.6243e-04 - real_MSE: 3.5689e-05 - params_MSE: 3.6695e-06 - ls_jacobian_norm: 1.5593 - tot_time: 0h 38m 38.7s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9595e-04 - mse: 1.9680e-05 - NMSE: 1.6244e-04 - real_MSE: 3.5691e-05 - params_MSE: 3.6693e-06 - ls_jacobian_norm: 1.5593 - val_loss: 1.9241e-04 - val_mse: 1.6140e-05 - val_NMSE: 1.3020e-04 - val_real_MSE: 2.8517e-05 - val_params_MSE: 3.7626e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 26/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 1.9589e-04 - mse: 1.9662e-05 - NMSE: 1.6236e-04 - real_MSE: 3.5676e-05 - params_MSE: 3.6476e-06 - ls_jacobian_norm: 1.5600 - tot_time: 0h 39m 13.6s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9589e-04 - mse: 1.9663e-05 - NMSE: 1.6238e-04 - real_MSE: 3.5679e-05 - params_MSE: 3.6476e-06 - ls_jacobian_norm: 1.5600 - val_loss: 1.9757e-04 - val_mse: 2.1390e-05 - val_NMSE: 1.7748e-04 - val_real_MSE: 3.9022e-05 - val_params_MSE: 3.7587e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 27/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 1.9582e-04 - mse: 1.9641e-05 - NMSE: 1.6219e-04 - real_MSE: 3.5639e-05 - params_MSE: 3.6427e-06 - ls_jacobian_norm: 1.5605 - tot_time: 0h 39m 48.6s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9582e-04 - mse: 1.9643e-05 - NMSE: 1.6220e-04 - real_MSE: 3.5640e-05 - params_MSE: 3.6453e-06 - ls_jacobian_norm: 1.5605 - val_loss: 1.9307e-04 - val_mse: 1.6928e-05 - val_NMSE: 1.3729e-04 - val_real_MSE: 3.0091e-05 - val_params_MSE: 3.7654e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 28/200
# 4991/5001 [============================>.] - ETA: 0s - loss: 1.9576e-04 - mse: 1.9648e-05 - NMSE: 1.6222e-04 - real_MSE: 3.5643e-05 - params_MSE: 3.6534e-06 - ls_jacobian_norm: 1.5611 - tot_time: 0h 40m 24.1s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9576e-04 - mse: 1.9646e-05 - NMSE: 1.6221e-04 - real_MSE: 3.5641e-05 - params_MSE: 3.6517e-06 - ls_jacobian_norm: 1.5611 - val_loss: 1.9284e-04 - val_mse: 1.6759e-05 - val_NMSE: 1.3573e-04 - val_real_MSE: 2.9742e-05 - val_params_MSE: 3.7760e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 29/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 1.9565e-04 - mse: 1.9597e-05 - NMSE: 1.6178e-04 - real_MSE: 3.5547e-05 - params_MSE: 3.6472e-06 - ls_jacobian_norm: 1.5615Restoring model weights from the end of the best epoch: 19.
#  - tot_time: 0h 40m 59.8s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9565e-04 - mse: 1.9596e-05 - NMSE: 1.6178e-04 - real_MSE: 3.5545e-05 - params_MSE: 3.6471e-06 - ls_jacobian_norm: 1.5615 - val_loss: 1.9468e-04 - val_mse: 1.8636e-05 - val_NMSE: 1.5232e-04 - val_real_MSE: 3.3422e-05 - val_params_MSE: 3.8488e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 29: early stopping
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 1e-05 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9558e-04 - mse: 1.8985e-05 - NMSE: 1.5627e-04 - real_MSE: 3.4322e-05 - params_MSE: 3.6480e-06 - ls_jacobian_norm: 1.5582 - tot_time: 0h 41m 35.2s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9557e-04 - mse: 1.8984e-05 - NMSE: 1.5627e-04 - real_MSE: 3.4321e-05 - params_MSE: 3.6474e-06 - ls_jacobian_norm: 1.5582 - val_loss: 1.9222e-04 - val_mse: 1.5627e-05 - val_NMSE: 1.2559e-04 - val_real_MSE: 2.7491e-05 - val_params_MSE: 3.7643e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 2/200
# 4995/5001 [============================>.] - ETA: 0s - loss: 1.9556e-04 - mse: 1.8966e-05 - NMSE: 1.5614e-04 - real_MSE: 3.4294e-05 - params_MSE: 3.6389e-06 - ls_jacobian_norm: 1.5580 - tot_time: 0h 42m 11.1s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9556e-04 - mse: 1.8965e-05 - NMSE: 1.5613e-04 - real_MSE: 3.4292e-05 - params_MSE: 3.6392e-06 - ls_jacobian_norm: 1.5580 - val_loss: 1.9236e-04 - val_mse: 1.5761e-05 - val_NMSE: 1.2687e-04 - val_real_MSE: 2.7777e-05 - val_params_MSE: 3.7461e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 3/200
# 4999/5001 [============================>.] - ETA: 0s - loss: 1.9554e-04 - mse: 1.8946e-05 - NMSE: 1.5598e-04 - real_MSE: 3.4258e-05 - params_MSE: 3.6349e-06 - ls_jacobian_norm: 1.5579 - tot_time: 0h 42m 46.3s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9554e-04 - mse: 1.8947e-05 - NMSE: 1.5598e-04 - real_MSE: 3.4258e-05 - params_MSE: 3.6351e-06 - ls_jacobian_norm: 1.5578 - val_loss: 1.9219e-04 - val_mse: 1.5595e-05 - val_NMSE: 1.2539e-04 - val_real_MSE: 2.7449e-05 - val_params_MSE: 3.7402e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 4/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9553e-04 - mse: 1.8943e-05 - NMSE: 1.5598e-04 - real_MSE: 3.4261e-05 - params_MSE: 3.6258e-06 - ls_jacobian_norm: 1.5576 - tot_time: 0h 43m 21.9s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9553e-04 - mse: 1.8941e-05 - NMSE: 1.5597e-04 - real_MSE: 3.4257e-05 - params_MSE: 3.6255e-06 - ls_jacobian_norm: 1.5576 - val_loss: 1.9220e-04 - val_mse: 1.5613e-05 - val_NMSE: 1.2556e-04 - val_real_MSE: 2.7487e-05 - val_params_MSE: 3.7385e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 5/200
# 4996/5001 [============================>.] - ETA: 0s - loss: 1.9552e-04 - mse: 1.8934e-05 - NMSE: 1.5590e-04 - real_MSE: 3.4242e-05 - params_MSE: 3.6262e-06 - ls_jacobian_norm: 1.5575 - tot_time: 0h 43m 57.7s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9552e-04 - mse: 1.8932e-05 - NMSE: 1.5588e-04 - real_MSE: 3.4238e-05 - params_MSE: 3.6264e-06 - ls_jacobian_norm: 1.5575 - val_loss: 1.9222e-04 - val_mse: 1.5619e-05 - val_NMSE: 1.2563e-04 - val_real_MSE: 2.7502e-05 - val_params_MSE: 3.7363e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 6/200
# 4994/5001 [============================>.] - ETA: 0s - loss: 1.9552e-04 - mse: 1.8932e-05 - NMSE: 1.5590e-04 - real_MSE: 3.4241e-05 - params_MSE: 3.6224e-06 - ls_jacobian_norm: 1.5571 - tot_time: 0h 44m 33.3s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9552e-04 - mse: 1.8932e-05 - NMSE: 1.5589e-04 - real_MSE: 3.4241e-05 - params_MSE: 3.6237e-06 - ls_jacobian_norm: 1.5571 - val_loss: 1.9223e-04 - val_mse: 1.5648e-05 - val_NMSE: 1.2591e-04 - val_real_MSE: 2.7565e-05 - val_params_MSE: 3.7314e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 7/200
# 5001/5001 [==============================] - ETA: 0s - loss: 1.9550e-04 - mse: 1.8922e-05 - NMSE: 1.5584e-04 - real_MSE: 3.4229e-05 - params_MSE: 3.6161e-06 - ls_jacobian_norm: 1.5570 - tot_time: 0h 45m 8.3s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9550e-04 - mse: 1.8922e-05 - NMSE: 1.5584e-04 - real_MSE: 3.4229e-05 - params_MSE: 3.6161e-06 - ls_jacobian_norm: 1.5570 - val_loss: 1.9213e-04 - val_mse: 1.5546e-05 - val_NMSE: 1.2493e-04 - val_real_MSE: 2.7346e-05 - val_params_MSE: 3.7458e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 8/200
# 5000/5001 [============================>.] - ETA: 0s - loss: 1.9549e-04 - mse: 1.8918e-05 - NMSE: 1.5579e-04 - real_MSE: 3.4219e-05 - params_MSE: 3.6175e-06 - ls_jacobian_norm: 1.5570 - tot_time: 0h 45m 44.1s
# 5001/5001 [==============================] - 36s 7ms/step - loss: 1.9549e-04 - mse: 1.8918e-05 - NMSE: 1.5579e-04 - real_MSE: 3.4219e-05 - params_MSE: 3.6175e-06 - ls_jacobian_norm: 1.5570 - val_loss: 1.9227e-04 - val_mse: 1.5695e-05 - val_NMSE: 1.2636e-04 - val_real_MSE: 2.7667e-05 - val_params_MSE: 3.7236e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 9/200
# 4998/5001 [============================>.] - ETA: 0s - loss: 1.9546e-04 - mse: 1.8893e-05 - NMSE: 1.5557e-04 - real_MSE: 3.4171e-05 - params_MSE: 3.6157e-06 - ls_jacobian_norm: 1.5570 - tot_time: 0h 46m 19.4s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9546e-04 - mse: 1.8892e-05 - NMSE: 1.5556e-04 - real_MSE: 3.4168e-05 - params_MSE: 3.6156e-06 - ls_jacobian_norm: 1.5570 - val_loss: 1.9219e-04 - val_mse: 1.5617e-05 - val_NMSE: 1.2567e-04 - val_real_MSE: 2.7513e-05 - val_params_MSE: 3.7204e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 10/200
# 4997/5001 [============================>.] - ETA: 0s - loss: 1.9544e-04 - mse: 1.8872e-05 - NMSE: 1.5541e-04 - real_MSE: 3.4134e-05 - params_MSE: 3.6094e-06 - ls_jacobian_norm: 1.5568 - tot_time: 0h 46m 54.9s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9544e-04 - mse: 1.8874e-05 - NMSE: 1.5542e-04 - real_MSE: 3.4138e-05 - params_MSE: 3.6102e-06 - ls_jacobian_norm: 1.5569 - val_loss: 1.9222e-04 - val_mse: 1.5654e-05 - val_NMSE: 1.2598e-04 - val_real_MSE: 2.7582e-05 - val_params_MSE: 3.7258e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 11/200
# 5001/5001 [==============================] - ETA: 0s - loss: 1.9544e-04 - mse: 1.8875e-05 - NMSE: 1.5544e-04 - real_MSE: 3.4142e-05 - params_MSE: 3.6086e-06 - ls_jacobian_norm: 1.5567Restoring model weights from the end of the best epoch: 1.
#  - tot_time: 0h 47m 30.1s
# 5001/5001 [==============================] - 35s 7ms/step - loss: 1.9544e-04 - mse: 1.8875e-05 - NMSE: 1.5544e-04 - real_MSE: 3.4142e-05 - params_MSE: 3.6086e-06 - ls_jacobian_norm: 1.5567 - val_loss: 1.9214e-04 - val_mse: 1.5582e-05 - val_NMSE: 1.2537e-04 - val_real_MSE: 2.7446e-05 - val_params_MSE: 3.7175e-06 - val_ls_jacobian_norm: -1.0000
# Epoch 11: early stopping

# %%
temp = []
for lst in train_ls_jacobian_norm_hist:
    temp.extend(lst)
train_ls_jacobian_norm_hist_og = train_ls_jacobian_norm_hist
train_ls_jacobian_norm_hist = np.array(temp)

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    test_metrics = ae_net.evaluate(
        testing_data, testing_data,
    )
    train_metrics = ae_net.evaluate(training_data, training_data)
    val_metrics = ae_net.evaluate(val_data, val_data)

    save_path = dir_name_ae+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'val_MSE_hist':val_MSE_hist,
            'train_MSE_hist':train_MSE_hist,
            'val_NMSE_hist':val_NMSE_hist,
            'train_NMSE_hist':train_NMSE_hist,
            'train_ls_jacobian_norm_hist':train_ls_jacobian_norm_hist,
            'lr_change':lr_change,
            'test_loss':test_metrics[0],
            'test_mse':test_metrics[1],
            'train_loss':train_metrics[0],
            'train_mse':train_metrics[1],
            'val_loss':val_metrics[0],
            'val_mse':val_metrics[1],
        }))

    ae_net.save_everything(
        file_name=save_path+dir_sep+'final_net')
# Out:
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9188e-04 - mse: 1.5284e-05 - NMSE: 1.2437e-04 - real_MSE: 2.7272e-05 - params_MSE: 3.2960e-06 - ls_jacobian_norm: -1.0000
# 10001/10001 [==============================] - 39s 4ms/step - loss: 1.9246e-04 - mse: 1.5866e-05 - NMSE: 1.2821e-04 - real_MSE: 2.8087e-05 - params_MSE: 3.6458e-06 - ls_jacobian_norm: -1.0000
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9222e-04 - mse: 1.5627e-05 - NMSE: 1.2559e-04 - real_MSE: 2.7491e-05 - params_MSE: 3.7643e-06 - ls_jacobian_norm: -1.0000

# %%
print('lr_change : ', lr_change)
# Out:
# lr_change :  [0, 45, 74, 85]

# %%
# plotting losses
dir_name_plot = dir_name_ae + '/plots'
if not os.path.isdir(dir_name_plot):
    os.makedirs(dir_name_plot)

xlabel_kwargs = {"fontsize":15}
ylabel_kwargs = {"fontsize":15}
legend_kwargs = {"fontsize":12}
    
# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
)

plt.savefig(dir_name_plot + '{ds}loss_history.pdf'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()


fig, ax = plot_losses(
    training_loss=train_MSE_hist,
    val_loss=val_MSE_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=['Training MSE', 'Validation MSE'],
    xlabel='Epoch',
    ylabel='MSE',
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
    
)
plt.savefig(dir_name_plot+'/MSE_history.pdf', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_NMSE_hist,
    val_loss=val_NMSE_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=['Training NMSE', 'Validation NMSE'],
    xlabel='Epoch',
    ylabel='NMSE',
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
)
plt.savefig(dir_name_plot+'/NMSE_history.pdf', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_ls_jacobian_norm_hist,
    val_loss=None,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=[r"$\| \nabla_{x} z^{encoded} \|$"],
    xlabel='Epoch',
    ylabel=r"$\| \nabla_{x} v^{encoded} \|$",
    plot_type='plot',
    xlabel_kwargs=xlabel_kwargs,
    ylabel_kwargs=ylabel_kwargs,
    legend_kwargs=legend_kwargs,
)
plt.savefig(dir_name_plot+'/train_ls_jacobian_norm_hist.pdf', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()

# %%
reconstructed_data = ae_net.predict(all_data)

# %%
plot_reconstructed_data_cdv(
    boundary_idx_arr,
    dir_name_ae,
    all_data,
    reconstructed_data,
    params_mat,
    dt_ae,
    save_figs=True,
    xlabel_kwargs={'fontsize': 15},
    ylabel_kwargs={'fontsize': 15},
    title_kwargs={'fontsize': 18},
    legend_kwargs={'fontsize': 12},
    save_extension='png',
)

# %%
final_idx = int(1000/dt_ae)
plot_reconstructed_data_cdv(
    [final_idx],# boundary_idx_arr,
    dir_name_ae,
    all_data[0:final_idx, :],
    reconstructed_data[0:final_idx, :],
    params_mat,
    dt_ae,
    save_figs=True,
    xlabel_kwargs={'fontsize': 15},
    ylabel_kwargs={'fontsize': 15},
    title_kwargs={'fontsize': 18},
    legend_kwargs={'fontsize': 12},
    save_extension='pdf',
)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data)

# %%
fig, ax = plot_latent_states_cdv(
    boundary_idx_arr,
    latent_states_all,
    dt_ae,
    params_mat,
    save_config_path=dir_name_plot,
    xlabel_kwargs={'fontsize':15},
    ylabel_kwargs={'fontsize':15},
    legend_kwargs={'fontsize':12},
    title_kwargs={'fontsize':18},
)

fig.savefig(dir_name_plot+'/latent_states.png', dpi=300, bbox_inches='tight')

# %%
final_idx = int(1000/dt_ae)
new_data = np.empty(shape=(len(boundary_idx_arr)*final_idx,)+latent_states_all.shape[1:])
new_boundary_idx_arr = np.empty_like(boundary_idx_arr)
begin_idx = 0
new_begin_idx = 0
for i in range(boundary_idx_arr.shape[0]):
    new_data[new_begin_idx:new_begin_idx+final_idx] = latent_states_all[begin_idx:begin_idx+final_idx]
    begin_idx = boundary_idx_arr[i]
    new_boundary_idx_arr[i] = new_begin_idx+final_idx
    new_begin_idx = new_boundary_idx_arr[i]

fig, ax = plot_latent_states_cdv(
    new_boundary_idx_arr, #boundary_idx_arr,
    new_data,
    dt_ae,
    params_mat,
    save_config_path=dir_name_plot,
    xlabel_kwargs={'fontsize':15},
    ylabel_kwargs={'fontsize':15},
    legend_kwargs={'fontsize':12},
    title_kwargs={'fontsize':18},
)

fig.savefig(dir_name_plot+'/latent_states.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# # KE and Dissipation

# %%
if ae_net.use_weights_post_dense == True:
    print(ae_net.decoder_layers_list[-1].individual_weights)
# Out:
# <tf.Variable 'single_weights/individual_weights:0' shape=(12,) dtype=float32, numpy=
# array([ 1.3421261e+00,  1.4936506e+00,  1.2129383e+00,  1.5486168e+00,
#         2.0466380e+00,  1.4487588e+00,  1.1483769e+00,  1.0504503e+00,
#         1.2191663e+00, -3.0957014e-32,  1.2191647e+00,  1.2290338e-30],
#       dtype=float32)>
