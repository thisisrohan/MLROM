# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz

# %%
from tools.misc_tools import create_Lorenz_data, create_data_for_RNN, mytimecallback, SaveLosses, plot_losses, plot_reconstructed_data, plot_latent_states, readAndReturnLossHistories, sigmoidWarmupAndDecayLRSchedule
from tools.ae_v3 import Autoencoder
from tools.LSTM_AR_v2 import AR_RNN_LSTM as RNN_LSTM

# %%
# behaviour = 'initialiseAndTrainFromScratch'
behaviour = 'loadCheckpointAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
# setting seed for PRNGs
if behaviour == 'initialiseAndTrainFromScratch':
    prng_seed = 42
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
print(tf.test.gpu_device_name())
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# # Lorenz System

# %%
# setting up params (and saving, if applicable)
from numpy import *

if behaviour == 'initialiseAndTrainFromScratch':
    # making RNN save directory
    dir_name_rnn = os.getcwd() + dir_sep + 'saved_rnn'
    if not os.path.isdir(dir_name_rnn):
        os.makedirs(dir_name_rnn)

    counter = 0
    while True:
        dir_check = 'rnn_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_rnn + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_rnn = dir_name_rnn + dir_sep + dir_check
    os.makedirs(dir_name_rnn)
    os.makedirs(dir_name_rnn+dir_sep+'plots')

    # autoencoder directory
    ae_idx = '010'
    dir_name_ae = os.getcwd()+'{ds}saved_ae{ds}ae_'.format(ds=dir_sep)+ae_idx

    # reading simulation parameters
    with open(dir_name_ae + dir_sep + 'sim_data_params.txt') as f:
        lines = f.readlines()

    params_dict = eval(lines[0])

    rho_arr = params_dict['rho_arr']
    sigma_arr = params_dict['sigma_arr']
    beta_arr = params_dict['beta_arr']

    x0 = params_dict['x0']
    y0 = params_dict['y0']
    z0 = params_dict['z0']

    t0 = params_dict['t0']
    T = 5*params_dict['T']
    delta_t = params_dict['delta_t']

    return_params_arr = params_dict['return_params_arr']
    normalize_flag = params_dict['normalize_flag']
else:
    # RNN directory
    dir_name_rnn = os.getcwd()+'/saved_rnn/rnn_012'

    # reading simulation parameters
    with open(dir_name_rnn + '/sim_data_AE_params.txt') as f:
        lines = f.readlines()

    params_dict = eval(''.join(lines))

    dir_name_ae = params_dict['dir_name_ae']
    ae_idx = dir_name_ae[-3:]

    rho_arr = params_dict['rho_arr']
    sigma_arr = params_dict['sigma_arr']
    beta_arr = params_dict['beta_arr']

    x0 = params_dict['x0']
    y0 = params_dict['y0']
    z0 = params_dict['z0']

    t0 = params_dict['t0']
    T = params_dict['T']
    delta_t = params_dict['delta_t']

    normalize_flag = params_dict['normalize_flag']

    # reading RNN paramaters
    with open(dir_name_rnn + '/RNN_specific_data.txt') as f:
        lines = f.readlines()

    params_rnn_dict = eval(''.join(lines))

    dt_rnn = params_rnn_dict['dt_rnn']
    T_sample_input = params_rnn_dict['T_sample_input']
    T_sample_output = params_rnn_dict['T_sample_output']
    T_offset = params_rnn_dict['T_offset']
    return_params_arr = params_rnn_dict['return_params_arr']
    params = params_rnn_dict['params']

# %%
res_dict = create_Lorenz_data(
    T, t0, delta_t,
    rho_arr, sigma_arr, beta_arr,
    x0, y0, z0, return_params_arr=return_params_arr,
    normalize=normalize_flag
)

all_data = res_dict['all_data']
N = res_dict['N']
boundary_idx_arr = res_dict['boundary_idx_arr']

if return_params_arr == True:
    params_arr = res_dict['params_arr']

if normalize_flag == True:
    normalization_constant_arr = res_dict['normalization_constant_arr']

# %%
n = len(boundary_idx_arr)

# %% [markdown]
# # Autoencoder

# %%
from tools.ae_v3 import Autoencoder

# %%
# load_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_class_dict.txt'
# wt_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_ae_weights.h5'

load_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_class_dict.txt'
wt_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_ae_weights.h5'

# %%
ae_net = Autoencoder(6, load_file=load_file)
ae_net.load_weights_from_file(wt_file)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data)

# %%
fig, ax = plot_latent_states(
    boundary_idx_arr=boundary_idx_arr,
    latent_states_all=latent_states_all,
    all_data=all_data,
    xlim=[-1,1],
    ylim=[-1,1],
    cmap_name='jet')

# %%
# for i in range(ae_net.layers):
#     tf.keras.utils.plot_model(
#         ae_net.layers[i],
#         to_file=dir_name_ae+'/plots/netlayer_{}.png'.format(i),
#         show_shapes=True,
#         dpi=300
# )

# %% [markdown]
# # LSTM

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    # RNN data parameters
    dt_rnn = 0.01
    T_sample_input = dt_rnn
    T_sample_output = 4
    T_offset = dt_rnn
    if return_params_arr != False:
        params = params_arr
    else:
        params = None

    # saving simulation data
    sim_data = {
        'rho_arr':rho_arr,
        'sigma_arr':sigma_arr,
        'beta_arr':beta_arr,
        'x0':x0,
        'y0':y0,
        'z0':z0,
        't0':t0,
        'T':T,
        'delta_t':delta_t,
        'dir_name_ae':dir_name_ae,
        'normalize_flag':normalize_flag
    }


    with open(dir_name_rnn+dir_sep+'sim_data_AE_params.txt', 'w') as f:
        f.write(str(sim_data))
        
    # saving RNN specific data
    RNN_specific_data = {
        'dt_rnn':dt_rnn,
        'T_sample_input':T_sample_input,
        'T_sample_output':T_sample_output,
        'T_offset':T_offset,
        'N':N,
        'boundary_idx_arr':boundary_idx_arr,
        'delta_t':delta_t,
        'params':params,
        'return_params_arr':return_params_arr
    }

    with open(dir_name_rnn+dir_sep+'RNN_specific_data.txt', 'w') as f:
        f.write(str(RNN_specific_data))

# %%
data_rnn_input, data_rnn_output, org_data_idx_arr_input, org_data_idx_arr_output, num_samples = create_data_for_RNN(
    latent_states_all,
    dt_rnn,
    T_sample_input,
    T_sample_output,
    T_offset,
    N,
    boundary_idx_arr,
    delta_t,
    params=params,
    return_numsamples=True)

# %%
# setting up training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_dict = {
        'eta_begin':0.0001,
        'eta_high':0.001,
        'eta_low':0.00001
    }
    epochs = 1000
    patience = 50  # parameter for early stopping
    min_delta = 1e-6  # parameter for early stopping
    lambda_reg = 1e-5  # weight for regularizer
    train_split = 0.8
    val_split = 0.1
    test_split = 1 - train_split - val_split
    batch_size = 64

    # saving training params
    training_specific_params = {
        'learning_rate_dict':learning_rate_dict,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size
    }

    with open(dir_name_rnn+dir_sep+'training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))
else:
    with open(dir_name_rnn + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()

    tparams_dict = eval(''.join(lines))

    learning_rate_dict = tparams_dict['learning_rate_dict']
    epochs = tparams_dict['epochs']
    patience = tparams_dict['patience']
    min_delta = tparams_dict['min_delta']
    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']

    test_split = 1 - train_split - val_split

    # setting seed for PRNGs
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
# idx = np.arange(data_rnn_input.shape[0])
# np.random.shuffle(idx)
# boundary = int(np.round(train_split*data_rnn_input.shape[0]))

# training_data_rnn_input = data_rnn_input[idx[0:boundary]]
# training_data_rnn_output = data_rnn_output[idx[0:boundary]]

# testing_data_rnn_input = data_rnn_input[idx[boundary:]]
# testing_data_rnn_output = data_rnn_output[idx[boundary:]]

# %%
idx = np.arange(num_samples)
# np.random.shuffle(idx)
boundary = int(np.round(
    (1-test_split) * num_samples
))

# defining shapes
training_input_shape = [boundary*len(boundary_idx_arr)]
training_input_shape.extend(data_rnn_input.shape[1:])

training_output_shape = [boundary*len(boundary_idx_arr)]
training_output_shape.extend(data_rnn_output.shape[1:])

testing_input_shape = [(num_samples-boundary)*len(boundary_idx_arr)]
testing_input_shape.extend(data_rnn_input.shape[1:])

testing_output_shape = [(num_samples-boundary)*len(boundary_idx_arr)]
testing_output_shape.extend(data_rnn_output.shape[1:])

# defining required arrays
training_data_rnn_input = np.empty(shape=training_input_shape)
training_data_rnn_output = np.empty(shape=training_output_shape)

testing_data_rnn_input = np.empty(shape=testing_input_shape)
testing_data_rnn_output = np.empty(shape=testing_output_shape)

for i in range(len(boundary_idx_arr)):
    np.random.shuffle(idx)

    training_data_rnn_input[i*boundary:(i+1)*boundary] = data_rnn_input[i*num_samples + idx[0:boundary]]
    training_data_rnn_output[i*boundary:(i+1)*boundary] = data_rnn_output[i*num_samples + idx[0:boundary]]

    testing_data_rnn_input[i*(num_samples-boundary):(i+1)*(num_samples-boundary)] = data_rnn_input[i*num_samples + idx[boundary:]]
    testing_data_rnn_output[i*(num_samples-boundary):(i+1)*(num_samples-boundary)] = data_rnn_output[i*num_samples + idx[boundary:]]

# further shuffling
idx = np.arange(0, training_data_rnn_input.shape[0])
np.random.shuffle(idx)
training_data_rnn_input = training_data_rnn_input[idx]
training_data_rnn_output = training_data_rnn_output[idx]

idx = np.arange(0, testing_data_rnn_input.shape[0])
np.random.shuffle(idx)
testing_data_rnn_input = testing_data_rnn_input[idx]
testing_data_rnn_output = testing_data_rnn_output[idx]

# %%
# Initialize network
if behaviour == 'initialiseAndTrainFromScratch':
    rnn_layers_units = [2**6]*2
    if return_params_arr != False:
        data_dim = 5
    else:
        data_dim = 2

    rnn_net = RNN_LSTM(
        data_dim=data_dim,
    #     in_steps=int(T_sample_input // dt_rnn),
    #     out_steps=int(T_sample_output // dt_rnn),
        dt_rnn=dt_rnn,
        lambda_reg=lambda_reg,
        reg_name='L2',
        rnn_layers_units=rnn_layers_units,
        dense_layer_act_func='linear',
        load_file=None,
        T_input=T_sample_input,
        T_output=T_sample_output
    )
    save_path = dir_name_rnn+dir_sep+'final_net'
    if not os.path.isdir(save_path):
        os.makedirs(save_path)
    rnn_net.save_class_dict(save_path+dir_sep+'final_net_class_dict.txt')
else:
    load_file = dir_name_rnn + dir_sep + 'final_net' + dir_sep + 'final_net_class_dict.txt'
    rnn_net = RNN_LSTM(
        load_file=load_file,
        T_input=T_sample_input,
        T_output=T_sample_output
    )
    
    if behaviour == 'loadCheckpointAndContinueTraining':
        wt_file = tf.train.latest_checkpoint(dir_name_rnn+dir_sep+'checkpoints')
    elif behaviour == 'loadFinalNetAndPlot':
        wt_file = dir_name_rnn+dir_sep+'final_net'+dir_sep+'final_net_lstm_weights.h5'
        # wt_file = dir_name_rnn+dir_sep+'final_net'+dir_sep+'f2'#+dir_sep+'saved_model.pb'
    
    # this forces the model to initialize its kernel weights/biases
    temp = rnn_net.predict(tf.ones(shape=[batch_size, int(T_sample_input//dt_rnn), rnn_net.data_dim]))
    # this loads just the kernel wieghts and biases of the model
    rnn_net.load_weights_from_file(wt_file)

    # rnn_net = tf.keras.models.load_model(wt_file)

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs)*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs)*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
    earlystopping_wait = 0
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt, earlystopping_wait = readAndReturnLossHistories(
        dir_name_ae=dir_name_rnn,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=[0],
        return_earlystopping_wait=True)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_rnn+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
# compiling the network
rnn_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_dict['eta_begin']),
    loss=losses.MeanSquaredError(),
    run_eagerly=False
)

if behaviour == 'loadCheckpointAndContinueTraining':
    # this loads the weights/attributes of the optimizer as well
    rnn_net.load_weights(wt_file)

if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    # implementing early stopping
    baseline = None
    if behaviour == 'loadCheckpointAndContinueTraining':
        baseline = np.min(val_loss_hist)
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        restore_best_weights=True,
        verbose=True,
        min_delta=min_delta,
        baseline=baseline
    )
    # the below two lines are useless because wait is set to 0 in on_train_begin
    # early_stopping_cb.wait = earlystopping_wait
    # print('early_stopping_cb.wait : {}\n'.format(early_stopping_cb.wait))

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_rnn+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        initial_value_threshold=baseline,
        period=1  # saves every 5 epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=1)
    savelosses_cb.update_offset(epochs - num_epochs_left)

    # sigmoid annealing lr schedule
    lrschedule_cb = sigmoidWarmupAndDecayLRSchedule(
        eta_begin=learning_rate_dict['eta_begin'],
        eta_high=learning_rate_dict['eta_high'],
        eta_low=learning_rate_dict['eta_low'],
        warmup=20,
        expected_epochs=200,
        g_star=0.999,
        f_star=0.001
    )
    lrschedule_cb.update_offset(epochs - num_epochs_left)

    # training the network    
    history = rnn_net.fit(training_data_rnn_input, training_data_rnn_output,
        epochs=num_epochs_left,
        batch_size=batch_size,
        validation_split=val_split/(train_split+val_split),
        callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb, lrschedule_cb],
        verbose=1
    )

    val_loss_hist.extend(history.history['val_loss'])
    train_loss_hist.extend(history.history['loss'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 0h 10m 4.1s
#
# Epoch 1: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 604s 395ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 2/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 0h 18m 4.1s
#
# Epoch 2: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 481s 387ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 3/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 26m 4.8s
#
# Epoch 3: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 480s 387ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 4/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 0h 34m 6.5s
#
# Epoch 4: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 482s 388ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 5/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 0h 42m 8.7s
#
# Epoch 5: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 482s 389ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 6/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 50m 10.8s
#
# Epoch 6: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 482s 388ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 7/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 0h 58m 13.2s
#
# Epoch 7: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 482s 389ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 8/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0032 - tot_time: 1h 6m 18.6s
#
# Epoch 8: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 485s 391ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 9/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0028 - tot_time: 1h 14m 22.5s
#
# Epoch 9: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 484s 390ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 10/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 22m 26.1s
#
# Epoch 10: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 484s 390ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 11/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 30m 36.4s
#
# Epoch 11: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 12/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 1h 38m 48.3s
#
# Epoch 12: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 492s 396ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 13/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 1h 46m 57.9s
#
# Epoch 13: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 14/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 1h 55m 8.5s
#
# Epoch 14: val_loss did not improve from 0.00203
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 491s 395ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 15/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 2h 3m 17.7s
#
# Epoch 15: val_loss improved from 0.00203 to 0.00200, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 489s 394ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 16/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 2h 11m 27.7s
#
# Epoch 16: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 17/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 2h 19m 36.5s
#
# Epoch 17: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 489s 394ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 18/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 2h 27m 45.8s
#
# Epoch 18: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 489s 394ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 19/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 2h 35m 54.9s
#
# Epoch 19: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 489s 394ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 20/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 2h 44m 5.0s
#
# Epoch 20: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 21/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 2h 52m 14.8s
#
# Epoch 21: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 22/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 0m 24.8s
#
# Epoch 22: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 23/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 8m 35.4s
#
# Epoch 23: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 491s 395ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 24/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 3h 16m 43.5s
#
# Epoch 24: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 488s 393ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 25/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 24m 53.9s
#
# Epoch 25: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 26/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 33m 6.1s
#
# Epoch 26: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 492s 397ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 27/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 41m 17.1s
#
# Epoch 27: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 491s 396ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 28/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 49m 25.7s
#
# Epoch 28: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 489s 394ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 29/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 3h 57m 32.8s
#
# Epoch 29: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 487s 392ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 30/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 4h 5m 50.5s
#
# Epoch 30: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 498s 401ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 31/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 4h 14m 3.0s
#
# Epoch 31: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 492s 397ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 32/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 4h 22m 19.3s
#
# Epoch 32: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 496s 400ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 33/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 4h 30m 37.2s
#
# Epoch 33: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 498s 401ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 34/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 4h 38m 50.3s
#
# Epoch 34: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 493s 397ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 35/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 4h 47m 4.0s
#
# Epoch 35: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 494s 398ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 36/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 4h 55m 16.4s
#
# Epoch 36: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 492s 397ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 37/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 5h 3m 30.3s
#
# Epoch 37: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 494s 398ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 38/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 5h 11m 49.8s
#
# Epoch 38: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 499s 402ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 39/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 5h 20m 7.2s
#
# Epoch 39: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 497s 401ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 40/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 5h 28m 22.6s
#
# Epoch 40: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 495s 399ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 41/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 5h 36m 36.7s
#
# Epoch 41: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 494s 398ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 42/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 5h 44m 54.7s
#
# Epoch 42: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 498s 401ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 43/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 5h 53m 13.0s
#
# Epoch 43: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 498s 401ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 44/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 6h 1m 29.2s
#
# Epoch 44: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 496s 400ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 45/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 6h 9m 42.2s
#
# Epoch 45: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 493s 397ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 46/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 6h 17m 57.5s
#
# Epoch 46: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 495s 399ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 47/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 6h 26m 7.5s
#
# Epoch 47: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 48/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 34m 17.2s
#
# Epoch 48: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 490s 395ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 49/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 6h 42m 28.1s
#
# Epoch 49: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 491s 396ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 50/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 6h 50m 40.6s
#
# Epoch 50: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 492s 397ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 51/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 6h 59m 5.2s
#
# Epoch 51: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 505s 407ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 52/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 7h 7m 28.8s
#
# Epoch 52: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 504s 406ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 53/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 7h 15m 43.9s
#
# Epoch 53: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 495s 399ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 54/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 7h 23m 58.4s
#
# Epoch 54: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 495s 398ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 55/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 7h 32m 12.1s
#
# Epoch 55: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 494s 398ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 56/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 7h 40m 26.4s
#
# Epoch 56: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 494s 398ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 57/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 7h 48m 38.3s
#
# Epoch 57: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 492s 396ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 58/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 7h 56m 49.0s
#
# Epoch 58: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 491s 395ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 59/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 8h 4m 57.0s
#
# Epoch 59: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 488s 393ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 60/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 8h 13m 5.1s
#
# Epoch 60: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 488s 393ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 61/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 8h 21m 11.7s
#
# Epoch 61: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 487s 392ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 62/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 8h 29m 20.0s
#
# Epoch 62: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 488s 393ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 63/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 8h 37m 25.8s
#
# Epoch 63: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 486s 392ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 64/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0020 - tot_time: 8h 45m 34.8s
#
# Epoch 64: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 489s 394ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 65/424
# 1241/1241 [==============================] - ETA: 0s - loss: 0.0021Restoring model weights from the end of the best epoch: 15.
#  - tot_time: 8h 53m 42.9s
#
# Epoch 65: val_loss did not improve from 0.00200
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_rnn/rnn_012/checkpoints/LossHistoriesCheckpoint
# 1241/1241 [==============================] - 488s 393ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 65: early stopping

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining' or True:
    test_loss = rnn_net.evaluate(
        testing_data_rnn_input, testing_data_rnn_output,
    )

    save_path = dir_name_rnn+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'lr_change':lr_change,
            'test_loss':test_loss
        }))

    rnn_net.save_everything(
        file_name=save_path+dir_sep+'final_net',
        H5=True)

    # tf.saved_model.save(rnn_net, save_path+dir_sep+'final_net')
    # rnn_net.save_weights(save_path+dir_sep+'final_net.h5')
# Out:
# 310/310 [==============================] - 33s 74ms/step - loss: 0.0020

# %%
# rnn_net.save_weights(save_path+dir_sep+'final_net_lstm_weights')
# rnn_net.save(save_path+dir_sep+'f2')

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
# plotting losses

# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=None
)

plt.savefig(dir_name_rnn+'{ds}plots{ds}loss_history.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()

# %%
data_idx = np.arange(testing_data_rnn_output.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 10
print('data_idx : {}'.format(data_idx))


plt.plot(testing_data_rnn_output[data_idx, :, 0], testing_data_rnn_output[data_idx, :, 1])
prediction = rnn_net.predict(testing_data_rnn_input[data_idx:data_idx+1, :, :])
plt.plot(prediction[0, :, 0], prediction[0, :, 1])

plt.grid(True)
plt.show()
# Out:
# data_idx : 4499

# %%
data_type = 'training'
# data_type = 'testing'

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 10
print('data_idx : {}'.format(data_idx))

### initial point
plt.plot(data_in[data_idx, :, 0], data_in[data_idx, :, 1], 'o')

### actual trajectory
plt.plot(data_out[data_idx, 0, 0], data_out[data_idx, 0, 1], 'o')
plt.plot(data_out[data_idx, :, 0], data_out[data_idx, :, 1], 'C1')

### predicted trajectory
prediction = rnn_net.predict(data_in[data_idx:data_idx+1, :, :])
# plt.plot([data_in[data_idx, :, 0], ].extend(prediction[0, :, 0]), [data_in[data_idx, :, 1], ].extend(prediction[0, :, 1]))
plt.plot(prediction[0, :, 0], prediction[0, :, 1])
plt.plot(prediction[0, 0, 0], prediction[0, 0, 1], 'o', color='C2')

plt.grid(True)
plt.show()
# Out:
# data_idx : 18841

# %%
data_out[data_idx].shape
# Out:
# (400, 2)
