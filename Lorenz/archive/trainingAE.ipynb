# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz

# %%
# setting seed for PRNGs
prng_seed = 42
np.random.seed(prng_seed)
tf.random.set_seed(prng_seed)

# %%
tf.test.gpu_device_name()
# Out:
# ''

# %% [markdown]
# # Lorenz System

# %%
from tools.misc_tools import create_Lorenz_data

# %%
# setting up params
sigma_arr = np.array([10, 15, 20])
rho_arr = np.array([20, 25, 30])
beta_arr = np.array([4/3, 6/3, 8/3])

x0 = 1
y0 = 1
z0 = 1

t0 = 0.0
T = 100.0
delta_t = 0.01

return_params_arr = False
normalize_flag = True

# %%
res_dict = create_Lorenz_data(
    T, t0, delta_t,
    rho_arr, sigma_arr, beta_arr,
    x0, y0, z0, return_params_arr=return_params_arr,
    normalize=normalize_flag
)

all_data = res_dict['all_data']
N = res_dict['N']
boundary_idx_arr = res_dict['boundary_idx_arr']

if return_params_arr == True:
    params_arr = res_dict['params_arr']

if normalize_flag == True:
    normalization_constant_arr = res_dict['normalization_constant_arr']

# %%
n = len(boundary_idx_arr)
# # '''
# num_cols = 1
# num_rows = n

# fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

# prev_idx = 0
# for i in range(n):
#     # ax = plt.axes(projection ='3d')
#     next_idx = boundary_idx_arr[i]
    
#     ax_orig = fig.add_subplot(num_rows, num_cols, i+1, projection ='3d')
#     ax_orig.plot(all_data[prev_idx:next_idx, 0], all_data[prev_idx:next_idx, 1], all_data[prev_idx:next_idx, 2])
#     ax_orig.title.set_text(r'Actual Data - [$\sigma$, $\rho$, $\beta$] = ' + str(all_data[next_idx-1, 3:]))
#     ax_orig.set_xlabel('x')
#     ax_orig.set_ylabel('y')
#     ax_orig.set_zlabel('z')
    
#     # ax_predict = fig.add_subplot(num_rows, num_cols, 2*i+2, projection ='3d')
#     # ax_predict.plot(reconstructed_data[prev_idx:next_idx, 0], reconstructed_data[prev_idx:next_idx, 1], reconstructed_data[prev_idx:next_idx, 2])
#     # ax_predict.title.set_text(r'NN Reconstructed Data - [$\sigma$, $\rho$, $\beta$] = ' + str(all_data[next_idx-1, 3:])
#     # )
#     # ax_predict.set_xlabel('x')
#     # ax_predict.set_ylabel('y')
#     # ax_predict.set_zlabel('z')

#     prev_idx = next_idx
# # '''

# %% [markdown]
# # Autoencoder

# %%
# setting up data
train_split = 0.8
val_split = 0.1  # to be used later on;
                 # `val_split` of total data will
                 # be taken out of `training_data`
                 # to use as validation data.
test_split = 1 - train_split - val_split


idx = np.arange(all_data.shape[0])
np.random.shuffle(idx)
boundary = int(np.round((1-test_split)*all_data.shape[0]))
training_data = all_data[idx[0:boundary], :]
testing_data = all_data[idx[boundary:], :]

# train_dataset = tf.data.Dataset.from_tensor_slices((training_data, training_data))
# test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_data))

batch_size = 64
# SHUFFLE_BUFFER_SIZE = 100

# # train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
# train_dataset = train_dataset.batch(BATCH_SIZE)
# test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
from tools.ae_v3 import Autoencoder

# %%
# Training parameters
learning_rate_list = [0.001, 0.0001, 0.00001]
epochs = 2000
patience = 200  # parameter for early stopping
min_delta = 1e-6  # parameter for early stopping
lambda_reg = 1e-5  # weight for regularizer

# Initialize network
ae_net = Autoencoder(
    data_dim=6,
    enc_layers=[16,12,8,8,4,4,2],
    dec_layers=[2,4,4,8,8,12,16],
    latent_space_dim=2,
    lambda_reg=lambda_reg,
    reg_name='L2',
    enc_layer_act_func='elu',
    enc_final_layer_act_func='tanh',
    dec_layer_act_func='elu',
    dec_final_layer_act_func='linear',
    # batch_norm=True,
    load_file=None)

# %%
# saving the autoencoder
dir_name_ae = os.getcwd() + '/saved_ae'
if not os.path.isdir(dir_name_ae):
    os.makedirs(dir_name_ae)

counter = 0
while True:
    dir_check = 'ae_' + str(counter).zfill(3)
    if os.path.isdir(dir_name_ae + '/' + dir_check):
        counter += 1
    else:
        break

dir_name_ae = dir_name_ae + '/' + dir_check
print('AE save dir : '+dir_name_ae)
os.makedirs(dir_name_ae)
os.makedirs(dir_name_ae+'/plots')

sim_data = {
    'rho_arr':rho_arr,
    'sigma_arr':sigma_arr,
    'beta_arr':beta_arr,
    'x0':x0,
    'y0':y0,
    'z0':z0,
    't0':t0,
    'T':T,
    'delta_t':delta_t,
    'return_params_arr':return_params_arr,
    'normalize_flag':normalize_flag
}

# import pandas as pd

# data_df = pd.DataFrame(data, columns=[key for key in sim_data.keys()])
# data_df.to_csv(dir_name_ae + '/sim_data_params.csv')

with open(dir_name_ae+'/sim_data_params.txt', 'w') as f:
    f.write(str(sim_data))


training_specific_params = {
    'learning_rate_list':learning_rate_list,
    'epochs':epochs,
    'patience':patience,
    'min_delta':min_delta,
    'prng_seed':prng_seed,
    'train_split':train_split,
    'val_split':val_split,
    'batch_size':batch_size
}

with open(dir_name_ae+'/training_specific_params.txt', 'w') as f:
    f.write(str(training_specific_params))
# Out:
# AE save dir : /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001

# %%
from tools.misc_tools import mytimecallback, SaveLosses

# %%
# compiling the network
ae_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
    loss=losses.MeanSquaredError()
)

# implementing early stopping
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=patience,
    restore_best_weights=True,
    verbose=True,
    min_delta=min_delta
)

# model checkpoint callback
dir_name_ckpt = dir_name_ae+'/checkpoints'
if not os.path.isdir(dir_name_ckpt):
    os.makedirs(dir_name_ckpt)
os.makedirs(dir_name_ckpt)
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
    monitor='val_loss',
    save_best_only=True,
    verbose=2,
    save_weights_only=True,
    period=5
)

timekeeper_cb = mytimecallback()

savelosses_cb_vallossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
savelosses_cb_trainlossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
savelosses_cb = SaveLosses(
    filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
    val_loss_arr=savelosses_cb_vallossarr,
    train_loss_arr=savelosses_cb_trainlossarr,
    total_epochs=epochs,
    period=10)


# training the network
val_loss_hist = []
train_loss_hist = []
lr_change=[0]
for i in range(len(learning_rate_list)):
    learning_rate = learning_rate_list[i]
    K.set_value(ae_net.optimizer.lr, learning_rate)

    savelosses_cb.update_lr_idx(i)

    total_s_len = 80
    sep_lr_s = ' LEARNING RATE : {} '.format(learning_rate)
    sep_lr_s = int((total_s_len - len(sep_lr_s))//2)*'-' + sep_lr_s
    sep_lr_s = sep_lr_s + (total_s_len-len(sep_lr_s))*'-'
    print('\n\n' + '-'*len(sep_lr_s))
    print('\n' + sep_lr_s+'\n')
    print('-'*len(sep_lr_s) + '\n\n')
    
    history = ae_net.fit(training_data, training_data,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=val_split/train_split,
        callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb],
        verbose=1
    )

    val_loss_hist.extend(history.history['val_loss'])
    train_loss_hist.extend(history.history['loss'])
    
    lr_change.append(lr_change[i]+len(history.history['val_loss']))
# Out:
# Streaming output truncated to the last 5000 lines.
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 53m 14.2s
#
# Epoch 725: val_loss did not improve from 0.00299
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 726/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 53m 26.6s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0032 - val_loss: 0.0050
# Epoch 727/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 53m 37.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 728/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 53m 48.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 729/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 53m 58.7s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 730/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 54m 9.0s
#
# Epoch 730: val_loss did not improve from 0.00299
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 731/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 54m 19.6s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 732/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 54m 29.9s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 733/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 54m 40.3s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 734/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 54m 51.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 735/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 55m 1.5s
#
# Epoch 735: val_loss improved from 0.00299 to 0.00288, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/checkpoint
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 736/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 55m 12.0s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 737/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 55m 22.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 738/2000
# 3308/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 55m 33.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 739/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 55m 43.9s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 740/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 55m 54.4s
#
# Epoch 740: val_loss did not improve from 0.00288
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 741/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 56m 5.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 742/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 56m 15.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 743/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 56m 26.1s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 744/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 56m 36.6s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 745/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 56m 47.1s
#
# Epoch 745: val_loss did not improve from 0.00288
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 746/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 56m 57.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 747/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 57m 8.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 748/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 57m 21.1s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 749/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 57m 32.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 750/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 57m 42.8s
#
# Epoch 750: val_loss did not improve from 0.00288
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 751/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 57m 54.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 752/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0031 - tot_time: 1h 58m 4.7s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 753/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 58m 15.2s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 754/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 58m 25.5s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 755/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 58m 36.1s
#
# Epoch 755: val_loss improved from 0.00288 to 0.00284, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/checkpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 756/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 58m 46.5s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 757/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 58m 57.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 758/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 59m 7.4s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 759/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 59m 17.8s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 760/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 59m 28.5s
#
# Epoch 760: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 761/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 1h 59m 39.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 762/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 1h 59m 50.0s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 763/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 0m 0.3s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 764/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0032 - tot_time: 2h 0m 10.7s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 765/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 0m 21.0s
#
# Epoch 765: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 766/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 0m 31.4s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 767/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 0m 43.5s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 768/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 0m 54.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 769/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 1m 5.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 770/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 1m 15.7s
#
# Epoch 770: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 771/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 1m 26.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 772/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 1m 37.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 773/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 1m 48.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 774/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 1m 59.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 775/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 2m 9.8s
#
# Epoch 775: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 776/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 2m 20.2s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 777/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 2m 30.6s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 778/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 2m 41.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0042
# Epoch 779/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 2m 52.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 780/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0031 - tot_time: 2h 3m 3.8s
#
# Epoch 780: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 781/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 3m 14.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 782/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 3m 25.4s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 783/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 3m 36.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 784/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 3m 47.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 785/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 3m 58.1s
#
# Epoch 785: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 786/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 4m 8.5s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 787/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 4m 21.1s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 788/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 4m 31.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 789/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 4m 42.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 790/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 4m 52.9s
#
# Epoch 790: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 791/2000
# 3308/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 5m 3.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 792/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 5m 14.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 793/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 5m 25.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 794/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 5m 36.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 795/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 5m 46.8s
#
# Epoch 795: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 796/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 5m 57.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 797/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 6m 8.0s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 798/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 6m 18.4s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 799/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 6m 29.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 800/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 6m 40.0s
#
# Epoch 800: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 801/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 6m 51.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 802/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 7m 1.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 803/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 7m 12.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 804/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 7m 23.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 805/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 7m 33.9s
#
# Epoch 805: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 806/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 7m 44.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 807/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 7m 55.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 808/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 8m 6.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 809/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 8m 17.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 810/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 8m 28.6s
#
# Epoch 810: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 12s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 811/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 8m 39.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 812/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 8m 50.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 813/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 9m 1.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 814/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 9m 12.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 815/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 9m 22.9s
#
# Epoch 815: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 816/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 9m 34.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 817/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 9m 44.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 818/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 9m 55.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 819/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 10m 6.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 820/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 10m 16.9s
#
# Epoch 820: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 821/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 10m 27.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 822/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 10m 38.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 823/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 10m 49.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 824/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 10m 59.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 825/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0031 - tot_time: 2h 11m 10.1s
#
# Epoch 825: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 826/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 11m 20.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 827/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 11m 31.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 828/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 11m 42.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 829/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 11m 53.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 830/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 12m 3.8s
#
# Epoch 830: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 831/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 12m 17.1s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 832/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 12m 27.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 833/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 12m 38.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 834/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 12m 49.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 835/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 13m 0.2s
#
# Epoch 835: val_loss improved from 0.00284 to 0.00284, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/checkpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 836/2000
# 3308/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 13m 10.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 837/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 13m 21.3s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 838/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 13m 32.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 839/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 13m 42.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 840/2000
# 3306/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 13m 53.5s
#
# Epoch 840: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 841/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 14m 4.2s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 842/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 14m 15.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 843/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 14m 25.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 844/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 14m 36.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 845/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 14m 47.3s
#
# Epoch 845: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 846/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 14m 58.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 847/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0031 - tot_time: 2h 15m 9.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 848/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 15m 19.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 849/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 15m 30.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 850/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 15m 41.1s
#
# Epoch 850: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 851/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 15m 52.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 852/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 16m 3.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 853/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 16m 13.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 854/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 16m 25.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 855/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 16m 35.9s
#
# Epoch 855: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 856/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 16m 48.7s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 857/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 16m 59.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 858/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 17m 10.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 859/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 17m 21.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 860/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 17m 32.0s
#
# Epoch 860: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 861/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 17m 43.6s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 862/2000
# 3306/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 17m 54.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 863/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 18m 4.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 864/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 18m 15.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 865/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 18m 26.8s
#
# Epoch 865: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 866/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0031 - tot_time: 2h 18m 38.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 867/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 18m 49.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 868/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 18m 60.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 869/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 19m 10.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 870/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 19m 21.5s
#
# Epoch 870: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 871/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 19m 32.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 872/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 19m 43.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 873/2000
# 3306/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 19m 54.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 874/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 20m 5.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 875/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 20m 17.0s
#
# Epoch 875: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 876/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 20m 28.7s
# 3323/3323 [==============================] - 12s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 877/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 20m 39.2s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 878/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 20m 49.6s
# 3323/3323 [==============================] - 10s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 879/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 21m 0.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 880/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 21m 11.6s
#
# Epoch 880: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 881/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 21m 23.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 882/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 21m 33.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 883/2000
# 3306/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 21m 45.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 884/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 21m 56.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 885/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 22m 8.4s
#
# Epoch 885: val_loss did not improve from 0.00284
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 886/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 22m 19.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 887/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 22m 30.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 888/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 22m 41.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 889/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 22m 53.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 890/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 23m 4.0s
#
# Epoch 890: val_loss did not improve from 0.00284
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 891/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 23m 15.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 892/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 23m 26.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 893/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 23m 37.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 894/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 23m 50.1s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 895/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 24m 1.3s
#
# Epoch 895: val_loss improved from 0.00284 to 0.00277, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/checkpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 896/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 24m 12.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 897/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 24m 22.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 898/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 24m 34.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 899/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 24m 45.8s
# 3323/3323 [==============================] - 12s 3ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 900/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 24m 56.9s
#
# Epoch 900: val_loss did not improve from 0.00277
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 901/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 25m 8.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 902/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 25m 19.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 903/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 25m 30.6s
# 3323/3323 [==============================] - 12s 3ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 904/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 25m 41.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 905/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 25m 52.4s
#
# Epoch 905: val_loss did not improve from 0.00277
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 906/2000
# 3308/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 26m 3.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 907/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 26m 14.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 908/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 26m 25.0s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 909/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 26m 36.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 910/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 26m 47.1s
#
# Epoch 910: val_loss did not improve from 0.00277
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 911/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 26m 58.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 912/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 27m 9.8s
# 3323/3323 [==============================] - 12s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 913/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 27m 21.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 914/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 27m 32.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 915/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 27m 45.1s
#
# Epoch 915: val_loss did not improve from 0.00277
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 916/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 27m 55.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 917/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 28m 7.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 918/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 28m 17.7s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 919/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 28m 29.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 920/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0030 - tot_time: 2h 28m 40.1s
#
# Epoch 920: val_loss did not improve from 0.00277
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0037
# Epoch 921/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 28m 51.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 922/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 29m 2.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 923/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 29m 12.8s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 924/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 29m 23.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 925/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 29m 34.8s
#
# Epoch 925: val_loss did not improve from 0.00277
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 926/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 29m 45.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 927/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 29m 56.4s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 928/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 30m 7.9s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 929/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 30m 18.5s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 930/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 30m 29.2s
#
# Epoch 930: val_loss did not improve from 0.00277
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 931/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 30m 40.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 932/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0029 - tot_time: 2h 30m 51.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 933/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 31m 2.2s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 934/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 31m 13.3s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 935/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0029 - tot_time: 2h 31m 24.4s
#
# Epoch 935: val_loss did not improve from 0.00277
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 936/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 31m 35.1s
# 3323/3323 [==============================] - 11s 3ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 937/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0030 - tot_time: 2h 31m 47.2s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 938/2000
# ...
# Epoch 245/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 32m 6.5s
#
# Epoch 245: val_loss did not improve from 0.00218
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 246/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 32m 19.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 247/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 32m 32.8s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 248/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 32m 45.5s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 249/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 32m 58.7s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 250/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 33m 11.6s
#
# Epoch 250: val_loss did not improve from 0.00218
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 251/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 33m 24.7s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 252/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 33m 37.7s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 253/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 33m 50.5s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 254/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 34m 3.0s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 255/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 34m 16.0s
#
# Epoch 255: val_loss did not improve from 0.00218
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 256/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 34m 29.0s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 257/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 34m 41.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 258/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 34m 54.5s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 259/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 35m 7.7s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 260/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 35m 21.5s
#
# Epoch 260: val_loss did not improve from 0.00218
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 14s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 261/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 35m 34.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 262/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 35m 47.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 263/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 36m 0.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 264/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 36m 13.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 265/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 36m 26.5s
#
# Epoch 265: val_loss did not improve from 0.00218
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 266/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 36m 39.8s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 267/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 36m 52.5s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 268/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 37m 4.9s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 269/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 37m 17.9s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 270/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 37m 31.0s
#
# Epoch 270: val_loss did not improve from 0.00218
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 271/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 37m 44.2s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 272/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 37m 56.5s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 273/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 38m 9.3s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 274/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 38m 22.7s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 275/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 38m 35.2s
#
# Epoch 275: val_loss did not improve from 0.00218
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 276/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 38m 48.3s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 277/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 39m 1.4s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 278/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 39m 13.7s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 279/2000
# 3320/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 39m 27.5s
# 3323/3323 [==============================] - 14s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 280/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 39m 40.8s
#
# Epoch 280: val_loss improved from 0.00218 to 0.00217, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 14s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 281/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 39m 54.2s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 282/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 40m 6.5s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 283/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 40m 18.4s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 284/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 40m 30.7s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 285/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 40m 43.1s
#
# Epoch 285: val_loss did not improve from 0.00217
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 286/2000
# 3311/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 40m 55.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 287/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 41m 8.0s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 288/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 41m 21.3s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 289/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 41m 34.3s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 290/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 41m 47.5s
#
# Epoch 290: val_loss did not improve from 0.00217
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 291/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 42m 1.2s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 292/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 42m 14.2s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 293/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 42m 27.0s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 294/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 42m 39.0s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 295/2000
# 3309/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 42m 51.6s
#
# Epoch 295: val_loss did not improve from 0.00217
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 296/2000
# 3314/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 43m 4.5s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 297/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 43m 17.4s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 298/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 43m 29.8s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 299/2000
# 3312/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 43m 42.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 300/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 43m 55.6s
#
# Epoch 300: val_loss did not improve from 0.00217
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 301/2000
# 3318/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 44m 8.4s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 302/2000
# 3313/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 44m 21.2s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 303/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 44m 34.6s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 304/2000
# 3308/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 44m 47.1s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 305/2000
# 3310/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 44m 59.3s
#
# Epoch 305: val_loss improved from 0.00217 to 0.00216, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/checkpoint
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 306/2000
# 3323/3323 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 6h 45m 13.3s
# 3323/3323 [==============================] - 14s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 307/2000
# 3317/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 45m 26.1s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 308/2000
# 3316/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 45m 39.2s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 309/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 45m 52.0s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 310/2000
# 3322/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 46m 5.1s
#
# Epoch 310: val_loss did not improve from 0.00216
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae/ae_001/checkpoints/LossHistoriesCheckpoint
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 311/2000
# 3321/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 46m 18.4s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 312/2000
# 3307/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 46m 30.6s
# 3323/3323 [==============================] - 12s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 313/2000
# 3315/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 46m 43.5s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 314/2000
# 3319/3323 [============================>.] - ETA: 0s - loss: 0.0022 - tot_time: 6h 46m 56.4s
# 3323/3323 [==============================] - 13s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 315/2000
#    1/3323 [..............................] - ETA: 15s - loss: 0.0023

# %%
# plotting losses
from tools.misc_tools import plot_losses


test_loss = ae_net.evaluate(
    testing_data, testing_data,
)
# lr_change = [0, 987, 987+334]
# for i in range(1,len(lr_change)):
#     lr_change[i] += lr_change[i-1]

# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list
)

plt.savefig(dir_name_ae+'/plots/loss_history.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
reconstructed_data = ae_net.predict(all_data)

# %%
fig = plot_reconstructed_data(
    boundary_idx_arr=boundary_idx_arr,
    dir_name_ae=dir_name_ae,
    all_data=all_data,
    reconstructed_data=reconstructed_data,
    save_figs=False)

# %%
plot_reconstructed_data(
    boundary_idx_arr=boundary_idx_arr,
    dir_name_ae=dir_name_ae,
    all_data=all_data,
    reconstructed_data=reconstructed_data,
    save_figs=True)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data)

# %%
from tools.misc_tools import plot_latent_states

# %%
fig, ax = plot_latent_states(
    boundary_idx_arr=boundary_idx_arr,
    latent_states_all=latent_states_all,
    all_data=all_data,
    xlim=[-1,1],
    ylim=[-1,1],
    cmap_name='gist_rainbow',
    legend_markerscale=10
    )

plt.savefig(dir_name_ae + '{ds}plots{ds}latent_space.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')

# %%
# ae_net.summary()

# %%
save_path = dir_name_ae+dir_sep+'final_net'

if not os.path.isdir(save_path):
    os.makedirs(save_path)

with open(save_path+dir_sep+'losses.txt', 'w') as f:
    f.write(str({
        'val_loss_hist':val_loss_hist,
        'train_loss_hist':train_loss_hist,
        'lr_change':lr_change,
        'test_loss':test_loss
    }))

ae_net.save_everything(file_name=save_path+dir_sep+'final_net')

# %%
n = len(boundary_idx_arr)
num_cols = 1
num_rows = 3*n

# plt.ion()

fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

Tt = N * delta_t
time_arr = np.arange(0, N+1) * Tt / N

y_labels = [r'$x_1$', r'$x_2$', r'$x_3$']

prev_idx = 0
for i in range(n):
    # ax = plt.axes(projection ='3d')
    next_idx = boundary_idx_arr[i]

    for j in range(3):
        ax = fig.add_subplot(num_rows, num_cols, 3*i+j+1)
        ax.plot(time_arr, all_data[prev_idx:next_idx, j], label='original')
        ax.plot(time_arr, reconstructed_data[prev_idx:next_idx, j], label='reconstructed')
        ax.set_ylabel(y_labels[j])
        ax.set_xlabel('time')
        ax.grid(True)


    prev_idx = next_idx

# %% [markdown]
# # LSTM
