# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/')
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz

# %%
from tools.misc_tools import create_Lorenz_data, create_data_for_RNN, mytimecallback, SaveLosses, plot_losses, plot_reconstructed_data, plot_latent_states, readAndReturnLossHistories
from tools.ae_v3 import Autoencoder
from tools.LSTM_SingleStep_v1 import RNN_LSTM
from tools.Combined_AE_RNN_v1 import Combined_AE_RNN

# %%
behaviour = 'initialiseAndTrainFromScratch'
# behaviour = 'loadCheckpointAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
# setting seed for PRNGs
if behaviour == 'initialiseAndTrainFromScratch':
    prng_seed = 42
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
tf.test.gpu_device_name()
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# # Lorenz System

# %%
# setting up params

from numpy import *

### Simutlation paramaters
if behaviour == 'initialiseAndTrainFromScratch':
    dir_name_rnn = os.getcwd()+'/saved_rnn/rnn_003'
    dir_sim_data = dir_name_rnn
    dir_rnn_data = dir_name_rnn
else:
    dir_name_ae_rnn = os.getcwd()+'/saved_ae_rnn/ae_rnn_003'
    # dir_name_rnn = dir_name_ae_rnn + '{ds}initial_net{ds}RNN'.format(ds=dir_sep)
    # dir_name_ae = dir_name_ae_rnn + '{ds}initial_net{ds}AE'.format(ds=dir_sep)
    dir_sim_data = dir_name_ae_rnn
    dir_rnn_data = dir_name_ae_rnn

with open(dir_sim_data + '/sim_data_AE_params.txt') as f:
    lines = f.readlines()

params_dict = eval(''.join(lines))


dir_name_ae = params_dict['dir_name_ae']
ae_idx = dir_name_ae[-3:]

rho_arr = params_dict['rho_arr']
sigma_arr = params_dict['sigma_arr']
beta_arr = params_dict['beta_arr']

x0 = params_dict['x0']
y0 = params_dict['y0']
z0 = params_dict['z0']

t0 = params_dict['t0']
T = params_dict['T']
delta_t = params_dict['delta_t']

normalize_flag = params_dict['normalize_flag']


### RNN paramaters
with open(dir_rnn_data + '/RNN_specific_data.txt') as f:
    lines = f.readlines()

params_rnn_dict = eval(''.join(lines))

dt_rnn = params_rnn_dict['dt_rnn']
T_sample_input = params_rnn_dict['T_sample_input']
T_sample_output = params_rnn_dict['T_sample_output']
T_offset = params_rnn_dict['T_offset']
return_params_arr = params_rnn_dict['return_params_arr']

# %%
res_dict = create_Lorenz_data(
    T, t0, delta_t,
    rho_arr, sigma_arr, beta_arr,
    x0, y0, z0, return_params_arr=return_params_arr,
    normalize=normalize_flag
)

all_data = res_dict['all_data']
N = res_dict['N']
boundary_idx_arr = res_dict['boundary_idx_arr']

if return_params_arr == True:
    params_arr = res_dict['params_arr']

if normalize_flag == True:
    normalization_constant_arr = res_dict['normalization_constant_arr']

# %%
n = len(boundary_idx_arr)

# %% [markdown]
# # Autoencoder

# %%
# load_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_class_dict.txt'
# wt_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_ae_weights.h5'

if behaviour == 'initialiseAndTrainFromScratch':
    load_file = dir_name_ae + '{ds}final_net{ds}'.format(ds=dir_sep)
elif behaviour == 'loadCheckpointAndContinueTraining':
    load_file = dir_name_ae_rnn + '{ds}initial_net{ds}AE{ds}'.format(ds=dir_sep)
elif behaviour == 'loadFinalNetAndPlot':
    load_file = dir_name_ae_rnn + '{ds}final_net{ds}AE{ds}'.format(ds=dir_sep)

wt_file = load_file + 'final_net_ae_weights.h5'
load_file += 'final_net_class_dict.txt'

# %%
ae_net = Autoencoder(6, load_file=load_file)
ae_net.load_weights_from_file(wt_file)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data)

# %%
fig, ax = plot_latent_states(
    boundary_idx_arr=boundary_idx_arr,
    latent_states_all=latent_states_all,
    all_data=all_data,
    xlim=[-1,1],
    ylim=[-1,1],
    cmap_name='jet')

# %% [markdown]
# # LSTM

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    rnn_load_file_path = dir_name_rnn+'{ds}final_net{ds}'.format(ds=dir_sep)
elif behaviour == 'loadCheckpointAndContinueTraining':
    rnn_load_file_path = dir_name_ae_rnn + '{ds}initial_net{ds}RNN{ds}'.format(ds=dir_sep)
elif behaviour == 'loadFinalNetAndPlot':
    rnn_load_file_path = dir_name_ae_rnn + '{ds}final_net{ds}RNN{ds}'.format(ds=dir_sep)

rnn_weights_path = rnn_load_file_path + 'final_net_lstm_weights.h5'
rnn_load_file_path += 'final_net_class_dict.txt'

# %%
rnn_net = RNN_LSTM(load_file=rnn_load_file_path)
temp = rnn_net.predict(tf.ones(shape=[1, 1, rnn_net.data_dim]))
rnn_net.load_weights_from_file(file_name=rnn_weights_path)

# %% [markdown]
# # Combined Model

# %%
if return_params_arr != False:
    params = params_arr
else:
    params = None

data_rnn_input, data_rnn_output, org_data_idx_arr_input, org_data_idx_arr_output, num_samples = create_data_for_RNN(
    all_data,
    dt_rnn,
    T_sample_input,
    T_sample_output,
    T_offset,
    N,
    boundary_idx_arr,
    delta_t,
    params=params,
    return_numsamples=True)

# %%
# saving training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_list = [0.00001]
    epochs = 200
    patience = 20  # parameter for early stopping
    min_delta = 1e-6  # parameter for early stopping
    lambda_reg = 1e-5  # weight for regularizer
    train_split = 0.8
    val_split = 0.1
    test_split = 1 - train_split - val_split
    batch_size = 64
else:
    with open(dir_name_ae_rnn+'/training_specific_params.txt', 'r') as f:
        lines = f.readlines()

    training_param_dict = eval(''.join(lines))

    learning_rate_list = training_param_dict['learning_rate_list']
    epochs = training_param_dict['epochs']
    patience = training_param_dict['patience']
    min_delta = training_param_dict['min_delta']
    prng_seed = training_param_dict['prng_seed']
    train_split = training_param_dict['train_split']
    val_split = training_param_dict['val_split']
    batch_size = training_param_dict['batch_size']
    test_split = 1 - train_split - val_split

    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
idx = np.arange(num_samples)
# np.random.shuffle(idx)
boundary = int(np.round(
    (1-test_split) * num_samples
))

# defining shapes
training_input_shape = [boundary*len(boundary_idx_arr)]
training_input_shape.extend(data_rnn_input.shape[1:])

training_output_shape = [boundary*len(boundary_idx_arr)]
training_output_shape.extend(data_rnn_output.shape[1:])

testing_input_shape = [(num_samples-boundary)*len(boundary_idx_arr)]
testing_input_shape.extend(data_rnn_input.shape[1:])

testing_output_shape = [(num_samples-boundary)*len(boundary_idx_arr)]
testing_output_shape.extend(data_rnn_output.shape[1:])

# defining required arrays
training_data_rnn_input = np.empty(shape=training_input_shape)
training_data_rnn_output = np.empty(shape=training_output_shape)

testing_data_rnn_input = np.empty(shape=testing_input_shape)
testing_data_rnn_output = np.empty(shape=testing_output_shape)

for i in range(len(boundary_idx_arr)):
    np.random.shuffle(idx)

    training_data_rnn_input[i*boundary:(i+1)*boundary] = data_rnn_input[i*num_samples + idx[0:boundary]]
    training_data_rnn_output[i*boundary:(i+1)*boundary] = data_rnn_output[i*num_samples + idx[0:boundary]]

    testing_data_rnn_input[i*(num_samples-boundary):(i+1)*(num_samples-boundary)] = data_rnn_input[i*num_samples + idx[boundary:]]
    testing_data_rnn_output[i*(num_samples-boundary):(i+1)*(num_samples-boundary)] = data_rnn_output[i*num_samples + idx[boundary:]]

# further shuffling
idx = np.arange(0, training_data_rnn_input.shape[0])
np.random.shuffle(idx)
training_data_rnn_input = training_data_rnn_input[idx]
training_data_rnn_output = training_data_rnn_output[idx]

idx = np.arange(0, testing_data_rnn_input.shape[0])
np.random.shuffle(idx)
testing_data_rnn_input = testing_data_rnn_input[idx]
testing_data_rnn_output = testing_data_rnn_output[idx]

# %%
# defining the combined model
combined_net = Combined_AE_RNN(
    data_dim=6,
    AE_net=ae_net,
    RNN_net=rnn_net)

# %%
if behaviour == 'loadCheckpointAndContinueTraining':
    combined_net.load_weights(dir_name_ae_rnn+'{ds}checkpoints{ds}checkpoint'.format(ds=dir_sep))

# %%
# saving some data
if behaviour == 'initialiseAndTrainFromScratch':
    dir_name_ae_rnn = os.getcwd() + dir_sep + 'saved_ae_rnn'
    if not os.path.isdir(dir_name_ae_rnn):
        os.makedirs(dir_name_ae_rnn)

    counter = 0
    while True:
        dir_check = 'ae_rnn_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_ae_rnn + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_ae_rnn = dir_name_ae_rnn + dir_sep + dir_check
    print('AE-RNN save directory : ' + dir_name_ae_rnn)
    os.makedirs(dir_name_ae_rnn)
    os.makedirs(dir_name_ae_rnn+dir_sep+'plots')
    dir_name_data = {
        'dir_name_rnn':dir_name_rnn,
        'dir_name_ae':dir_name_ae,
    }

    with open(dir_name_ae_rnn+dir_sep+'ae_rnn_dirs.txt', 'w') as f:
        f.write(str(dir_name_data))

    with open(dir_name_ae_rnn+dir_sep+'sim_data_AE_params.txt', 'w') as f:
        f.write(str(params_dict))

    with open(dir_name_ae_rnn+dir_sep+'RNN_specific_data.txt', 'w') as f:
        f.write(str(params_rnn_dict))

    training_specific_params = {
        'learning_rate_list':learning_rate_list,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size
    }

    with open(dir_name_ae_rnn+'/training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))

    combined_net.save_everything(
        save_dir=dir_name_ae_rnn+dir_sep+'initial_net',
        dir_sep=dir_sep)
# Out:
# AE-RNN save directory : /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt = readAndReturnLossHistories(
        dir_name_ae=dir_name_ae_rnn,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=learning_rate_list)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_ae_rnn+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
# compiling the network
combined_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
    loss=losses.MeanSquaredError(),
    run_eagerly=False
)

if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    # implementing early stopping
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        restore_best_weights=True,
        verbose=True,
        min_delta=min_delta
    )

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_ae_rnn+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        period=5  # saves every 5 epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=5)

    # training the network
    for i in range(starting_lr_idx, len(learning_rate_list)):
        learning_rate = learning_rate_list[i]
        K.set_value(combined_net.optimizer.lr, learning_rate)

        savelosses_cb.update_lr_idx(i)

        if i == starting_lr_idx:
            EPOCHS = num_epochs_left
            savelosses_cb.update_offset(epochs-num_epochs_left)
        else:
            EPOCHS = epochs
            savelosses_cb.update_offset(0)

        total_s_len = 80
        sep_lr_s = ' LEARNING RATE : {} '.format(learning_rate)
        sep_lr_s = int((total_s_len - len(sep_lr_s))//2)*'-' + sep_lr_s
        sep_lr_s = sep_lr_s + (total_s_len-len(sep_lr_s))*'-'
        print('\n\n' + '-'*len(sep_lr_s))
        print('\n' + sep_lr_s+'\n')
        print('-'*len(sep_lr_s) + '\n\n')
        
        history = combined_net.fit(training_data_rnn_input, training_data_rnn_output,
            epochs=EPOCHS,
            batch_size=batch_size,
            validation_split=val_split/train_split,
            callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb],
            verbose=1
        )

        val_loss_hist.extend(history.history['val_loss'])
        train_loss_hist.extend(history.history['loss'])
        
        if i == starting_lr_idx:
            lr_change[i+1] += len(history.history['val_loss'])
        else:
            lr_change.append(lr_change[i]+len(history.history['val_loss']))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 1e-05 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0026 - tot_time: 0h 0m 38.9s
# 223/223 [==============================] - 39s 145ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 2/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0026 - tot_time: 0h 1m 11.3s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 3/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 1m 42.7s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 4/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 2m 15.8s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 5/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 2m 47.5s
#
# Epoch 5: val_loss improved from inf to 0.00249, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 6/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 3m 19.5s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 7/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 3m 51.6s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 8/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 4m 23.7s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 9/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 4m 55.6s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 10/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 5m 28.7s
#
# Epoch 10: val_loss improved from 0.00249 to 0.00246, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 34s 152ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 11/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 6m 0.9s
# 223/223 [==============================] - 32s 141ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 12/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 6m 32.5s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 13/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 7m 4.0s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 14/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 7m 35.5s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 15/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 8m 6.7s
#
# Epoch 15: val_loss improved from 0.00246 to 0.00244, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 141ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 16/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 8m 38.4s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 17/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 9m 11.0s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 18/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 9m 42.2s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 19/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 10m 13.3s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 20/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 10m 47.3s
#
# Epoch 20: val_loss improved from 0.00244 to 0.00242, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 34s 154ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 21/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0025 - tot_time: 0h 11m 19.0s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 22/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 11m 50.1s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 23/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 12m 21.6s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 24/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 12m 54.5s
# 223/223 [==============================] - 33s 148ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 25/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 13m 25.8s
#
# Epoch 25: val_loss improved from 0.00242 to 0.00240, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 26/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 13m 57.3s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 27/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 14m 28.4s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 28/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 14m 59.8s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 29/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 15m 30.9s
# 223/223 [==============================] - 31s 139ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 30/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 16m 2.3s
#
# Epoch 30: val_loss improved from 0.00240 to 0.00239, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 31/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 16m 35.7s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 32/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 17m 6.9s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 33/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 17m 38.2s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 34/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 18m 10.0s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 35/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 18m 41.9s
#
# Epoch 35: val_loss improved from 0.00239 to 0.00238, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 36/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 19m 13.9s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 37/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 19m 45.5s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 38/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 20m 18.9s
# 223/223 [==============================] - 33s 150ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 39/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 20m 50.6s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 40/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 21m 22.8s
#
# Epoch 40: val_loss improved from 0.00238 to 0.00237, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 41/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 21m 55.0s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 42/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 22m 26.7s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 43/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 22m 58.2s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 44/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 23m 30.4s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 45/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 24m 3.5s
#
# Epoch 45: val_loss improved from 0.00237 to 0.00236, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 46/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 24m 35.3s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 47/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 25m 7.0s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 48/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 25m 38.3s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 49/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 26m 9.6s
# 223/223 [==============================] - 31s 140ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 50/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 26m 41.0s
#
# Epoch 50: val_loss improved from 0.00236 to 0.00235, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 51/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 27m 14.5s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 52/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 27m 46.0s
# 223/223 [==============================] - 32s 141ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 53/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 28m 17.8s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 54/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 28m 49.5s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 55/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 29m 21.3s
#
# Epoch 55: val_loss improved from 0.00235 to 0.00234, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 56/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 29m 53.1s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 57/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 30m 26.8s
# 223/223 [==============================] - 34s 151ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 58/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 30m 58.4s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 59/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 31m 30.2s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 60/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 32m 1.8s
#
# Epoch 60: val_loss improved from 0.00234 to 0.00233, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 61/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 32m 33.8s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 62/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 33m 5.4s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 63/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 33m 37.3s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 64/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 34m 10.8s
# 223/223 [==============================] - 33s 150ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 65/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 34m 42.6s
#
# Epoch 65: val_loss improved from 0.00233 to 0.00233, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 66/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 35m 14.7s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 67/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 35m 46.5s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 68/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 36m 18.3s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 69/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 36m 49.9s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 70/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 37m 21.8s
#
# Epoch 70: val_loss improved from 0.00233 to 0.00232, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 71/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0024 - tot_time: 0h 37m 55.5s
# 223/223 [==============================] - 33s 150ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 72/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 38m 27.2s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 73/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 38m 58.5s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 74/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 39m 30.1s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 75/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 40m 1.9s
#
# Epoch 75: val_loss improved from 0.00232 to 0.00231, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 76/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 40m 33.8s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 77/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 41m 7.0s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 78/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 41m 38.6s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 79/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 42m 10.3s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 80/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 42m 42.0s
#
# Epoch 80: val_loss improved from 0.00231 to 0.00231, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 81/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 43m 14.2s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 82/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 43m 45.9s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 83/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 44m 17.3s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 84/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 44m 50.5s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 85/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 45m 22.0s
#
# Epoch 85: val_loss improved from 0.00231 to 0.00230, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 86/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 45m 54.0s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 87/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 46m 25.8s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 88/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 46m 57.3s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 89/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 47m 28.8s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 90/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 48m 2.1s
#
# Epoch 90: val_loss improved from 0.00230 to 0.00229, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 34s 151ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 91/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 48m 34.6s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 92/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 49m 6.4s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 93/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 49m 37.8s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 94/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 50m 9.2s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 95/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 50m 41.0s
#
# Epoch 95: val_loss improved from 0.00229 to 0.00229, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 96/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 51m 13.5s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 97/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 51m 47.1s
# 223/223 [==============================] - 34s 151ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 98/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 52m 18.8s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 99/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 52m 50.7s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 100/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 53m 22.6s
#
# Epoch 100: val_loss improved from 0.00229 to 0.00228, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 101/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 53m 54.7s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 102/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 54m 26.2s
# 223/223 [==============================] - 32s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 103/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 54m 59.4s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 104/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 55m 30.9s
# 223/223 [==============================] - 32s 141ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 105/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 56m 2.6s
#
# Epoch 105: val_loss improved from 0.00228 to 0.00228, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 106/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 56m 34.9s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 107/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 57m 6.6s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 108/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 57m 38.3s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 109/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 58m 11.8s
# 223/223 [==============================] - 33s 150ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 110/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 58m 43.5s
#
# Epoch 110: val_loss improved from 0.00228 to 0.00227, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 111/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 59m 15.5s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 112/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 0h 59m 47.2s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 113/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 0m 19.0s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 114/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 0m 50.9s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 115/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 1m 24.5s
#
# Epoch 115: val_loss improved from 0.00227 to 0.00227, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 34s 152ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 116/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 1m 57.1s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 117/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 2m 29.4s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 118/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 3m 1.7s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 119/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 3m 34.0s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 120/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 4m 6.2s
#
# Epoch 120: val_loss improved from 0.00227 to 0.00226, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 121/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 4m 40.3s
# 223/223 [==============================] - 34s 152ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 122/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 5m 12.6s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 123/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 5m 44.6s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 124/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 6m 17.4s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 125/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 6m 49.6s
#
# Epoch 125: val_loss improved from 0.00226 to 0.00225, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 146ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 126/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 7m 21.6s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 127/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 7m 55.2s
# 223/223 [==============================] - 34s 151ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 128/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 8m 27.1s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 129/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 8m 58.7s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 130/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 9m 30.4s
#
# Epoch 130: val_loss improved from 0.00225 to 0.00225, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 131/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 10m 2.1s
# 223/223 [==============================] - 31s 141ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 132/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 10m 35.3s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 133/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 11m 7.2s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 134/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 11m 38.9s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 135/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 12m 10.6s
#
# Epoch 135: val_loss improved from 0.00225 to 0.00224, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 136/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 12m 42.8s
# 223/223 [==============================] - 32s 143ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 137/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 13m 14.5s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 138/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 13m 46.2s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 139/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 14m 19.5s
# 223/223 [==============================] - 33s 150ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 140/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 14m 51.0s
#
# Epoch 140: val_loss improved from 0.00224 to 0.00224, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 141/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 15m 23.0s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 142/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 15m 54.6s
# 223/223 [==============================] - 32s 141ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 143/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 16m 26.3s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 144/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 16m 58.1s
# 223/223 [==============================] - 32s 142ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 145/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 17m 31.6s
#
# Epoch 145: val_loss improved from 0.00224 to 0.00224, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 34s 151ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 146/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 18m 4.0s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 147/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 18m 36.4s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 148/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 19m 8.8s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 149/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 19m 41.3s
# 223/223 [==============================] - 32s 146ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 150/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 20m 15.5s
#
# Epoch 150: val_loss improved from 0.00224 to 0.00223, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 35s 155ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 151/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 20m 48.6s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 152/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 21m 21.3s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 153/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 21m 54.0s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 154/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 22m 26.7s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 155/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 22m 59.3s
#
# Epoch 155: val_loss improved from 0.00223 to 0.00223, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 156/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 23m 33.8s
# 223/223 [==============================] - 34s 153ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 157/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 24m 6.3s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 158/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 24m 38.8s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 159/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0023 - tot_time: 1h 25m 11.6s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 160/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 25m 44.1s
#
# Epoch 160: val_loss improved from 0.00223 to 0.00222, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 161/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 26m 18.5s
# 223/223 [==============================] - 34s 154ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 162/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 26m 51.0s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 163/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 27m 23.5s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 164/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 27m 56.0s
# 223/223 [==============================] - 32s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 165/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 28m 28.2s
#
# Epoch 165: val_loss improved from 0.00222 to 0.00222, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 166/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 29m 0.7s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 167/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 29m 34.3s
# 223/223 [==============================] - 34s 151ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 168/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 30m 6.4s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 169/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 30m 38.7s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 170/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 31m 10.9s
#
# Epoch 170: val_loss improved from 0.00222 to 0.00221, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 32s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 171/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 31m 43.3s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 172/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 32m 15.6s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 173/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 32m 49.7s
# 223/223 [==============================] - 34s 153ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 174/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 33m 22.2s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 175/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 33m 54.7s
#
# Epoch 175: val_loss improved from 0.00221 to 0.00221, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 176/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 34m 27.6s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 177/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 35m 0.1s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 178/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 35m 34.4s
# 223/223 [==============================] - 34s 154ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 179/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 36m 7.2s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 180/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 36m 39.7s
#
# Epoch 180: val_loss improved from 0.00221 to 0.00220, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 181/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 37m 12.4s
# 223/223 [==============================] - 32s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 182/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 37m 45.2s
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 183/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 38m 19.3s
# 223/223 [==============================] - 34s 153ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 184/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 38m 51.7s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 185/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 39m 24.0s
#
# Epoch 185: val_loss improved from 0.00220 to 0.00220, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 186/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 39m 56.5s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 187/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 40m 28.8s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 188/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 41m 2.1s
# 223/223 [==============================] - 33s 149ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 189/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 41m 34.7s
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 190/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 42m 7.1s
#
# Epoch 190: val_loss improved from 0.00220 to 0.00220, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 147ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 191/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 42m 39.8s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 192/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 43m 12.2s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 193/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 43m 44.5s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 194/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 44m 18.4s
# 223/223 [==============================] - 34s 152ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 195/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 44m 50.8s
#
# Epoch 195: val_loss improved from 0.00220 to 0.00219, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 33s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 196/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 45m 23.5s
# 223/223 [==============================] - 32s 146ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 197/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 45m 55.9s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 198/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 46m 28.2s
# 223/223 [==============================] - 32s 145ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 199/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 47m 0.3s
# 223/223 [==============================] - 32s 144ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 200/200
# 223/223 [==============================] - ETA: 0s - loss: 0.0022 - tot_time: 1h 47m 34.0s
#
# Epoch 200: val_loss improved from 0.00219 to 0.00219, saving model to /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/checkpoint
#  - saving loss histories at /content/drive/MyDrive/Colab Notebooks/Thesis/Lorenz/saved_ae_rnn/ae_rnn_005/checkpoints/LossHistoriesCheckpoint
# 223/223 [==============================] - 34s 153ms/step - loss: 0.0022 - val_loss: 0.0022

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    test_loss = combined_net.evaluate(
        testing_data_rnn_input, testing_data_rnn_output,
    )

    save_path = dir_name_ae_rnn+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'lr_change':lr_change,
            'test_loss':test_loss
        }))

    combined_net.save_everything(
        save_dir=save_path,
        dir_sep=dir_sep)
# Out:
# 57/57 [==============================] - 2s 30ms/step - loss: 0.0022

# %%
# plotting losses

# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list
)

# plt.savefig(dir_name_ae_rnn+'{ds}plots{ds}loss_history.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()

# %%
# new latent states
latent_states_new = combined_net.AE_net.encoder_net.predict(all_data)

# %%
fig, ax = plot_latent_states(
    boundary_idx_arr=boundary_idx_arr,
    latent_states_all=latent_states_new,
    all_data=all_data,
    xlim=[-1,1],
    ylim=[-1,1],
    cmap_name='jet')

plt.savefig(dir_name_ae_rnn + '{ds}plots{ds}latent_space_new.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')

# %%
# reconstructed data
reconstructed_data = combined_net.AE_net.predict(all_data)

# %%
fig = plot_reconstructed_data(
    boundary_idx_arr=boundary_idx_arr,
    dir_name_ae=dir_name_ae_rnn,
    all_data=all_data,
    reconstructed_data=reconstructed_data,
    save_figs=False)

# %%
plot_reconstructed_data(
    boundary_idx_arr=boundary_idx_arr,
    dir_name_ae=dir_name_ae_rnn,
    all_data=all_data,
    reconstructed_data=reconstructed_data,
    save_figs=True)
