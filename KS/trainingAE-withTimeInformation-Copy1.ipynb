# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

tf.keras.backend.set_floatx('float32')

# %%
colab_flag = False

FTYPE = np.float32
ITYPE = np.int32

strategy = None
# strategy = tf.distribute.MirroredStrategy()

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
if colab_flag == True:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Github/MLROM/KS/')

# %%
print(os.getcwd())
# Out:
# /home/rkaushik/Documents/Thesis/MLROM/KS

# %%
from tools.misc_tools import mytimecallback, SaveLosses, plot_losses, readAndReturnLossHistories, plot_reconstructed_data_KS, plot_latent_states_KS 
from tools.ae_v6 import Autoencoder

# %%
behaviour = 'initialiseAndTrainFromScratch'
# behaviour = 'loadCheckpointAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
# setting seed for PRNGs
if behaviour == 'initialiseAndTrainFromScratch':
    prng_seed = 42
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if colab_flag == False:
    if strategy is None:
        if gpus:
            gpu_to_use = 0
            tf.config.set_visible_devices(gpus[gpu_to_use], 'GPU')
    logical_devices = tf.config.list_logical_devices('GPU')
    print(logical_devices)
# Out:
# 2023-01-09 19:53:42.946157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:42.946982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.018500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.018989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.019276: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.019651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from S
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# ysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.021258: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-09 19:53:43.021972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.022394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.022785: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.655140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.655379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.655578: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-09 19:53:43.655744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3359 MB memory:  -> device: 0, name: Quadro K2200, pci bus id: 0000:02:00.0, compute capability: 5.0

# %%
# print(tf.test.gpu_device_name())
print(tf.config.list_physical_devices())
print(tf.config.list_logical_devices())
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2.8.1

# %% [markdown]
# # KS System

# %%
# setting up params (and saving, if applicable)
from numpy import *

if behaviour == 'initialiseAndTrainFromScratch':
    # loading data directory
    data_dir_idx = '005'

    # making ae save directory
    dir_name_ae = os.getcwd() + dir_sep + 'saved_ae'
    if not os.path.isdir(dir_name_ae):
        os.makedirs(dir_name_ae)

    counter = 0
    while True:
        dir_check = 'ae_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_ae + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_ae = dir_name_ae + dir_sep + dir_check
    os.makedirs(dir_name_ae)
    os.makedirs(dir_name_ae+dir_sep+'plots')
else:
    # some paramaters
    dir_name_ae = os.getcwd()+'{ds}saved_ae{ds}ae_015'.format(ds=dir_sep)

    with open(dir_name_ae + dir_sep + 'ae_data.txt') as f:
        lines = f.readlines()

    params_dict = eval(''.join(lines))
    data_dir_idx = params_dict['data_dir_idx']
    normalizeforae_flag = params_dict['normalizeforae_flag']
    normalization_constant_arr_aedata = params_dict['normalization_constant_arr_aedata']
    if os.path.exists(dir_name_ae+dir_sep+'normalization_data.npz'):
        with np.load(dir_name_ae+dir_sep+'normalization_data.npz', allow_pickle=True) as fl:
            normalization_constant_arr_aedata = fl['normalization_constant_arr_aedata'][0]

print('dir_name_ae:', dir_name_ae)
# loading data
dir_name_data = os.getcwd() + dir_sep + 'saved_data' + dir_sep + 'data_' + data_dir_idx
    
with open(dir_name_data + dir_sep + 'sim_data_params.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
params_mat = params_dict['params_mat']
# init_state = params_dict['init_state']
t0 = params_dict['t0']
T = params_dict['T']
delta_t = params_dict['delta_t']
numpoints_xgrid = params_dict['numpoints_xgrid']
length = params_dict['length']
return_params_arr = params_dict['return_params_arr']
normalize_flag_ogdata = params_dict['normalize_flag']
print('normalize_flag_ogdata:', normalize_flag_ogdata)
alldata_withparams_flag = params_dict['alldata_withparams_flag']

xgrid = length*np.linspace(0, 1, numpoints_xgrid)

with np.load(dir_name_data+dir_sep+'data.npz', allow_pickle=True) as fl:
    all_data = fl['all_data'].astype(FTYPE)
    boundary_idx_arr = fl['boundary_idx_arr']
    normalization_constant_arr_ogdata = fl['normalization_constant_arr'][0]
    initial_t0 = fl['initial_t0']
    init_state_mat = fl['init_state_mat']

    lyapunov_spectrum_mat = fl['lyapunov_spectrum_mat']
# Out:
# dir_name_ae: /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060
# normalize_flag_ogdata: False

# %%
lyapunov_time_arr = np.empty(shape=lyapunov_spectrum_mat.shape[0], dtype=FTYPE)
for i in range(lyapunov_spectrum_mat.shape[0]):
    lyapunov_time_arr[i] = 1/lyapunov_spectrum_mat[i, 0]
    print('Case : {}, lyapunov exponent : {}, lyapunov time : {}s'.format(i+1, lyapunov_spectrum_mat[i, 0], lyapunov_time_arr[i]))
# Out:
# Case : 1, lyapunov exponent : 0.06465670311438651, lyapunov time : 15.466300964355469s

# %%
def plot(
        boundary_idx_arr,
        delta_t,
        all_data,
        xgrid,
        xticks_snapto=20,
        num_yticks=11,
        save_dir=None,
        xlabel=r'Time',
        ylabel=r'$x$',
        ax_titles_list=None
    ):

    n = len(boundary_idx_arr)
    num_digits_n = int(np.log10(n)+1)

    # '''
    num_cols = 1
    num_rows = 1
    factor = 1
    # fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

    num_modes = xgrid.shape[0]

    prev_idx = 0
    for i in range(len(boundary_idx_arr)):
        next_idx = boundary_idx_arr[i]
        fig, ax = plt.subplots(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
        N = next_idx - prev_idx
        input_time = np.arange(0, N)*delta_t

        im = ax.imshow(all_data[prev_idx:next_idx, 0:num_modes].transpose(), aspect='auto', origin='lower')
        num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
        # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
        xticks = np.arange(0, N, int((xticks_snapto+0.5*delta_t)//delta_t))
        ax.set_xticks(ticks=xticks)
        ax.set_xticklabels(np.round(xticks*delta_t, 1))
        ax.tick_params(axis='x', rotation=270+45)

        yticks = np.linspace(0, 1, 10+1)*(len(xgrid)-1)
        yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
        ax.set_yticks(ticks=yticks)
        ax.set_yticklabels(yticklabels)

        ax.set_xlabel('Time')
        ax.set_ylabel(r'$x$')
        # ax.title.set_text(r'Latent States')
        if ax_titles_list is not None:
            ax.title.set_text(ax_titles_list[i])
        else:
            ax.title.set_text(r'Case '+str(i+1))

        plt.colorbar(im)
        if save_dir is not None:
            fig.savefig(save_dir+'/Case_'+str(i+1).zfill(num_digits_n)+'.png', dpi=300, bbox_inches='tight')
            fig.clear()
            plt.close()
        else:
            plt.show()
            print('')

        prev_idx = next_idx

    # '''

# %%
temp = boundary_idx_arr[0] + np.sum(boundary_idx_arr[1:] - boundary_idx_arr[0:-1])
temp /= len(boundary_idx_arr)
temp *= delta_t
chosen_interval = temp//10
sn = np.format_float_scientific(chosen_interval, exp_digits=4)
snap = np.max([0.1, 25*np.round(10*float(sn[0:-6])/25)/10])
snap *= float('1'+sn[-6:])
xticks_snapto = int(snap*np.round(chosen_interval/snap))

plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    xgrid,
    xticks_snapto=xticks_snapto)

# %%
# dealing with normalizing the data before feeding into autoencoder
if behaviour == 'initialiseAndTrainFromScratch':
    # normalize data before feeding into autoencoder?
    normalizeforae_flag = True
    normalization_type = 'stddev' # could be 'stddev' or 'minmax'
    stddev_multiplier = 3
    
    ae_data_with_params = False # whether to feed in the parameters to the AE along with the data?

    normalization_constant_arr_aedata = None
    if normalizeforae_flag == True:
        normalization_constant_arr_aedata = np.empty(shape=(2, numpoints_xgrid), dtype=FTYPE)
        if normalization_type == 'stddev':
            for i in range(numpoints_xgrid):
                sample_mean = np.mean(all_data[:, i])
                sample_std = np.std(all_data[:, i])
                normalization_constant_arr_aedata[0, i] = sample_mean
                normalization_constant_arr_aedata[1, i] = stddev_multiplier*sample_std
        elif normalization_type == 'minmax':
            for i in range(numpoints_xgrid):
                sample_min = np.min(all_data[:, i])
                sample_max = np.max(all_data[:, i])
                if sample_max - sample_min == 0:
                    sample_min = sample_min - 0.5
                    sample_max = sample_min + 1
                normalization_constant_arr_aedata[0, i] = sample_min
                normalization_constant_arr_aedata[1, i] = sample_max - sample_min
        for i in range(numpoints_xgrid):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]
            
    # saving sim data
    ae_data = {
        'data_dir_idx':data_dir_idx,
        'normalizeforae_flag':normalizeforae_flag,
        'normalization_constant_arr_aedata':normalization_constant_arr_aedata,
        'normalization_type':normalization_type,
        'stddev_multiplier':stddev_multiplier,
        'ae_data_with_params':ae_data_with_params,
        'module':Autoencoder.__module__,
    }
    with open(dir_name_ae+dir_sep+'ae_data.txt', 'w') as f:
        f.write(str(ae_data))
    np.savez(
        dir_name_ae+dir_sep+'normalization_data',
        normalization_constant_arr_aedata=[normalization_constant_arr_aedata],
    )
else:
    if normalizeforae_flag == True:
        for i in range(numpoints_xgrid):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]
            
time_stddev = np.std(all_data, axis=0)
if ae_data_with_params == False:
    all_data = all_data[:, 0:numpoints_xgrid]
    time_stddev = time_stddev[0:numpoints_xgrid]
else:
    time_stddev[numpoints_xgrid:] = 1.0

# %%
plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    xgrid,
    xticks_snapto=xticks_snapto)

# %%
num_tsteps_to_take = 2

begin_idx = 0
for i in range(boundary_idx_arr.shape[0]):
    end_idx = boundary_idx_arr[i]
    num_samples = end_idx - begin_idx
    num_samples_new = int(num_samples) // num_tsteps_to_take
    
    end_idx_new = num_samples_new * num_tsteps_to_take
    
    difference_idx = end_idx - end_idx_new
    temp_idx = begin_idx+end_idx_new
    all_data[temp_idx:boundary_idx_arr[-1]-difference_idx] = all_data[begin_idx+end_idx:]
    
    boundary_idx_arr[i:] -= difference_idx
    all_data = all_data[0:boundary_idx_arr[-1]]

# %%
new_data = np.reshape(
    all_data,
    newshape=(
        int(all_data.shape[0]/num_tsteps_to_take),
        num_tsteps_to_take,
        all_data.shape[1]
    ),
    order='C'
)

# %%
all_data_og = all_data
all_data = new_data

# %%
boundary_idx_arr_og = boundary_idx_arr
boundary_idx_arr = boundary_idx_arr // num_tsteps_to_take

# %% [markdown]
# # Autoencoder

# %%
# setting up training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_list = [1e-3, 1e-4, 1e-5]
    epochs = 1000
    patience = 25  # parameter for early stopping
    min_delta = 1e-6  # parameter for early stopping
    lambda_reg = 1e-6 # weight for regularizer
    train_split = 0.8
    val_split = 0.1
    test_split = 1 - train_split - val_split
    batch_size = 64
    fRMS = 1/100
    timeMeanofSpaceRMS = np.mean(np.mean(all_data**2, axis=1)**0.5)
    
    # stddev = fRMS*timeMeanofSpaceRMS
    stddev = fRMS * np.mean(time_stddev[0:numpoints_xgrid])
    contractive_lmda = 0.0
    dropout_rate = 0.0
    lmda_latentspace_dist = 0.005


    # saving training params
    training_specific_params = {
        'learning_rate_list':learning_rate_list,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size,
        'fRMS':fRMS,
        'timeMeanofSpaceRMS':timeMeanofSpaceRMS,
        'stddev':stddev,
        'contractive_lmda':contractive_lmda,
        'dropout_rate':dropout_rate,
    }

    with open(dir_name_ae+dir_sep+'training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))
else:
    with open(dir_name_ae + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()

    tparams_dict = eval(''.join(lines))

    learning_rate_list = tparams_dict['learning_rate_list']
    epochs = tparams_dict['epochs']
    patience = tparams_dict['patience']
    min_delta = tparams_dict['min_delta']
    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']
    try:
        stddev = tparams_dict['stddev']
    except:
        print("'stddev' not in tparams_dict, set to 0")
        stddev = 0.0
    try:
        contractive_lmda = tparams_dict['contractive_lmda']
    except:
        print("'contractive_lmda' not in tparams_dict, set to 0")
        contractive_lmda = 0.0
    try:
        dropout_rate = tparams_dict['dropout_rate']
    except:
        print("'dropout_rate' not in tparams_dict, set to 0")
        dropout_rate = 0.0

    test_split = 1 - train_split - val_split

    # setting seed for PRNGs
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
# # setting up data
# idx = np.arange(all_data.shape[0])
# np.random.shuffle(idx)
# boundary = int(np.round((1-test_split)*all_data.shape[0]))
# training_data = all_data[idx[0:boundary], :]
# testing_data = all_data[idx[boundary:], :]

# %%
cum_samples = boundary_idx_arr[-1]
# idx = np.arange(cum_samples)
# np.random.shuffle(idx)
num_train = 0
num_val = 0
begin_idx = 0
for i in range(len(boundary_idx_arr)):
    num_samples = boundary_idx_arr[i] - begin_idx
    num_train += int( (1-test_split-val_split)*num_samples )
    num_val += int(val_split*num_samples)
    begin_idx = boundary_idx_arr[i]

# defining shapes
training_shape = [num_train]
training_shape.extend(all_data.shape[1:])

val_shape = [num_val]
val_shape.extend(all_data.shape[1:])

testing_shape = [cum_samples-num_train-num_val]
testing_shape.extend(all_data.shape[1:])

# defining required arrays
training_data = np.empty(shape=training_shape)

val_data = np.empty(shape=val_shape)

testing_data = np.empty(shape=testing_shape)

begin_idx = 0
training_data_rolling_count = 0
val_data_rolling_count = 0
testing_data_rolling_count = 0
for i in range(len(boundary_idx_arr)):
    idx = np.arange(begin_idx, boundary_idx_arr[i])
    # np.random.shuffle(idx)
    num_samples = idx.shape[0]
    num_train = int( (1-test_split-val_split)*num_samples )
    num_val = int(val_split*num_samples)

    training_data[training_data_rolling_count:training_data_rolling_count+num_train] = all_data[idx[0:num_train]]
    training_data_rolling_count += num_train

    val_data[val_data_rolling_count:val_data_rolling_count+num_val] = all_data[idx[num_train:num_train+num_val]]
    val_data_rolling_count += num_val

    num_test = num_samples-num_train-num_val+1
    testing_data[testing_data_rolling_count:testing_data_rolling_count+num_test] = all_data[idx[num_train+num_val:]]
    testing_data_rolling_count += num_test

    begin_idx = boundary_idx_arr[i]

# further shuffling
# idx = np.arange(0, training_data.shape[0])
# np.random.shuffle(idx)
# training_data_rnn_input = training_data_rnn_input[idx]
np.random.shuffle(training_data)

# idx = np.arange(0, val_data.shape[0])
# np.random.shuffle(idx)
# val_data = val_data[idx]
np.random.shuffle(val_data)

# idx = np.arange(0, testing_data.shape[0])
# np.random.shuffle(idx)
# testing_data = testing_data[idx]
np.random.shuffle(testing_data)

# %%
# Initialize network
if behaviour == 'initialiseAndTrainFromScratch':
    latent_space_dim = 16
    enc_layers = [128, 96, 64, 48, 32, 24, 26, 8, 4]
    # enc_layers = [192, 96, 48, 24, 12, 6, 3]
    # enc_layers = [96, 48, 24, 12, 6, 3]
    # enc_layers = [128, 64, 32, 16, 8, 4]
    # enc_layers = []
#     enc_layers = [32, 16, 8, 4]
    for i in range(len(enc_layers)):
        if latent_space_dim < enc_layers[-i-1]:
            enc_layers = enc_layers[0:-i]
            break
        if i == len(enc_layers)-1:
            enc_layers = []
    dec_layers = enc_layers[::-1]
    
    enc_layer_act_func = 'elu'
    enc_final_layer_act_func = 'tanh'
    dec_layer_act_func = 'elu'
    dec_final_layer_act_func = 'linear'
    reg_name = 'L2'
    use_weights_post_dense = False
    
    if strategy is not None:
        with strategy.scope():
            ae_net = Autoencoder(
                data_dim=all_data.shape[-1],
                enc_layers=enc_layers,
                dec_layers=dec_layers,
                latent_space_dim=latent_space_dim,
                lambda_reg=lambda_reg,
                reg_name=reg_name,
                enc_layer_act_func=enc_layer_act_func,
                enc_final_layer_act_func=enc_final_layer_act_func,
                dec_layer_act_func=dec_layer_act_func,
                dec_final_layer_act_func=dec_final_layer_act_func,
                load_file=None,
                stddev=stddev,
                contractive_lmda=contractive_lmda,
                dropout_rate=dropout_rate,
                use_weights_post_dense=use_weights_post_dense,)
    else:
        ae_net = Autoencoder(
            data_dim=all_data.shape[-1],
            enc_layers=enc_layers,
            dec_layers=dec_layers,
            latent_space_dim=latent_space_dim,
            lambda_reg=lambda_reg,
            reg_name=reg_name,
            enc_layer_act_func=enc_layer_act_func,
            enc_final_layer_act_func=enc_final_layer_act_func,
            dec_layer_act_func=dec_layer_act_func,
            dec_final_layer_act_func=dec_final_layer_act_func,
            load_file=None,
            stddev=stddev,
            contractive_lmda=contractive_lmda,
            dropout_rate=dropout_rate,
            use_weights_post_dense=use_weights_post_dense,)
    # saving the AE configuration
    save_path = dir_name_ae+dir_sep+'final_net'
    if not os.path.isdir(save_path):
        os.makedirs(save_path)
    ae_net.save_class_dict(save_path+dir_sep+'final_net_class_dict.txt')
else:
    load_file = dir_name_ae + dir_sep + 'final_net' + dir_sep + 'final_net_class_dict.txt'
    if strategy is not None:
        with strategy.scope():
            ae_net = Autoencoder(data_dim=all_data.shape[-1], load_file=load_file)
    else:
        ae_net = Autoencoder(data_dim=all_data.shape[-1], load_file=load_file)
    
    if behaviour == 'loadCheckpointAndContinueTraining':
        wt_file = tf.train.latest_checkpoint(dir_name_ae+dir_sep+'checkpoints')
        # ae_net.load_weights(wt_file)
    elif behaviour == 'loadFinalNetAndPlot':
        wt_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_ae_weights.h5'
        ae_net.load_weights_from_file(wt_file)

# %%
from keras.engine import data_adapter

class AE_withTime(tf.keras.models.Model):
    def __init__(self, ae_net, lmda_latentspace_dist):
        super().__init__()
        self.ae_net = ae_net
        self.lmda_latentspace_dist = lmda_latentspace_dist
        # self.beta_latentspace_dist = tf.Variable(
        #     initial_value=1.0,
        #     name='beta_latentspace_dist',
        #     trainable=True,
        # )

    @tf.function
    def call(self, inputs, training=None):
        outputs = tf.keras.layers.TimeDistributed(self.ae_net.ae_net)(inputs, training=training)
        return outputs
        
    def train_step(self, data):

        # x, y = data
        x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
        
        with tf.GradientTape() as tape1:
            ls_jacobian_norm = 0.0
            # encoded = []
            # for i in range(x.shape[1]):
            #     with tf.GradientTape() as tape2:
            #         encoded_i = self.ae_net.encoder_net(x[:, i, :], training=True)
            #     ls_jacobian_norm = ls_jacobian_norm + tf.norm(
            #         tape2.batch_jacobian(encoded_i, x[:, i, :]),
            #         ord='fro',
            #         axis=[-2, -1]
            #     )
            #     encoded.append(encoded_i)
            # ls_jacobian_norm = ls_jacobian_norm / x.shape[1]
            # encoded = tf.stack(encoded)
            # encoded = tf.transpose(encoded, perm=[1, 0, 2])

            encoded = tf.keras.layers.TimeDistributed(self.ae_net.encoder_net)(x, training=True)
            decoded = tf.keras.layers.TimeDistributed(self.ae_net.decoder_net)(encoded, training=True)
            
            x_norm = tf.norm(
                x[:, 1:, :] - x[:, 0:-1, :],
                ord='euclidean',
                axis=-1
            )
            ls_norm = tf.norm(
                encoded[:, 1:, :] - encoded[:, 0:-1, :],
                ord='euclidean',
                axis=-1
            )
            ls_dist_loss = tf.reduce_mean(ls_norm / x_norm)
            loss = self.compiled_loss(
                y,
                decoded,
                sample_weight,
                regularization_losses=self.losses
            ) + self.ae_net.contractive_lmda*ls_jacobian_norm + self.lmda_latentspace_dist*ls_dist_loss

        self._validate_target_and_loss(decoded, loss)

        trainable_vars = self.trainable_variables
        gradients = tape1.gradient(loss, trainable_vars)
        
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        
        return self.compute_metrics(x, y, decoded, sample_weight, ls_jacobian_norm, ls_dist_loss)
    
    def compute_metrics(self, x, y, decoded, sample_weight, ls_jacobian_norm=0.0, ls_dist_loss=0.0, beta_latentspace_dist=0.0):
        metric_results = super().compute_metrics(x, y, decoded, sample_weight)
        metric_results['ls_jacobian_norm'] = ls_jacobian_norm
        metric_results['ls_dist_loss'] = ls_dist_loss
        metric_results['beta_latentspace_dist'] = beta_latentspace_dist
        return metric_results

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt = readAndReturnLossHistories(
        dir_name_ae=dir_name_ae,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=learning_rate_list)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_ae+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
train_MSE_hist = []
val_MSE_hist = []

train_NMSE_hist = []
val_NMSE_hist = []

train_ls_jacobian_loss_hist = []
train_ls_dist_loss_hist = []
train_betals_hist = []

# %%
class NMSE(tf.keras.metrics.MeanSquaredError):
    def __init__(self, divisor_arr, name='NMSE', **kwargs):
        super(NMSE, self).__init__(name, **kwargs)
        self.divisor_arr = divisor_arr

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = y_true / self.divisor_arr
        y_pred = y_pred / self.divisor_arr
        return super(NMSE, self).update_state(y_true, y_pred, sample_weight)

# %%
# compiling the network
ae_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
    loss=losses.MeanSquaredError(),
#     loss=losses.BinaryCrossentropy(from_logits=False),
    run_eagerly=False,
    metrics=['mse', NMSE(divisor_arr=tf.constant(time_stddev))]
)

if behaviour == 'loadCheckpointAndContinueTraining':
    # this loads the weights/attributes of the optimizer as well
    if strategy is not None:
        with strategy.scope():
            ae_net.load_weights(wt_file)
    else:
        ae_net.load_weights(wt_file)

if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    ae_t_net = AE_withTime(ae_net, lmda_latentspace_dist)
    ae_t_net.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
        loss=losses.MeanSquaredError(),
    #     loss=losses.BinaryCrossentropy(from_logits=False),
        run_eagerly=False,
        metrics=['mse', NMSE(divisor_arr=tf.constant(time_stddev))]
    )
    
    # implementing early stopping
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor='val_NMSE',
        patience=patience,
        restore_best_weights=True,
        verbose=True,
        min_delta=min_delta
    )

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_ae+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor='val_NMSE',
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        period=1  # saves every 5 epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=1)

    # training the network
    for i in range(starting_lr_idx, len(learning_rate_list)):
        learning_rate = learning_rate_list[i]
        K.set_value(ae_net.optimizer.lr, learning_rate)

        savelosses_cb.update_lr_idx(i)

        if i == starting_lr_idx:
            EPOCHS = num_epochs_left
            savelosses_cb.update_offset(epochs-num_epochs_left)
        else:
            EPOCHS = epochs
            savelosses_cb.update_offset(0)

        total_s_len = 80
        sep_lr_s = ' LEARNING RATE : {} '.format(learning_rate)
        sep_lr_s = int((total_s_len - len(sep_lr_s))//2)*'-' + sep_lr_s
        sep_lr_s = sep_lr_s + (total_s_len-len(sep_lr_s))*'-'
        print('\n\n' + '-'*len(sep_lr_s))
        print('\n' + sep_lr_s+'\n')
        print('-'*len(sep_lr_s) + '\n\n')
        
        history = ae_t_net.fit(training_data, training_data,
            epochs=EPOCHS,
            batch_size=batch_size,
#             validation_split=val_split/train_split,
            validation_data=(val_data, val_data),
            callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb],
            verbose=1
        )

        val_loss_hist.extend(history.history['val_loss'])
        train_loss_hist.extend(history.history['loss'])
        
        val_MSE_hist.extend(history.history['val_mse'])
        train_MSE_hist.extend(history.history['mse'])
        
        val_NMSE_hist.extend(history.history['val_NMSE'])
        train_NMSE_hist.extend(history.history['NMSE'])
        
        train_ls_jacobian_loss_hist.append(history.history['ls_jacobian_norm'])
        train_ls_dist_loss_hist.append(history.history['ls_dist_loss'])
        
        train_betals_hist.append(history.history['beta_latentspace_dist'])
        
        if i == starting_lr_idx:
            lr_change[i+1] += len(history.history['val_loss'])
        else:
            lr_change.append(lr_change[i]+len(history.history['val_loss']))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 0.001 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 0.0042 - mse: 0.0033 - NMSE: 0.0301 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.1059 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 0m 20.5s
#
# Epoch 1: val_NMSE improved from inf to 0.00544, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 0.0042 - mse: 0.0033 - NMSE: 0.0300 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.1058 - beta_latentspace_dist: 0.0000e+00 - val_loss: 0.0015 - val_mse: 6.0431e-04 - val_NMSE: 0.0054 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 2/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 0.0013 - mse: 4.6342e-04 - NMSE: 0.0042 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0399 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 0m 38.3s
#
# Epoch 2: val_NMSE did not improve from 0.00544
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 0.0013 - mse: 4.6332e-04 - NMSE: 0.0042 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0399 - beta_latentspace_dist: 0.0000e+00 - val_loss: 0.0014 - val_mse: 6.2939e-04 - val_NMSE: 0.0057 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 3/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 0.0011 - mse: 3.5356e-04 - NMSE: 0.0032 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0327 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 0m 56.0s
#
# Epoch 3: val_NMSE improved from 0.00544 to 0.00425, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 0.0011 - mse: 3.5345e-04 - NMSE: 0.0032 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0327 - beta_latentspace_dist: 0.0000e+00 - val_loss: 0.0011 - val_mse: 4.7165e-04 - val_NMSE: 0.0042 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 4/1000
# 3116/3126 [============================>.] - ETA: 0s - loss: 9.4738e-04 - mse: 3.0856e-04 - NMSE: 0.0028 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0301 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 1m 13.6s
#
# Epoch 4: val_NMSE improved from 0.00425 to 0.00360, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 9.4733e-04 - mse: 3.0861e-04 - NMSE: 0.0028 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0301 - beta_latentspace_dist: 0.0000e+00 - val_loss: 0.0010 - val_mse: 4.0010e-04 - val_NMSE: 0.0036 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 5/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 8.5391e-04 - mse: 2.7672e-04 - NMSE: 0.0025 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0283 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 1m 31.1s
#
# Epoch 5: val_NMSE improved from 0.00360 to 0.00331, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 8.5400e-04 - mse: 2.7685e-04 - NMSE: 0.0025 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0283 - beta_latentspace_dist: 0.0000e+00 - val_loss: 9.2000e-04 - val_mse: 3.6764e-04 - val_NMSE: 0.0033 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 6/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 7.9846e-04 - mse: 2.6444e-04 - NMSE: 0.0024 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0275 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 1m 48.7s
#
# Epoch 6: val_NMSE did not improve from 0.00331
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 7.9844e-04 - mse: 2.6444e-04 - NMSE: 0.0024 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0275 - beta_latentspace_dist: 0.0000e+00 - val_loss: 0.0010 - val_mse: 4.9187e-04 - val_NMSE: 0.0044 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 7/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 7.5325e-04 - mse: 2.4747e-04 - NMSE: 0.0022 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0266 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 2m 6.3s
#
# Epoch 7: val_NMSE improved from 0.00331 to 0.00272, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 7.5318e-04 - mse: 2.4741e-04 - NMSE: 0.0022 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0266 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.9662e-04 - val_mse: 3.0196e-04 - val_NMSE: 0.0027 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 8/1000
# 3117/3126 [============================>.] - ETA: 0s - loss: 7.2168e-04 - mse: 2.3520e-04 - NMSE: 0.0021 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0259 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 2m 24.0s
#
# Epoch 8: val_NMSE did not improve from 0.00272
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 7.2174e-04 - mse: 2.3529e-04 - NMSE: 0.0021 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0259 - beta_latentspace_dist: 0.0000e+00 - val_loss: 8.9146e-04 - val_mse: 4.1346e-04 - val_NMSE: 0.0037 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 9/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 7.0200e-04 - mse: 2.2943e-04 - NMSE: 0.0021 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0256 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 2m 42.7s
#
# Epoch 9: val_NMSE did not improve from 0.00272
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 7.0204e-04 - mse: 2.2947e-04 - NMSE: 0.0021 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0256 - beta_latentspace_dist: 0.0000e+00 - val_loss: 8.5122e-04 - val_mse: 3.8407e-04 - val_NMSE: 0.0035 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 10/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 6.8005e-04 - mse: 2.1666e-04 - NMSE: 0.0020 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0249 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 3m 1.2s
#
# Epoch 10: val_NMSE improved from 0.00272 to 0.00219, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.8005e-04 - mse: 2.1666e-04 - NMSE: 0.0020 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0249 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.0353e-04 - val_mse: 2.4341e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 11/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 6.7000e-04 - mse: 2.1390e-04 - NMSE: 0.0019 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0245 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 3m 20.9s
#
# Epoch 11: val_NMSE did not improve from 0.00219
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.6999e-04 - mse: 2.1390e-04 - NMSE: 0.0019 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0245 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.4237e-04 - val_mse: 2.8904e-04 - val_NMSE: 0.0026 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 12/1000
# 3120/3126 [============================>.] - ETA: 0s - loss: 6.5539e-04 - mse: 2.0464e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0241 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 3m 40.0s
#
# Epoch 12: val_NMSE improved from 0.00219 to 0.00217, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.5537e-04 - mse: 2.0462e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0241 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.8943e-04 - val_mse: 2.4083e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 13/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 6.4798e-04 - mse: 2.0172e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0239 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 3m 59.8s
#
# Epoch 13: val_NMSE did not improve from 0.00217
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.4798e-04 - mse: 2.0172e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0239 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.0259e-04 - val_mse: 2.5821e-04 - val_NMSE: 0.0023 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 14/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 6.3988e-04 - mse: 1.9688e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0236 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 4m 19.3s
#
# Epoch 14: val_NMSE did not improve from 0.00217
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.3989e-04 - mse: 1.9690e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0236 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.8308e-04 - val_mse: 3.4112e-04 - val_NMSE: 0.0031 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 15/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 6.3545e-04 - mse: 1.9502e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0235 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 4m 38.6s
#
# Epoch 15: val_NMSE improved from 0.00217 to 0.00173, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.3539e-04 - mse: 1.9496e-04 - NMSE: 0.0018 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0235 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.3031e-04 - val_mse: 1.9173e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 16/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 6.2852e-04 - mse: 1.9028e-04 - NMSE: 0.0017 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0233 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 4m 57.6s
#
# Epoch 16: val_NMSE did not improve from 0.00173
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.2851e-04 - mse: 1.9027e-04 - NMSE: 0.0017 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0233 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.7714e-04 - val_mse: 2.3980e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 17/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 6.2575e-04 - mse: 1.8952e-04 - NMSE: 0.0017 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0233 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 5m 17.1s
#
# Epoch 17: val_NMSE did not improve from 0.00173
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.2571e-04 - mse: 1.8949e-04 - NMSE: 0.0017 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0233 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.8247e-04 - val_mse: 2.4652e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 18/1000
# 3120/3126 [============================>.] - ETA: 0s - loss: 6.1738e-04 - mse: 1.8184e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0229 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 5m 36.8s
#
# Epoch 18: val_NMSE did not improve from 0.00173
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.1749e-04 - mse: 1.8195e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0229 - beta_latentspace_dist: 0.0000e+00 - val_loss: 0.0010 - val_mse: 6.0455e-04 - val_NMSE: 0.0054 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 19/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 6.2178e-04 - mse: 1.8796e-04 - NMSE: 0.0017 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0231 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 5m 56.2s
#
# Epoch 19: val_NMSE improved from 0.00173 to 0.00164, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.2178e-04 - mse: 1.8796e-04 - NMSE: 0.0017 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0231 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1551e-04 - val_mse: 1.8226e-04 - val_NMSE: 0.0016 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 20/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 6.1285e-04 - mse: 1.7965e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0229 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 6m 15.7s
#
# Epoch 20: val_NMSE improved from 0.00164 to 0.00155, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.1284e-04 - mse: 1.7963e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0229 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.0557e-04 - val_mse: 1.7249e-04 - val_NMSE: 0.0016 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 21/1000
# 3120/3126 [============================>.] - ETA: 0s - loss: 6.1476e-04 - mse: 1.8232e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0228 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 6m 35.8s
#
# Epoch 21: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.1480e-04 - mse: 1.8236e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0228 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.2355e-04 - val_mse: 2.9134e-04 - val_NMSE: 0.0026 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 22/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 6.1179e-04 - mse: 1.8007e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0228 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 6m 55.5s
#
# Epoch 22: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.1187e-04 - mse: 1.8015e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0228 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.7990e-04 - val_mse: 3.4854e-04 - val_NMSE: 0.0031 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 23/1000
# 3118/3126 [============================>.] - ETA: 0s - loss: 6.1106e-04 - mse: 1.7972e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0227 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 7m 15.4s
#
# Epoch 23: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.1108e-04 - mse: 1.7974e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0227 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.9871e-04 - val_mse: 2.6788e-04 - val_NMSE: 0.0024 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 24/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 6.0574e-04 - mse: 1.7446e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0225 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 7m 34.7s
#
# Epoch 24: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.0574e-04 - mse: 1.7446e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0225 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.4313e-04 - val_mse: 3.1281e-04 - val_NMSE: 0.0028 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 25/1000
# 3125/3126 [============================>.] - ETA: 0s - loss: 6.0642e-04 - mse: 1.7583e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0226 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 7m 54.5s
#
# Epoch 25: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.0642e-04 - mse: 1.7583e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0226 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.3304e-04 - val_mse: 2.0292e-04 - val_NMSE: 0.0018 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 26/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 6.0123e-04 - mse: 1.7080e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0225 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 8m 14.0s
#
# Epoch 26: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 6.0123e-04 - mse: 1.7079e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0225 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.8323e-04 - val_mse: 2.5256e-04 - val_NMSE: 0.0023 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 27/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 6.0379e-04 - mse: 1.7381e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0226 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 8m 33.1s
#
# Epoch 27: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.0383e-04 - mse: 1.7385e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0226 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.8814e-04 - val_mse: 3.5779e-04 - val_NMSE: 0.0032 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 28/1000
# 3125/3126 [============================>.] - ETA: 0s - loss: 6.0356e-04 - mse: 1.7342e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0224 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 8m 52.4s
#
# Epoch 28: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.0356e-04 - mse: 1.7342e-04 - NMSE: 0.0016 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0224 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.3338e-04 - val_mse: 2.0373e-04 - val_NMSE: 0.0018 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 29/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 5.9844e-04 - mse: 1.6862e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0224 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 9m 12.6s
#
# Epoch 29: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 5.9843e-04 - mse: 1.6861e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0224 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.4817e-04 - val_mse: 2.1751e-04 - val_NMSE: 0.0020 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 30/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 6.0151e-04 - mse: 1.7174e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0224 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 9m 31.7s
#
# Epoch 30: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 6.0150e-04 - mse: 1.7173e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0224 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.4939e-04 - val_mse: 2.1935e-04 - val_NMSE: 0.0020 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 31/1000
# 3115/3126 [============================>.] - ETA: 0s - loss: 5.9810e-04 - mse: 1.6800e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 9m 51.1s
#
# Epoch 31: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 5.9803e-04 - mse: 1.6793e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.2765e-04 - val_mse: 1.9813e-04 - val_NMSE: 0.0018 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 32/1000
# 3118/3126 [============================>.] - ETA: 0s - loss: 5.9198e-04 - mse: 1.6176e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 10m 10.9s
#
# Epoch 32: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 5.9192e-04 - mse: 1.6170e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.4048e-04 - val_mse: 2.1008e-04 - val_NMSE: 0.0019 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 33/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.9567e-04 - mse: 1.6571e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 10m 30.2s
#
# Epoch 33: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 5.9563e-04 - mse: 1.6568e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1930e-04 - val_mse: 1.9023e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 34/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.9555e-04 - mse: 1.6639e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0223 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 10m 49.8s
#
# Epoch 34: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 5.9553e-04 - mse: 1.6637e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0223 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1160e-04 - val_mse: 1.8235e-04 - val_NMSE: 0.0016 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 35/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.9203e-04 - mse: 1.6269e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 11m 9.4s
#
# Epoch 35: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 5.9204e-04 - mse: 1.6271e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.3563e-04 - val_mse: 3.0582e-04 - val_NMSE: 0.0028 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 36/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 5.9666e-04 - mse: 1.6722e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 11m 28.6s
#
# Epoch 36: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 5.9664e-04 - mse: 1.6720e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1826e-04 - val_mse: 1.8984e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 37/1000
# 3120/3126 [============================>.] - ETA: 0s - loss: 5.8981e-04 - mse: 1.6064e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 11m 48.3s
#
# Epoch 37: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 20s 6ms/step - loss: 5.8981e-04 - mse: 1.6064e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.6567e-04 - val_mse: 2.3588e-04 - val_NMSE: 0.0021 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 38/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.9325e-04 - mse: 1.6433e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 12m 7.2s
#
# Epoch 38: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 19s 6ms/step - loss: 5.9329e-04 - mse: 1.6437e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.7250e-04 - val_mse: 2.4307e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 39/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 5.9259e-04 - mse: 1.6373e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 12m 25.7s
#
# Epoch 39: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.9259e-04 - mse: 1.6373e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0222 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.2539e-04 - val_mse: 1.9608e-04 - val_NMSE: 0.0018 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 40/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.9041e-04 - mse: 1.6131e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 12m 43.5s
#
# Epoch 40: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.9040e-04 - mse: 1.6130e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.3447e-04 - val_mse: 2.0509e-04 - val_NMSE: 0.0018 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 41/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 5.8904e-04 - mse: 1.5985e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 13m 0.8s
#
# Epoch 41: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 17s 6ms/step - loss: 5.8908e-04 - mse: 1.5989e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.8065e-04 - val_mse: 2.5170e-04 - val_NMSE: 0.0023 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 42/1000
# 3117/3126 [============================>.] - ETA: 0s - loss: 5.9080e-04 - mse: 1.6187e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 13m 18.9s
#
# Epoch 42: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.9073e-04 - mse: 1.6180e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.3888e-04 - val_mse: 2.1002e-04 - val_NMSE: 0.0019 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 43/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 5.8667e-04 - mse: 1.5758e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 13m 36.7s
#
# Epoch 43: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8669e-04 - mse: 1.5760e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.1533e-04 - val_mse: 2.8585e-04 - val_NMSE: 0.0026 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 44/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.9180e-04 - mse: 1.6307e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 13m 54.7s
#
# Epoch 44: val_NMSE did not improve from 0.00155
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.9177e-04 - mse: 1.6305e-04 - NMSE: 0.0015 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.6695e-04 - val_mse: 2.3815e-04 - val_NMSE: 0.0021 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 45/1000
# 3119/3126 [============================>.] - ETA: 0s - loss: 5.8272e-04 - mse: 1.5369e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 14m 12.4s
#
# Epoch 45: val_NMSE improved from 0.00155 to 0.00143, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8263e-04 - mse: 1.5360e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.8948e-04 - val_mse: 1.5941e-04 - val_NMSE: 0.0014 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 46/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 5.8890e-04 - mse: 1.5975e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 14m 30.1s
#
# Epoch 46: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8899e-04 - mse: 1.5983e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.0960e-04 - val_mse: 2.8104e-04 - val_NMSE: 0.0025 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 47/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.8540e-04 - mse: 1.5649e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 14m 47.7s
#
# Epoch 47: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8539e-04 - mse: 1.5647e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.5681e-04 - val_mse: 2.2785e-04 - val_NMSE: 0.0021 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 48/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.8732e-04 - mse: 1.5847e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 15m 5.3s
#
# Epoch 48: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8730e-04 - mse: 1.5845e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1113e-04 - val_mse: 1.8215e-04 - val_NMSE: 0.0016 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 49/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 5.8487e-04 - mse: 1.5605e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 15m 22.5s
#
# Epoch 49: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 17s 6ms/step - loss: 5.8490e-04 - mse: 1.5608e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.5575e-04 - val_mse: 2.2631e-04 - val_NMSE: 0.0020 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 50/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 5.8767e-04 - mse: 1.5898e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 15m 40.3s
#
# Epoch 50: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8767e-04 - mse: 1.5898e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1702e-04 - val_mse: 1.8812e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 51/1000
# 3118/3126 [============================>.] - ETA: 0s - loss: 5.8584e-04 - mse: 1.5717e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 15m 58.3s
#
# Epoch 51: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8575e-04 - mse: 1.5707e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.9515e-04 - val_mse: 1.6608e-04 - val_NMSE: 0.0015 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 52/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 5.8218e-04 - mse: 1.5337e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 16m 15.5s
#
# Epoch 52: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 17s 6ms/step - loss: 5.8217e-04 - mse: 1.5336e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.2069e-04 - val_mse: 1.9125e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 53/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 5.8918e-04 - mse: 1.6104e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 16m 32.8s
#
# Epoch 53: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 17s 6ms/step - loss: 5.8918e-04 - mse: 1.6104e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0221 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.8674e-04 - val_mse: 2.5875e-04 - val_NMSE: 0.0023 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 54/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.8357e-04 - mse: 1.5506e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 16m 51.0s
#
# Epoch 54: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8356e-04 - mse: 1.5504e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.4580e-04 - val_mse: 2.1731e-04 - val_NMSE: 0.0020 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 55/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 5.8475e-04 - mse: 1.5639e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 17m 8.3s
#
# Epoch 55: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 17s 6ms/step - loss: 5.8474e-04 - mse: 1.5638e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0220 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.0364e-04 - val_mse: 1.7520e-04 - val_NMSE: 0.0016 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 56/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.8394e-04 - mse: 1.5532e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 17m 25.6s
#
# Epoch 56: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 17s 6ms/step - loss: 5.8398e-04 - mse: 1.5536e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.9884e-04 - val_mse: 2.7034e-04 - val_NMSE: 0.0024 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 57/1000
# 3118/3126 [============================>.] - ETA: 0s - loss: 5.8068e-04 - mse: 1.5178e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0218 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 17m 43.2s
#
# Epoch 57: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8061e-04 - mse: 1.5172e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0218 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.4254e-04 - val_mse: 2.1357e-04 - val_NMSE: 0.0019 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 58/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.8259e-04 - mse: 1.5375e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0218 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 18m 1.3s
#
# Epoch 58: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8257e-04 - mse: 1.5373e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0218 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.0551e-04 - val_mse: 1.7662e-04 - val_NMSE: 0.0016 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 59/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.8290e-04 - mse: 1.5432e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 18m 19.5s
#
# Epoch 59: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8297e-04 - mse: 1.5439e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.7452e-04 - val_mse: 3.4677e-04 - val_NMSE: 0.0031 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 60/1000
# 3125/3126 [============================>.] - ETA: 0s - loss: 5.8008e-04 - mse: 1.5147e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - tot_time: 0h 18m 37.3s
#
# Epoch 60: val_NMSE did not improve from 0.00143
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 18s 6ms/step - loss: 5.8008e-04 - mse: 1.5147e-04 - NMSE: 0.0014 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0219 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.2944e-04 - val_mse: 2.0059e-04 - val_NMSE: 0.0018 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 61/1000
# ...
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6310e-04 - mse: 1.3534e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1306e-04 - val_mse: 1.8526e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 25/1000
# 3126/3126 [==============================] - ETA: 0s - loss: 5.6497e-04 - mse: 1.3721e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 39m 22.2s
#
# Epoch 25: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6497e-04 - mse: 1.3721e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.1315e-04 - val_mse: 1.8635e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 26/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.5927e-04 - mse: 1.3150e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 39m 49.7s
#
# Epoch 26: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.5925e-04 - mse: 1.3147e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.7322e-04 - val_mse: 1.4507e-04 - val_NMSE: 0.0013 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 27/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.6313e-04 - mse: 1.3552e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 40m 17.7s
#
# Epoch 27: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6313e-04 - mse: 1.3551e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.6023e-04 - val_mse: 2.3267e-04 - val_NMSE: 0.0021 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 28/1000
# 3125/3126 [============================>.] - ETA: 0s - loss: 5.6261e-04 - mse: 1.3483e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 40m 45.6s
#
# Epoch 28: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6261e-04 - mse: 1.3483e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.9694e-04 - val_mse: 1.6940e-04 - val_NMSE: 0.0015 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 29/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.6349e-04 - mse: 1.3620e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0213 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 41m 13.6s
#
# Epoch 29: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6347e-04 - mse: 1.3618e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0213 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.7016e-04 - val_mse: 1.4235e-04 - val_NMSE: 0.0013 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 30/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 5.6430e-04 - mse: 1.3673e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 41m 41.7s
#
# Epoch 30: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6430e-04 - mse: 1.3673e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.8704e-04 - val_mse: 1.5973e-04 - val_NMSE: 0.0014 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 31/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.6338e-04 - mse: 1.3586e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 42m 9.9s
#
# Epoch 31: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6336e-04 - mse: 1.3584e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.7792e-04 - val_mse: 1.5065e-04 - val_NMSE: 0.0014 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 32/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 5.5832e-04 - mse: 1.3027e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0210 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 42m 37.7s
#
# Epoch 32: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.5828e-04 - mse: 1.3022e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0210 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.5299e-04 - val_mse: 1.2478e-04 - val_NMSE: 0.0011 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 33/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.6197e-04 - mse: 1.3402e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0211 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 43m 5.6s
#
# Epoch 33: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6196e-04 - mse: 1.3401e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0211 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.2244e-04 - val_mse: 1.9420e-04 - val_NMSE: 0.0017 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 34/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.6261e-04 - mse: 1.3504e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 43m 33.7s
#
# Epoch 34: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6261e-04 - mse: 1.3504e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.9142e-04 - val_mse: 1.6348e-04 - val_NMSE: 0.0015 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 35/1000
# 3125/3126 [============================>.] - ETA: 0s - loss: 5.6394e-04 - mse: 1.3646e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 44m 1.4s
#
# Epoch 35: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6394e-04 - mse: 1.3646e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.9593e-04 - val_mse: 2.6835e-04 - val_NMSE: 0.0024 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 36/1000
# 3120/3126 [============================>.] - ETA: 0s - loss: 5.6241e-04 - mse: 1.3480e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 44m 29.6s
#
# Epoch 36: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6236e-04 - mse: 1.3475e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.9800e-04 - val_mse: 1.7032e-04 - val_NMSE: 0.0015 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 37/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.6177e-04 - mse: 1.3416e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 44m 57.3s
#
# Epoch 37: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6179e-04 - mse: 1.3418e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.4040e-04 - val_mse: 2.1241e-04 - val_NMSE: 0.0019 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 38/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 5.6274e-04 - mse: 1.3513e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 45m 25.2s
#
# Epoch 38: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6275e-04 - mse: 1.3514e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.6971e-04 - val_mse: 2.4160e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 39/1000
# 3123/3126 [============================>.] - ETA: 0s - loss: 5.6184e-04 - mse: 1.3433e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 45m 53.2s
#
# Epoch 39: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6184e-04 - mse: 1.3432e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.8283e-04 - val_mse: 1.5458e-04 - val_NMSE: 0.0014 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 40/1000
# 3124/3126 [============================>.] - ETA: 0s - loss: 5.6296e-04 - mse: 1.3541e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 46m 20.8s
#
# Epoch 40: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6298e-04 - mse: 1.3543e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 6.7741e-04 - val_mse: 2.4952e-04 - val_NMSE: 0.0022 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 41/1000
# 3122/3126 [============================>.] - ETA: 0s - loss: 5.6176e-04 - mse: 1.3407e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 46m 49.2s
#
# Epoch 41: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6176e-04 - mse: 1.3408e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.9538e-04 - val_mse: 1.6786e-04 - val_NMSE: 0.0015 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 42/1000
# 3125/3126 [============================>.] - ETA: 0s - loss: 5.6273e-04 - mse: 1.3523e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 47m 17.4s
#
# Epoch 42: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6273e-04 - mse: 1.3523e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.9594e-04 - val_mse: 1.6855e-04 - val_NMSE: 0.0015 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 43/1000
# 3121/3126 [============================>.] - ETA: 0s - loss: 5.6047e-04 - mse: 1.3291e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - tot_time: 1h 47m 45.5s
#
# Epoch 43: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6056e-04 - mse: 1.3300e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0212 - beta_latentspace_dist: 0.0000e+00 - val_loss: 7.2223e-04 - val_mse: 2.9451e-04 - val_NMSE: 0.0027 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 44/1000
# 3116/3126 [============================>.] - ETA: 0s - loss: 5.6270e-04 - mse: 1.3498e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0211 - beta_latentspace_dist: 0.0000e+00Restoring model weights from the end of the best epoch: 19.
#  - tot_time: 1h 48m 13.7s
#
# Epoch 44: val_NMSE did not improve from 0.00098
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_060/checkpoints/LossHistoriesCheckpoint
# 3126/3126 [==============================] - 28s 9ms/step - loss: 5.6262e-04 - mse: 1.3490e-04 - NMSE: 0.0012 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0211 - beta_latentspace_dist: 0.0000e+00 - val_loss: 5.8199e-04 - val_mse: 1.5436e-04 - val_NMSE: 0.0014 - val_ls_jacobian_norm: 0.0000e+00 - val_ls_dist_loss: 0.0000e+00 - val_beta_latentspace_dist: 0.0000e+00
# Epoch 44: early stopping

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    test_metrics = ae_t_net.evaluate(
        testing_data, testing_data,
    )
    train_metrics = ae_t_net.evaluate(training_data, training_data)
    val_metrics = ae_t_net.evaluate(val_data, val_data)

    save_path = dir_name_ae+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'val_MSE_hist':val_MSE_hist,
            'train_MSE_hist':train_MSE_hist,
            'val_NMSE_hist':val_NMSE_hist,
            'train_NMSE_hist':train_NMSE_hist,
            'train_ls_jacobian_loss_hist':train_ls_jacobian_loss_hist,
            'train_ls_dist_loss_hist':train_ls_dist_loss_hist,
            'train_betals_hist':train_betals_hist,
            'lr_change':lr_change,
            'test_loss':test_metrics[0],
            'test_mse':test_metrics[1],
            'train_loss':train_metrics[0],
            'train_mse':train_metrics[1],
            'val_loss':val_metrics[0],
            'val_mse':val_metrics[1],
        }))

    ae_net.save_everything(
        file_name=save_path+dir_sep+'final_net')
# Out:
# 782/782 [==============================] - 3s 4ms/step - loss: 5.5128e-04 - mse: 1.2413e-04 - NMSE: 0.0011 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0000e+00 - beta_latentspace_dist: 0.0000e+00
# 6251/6251 [==============================] - 28s 4ms/step - loss: 5.4858e-04 - mse: 1.2142e-04 - NMSE: 0.0011 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0000e+00 - beta_latentspace_dist: 0.0000e+00
# 782/782 [==============================] - 3s 4ms/step - loss: 5.4948e-04 - mse: 1.2233e-04 - NMSE: 0.0011 - ls_jacobian_norm: 0.0000e+00 - ls_dist_loss: 0.0000e+00 - beta_latentspace_dist: 0.0000e+00

# %%
print('lr_change : ', lr_change)
# Out:
# lr_change :  [0, 186, 243, 287]

# %%
temp = []
for lst in train_ls_dist_loss_hist:
    temp.extend(lst)
train_ls_dist_loss_hist_og = train_ls_dist_loss_hist
train_ls_dist_loss_hist = np.array(temp)

temp = []
for lst in train_ls_jacobian_loss_hist:
    temp.extend(lst)
train_ls_jacobian_loss_hist_og = train_ls_jacobian_loss_hist
train_ls_jacobian_loss_hist = np.array(temp)

temp = []
for lst in train_betals_hist:
    temp.extend(lst)
train_betals_hist_og = train_betals_hist
train_betals_hist = np.array(temp)

# %%
# plotting losses
dir_name_plot = dir_name_ae + '/plots'
if not os.path.isdir(dir_name_plot):
    os.makedirs(dir_name_plot)

# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list
)

plt.savefig(dir_name_plot + '{ds}loss_history.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()


fig, ax = plot_losses(
    training_loss=train_MSE_hist,
    val_loss=val_MSE_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=['Training MSE', 'Validation MSE'],
    xlabel='Epoch',
    ylabel='MSE',
)
plt.savefig(dir_name_plot+'/MSE_history.png', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_NMSE_hist,
    val_loss=val_NMSE_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=['Training NMSE', 'Validation NMSE'],
    xlabel='Epoch',
    ylabel='NMSE',
)
plt.savefig(dir_name_plot+'/NMSE_history.png', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_ls_jacobian_loss_hist,
    val_loss=None,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=[r"$\| \nabla_{x} z^{encoded} \|$"],
    xlabel='Epoch',
    ylabel=r"$\| \nabla_{x} v^{encoded} \|$",
    plot_type='plot',
)
plt.savefig(dir_name_plot+'/train_ls_jacobian_loss_hist.png', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_ls_dist_loss_hist,
    val_loss=None,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=[r"$|v_{(t)} - v_{(t-1)}| / |x_{(t)} - x_{(t-1)}|$"],
    xlabel='Epoch',
    ylabel=r"$|v_{(t)} - v_{(t-1)}| / |x_{(t)} - x_{(t-1)}|$",
    plot_type='plot',
)
plt.savefig(dir_name_plot+'/train_ls_dist_loss_hist.png', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()


fig, ax = plot_losses(
    training_loss=train_betals_hist,
    val_loss=None,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list,
    legend_list=[r"$\beta$"],
    xlabel='Epoch',
    ylabel=r"$\beta$",
    plot_type='plot',
)
plt.savefig(dir_name_plot+'/train_betals_hist.png', dpi=300, bbox_inches='tight')
plt.show()
plt.clf()

# %%
# Out:
# 3

# %%
reconstructed_data = ae_net.predict(all_data_og)

# %%
plot_reconstructed_data_KS(
    boundary_idx_arr,
    dir_name_ae,
    all_data_og,
    reconstructed_data, delta_t, xgrid,
    save_figs=False,
    normalization_constant_arr=normalization_constant_arr_aedata,
    xticks_snapto=xticks_snapto,
    num_yticks=11)

# %%
plot_reconstructed_data_KS(
    boundary_idx_arr,
    dir_name_ae,
    all_data_og,
    reconstructed_data, delta_t, xgrid,
    save_figs=True,
    normalization_constant_arr=normalization_constant_arr_aedata,
    xticks_snapto=xticks_snapto,
    num_yticks=11)

# %%
time_to_plot = 20



plot_reconstructed_data_KS(
    boundary_idx_arr,
    dir_name_ae,
    all_data_og,
    reconstructed_data, delta_t, xgrid,
    save_figs=True,
    normalization_constant_arr=normalization_constant_arr_aedata,
    xticks_snapto=xticks_snapto,
    num_yticks=11)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data_og)

# %%
plot_latent_states_KS(
    boundary_idx_arr,
    latent_states_all,
    delta_t,
    dir_name_ae,
    xticks_snapto=xticks_snapto,
    num_yticks=11,
    save_figs=False)

# %%
plot_latent_states_KS(
    boundary_idx_arr,
    latent_states_all,
    delta_t,
    dir_name_ae,
    xticks_snapto=xticks_snapto,
    num_yticks=11,
    save_figs=True)

# %%
# ae_net.summary()

# %%
n = len(boundary_idx_arr)
num_digits_n = int(np.log10(n)+1)

# '''
num_cols = 1
num_rows = latent_states_all.shape[-1]
factor = 1
num_modes = xgrid.shape[0]

prev_idx = 0
for i in range(n):
    lyap_time = lyapunov_time_arr[i]
    start_time = 0
    plot_time = 20*lyap_time
    # next_idx = boundary_idx_arr[i]
    prev_idx += int((start_time + 0.5*delta_t)//delta_t) 
    next_idx = prev_idx + int((plot_time+0.5*delta_t)//delta_t)
    fig, ax = plt.subplots(num_rows, num_cols, sharex=True, figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
    N = next_idx - prev_idx
    # print(N)
    input_time = (start_time + np.arange(0, N)*delta_t)/lyap_time
    
    # temp = N*delta_t
    # chosen_interval = temp//10
    # sn = np.format_float_scientific(chosen_interval, exp_digits=4)
    # # print(temp, sn)
    # snap = 25*np.round(10*float(sn[0:-6])/25)/10
    # if snap == 0:
    #     snap = 0.1
    # snap *= float('1'+sn[-6:])
    # xticks_snapto = int(snap*np.round(chosen_interval/snap))

    for j in range(latent_states_all.shape[-1]):
        ax[j].plot(input_time, latent_states_all[prev_idx:next_idx, j])
        # ax[j].plot(input_time, D_reconstructed_list[i][prev_idx:next_idx], color='C0', label='Reconstructed Data')
        # num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
        # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
        # xticks = int((start_time + 0.5*delta_t)//delta_t) + np.arange(0, N+1, int((xticks_snapto+0.5*delta_t)//delta_t))
        # print(xticks)
        # ax[j].set_xticks(ticks=np.round(xticks*delta_t, 1))
        # ax[j].set_xticklabels('')
        ax[j].tick_params(axis='x', rotation=270+45)
        ax[j].set_ylabel('latent state {}'.format(j+1))
        ax[j].set_xlabel(r'Time$^+$')
        ax[j].grid(True)

    # yticks = np.linspace(0, 1, 10+1)*(len(xgrid)-1)
    # yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
    # ax.set_yticks(ticks=yticks)
    # ax.set_yticklabels(yticklabels)

    # ax[-1].set_xlabel(r'Time$^+$')
    # ax[0].legend()
    # ax.title.set_text(r'Latent States')
    # if ax_titles_list is not None:
    #     ax.title.set_text(ax_titles_list[i])
    # else:
    ax[0].title.set_text(r'Case '+str(i+1))

    if save_dir is not None:
        fig.savefig(dir_name_plot+'/LatentSpace-Case_'+str(i+1).zfill(num_digits_n)+'.png', dpi=300, bbox_inches='tight')
        fig.clear()
        plt.close()
    else:
        plt.show()
        print('')

    prev_idx = boundary_idx_arr[i]

# %% [markdown]
# # KE and Dissipation

# %%
save_dir = dir_name_ae+dir_sep+'plots'
# save_dir = None

# %%
# Time evolution of Kinetic Energy
KE_org_list = []
KE_reconstructed_list = []
KE_nrmse = []

if normalizeforae_flag == True:
    rescaled_org_data = all_data_og[:, 0:xgrid.shape[0]]#.copy()
    rescaled_recon_data = reconstructed_data[:, 0:xgrid.shape[0]]#.copy()
    for i in range(xgrid.shape[0]):
        rescaled_org_data[:, i] *= normalization_constant_arr_aedata[1, i]
        rescaled_org_data[:, i] += normalization_constant_arr_aedata[0, i]
        rescaled_recon_data[:, i] *= normalization_constant_arr_aedata[1, i]
        rescaled_recon_data[:, i] += normalization_constant_arr_aedata[0, i]
else:
    rescaled_org_data = all_data_og[:, 0:xgrid.shape[0]]
    rescaled_recon_data = reconstructed_data[:, 0:xgrid.shape[0]]

if normalize_flag_ogdata == True:
    for i in range(xgrid.shape[0]):
        rescaled_org_data[:, i] *= normalization_constant_arr_ogdata[1, i]
        rescaled_org_data[:, i] += normalization_constant_arr_ogdata[0, i]
        rescaled_recon_data[:, i] *= normalization_constant_arr_ogdata[1, i]
        rescaled_recon_data[:, i] += normalization_constant_arr_ogdata[0, i]

begin_idx = 0
for i in range(len(boundary_idx_arr)):
    KE_org = np.sum(rescaled_org_data[begin_idx:boundary_idx_arr[i], 1:-1]**2, axis=1)
    KE_org += 0.5*(rescaled_org_data[begin_idx:boundary_idx_arr[i], 0]**2)
    KE_org += 0.5*(rescaled_org_data[begin_idx:boundary_idx_arr[i], -1]**2)
    KE_org /= xgrid.shape[0]-1
    KE_org_list.append(KE_org)
    
    KE_recon = np.sum(rescaled_recon_data[begin_idx:boundary_idx_arr[i], 1:-1]**2, axis=1)
    KE_recon += 0.5*(rescaled_recon_data[begin_idx:boundary_idx_arr[i], 0]**2)
    KE_recon += 0.5*(rescaled_recon_data[begin_idx:boundary_idx_arr[i], -1]**2)
    KE_recon /= xgrid.shape[0]-1
    KE_reconstructed_list.append(KE_recon)

    KE_rmse = np.mean((KE_recon - KE_org)**2)**0.5
    KE_mean = np.mean(KE_org)
    KE_rmse_normalized = KE_rmse/KE_mean
    KE_nrmse.append(KE_rmse_normalized)
    
    print('Case {} - KE_nrmse : {}'.format(i+1, KE_rmse_normalized))

    begin_idx = boundary_idx_arr[i]
# Out:
# Case 1 - KE_nrmse : 0.017378152627142335

# %%
n = len(boundary_idx_arr)
num_digits_n = int(np.log10(n)+1)

# '''
num_cols = 1
num_rows = 1
factor = 1

num_modes = xgrid.shape[0]

prev_idx = 0
for i in range(n):
    lyap_time = lyapunov_time_arr[i]
    print(lyap_time)
    start_time = 0
    plot_time = 20*lyap_time
    # next_idx = boundary_idx_arr[i]
    prev_idx += int((start_time + 0.5*delta_t)//delta_t) 
    next_idx = prev_idx + int((plot_time+0.5*delta_t)//delta_t)
    fig, ax = plt.subplots(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
    N = next_idx - prev_idx
    # print(N)
    input_time = (start_time + np.arange(0, N)*delta_t)/lyap_time

    # temp = N*delta_t
    # chosen_interval = temp//10
    # sn = np.format_float_scientific(chosen_interval, exp_digits=4)
    # # print(temp, sn)
    # snap = 25*np.round(10*float(sn[0:-6])/25)/10
    # if snap == 0:
    #     snap = 0.1
    # snap *= float('1'+sn[-6:])
    # xticks_snapto = int(snap*np.round(chosen_interval/snap))

    # prev_idx = boundary_idx_arr[i] - (next_idx-prev_idx)
    # next_idx = boundary_idx_arr[i]
    
    ax.plot(input_time, KE_org_list[i][prev_idx:next_idx], color='k', label='Original Data')
    ax.plot(input_time, KE_reconstructed_list[i][prev_idx:next_idx], color='C0', label='Reconstructed Data')
    # num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
    # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
    # xticks = int((start_time + 0.5*delta_t)//delta_t) + np.arange(0, N+1, int((xticks_snapto+0.5*delta_t)//delta_t))
    # print(xticks)
    # ax.set_xticks(ticks=np.round(xticks*delta_t, 1))
    # ax.set_xticklabels(np.round(xticks*delta_t, 1))
    ax.tick_params(axis='x', rotation=270+45)

    # yticks = np.linspace(0, 1, 10+1)*(len(xgrid)-1)
    # yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
    # ax.set_yticks(ticks=yticks)
    # ax.set_yticklabels(yticklabels)

    ax.set_xlabel(r'Time$^+$')
    ax.set_ylabel(r'$KE$')
    ax.grid(True)
    ax.legend()
    # ax.title.set_text(r'Latent States')
    # if ax_titles_list is not None:
    # ax.title.set_text(ax_titles_list[i])
    # else:
    ax.title.set_text(r'Case '+str(i+1))

    text_xy = [0.05, 0.05]
    ax.text(
        text_xy[0],
        text_xy[1],
        'latent space dimensions : {}'.format(
            latent_states_all.shape[1],
        ),
        transform=ax.transAxes,
        bbox=dict(
            boxstyle="round",
            ec=(0.6, 0.6, 1),
            fc=(0.9, 0.9, 1),
            alpha=0.8
        ),
        # bbox=dict(facecolor='C0', alpha=0.5, boxstyle='round,pad=0.2'),
        horizontalalignment='left',
        verticalalignment='bottom'
    )
    
    # plt.colorbar(im)
    if save_dir is not None:
        fig.savefig(save_dir+dir_sep+'KE-Case_'+str(i+1).zfill(num_digits_n)+'.png', dpi=300, bbox_inches='tight')
        fig.clear()
        plt.close()
    else:
        plt.show()
        print('')

    prev_idx = next_idx
# Out:
# 15.466301

# %%
def compute_laplace_operator(
        data,
        xgrid
    ):
    from scipy.fft import fft, ifft, fftfreq
    M = xgrid.shape[0]
    length = xgrid[-1]
    k = fftfreq(M) * M * 2*np.pi/length
    laplace_operated_data = data[:, 0:M].copy()
    for i in range(data.shape[0]):
        v = fft(data[i, 0:M])
        v = k*k*v
        laplace_operated_data[i, :] = np.real(ifft(v))
    return laplace_operated_data

# %%
# Time evolution of Dissipation
D_org_list = []
D_reconstructed_list = []
D_nrmse = []

begin_idx = 0
for i in range(len(boundary_idx_arr)):
    temp = compute_laplace_operator(rescaled_org_data[begin_idx:boundary_idx_arr[i]], xgrid)
    D_org = np.sum(temp[:, 1:-1]**2, axis=1)
    D_org += 0.5*(temp[:, 0]**2)
    D_org += 0.5*(temp[:, -1]**2)
    D_org /= xgrid.shape[0]-1
    D_org_list.append(D_org)
    
    temp = compute_laplace_operator(rescaled_recon_data[begin_idx:boundary_idx_arr[i]], xgrid)
    D_recon = np.sum(temp[:, 1:-1]**2, axis=1)
    D_recon += 0.5*(temp[:, 0]**2)
    D_recon += 0.5*(temp[:, -1]**2)
    D_recon /= xgrid.shape[0]-1
    D_reconstructed_list.append(D_recon)
    
    D_rmse = np.mean((D_recon - D_org)**2)**0.5
    D_mean = np.mean(D_org)
    D_rmse_normalized = D_rmse/D_mean
    D_nrmse.append(D_rmse_normalized)
    
    print('Case {} - D_nrmse : {}'.format(i+1, D_rmse_normalized))
    
    begin_idx = boundary_idx_arr[i]
# Out:
# Case 1 - D_nrmse : 0.03835365309311775

# %%
n = len(boundary_idx_arr)
num_digits_n = int(np.log10(n)+1)

# '''
num_cols = 1
num_rows = 1
factor = 1
num_modes = xgrid.shape[0]

prev_idx = 0
for i in range(n):
    lyap_time = lyapunov_time_arr[i]
    start_time = 0
    plot_time = 20*lyap_time
    # next_idx = boundary_idx_arr[i]
    prev_idx += int((start_time + 0.5*delta_t)//delta_t) 
    next_idx = prev_idx + int((plot_time+0.5*delta_t)//delta_t)
    fig, ax = plt.subplots(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
    N = next_idx - prev_idx
    # print(N)
    input_time = (start_time + np.arange(0, N)*delta_t)/lyap_time
    
    # temp = N*delta_t
    # chosen_interval = temp//10
    # sn = np.format_float_scientific(chosen_interval, exp_digits=4)
    # # print(temp, sn)
    # snap = 25*np.round(10*float(sn[0:-6])/25)/10
    # if snap == 0:
    #     snap = 0.1
    # snap *= float('1'+sn[-6:])
    # xticks_snapto = int(snap*np.round(chosen_interval/snap))

    ax.plot(input_time, D_org_list[i][prev_idx:next_idx], color='k', label='Original Data')
    ax.plot(input_time, D_reconstructed_list[i][prev_idx:next_idx], color='C0', label='Reconstructed Data')
    # num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
    # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
    # xticks = int((start_time + 0.5*delta_t)//delta_t) + np.arange(0, N+1, int((xticks_snapto+0.5*delta_t)//delta_t))
    # print(xticks)
    # ax.set_xticks(ticks=np.round(xticks*delta_t, 1))
    # ax.set_xticklabels(np.round(xticks*delta_t, 1))
    ax.tick_params(axis='x', rotation=270+45)

    # yticks = np.linspace(0, 1, 10+1)*(len(xgrid)-1)
    # yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
    # ax.set_yticks(ticks=yticks)
    # ax.set_yticklabels(yticklabels)

    ax.set_xlabel(r'Time$^+$')
    ax.set_ylabel(r'$D$')
    ax.grid(True)
    ax.legend()
    # ax.title.set_text(r'Latent States')
    # if ax_titles_list is not None:
    #     ax.title.set_text(ax_titles_list[i])
    # else:
    ax.title.set_text(r'Case '+str(i+1))

    text_xy = [0.05, 0.05]
    ax.text(
        text_xy[0],
        text_xy[1],
        'latent space dimensions : {}'.format(
            latent_states_all.shape[1],
        ),
        transform=ax.transAxes,
        bbox=dict(
            boxstyle="round",
            ec=(0.6, 0.6, 1),
            fc=(0.9, 0.9, 1),
            alpha=0.8
        ),
        # bbox=dict(facecolor='C0', alpha=0.5, boxstyle='round,pad=0.2'),
        horizontalalignment='left',
        verticalalignment='bottom'
    )

    if save_dir is not None:
        fig.savefig(save_dir+'/Dissipation-Case_'+str(i+1).zfill(num_digits_n)+'.png', dpi=300, bbox_inches='tight')
        fig.clear()
        plt.close()
    else:
        plt.show()
        print('')

    prev_idx = next_idx

# %%
np.savez(
    dir_name_ae+dir_sep+'KE_D_data',
    KE_org_list=KE_org_list,
    KE_reconstructed_list=KE_reconstructed_list,
    KE_nrmse=KE_nrmse,
    D_org_list=D_org_list,
    D_reconstructed_list=D_reconstructed_list,
    D_nrmse=D_nrmse,
    num_latent_states=[latent_states_all.shape[1]],
)

# %%
# x = np.linspace(-5, 5, 100)

# a = 1 #- np.exp(-2)

# modified_relu = lambda x : tf.keras.activations.relu(x+a).numpy()-a
# elu = lambda x : tf.keras.activations.elu(x)

# y1 = modified_relu(x)
# y2 = elu(x)

# plt.plot(x, y1, label='modified_relu')
# plt.plot(x, y2, label='elu')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
ae_net.decoder_layers_list[-1].weights
# Out:
# [<tf.Variable 'dense_15/kernel:0' shape=(128, 64) dtype=float32, numpy=
#  array([[ 3.0002000e-02,  3.1718366e-02,  9.2884516e-03, ...,
#          -5.1376078e-02, -3.4386639e-02,  2.2868274e-03],
#         [ 2.8765887e-01,  1.3087529e-01,  8.5808253e-03, ...,
#          -9.4464958e-02,  1.4721152e-01,  3.2368770e-01],
#         [-1.7040737e-04, -6.5530039e-05,  9.1837201e-04, ...,
#          -4.9201358e-04,  3.7817546e-04,  5.5794575e-04],
#         ...,
#         [ 2.2743011e-04, -1.9915173e-04, -7.2469731e-04, ...,
#          -2.7553827e-04, -6.7087152e-04, -1.6763688e-04],
#         [ 4.2327166e-02,  8.0094347e-03, -2.2595864e-02, ...,
#          -3.2918565e-02,  2.7946142e-02,  5.5396467e-02],
#         [-1.3646954e-03,  5.8110466e-04,  1.4570737e-03, ...,
#           3.4539835e-03,  7.1651512e-04, -1.6721236e-03]], dtype=float32)>,
#  <tf.Variable 'dense_15/bias:0' shape=(64,) dtype=float32, numpy=
#  array([ 0.0454962 ,  0.03192328,  0.01450776,  0.00239776, -0.00186392,
#          0.00061009,  0.00199889, -0.00516005, -0.01507374, -0.0149869 ,
#         -0.00253483,  0.01391029,  0.02828529,  0.03885936,  0.03800662,
#          0.01342548, -0.02926624, -0.05929293, -0.05569451, -0.03429086,
#         -0.02561698, -0.03689682, -0.04523919, -0.0268344 ,  0.01203347,
#          0.03764716,  0.02522014, -0.01315046, -0.04114062, -0.03439927,
#         -0.00537928,  0.01264834,  0.00596749, -0.00756011, -0.00239972,
#          0.02718701,  0.05874426,  0.06152838,  0.03123963, -0.00297306,
#         -0.01463831, -0.00990095, -0.0110611 , -0.02337929, -0.02902151,
#         -0.01316772,  0.01308548,  0.02320809,  0.006027  , -0.01994039,
#         -0.0289901 , -0.01798083, -0.00401945, -0.00082039, -0.00525092,
#         -0.00219697,  0.01696505,  0.03739422,  0.03257634,  0.00085385,
#         -0.02523811, -0.01839059,  0.01301087,  0.04047124], dtype=float32)>]
