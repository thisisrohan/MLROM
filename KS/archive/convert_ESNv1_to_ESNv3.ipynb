# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

# %%
colab_flag = False

FTYPE = np.float32
ITYPE = np.int32

array = np.array
float32 = np.float32
int32 = np.int32
float64 = np.float64
int64 = np.int64

# %%
if colab_flag == True:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Github/MLROM/KS/')

# %%
print(os.getcwd())
# Out:
# /home/rkaushik/Documents/Thesis/MLROM/KS

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if colab_flag == False:
    if gpus:
        gpu_to_use = 0
        tf.config.set_visible_devices(gpus[gpu_to_use], 'GPU')
        logical_devices = tf.config.list_logical_devices('GPU')
        print(logical_devices)
# Out:
# 2022-12-04 12:43:30.405611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.405911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.438308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.438581: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.438887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.439088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-12-04 12:43:30.440374: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-04 12:43:30.440811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.441009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.441185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.978197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.978419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.978624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 12:43:30.978809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3359 MB memory:  -> device: 0, name: Quadro K2200, pci bus id: 0000:02:00.0, compute capability: 5.0

# %%
from tools.misc_tools import create_data_for_RNN
from tools.ae_v5 import Autoencoder
from tools.ESN_v1 import ESN
from tools.ESN_v3 import ESN as ESNv3

# %%
# print(tf.test.gpu_device_name())
print(tf.config.list_physical_devices())
print('')
print(tf.config.list_logical_devices())
print('')
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
#
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]
#
# 2.8.1

# %% [markdown]
# # KS System

# %%
gs_idx = '000'
dir_name_gs_all = os.getcwd() + '/grid_search/gridsearch_' + gs_idx

# worker_id = 0

worker_dir_list = os.listdir(dir_name_gs_all)
worker_dir_list = [dir_name_gs_all+'/'+dname for dname in worker_dir_list if os.path.isdir(dir_name_gs_all+'/'+dname)]

# worker_dir_list = [dir_name_gs_all+'/worker_{}'.format(worker_id)]

ESN_dir_list = []
for dname in worker_dir_list:
    temp = os.listdir(dname)
    temp = [dname+'/'+esndir for esndir in temp if os.path.isdir(dname+'/'+esndir)]
    ESN_dir_list.extend(temp)

# dir_name_esn_all = os.getcwd() + '/saved_ESN'
# ESN_dir_list = os.listdir(dir_name_esn_all)
# ESN_dir_list = [dir_name_esn_all+'/'+dname for dname in ESN_dir_list if os.path.isdir(dir_name_esn_all+'/'+dname)]

convert_only_if_not_already = True
del_original_wts_file = True

# %%
# # setting up params (and saving, if applicable)

# # RNN directory
# dir_name_rnn = ESN_dir_list[0]

# # reading AE directory
# with open(dir_name_rnn + '/sim_data_AE_params.txt') as f:
#     lines = f.readlines()

# params_dict = eval(''.join(lines))

# dir_name_ae = params_dict['dir_name_ae']
# ae_idx = dir_name_ae[-3:]
# dir_name_ae = os.getcwd()+'/saved_ae/ae_'+ae_idx
# try:
#     use_ae_data = params_dict['use_ae_data']
# except:
#     print("'use_ae_data' not present in sim_data_AE_params, set to True.")
#     use_ae_data = True

# # reading RNN paramaters
# with open(dir_name_rnn + '/RNN_specific_data.txt') as f:
#     lines = f.readlines()

# params_rnn_dict = eval(''.join(lines))



# dt_rnn = params_rnn_dict['dt_rnn']
# T_sample_input = params_rnn_dict['T_sample_input']
# T_sample_output = params_rnn_dict['T_sample_output']
# T_offset = params_rnn_dict['T_offset']
# return_params_arr = params_rnn_dict['return_params_arr']
# params = params_rnn_dict['params']
# delta_t = params_rnn_dict['delta_t']
# normalize_dataset = params_rnn_dict['normalize_dataset']
# num_input_tsteps = params_rnn_dict['num_input_tsteps']
# skip_intermediate = params_rnn_dict['skip_intermediate']
# normalization_type = params_rnn_dict['normalization_type']

# normalization_arr_rnn = None
# if normalize_dataset == True:
#     temp = np.load(dir_name_rnn+'/normalization_data.npz', allow_pickle=True)
#     normalization_arr_rnn = temp['normalization_arr'][0]
    
# # reading simulation parameters
# with open(dir_name_ae + '/ae_data.txt') as f:
#     lines = f.readlines()
# params_dict = eval(''.join(lines))
# data_dir_idx = params_dict['data_dir_idx']
# normalizeforae_flag = params_dict['normalizeforae_flag']

# temp = np.load(dir_name_ae+'/normalization_data.npz', allow_pickle=True)
# normalization_constant_arr_aedata = temp['normalization_constant_arr_aedata'][0]

# try:
#     ae_data_with_params = params_dict['ae_data_with_params']
# except:
#     print("'ae_data_with_params' not present in ae_data, set to 'True'.")
#     ae_data_with_params = True

# print('dir_name_rnn:', dir_name_rnn)
# print('dir_name_ae:', dir_name_ae)
# print('data_dir_idx:', data_dir_idx)

# # loading data
# dir_name_data = os.getcwd() + '/saved_data/data_' + data_dir_idx
    
# with open(dir_name_data + '/sim_data_params.txt') as f:
#     lines = f.readlines()
# params_dict = eval(''.join(lines))
# params_mat = params_dict['params_mat']
# # init_state_mat = params_dict['init_state_mat']
# t0 = params_dict['t0']
# T = params_dict['T']
# delta_t = params_dict['delta_t']
# numpoints_xgrid = params_dict['numpoints_xgrid']
# length = params_dict['length']
# return_params_arr = params_dict['return_params_arr']
# normalize_flag_ogdata = params_dict['normalize_flag']
# print('normalize_flag_ogdata:', normalize_flag_ogdata)
# alldata_withparams_flag = params_dict['alldata_withparams_flag']

# xgrid = length*np.linspace(0, 1, numpoints_xgrid)

# fl = np.load(dir_name_data+'/data.npz', allow_pickle=True)
# # all_data = fl['all_data']
# # boundary_idx_arr = fl['boundary_idx_arr']
# # normalization_constant_arr_ogdata = fl['normalization_constant_arr'][0]
# # initial_t0 = fl['initial_t0']
# # init_state_mat = fl['init_state_mat']
# lyapunov_spectrum_mat = fl['lyapunov_spectrum_mat']

# # training params
# with open(dir_name_rnn + '/training_specific_params.txt') as f:
#     lines = f.readlines()

# tparams_dict = eval(''.join(lines))

# # learning_rate_dict = tparams_dict['learning_rate_dict']
# epochs = tparams_dict['epochs']
# patience = tparams_dict['patience']
# min_delta = tparams_dict['min_delta']
# prng_seed = tparams_dict['prng_seed']
# train_split = tparams_dict['train_split']
# val_split = tparams_dict['val_split']
# batch_size = tparams_dict['batch_size']

# test_split = 1 - train_split - val_split

# # setting seed for PRNGs
# np.random.seed(prng_seed)
# tf.random.set_seed(prng_seed)

# %%
# lyapunov_time_arr = np.empty(shape=lyapunov_spectrum_mat.shape[0], dtype=FTYPE)
# for i in range(lyapunov_spectrum_mat.shape[0]):
#     lyapunov_time_arr[i] = 1/lyapunov_spectrum_mat[i, 0]
#     print('Case : {}, lyapunov exponent : {}, lyapunov time : {}s'.format(i+1, lyapunov_spectrum_mat[i, 0], lyapunov_time_arr[i]))

# %%
# def plot(
#         boundary_idx_arr,
#         delta_t,
#         all_data,
#         xgrid,
#         xticks_snapto=20,
#         num_yticks=11,
#     ):

#     n = len(boundary_idx_arr)
#     # '''
#     num_cols = 1
#     num_rows = 1
#     factor = 1
#     # fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

#     num_modes = xgrid.shape[0]

#     prev_idx = 0
#     for i in range(len(boundary_idx_arr)):
#         next_idx = boundary_idx_arr[i]
#         fig, ax = plt.subplots(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
#         N = next_idx - prev_idx
#         input_time = np.arange(0, N)*delta_t

#         im = ax.imshow(all_data[prev_idx:next_idx, 0:num_modes].transpose(), aspect='auto', origin='lower')
#         num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
#         # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
#         xticks = np.arange(0, N, int((xticks_snapto+0.5*delta_t)//delta_t))
#         ax.set_xticks(ticks=xticks)
#         ax.set_xticklabels(np.round(xticks*delta_t, 1))
#         ax.tick_params(axis='x', rotation=270+45)

#         yticks = np.linspace(0, 1, num_yticks)*(len(xgrid)-1)
#         yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
#         ax.set_yticks(ticks=yticks)
#         ax.set_yticklabels(yticklabels)

#         ax.set_xlabel('Time')
#         ax.set_ylabel(r'$x$')
#         # ax.title.set_text(r'Latent States')

#         plt.colorbar(im)
#         plt.show()
#         print('')

#         prev_idx = next_idx

#     # '''

# %%
# # dealing with normalizing the data before feeding into autoencoder
# if normalizeforae_flag == True and use_ae_data == True:
#     for i in range(numpoints_xgrid):
#         all_data[:, i] -= normalization_constant_arr_aedata[0, i]
#         all_data[:, i] /= normalization_constant_arr_aedata[1, i]
# if ae_data_with_params == False:
#     all_data = all_data[:, 0:numpoints_xgrid]

# %% [markdown]
# # Autoencoder

# %%
# load_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_class_dict.txt'
# wt_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_ae_weights.h5'
# if use_ae_data == True:
#     load_file = dir_name_ae+'/final_net/final_net_class_dict.txt'
#     wt_file = dir_name_ae+'/final_net/final_net_ae_weights.h5'

# %%
# if use_ae_data == True:
#     ae_net = Autoencoder(all_data.shape[1], load_file=load_file)
#     ae_net.load_weights_from_file(wt_file)

# %%
# # create data
# if use_ae_data == True:
#     latent_states_all = ae_net.encoder_net.predict(all_data)
#     del(all_data)
# else:
#     latent_states_all = all_data[:, 0:xgrid.shape[0]]

# num_latent_states = latent_states_all.shape[1]

# %%
# plot_latent_states_KS(
#     boundary_idx_arr,
#     latent_states_all,
#     delta_t,
#     dir_name_ae,
#     xticks_snapto=int(40*np.round((T//10)/40)),
#     num_yticks=11,
#     save_figs=False)

# %% [markdown]
# # ESN

# %%
for dname_idx in range(len(ESN_dir_list)):
    computation_time = time.time()
    dir_name_rnn = ESN_dir_list[dname_idx]

    sidx1 = dir_name_rnn[::-1].index('/')
    sidx2 = dir_name_rnn[-sidx1-2::-1].index('/')
    print(dir_name_rnn[-(sidx1+sidx2+1):] + ' -- {} / {}'.format(dname_idx+1, len(ESN_dir_list)))

    proceed = True
    if convert_only_if_not_already == True:
        if os.path.exists(dir_name_rnn+'/final_net/final_net_ESN_weights.hdf5'):
            # This dir has already been converted
            proceed = False

    if proceed == True:
        # Initialize ESN_v1 network
        load_file = dir_name_rnn + '/final_net/final_net_class_dict.txt'
        rnn_net = ESN(
            load_file=load_file,
            stddev=0.0,
        )
        rnn_net.build(input_shape=(1, 1, rnn_net.data_dim))

        wt_file = dir_name_rnn+'/final_net/final_net_ESN_weights.h5'
        rnn_net.load_weights_from_file(wt_file)

        new_ESN = ESNv3(load_file=load_file)
        new_ESN.build(input_shape=(1, 1, rnn_net.data_dim))

        for i in range(len(rnn_net.ESN_layers)):
            rnn_net_cell = rnn_net.ESN_layers[i].cell
            input_size = rnn_net_cell.input_size
            usebias_Win = rnn_net.usebias_Win[i]

            new_ESN_cell = new_ESN.ESN_layers[i].cell

            # setting Win
            K.set_value(new_ESN_cell.Win.kernel, rnn_net_cell.Win_np[0:input_size, :])
            if usebias_Win == True:
                K.set_value(new_ESN_cell.Win.bias, rnn_net_cell.Win_np[-1, :])

            # setting Wres
            K.set_value(new_ESN_cell.Wres.kernel, rnn_net_cell.Wres_np)

        # setting Wout
        usebias_Wout = rnn_net.usebias_Wout
        Wout_np = rnn_net.Wout.numpy()

        K.set_value(new_ESN.Wout.kernel, Wout_np[0:rnn_net.ESN_layers_units[-1], :])
        if usebias_Wout == True:
            K.set_value(new_ESN.Wout.bias, Wout_np[-1, :])

        new_ESN.save_model_weights(dir_name_rnn+'/final_net/final_net_ESN_weights')

    if del_original_wts_file == True:
        check1 = os.path.exists(dir_name_rnn+'/final_net/final_net_ESN_weights.h5')
        check2 = os.path.exists(dir_name_rnn+'/final_net/final_net_ESN_weights.hdf5')
        if check1 == True:
            if check2 == True:
                print('    Deleting original weights file.')
                os.remove(dir_name_rnn+'/final_net/final_net_ESN_weights.h5')
            else:
                print('    ***ERROR***')
                print('    NEW WEIGHTS FILE DOES NOT EXIST, CANNOT DELETE OLD.')
                break
        else:
            print("    Old weights file does not exist, cannot delete what isn't there.")
        
    
    print('    time taken : {} s\n'.format(time.time()-computation_time))
# Out:
# worker_1/ESN_030 -- 1 / 162
#     Deleting original weights file.
#     time taken : 0.07741165161132812 s
#
# worker_1/ESN_002 -- 2 / 162
#     Deleting original weights file.
#     time taken : 0.054689645767211914 s
#
# worker_1/ESN_076 -- 3 / 162
#     Deleting original weights file.
#     time taken : 0.03744697570800781 s
#
# worker_1/ESN_044 -- 4 / 162
#     Deleting original weights file.
#     time taken : 0.07478737831115723 s
#
# worker_1/ESN_029 -- 5 / 162
#     Deleting original weights file.
#     time taken : 0.001312255859375 s
#
# worker_1/ESN_041 -- 6 / 162
#     Deleting original weights file.
#     time taken : 0.0009446144104003906 s
#
# worker_1/ESN_007 -- 7 / 162
#     Deleting original weights file.
#     time taken : 0.0008573532104492188 s
#
# worker_1/ESN_023 -- 8 / 162
#     Deleting original weights file.
#     time taken : 0.028126239776611328 s
#
# worker_1/ESN_045 -- 9 / 162
#     Deleting original weights file.
#     time taken : 0.0007421970367431641 s
#
# worker_1/ESN_047 -- 10 / 162
#     Deleting original weights file.
#     time taken : 0.0006024837493896484 s
#
# worker_1/ESN_055 -- 11 / 162
#     Deleting original weights file.
#     time taken : 0.0006008148193359375 s
#
# worker_1/ESN_071 -- 12 / 162
#     Deleting original weights file.
#     time taken : 0.015675067901611328 s
#
# worker_1/ESN_054 -- 13 / 162
#     Deleting original weights file.
#     time taken : 0.09211444854736328 s
#
# worker_1/ESN_057 -- 14 / 162
#     Deleting original weights file.
#     time taken : 0.02319478988647461 s
#
# worker_1/ESN_042 -- 15 / 162
#     Deleting original weights file.
#     time taken : 0.0055391788482666016 s
#
# worker_1/ESN_038 -- 16 / 162
#     Deleting original weights file.
#     time taken : 0.025515317916870117 s
#
# worker_1/ESN_075 -- 17 / 162
#     Deleting original weights file.
#     time taken : 0.021117448806762695 s
#
# worker_1/ESN_034 -- 18 / 162
#     Deleting original weights file.
#     time taken : 0.0040435791015625 s
#
# worker_1/ESN_051 -- 19 / 162
#     Deleting original weights file.
#     time taken : 0.0008945465087890625 s
#
# worker_1/ESN_074 -- 20 / 162
#     Deleting original weights file.
#     time taken : 0.011446952819824219 s
#
# worker_1/ESN_010 -- 21 / 162
#     Deleting original weights file.
#     time taken : 0.010046720504760742 s
#
# worker_1/ESN_036 -- 22 / 162
#     Deleting original weights file.
#     time taken : 0.002702951431274414 s
#
# worker_1/ESN_031 -- 23 / 162
#     Deleting original weights file.
#     time taken : 0.00034737586975097656 s
#
# worker_1/ESN_058 -- 24 / 162
#     Deleting original weights file.
#     time taken : 0.002106904983520508 s
#
# worker_1/ESN_008 -- 25 / 162
#     Deleting original weights file.
#     time taken : 0.002671957015991211 s
#
# worker_1/ESN_039 -- 26 / 162
#     Deleting original weights file.
#     time taken : 0.0003337860107421875 s
#
# worker_1/ESN_006 -- 27 / 162
#     Deleting original weights file.
#     time taken : 0.0018243789672851562 s
#
# worker_1/ESN_022 -- 28 / 162
#     Deleting original weights file.
#     time taken : 0.0019583702087402344 s
#
# worker_1/ESN_032 -- 29 / 162
#     Deleting original weights file.
#     time taken : 0.0019693374633789062 s
#
# worker_1/ESN_063 -- 30 / 162
#     Deleting original weights file.
#     time taken : 0.016375064849853516 s
#
# worker_1/ESN_011 -- 31 / 162
#     Deleting original weights file.
#     time taken : 0.0003936290740966797 s
#
# worker_1/ESN_067 -- 32 / 162
#     Deleting original weights file.
#     time taken : 0.0009245872497558594 s
#
# worker_1/ESN_059 -- 33 / 162
#     Deleting original weights file.
#     time taken : 0.0005352497100830078 s
#
# worker_1/ESN_077 -- 34 / 162
#     Deleting original weights file.
#     time taken : 0.00032067298889160156 s
#
# worker_1/ESN_060 -- 35 / 162
#     Deleting original weights file.
#     time taken : 0.05576825141906738 s
#
# worker_1/ESN_019 -- 36 / 162
#     Deleting original weights file.
#     time taken : 0.0004911422729492188 s
#
# worker_1/ESN_021 -- 37 / 162
#     Deleting original weights file.
#     time taken : 0.024981260299682617 s
#
# worker_1/ESN_079 -- 38 / 162
#     Deleting original weights file.
#     time taken : 0.0006811618804931641 s
#
# worker_1/ESN_061 -- 39 / 162
#     Deleting original weights file.
#     time taken : 0.0004897117614746094 s
#
# worker_1/ESN_064 -- 40 / 162
#     Deleting original weights file.
#     time taken : 0.0025119781494140625 s
#
# worker_1/ESN_018 -- 41 / 162
#     Deleting original weights file.
#     time taken : 0.0020973682403564453 s
#
# worker_1/ESN_065 -- 42 / 162
#     Deleting original weights file.
#     time taken : 0.00033092498779296875 s
#
# worker_1/ESN_000 -- 43 / 162
#     Deleting original weights file.
#     time taken : 0.013180255889892578 s
#
# worker_1/ESN_013 -- 44 / 162
#     Deleting original weights file.
#     time taken : 0.0006582736968994141 s
#
# worker_1/ESN_012 -- 45 / 162
#     Deleting original weights file.
#     time taken : 0.00472569465637207 s
#
# worker_1/ESN_017 -- 46 / 162
#     Deleting original weights file.
#     time taken : 0.00133514404296875 s
#
# worker_1/ESN_028 -- 47 / 162
#     Deleting original weights file.
#     time taken : 0.007428169250488281 s
#
# worker_1/ESN_062 -- 48 / 162
#     Deleting original weights file.
#     time taken : 0.007432460784912109 s
#
# worker_1/ESN_080 -- 49 / 162
#     Deleting original weights file.
#     time taken : 0.007028341293334961 s
#
# worker_1/ESN_048 -- 50 / 162
#     Deleting original weights file.
#     time taken : 0.0060994625091552734 s
#
# worker_1/ESN_003 -- 51 / 162
#     Deleting original weights file.
#     time taken : 0.0012340545654296875 s
#
# worker_1/ESN_027 -- 52 / 162
#     Deleting original weights file.
#     time taken : 0.01246333122253418 s
#
# worker_1/ESN_043 -- 53 / 162
#     Deleting original weights file.
#     time taken : 0.0014765262603759766 s
#
# worker_1/ESN_068 -- 54 / 162
#     Deleting original weights file.
#     time taken : 0.007020235061645508 s
#
# worker_1/ESN_004 -- 55 / 162
#     Deleting original weights file.
#     time taken : 0.0071735382080078125 s
#
# worker_1/ESN_037 -- 56 / 162
#     Deleting original weights file.
#     time taken : 0.00131988525390625 s
#
# worker_1/ESN_026 -- 57 / 162
#     Deleting original weights file.
#     time taken : 0.016297340393066406 s
#
# worker_1/ESN_053 -- 58 / 162
#     Deleting original weights file.
#     time taken : 0.005397319793701172 s
#
# worker_1/ESN_009 -- 59 / 162
#     Deleting original weights file.
#     time taken : 0.002053499221801758 s
#
# worker_1/ESN_035 -- 60 / 162
#     Deleting original weights file.
#     time taken : 0.0016467571258544922 s
#
# worker_1/ESN_069 -- 61 / 162
#     Deleting original weights file.
#     time taken : 0.0015673637390136719 s
#
# worker_1/ESN_052 -- 62 / 162
#     Deleting original weights file.
#     time taken : 0.036273956298828125 s
#
# worker_1/ESN_005 -- 63 / 162
#     Deleting original weights file.
#     time taken : 0.001386404037475586 s
#
# worker_1/ESN_046 -- 64 / 162
#     Deleting original weights file.
#     time taken : 0.007523059844970703 s
#
# worker_1/ESN_049 -- 65 / 162
#     Deleting original weights file.
#     time taken : 0.001531839370727539 s
#
# worker_1/ESN_066 -- 66 / 162
#     Deleting original weights file.
#     time taken : 0.007715463638305664 s
#
# worker_1/ESN_015 -- 67 / 162
#     Deleting original weights file.
#     time taken : 0.0013256072998046875 s
#
# worker_1/ESN_001 -- 68 / 162
#     Deleting original weights file.
#     time taken : 0.0016188621520996094 s
#
# worker_1/ESN_020 -- 69 / 162
#     Deleting original weights file.
#     time taken : 0.11370706558227539 s
#
# worker_1/ESN_072 -- 70 / 162
#     Deleting original weights file.
#     time taken : 0.017024993896484375 s
#
# worker_1/ESN_014 -- 71 / 162
#     Deleting original weights file.
#     time taken : 0.015170097351074219 s
#
# worker_1/ESN_078 -- 72 / 162
#     Deleting original weights file.
#     time taken : 0.016222000122070312 s
#
# worker_1/ESN_040 -- 73 / 162
#     Deleting original weights file.
#     time taken : 0.01501774787902832 s
#
# worker_1/ESN_024 -- 74 / 162
#     Deleting original weights file.
#     time taken : 0.039391279220581055 s
#
# worker_1/ESN_070 -- 75 / 162
#     Deleting original weights file.
#     time taken : 0.037328481674194336 s
#
# worker_1/ESN_033 -- 76 / 162
#     Deleting original weights file.
#     time taken : 0.003888845443725586 s
#
# worker_1/ESN_050 -- 77 / 162
#     Deleting original weights file.
#     time taken : 0.018777847290039062 s
#
# worker_1/ESN_073 -- 78 / 162
#     Deleting original weights file.
#     time taken : 0.003601551055908203 s
#
# worker_1/ESN_025 -- 79 / 162
#     Deleting original weights file.
#     time taken : 0.024404287338256836 s
#
# worker_1/ESN_016 -- 80 / 162
#     Deleting original weights file.
#     time taken : 0.019019365310668945 s
#
# worker_1/ESN_056 -- 81 / 162
#     Deleting original weights file.
#     time taken : 0.03433513641357422 s
#
# worker_0/ESN_030 -- 82 / 162
#     Deleting original weights file.
#     time taken : 0.002024412155151367 s
#
# worker_0/ESN_002 -- 83 / 162
#     Deleting original weights file.
#     time taken : 0.0022063255310058594 s
#
# worker_0/ESN_076 -- 84 / 162
#     Deleting original weights file.
#     time taken : 0.0007483959197998047 s
#
# worker_0/ESN_044 -- 85 / 162
#     Deleting original weights file.
#     time taken : 0.0007328987121582031 s
#
# worker_0/ESN_029 -- 86 / 162
#     Deleting original weights file.
#     time taken : 0.02742171287536621 s
#
# worker_0/ESN_041 -- 87 / 162
#     Deleting original weights file.
#     time taken : 0.004307746887207031 s
#
# worker_0/ESN_007 -- 88 / 162
#     Deleting original weights file.
#     time taken : 0.010527610778808594 s
#
# worker_0/ESN_023 -- 89 / 162
#     Deleting original weights file.
#     time taken : 0.014018774032592773 s
#
# worker_0/ESN_045 -- 90 / 162
#     Deleting original weights file.
#     time taken : 0.006946563720703125 s
#
# worker_0/ESN_047 -- 91 / 162
#     Deleting original weights file.
#     time taken : 0.012126445770263672 s
#
# worker_0/ESN_055 -- 92 / 162
#     Deleting original weights file.
#     time taken : 0.0024912357330322266 s
#
# worker_0/ESN_071 -- 93 / 162
#     Deleting original weights file.
#     time taken : 0.003155231475830078 s
#
# worker_0/ESN_054 -- 94 / 162
#     Deleting original weights file.
#     time taken : 0.02482771873474121 s
#
# worker_0/ESN_057 -- 95 / 162
#     Deleting original weights file.
#     time taken : 0.0025784969329833984 s
#
# worker_0/ESN_042 -- 96 / 162
#     Deleting original weights file.
#     time taken : 0.00040841102600097656 s
#
# worker_0/ESN_038 -- 97 / 162
#     Deleting original weights file.
#     time taken : 0.00034928321838378906 s
#
# worker_0/ESN_075 -- 98 / 162
#     Deleting original weights file.
#     time taken : 0.0020294189453125 s
#
# worker_0/ESN_034 -- 99 / 162
#     Deleting original weights file.
#     time taken : 0.00034499168395996094 s
#
# worker_0/ESN_051 -- 100 / 162
#     Deleting original weights file.
#     time taken : 0.002277851104736328 s
#
# worker_0/ESN_074 -- 101 / 162
#     Deleting original weights file.
#     time taken : 0.0005137920379638672 s
#
# worker_0/ESN_010 -- 102 / 162
#     Deleting original weights file.
#     time taken : 0.0011305809020996094 s
#
# worker_0/ESN_036 -- 103 / 162
#     Deleting original weights file.
#     time taken : 0.0003287792205810547 s
#
# worker_0/ESN_031 -- 104 / 162
#     Deleting original weights file.
#     time taken : 0.008253097534179688 s
#
# worker_0/ESN_058 -- 105 / 162
#     Deleting original weights file.
#     time taken : 0.0003390312194824219 s
#
# worker_0/ESN_008 -- 106 / 162
#     Deleting original weights file.
#     time taken : 0.0008928775787353516 s
#
# worker_0/ESN_039 -- 107 / 162
#     Deleting original weights file.
#     time taken : 0.002229928970336914 s
#
# worker_0/ESN_006 -- 108 / 162
#     Deleting original weights file.
#     time taken : 0.01801776885986328 s
#
# worker_0/ESN_022 -- 109 / 162
#     Deleting original weights file.
#     time taken : 0.0010249614715576172 s
#
# worker_0/ESN_032 -- 110 / 162
#     Deleting original weights file.
#     time taken : 0.0010838508605957031 s
#
# worker_0/ESN_063 -- 111 / 162
#     Deleting original weights file.
#     time taken : 0.0028150081634521484 s
#
# worker_0/ESN_011 -- 112 / 162
#     Deleting original weights file.
#     time taken : 0.006212949752807617 s
#
# worker_0/ESN_067 -- 113 / 162
#     Deleting original weights file.
#     time taken : 0.0018069744110107422 s
#
# worker_0/ESN_059 -- 114 / 162
#     Deleting original weights file.
#     time taken : 0.021759510040283203 s
#
# worker_0/ESN_077 -- 115 / 162
#     Deleting original weights file.
#     time taken : 0.0020096302032470703 s
#
# worker_0/ESN_060 -- 116 / 162
#     Deleting original weights file.
#     time taken : 0.0005855560302734375 s
#
# worker_0/ESN_019 -- 117 / 162
#     Deleting original weights file.
#     time taken : 0.006005764007568359 s
#
# worker_0/ESN_021 -- 118 / 162
#     Deleting original weights file.
#     time taken : 0.07009601593017578 s
#
# worker_0/ESN_079 -- 119 / 162
#     Deleting original weights file.
#     time taken : 0.0035326480865478516 s
#
# worker_0/ESN_061 -- 120 / 162
#     Deleting original weights file.
#     time taken : 0.0034837722778320312 s
#
# worker_0/ESN_064 -- 121 / 162
#     Deleting original weights file.
#     time taken : 0.0006148815155029297 s
#
# worker_0/ESN_018 -- 122 / 162
#     Deleting original weights file.
#     time taken : 0.0017914772033691406 s
#
# worker_0/ESN_065 -- 123 / 162
#     Deleting original weights file.
#     time taken : 0.003462553024291992 s
#
# worker_0/ESN_000 -- 124 / 162
#     Deleting original weights file.
#     time taken : 0.0020830631256103516 s
#
# worker_0/ESN_013 -- 125 / 162
#     Deleting original weights file.
#     time taken : 0.009377241134643555 s
#
# worker_0/ESN_012 -- 126 / 162
#     Deleting original weights file.
#     time taken : 0.0017080307006835938 s
#
# worker_0/ESN_017 -- 127 / 162
#     Deleting original weights file.
#     time taken : 0.010441780090332031 s
#
# worker_0/ESN_028 -- 128 / 162
#     Deleting original weights file.
#     time taken : 0.020756006240844727 s
#
# worker_0/ESN_062 -- 129 / 162
#     Deleting original weights file.
#     time taken : 0.0013151168823242188 s
#
# worker_0/ESN_080 -- 130 / 162
#     Deleting original weights file.
#     time taken : 0.0016374588012695312 s
#
# worker_0/ESN_048 -- 131 / 162
#     Deleting original weights file.
#     time taken : 0.0014901161193847656 s
#
# worker_0/ESN_003 -- 132 / 162
#     Deleting original weights file.
#     time taken : 0.009046316146850586 s
#
# worker_0/ESN_027 -- 133 / 162
#     Deleting original weights file.
#     time taken : 0.007063627243041992 s
#
# worker_0/ESN_043 -- 134 / 162
#     Deleting original weights file.
#     time taken : 0.008703947067260742 s
#
# worker_0/ESN_068 -- 135 / 162
#     Deleting original weights file.
#     time taken : 0.0013325214385986328 s
#
# worker_0/ESN_004 -- 136 / 162
#     Deleting original weights file.
#     time taken : 0.0013556480407714844 s
#
# worker_0/ESN_037 -- 137 / 162
#     Deleting original weights file.
#     time taken : 0.0068492889404296875 s
#
# worker_0/ESN_026 -- 138 / 162
#     Deleting original weights file.
#     time taken : 0.0013175010681152344 s
#
# worker_0/ESN_053 -- 139 / 162
#     Deleting original weights file.
#     time taken : 0.020847558975219727 s
#
# worker_0/ESN_009 -- 140 / 162
#     Deleting original weights file.
#     time taken : 0.008741617202758789 s
#
# worker_0/ESN_035 -- 141 / 162
#     Deleting original weights file.
#     time taken : 0.008554935455322266 s
#
# worker_0/ESN_069 -- 142 / 162
#     Deleting original weights file.
#     time taken : 0.009271621704101562 s
#
# worker_0/ESN_052 -- 143 / 162
#     Deleting original weights file.
#     time taken : 0.0022008419036865234 s
#
# worker_0/ESN_005 -- 144 / 162
#     Deleting original weights file.
#     time taken : 0.02196955680847168 s
#
# worker_0/ESN_046 -- 145 / 162
#     Deleting original weights file.
#     time taken : 0.002466440200805664 s
#
# worker_0/ESN_049 -- 146 / 162
#     Deleting original weights file.
#     time taken : 0.024495363235473633 s
#
# worker_0/ESN_066 -- 147 / 162
#     Deleting original weights file.
#     time taken : 0.0012767314910888672 s
#
# worker_0/ESN_015 -- 148 / 162
#     Deleting original weights file.
#     time taken : 0.005792856216430664 s
#
# worker_0/ESN_001 -- 149 / 162
#     Deleting original weights file.
#     time taken : 0.0071506500244140625 s
#
# worker_0/ESN_020 -- 150 / 162
#     Deleting original weights file.
#     time taken : 0.0009059906005859375 s
#
# worker_0/ESN_072 -- 151 / 162
#     Deleting original weights file.
#     time taken : 0.0015053749084472656 s
#
# worker_0/ESN_014 -- 152 / 162
#     Deleting original weights file.
#     time taken : 0.0008726119995117188 s
#
# worker_0/ESN_078 -- 153 / 162
#     Deleting original weights file.
#     time taken : 0.0011096000671386719 s
#
# worker_0/ESN_040 -- 154 / 162
#     Deleting original weights file.
#     time taken : 0.0015141963958740234 s
#
# worker_0/ESN_024 -- 155 / 162
#     Deleting original weights file.
#     time taken : 0.0009238719940185547 s
#
# worker_0/ESN_070 -- 156 / 162
#     Deleting original weights file.
#     time taken : 0.0011446475982666016 s
#
# worker_0/ESN_033 -- 157 / 162
#     Deleting original weights file.
#     time taken : 0.00644993782043457 s
#
# worker_0/ESN_050 -- 158 / 162
#     Deleting original weights file.
#     time taken : 0.0012292861938476562 s
#
# worker_0/ESN_073 -- 159 / 162
#     Deleting original weights file.
#     time taken : 0.006953716278076172 s
#
# worker_0/ESN_025 -- 160 / 162
#     Deleting original weights file.
#     time taken : 0.005297660827636719 s
#
# worker_0/ESN_016 -- 161 / 162
#     Deleting original weights file.
#     time taken : 0.001056671142578125 s
#
# worker_0/ESN_056 -- 162 / 162
#     Deleting original weights file.
#     time taken : 0.001508474349975586 s

# %%
# new_ESN(np.ones(shape=(1, 1, rnn_net.data_dim)), training=False)
