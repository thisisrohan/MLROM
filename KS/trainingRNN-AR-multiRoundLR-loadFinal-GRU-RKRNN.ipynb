# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

tf.keras.backend.set_floatx('float32')

# %%
colab_flag = False
FTYPE = np.float32
ITYPE = np.int32

strategy = None
# strategy = tf.distribute.MirroredStrategy()

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
if colab_flag == True:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Github/MLROM/KS/')

# %%
print(os.getcwd())
# Out:
# /home/rkaushik/Documents/Thesis/MLROM/KS

# %%
from tools.misc_tools import create_data_for_RNN, mytimecallback, SaveLosses, plot_losses, plot_reconstructed_data_KS, plot_latent_states_KS , readAndReturnLossHistories, sigmoidWarmupAndDecayLRSchedule
from tools.ae_v5 import Autoencoder
from tools.GRU_AR_v6 import AR_RNN_GRU

# %%
behaviour = 'initialiseAndTrainFromScratch'
# behaviour = 'loadCheckpoin?tAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if colab_flag == False:
    if strategy is None:
        if gpus:
            gpu_to_use = 0
            tf.config.set_visible_devices(gpus[gpu_to_use], 'GPU')
    logical_devices = tf.config.list_logical_devices('GPU')
    print(logical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-12-10 03:10:54.701850: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.702138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.737274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.737548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.737856: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.738088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.739164: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-10 03:10:54.739746: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.739971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:54.740178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:55.304795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:55.305032: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:55.305237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-10 03:10:55.305405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3358 MB memory:  -> device: 0, name: Quadro K2200, pci bus id: 0000:02:00.0, compute capability: 5.0

# %%
# print(tf.test.gpu_device_name())
print(tf.config.list_physical_devices())
print(tf.config.list_logical_devices())
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2.8.1

# %% [markdown]
# # KS System

# %%
# setting up params (and saving, if applicable)
from numpy import *

if behaviour == 'initialiseAndTrainFromScratch':
    # RNN directory
    dir_name_rnn = os.getcwd()+'/saved_rnn/rnn_038'

    # making AR-RNN save directory
    dir_name_ARrnn = os.getcwd() + dir_sep + 'saved_AR_rnn'
    if not os.path.isdir(dir_name_ARrnn):
        os.makedirs(dir_name_ARrnn)

    counter = 0
    while True:
        dir_check = 'AR_rnn_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_ARrnn + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_ARrnn = dir_name_ARrnn + dir_sep + dir_check
    os.makedirs(dir_name_ARrnn)
    os.makedirs(dir_name_ARrnn+dir_sep+'plots')
    
    # reading RNN paramaters
    with open(dir_name_rnn + '/RNN_specific_data.txt') as f:
        lines = f.readlines()

    params_rnn_dict = eval(''.join(lines))

    dt_rnn = params_rnn_dict['dt_rnn']
    return_params_arr = params_rnn_dict['return_params_arr']
    params = params_rnn_dict['params']
    try:
        normalize_dataset = params_rnn_dict['normalize_dataset']
    except:
        print("'normalize_dataset' not present in rnn_specific_data, set to False.")
        normalize_dataset = False
    try:
        stddev_multiplier = params_rnn_dict['stddev_multiplier']
    except:
        print("'stddev_multiplier' not present in RNN_specific_data, set to None.")
        stddev_multiplier = None
    try:
        skip_intermediate = params_rnn_dict['skip_intermediate']
    except:
        print("'skip_intermediate' not present in RNN_specific_data, set to 1.")
        skip_intermediate = 1
    try:
        normalization_type = params_rnn_dict['normalization_type']
    except:
        print("'normalization_type' not present in RNN_specific_data, set to 'stddev'.")
        normalization_type = 'stddev'
    try:
        use_ae_data = params_rnn_dict['use_ae_data']
    except:
        print("'use_ae_data' not present in RNN_specific_data, set to True.")
        use_ae_data = True
    try:
        dense_layer_act_func = params_rnn_dict['dense_layer_act_func']
    except:
        print("'dense_layer_act_func' not present in RNN_specific_data, set to 'linear'.")
        dense_layer_act_func = 'linear'
    try:
        stateful = params_rnn_dict['stateful']
    except:
        print("'stateful' not present in RNN_specific_data, set to True.")
        stateful = True
    try:
        use_learnable_state = params_rnn_dict['use_learnable_state']
    except:
        print("'use_learnable_state' not present in RNN_specific_data, set to False.")
        use_learnable_state = False
    try:
        use_weights_post_dense = params_rnn_dict['use_weights_post_dense']
    except:
        print("'use_weights_post_dense' not present in RNN_specific_data, set to False.")
        use_weights_post_dense = False
        
    
    # training params
    with open(dir_name_rnn + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()

    tparams_dict = eval(''.join(lines))

    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']
    try:
        fRMS = tparams_dict['fRMS']
    except:
        fRMS = 0.0

    loss_weights = 0.98
else:
    # AR-RNN directory
    dir_name_ARrnn = os.getcwd()+'/saved_AR_rnn/AR_rnn_000'

    # reading AR-RNN parameters
    with open(dir_name_ARrnn + '/AR_rnn_specific_data.txt') as f:
        lines = f.readlines()
    
    params_AR_rnn_dict = eval(''.join(lines))

    dir_name_rnn = params_AR_rnn_dict['dir_name_rnn']
    rnn_idx = dir_name_rnn[-3:]
    dir_name_rnn = os.getcwd()+'/saved_rnn/rnn_'+rnn_idx

    dt_rnn = params_AR_rnn_dict['dt_rnn']
    T_sample_input = params_AR_rnn_dict['T_sample_input']
    T_sample_output = params_AR_rnn_dict['T_sample_output']
    T_offset = params_AR_rnn_dict['T_offset']
    return_params_arr = params_AR_rnn_dict['return_params_arr']
    params = params_AR_rnn_dict['params']
    try:
        normalize_dataset = params_AR_rnn_dict['normalize_dataset']
    except:
        print("'normalize_dataset' not present in AR_rnn_specific_data, set to False.")
        normalize_dataset = False
    try:
        stddev_multiplier = params_AR_rnn_dict['stddev_multiplier']
    except:
        print("'stddev_multiplier' not present in RNN_specific_data, set to None.")
        stddev_multiplier = None
    try:
        skip_intermediate = params_AR_rnn_dict['skip_intermediate']
    except:
        print("'skip_intermediate' not present in RNN_specific_data, set to 1.")
        skip_intermediate = 1
    try:
        use_ae_data = params_AR_rnn_dict['use_ae_data']
    except:
        print("'use_ae_data' not present in RNN_specific_data, set to True.")
        use_ae_data = True

    # training params
    with open(dir_name_ARrnn + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()

    tparams_dict = eval(''.join(lines))

    learning_rate_list = tparams_dict['learning_rate_list']
    epochs = tparams_dict['epochs']
    patience = tparams_dict['patience']
    min_delta = tparams_dict['min_delta']
    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']
    try:
        fRMS = tparams_dict['fRMS']
    except:
        fRMS = 0.0
    try:
        loss_weights = tparams_dict['loss_weights']
    except:
        loss_weights = None


# reading stddev
with open(dir_name_rnn + '/final_net/final_net_class_dict.txt') as f:
    lines = f.readlines()
finalnet_dict = eval(''.join(lines))
stddev = finalnet_dict['stddev']
# stddev = 0.0

# reading RNN normalization constants
normalization_arr_rnn = None
if normalize_dataset == True:
    with open(dir_name_rnn + '/final_net/rnn_normalization.txt') as f:
        lines = f.readlines()
    normarr_rnn_dict = eval(''.join(lines))
    normalization_arr_rnn = normarr_rnn_dict['normalization_arr']

if os.path.exists(dir_name_rnn+dir_sep+'normalization_data.npz'):
    with np.load(dir_name_rnn+dir_sep+'normalization_data.npz', allow_pickle=True) as fl:
        normalization_arr = fl['normalization_arr'][0]

# reading AE directory
with open(dir_name_rnn + '/sim_data_AE_params.txt') as f:
    lines = f.readlines()

params_dict = eval(''.join(lines))

dir_name_ae = params_dict['dir_name_ae']
ae_idx = dir_name_ae[-3:]
dir_name_ae = os.getcwd()+'/saved_ae/ae_'+ae_idx
try:
    use_ae_data = params_dict['use_ae_data']
except:
    print("'use_ae_data' not present in sim_data_AE_params, set to True.")
    normalize_dataset = True

# reading simulation parameters
with open(dir_name_ae + dir_sep + 'ae_data.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
data_dir_idx = params_dict['data_dir_idx']
normalizeforae_flag = params_dict['normalizeforae_flag']
normalization_constant_arr_aedata = params_dict['normalization_constant_arr_aedata']
if os.path.exists(dir_name_ae+dir_sep+'normalization_data.npz'):
    with np.load(dir_name_ae+dir_sep+'normalization_data.npz', allow_pickle=True) as fl:
        normalization_constant_arr_aedata = fl['normalization_constant_arr_aedata'][0]
try:
    ae_data_with_params = params_dict['ae_data_with_params']
except:
    print("'ae_data_with_params' not present in RNN_specific_data, set to True.")
    ae_data_with_params = True

print('dir_name_ARrnn:', dir_name_ARrnn)
print('dir_name_rnn:', dir_name_rnn)
print('dir_name_ae:', dir_name_ae)
print('data_dir_idx:', data_dir_idx)

# loading data
dir_name_data = os.getcwd() + dir_sep + 'saved_data' + dir_sep + 'data_' + data_dir_idx
    
with open(dir_name_data + dir_sep + 'sim_data_params.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
params_mat = params_dict['params_mat']
# init_state_mat = params_dict['init_state_mat']
t0 = params_dict['t0']
T = params_dict['T']
delta_t = params_dict['delta_t']
numpoints_xgrid = params_dict['numpoints_xgrid']
length = params_dict['length']
return_params_arr = params_dict['return_params_arr']
normalize_flag_ogdata = params_dict['normalize_flag']
print('normalize_flag_ogdata:', normalize_flag_ogdata)
alldata_withparams_flag = params_dict['alldata_withparams_flag']

xgrid = length*np.linspace(0, 1, numpoints_xgrid)

with np.load(dir_name_data+dir_sep+'data.npz', allow_pickle=True) as fl:
    all_data = fl['all_data']
    boundary_idx_arr = fl['boundary_idx_arr']
    normalization_constant_arr_ogdata = fl['normalization_constant_arr'][0]
    initial_t0 = fl['initial_t0']
    init_state_mat = fl['init_state_mat']
    lyapunov_spectrum_mat = fl['lyapunov_spectrum_mat']


test_split = 1 - train_split - val_split

# setting seed for PRNGs
np.random.seed(prng_seed)
tf.random.set_seed(prng_seed)
# Out:
# 'use_ae_data' not present in RNN_specific_data, set to True.
# dir_name_ARrnn: /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008
# dir_name_rnn: /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_038
# dir_name_ae: /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_046
# data_dir_idx: 005
# normalize_flag_ogdata: False

# %%
lyapunov_time_arr = np.empty(shape=lyapunov_spectrum_mat.shape[0], dtype=FTYPE)
for i in range(lyapunov_spectrum_mat.shape[0]):
    lyapunov_time_arr[i] = 1/lyapunov_spectrum_mat[i, 0]
    print('Case : {}, lyapunov exponent : {}, lyapunov time : {}s'.format(i+1, lyapunov_spectrum_mat[i, 0], lyapunov_time_arr[i]))
# Out:
# Case : 1, lyapunov exponent : 0.06465670311438651, lyapunov time : 15.466300964355469s

# %%
def plot(
        boundary_idx_arr,
        delta_t,
        all_data,
        xgrid,
        xticks_snapto=20,
        num_yticks=11,
    ):

    n = len(boundary_idx_arr)
    # '''
    num_cols = 1
    num_rows = 1
    factor = 1
    # fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

    num_modes = xgrid.shape[0]

    prev_idx = 0
    for i in range(len(boundary_idx_arr)):
        next_idx = boundary_idx_arr[i]
        fig, ax = plt.subplots(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
        N = next_idx - prev_idx
        input_time = np.arange(0, N)*delta_t

        im = ax.imshow(all_data[prev_idx:next_idx, 0:num_modes].transpose(), aspect='auto', origin='lower')
        num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
        # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
        xticks = np.arange(0, N, int((xticks_snapto+0.5*delta_t)//delta_t))
        ax.set_xticks(ticks=xticks)
        ax.set_xticklabels(np.round(xticks*delta_t, 1))
        ax.tick_params(axis='x', rotation=270+45)

        yticks = np.linspace(0, 1, num_yticks)*(len(xgrid)-1)
        yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
        ax.set_yticks(ticks=yticks)
        ax.set_yticklabels(yticklabels)

        ax.set_xlabel('Time')
        ax.set_ylabel(r'$x$')
        # ax.title.set_text(r'Latent States')

        plt.colorbar(im)
        plt.show()
        print('')

        prev_idx = next_idx

    # '''

# %%
plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    xgrid,
    xticks_snapto=int(40*np.round((T//10)/40))
)

# %%
# dealing with normalizing the data before feeding into autoencoder
if use_ae_data == True:
    if normalizeforae_flag == True:
        for i in range(numpoints_xgrid):
            all_data[:, i] -= normalization_constant_arr_aedata[0, i]
            all_data[:, i] /= normalization_constant_arr_aedata[1, i]

    if ae_data_with_params == False:
        all_data = all_data[:, 0:numpoints_xgrid]
else:
    # using raw data, neglecting the params attached (if any)
    all_data = all_data[:, 0:numpoints_xgrid]

# %%
plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    xgrid,
    xticks_snapto=int(40*np.round((T//10)/40))
)

# %% [markdown]
# # Autoencoder

# %%
if use_ae_data == True:
    load_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_class_dict.txt'
    wt_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_ae_weights.h5'

# %%
if use_ae_data == True:
    ae_net = Autoencoder(all_data.shape[1], load_file=load_file)
    ae_net.load_weights_from_file(wt_file)

# %%
# create data
if use_ae_data == True:
    latent_states_all = ae_net.encoder_net.predict(all_data)
    del(all_data)
else:
    latent_states_all = all_data
num_latent_states = latent_states_all.shape[1]

# %%
plot_latent_states_KS(
    boundary_idx_arr,
    latent_states_all,
    delta_t,
    dir_name_ae,
    xticks_snapto=int(40*np.round((T//10)/40)),
    num_yticks=11,
    save_figs=False)

# %%
# for i in range(ae_net.layers):
#     tf.keras.utils.plot_model(
#         ae_net.layers[i],
#         to_file=dir_name_ae+'/plots/netlayer_{}.png'.format(i),
#         show_shapes=True,
#         dpi=300
# )

# %% [markdown]
# # GRU

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    # RNN data parameters
    num_lyaptimesteps_totrain = 1 # 30*dt_rnn/np.mean(lyapunov_time_arr)
    num_timesteps_warmup = 1*np.mean(lyapunov_time_arr)/dt_rnn
    T_sample_input = num_timesteps_warmup*dt_rnn
    T_sample_output = num_lyaptimesteps_totrain*np.mean(lyapunov_time_arr)
    T_offset = T_sample_input
    skip_intermediate = 'full sample'
    stateful = True
    if return_params_arr != False:
        params = params_arr
    else:
        params = None

    # saving AR RNN specific data
    AR_RNN_specific_data = {
        'dt_rnn':dt_rnn,
        'T_sample_input':T_sample_input,
        'T_sample_output':T_sample_output,
        'T_offset':T_offset,
        'boundary_idx_arr':boundary_idx_arr,
        'delta_t':delta_t,
        'params':params,
        'return_params_arr':return_params_arr,
        'normalize_dataset':normalize_dataset,
        'num_lyaptimesteps_totrain':num_lyaptimesteps_totrain,
        'num_timesteps_warmup':num_timesteps_warmup,
        'dir_name_rnn':dir_name_rnn,
        'stddev_multiplier':stddev_multiplier,
        'skip_intermediate':skip_intermediate,
        'module':AR_RNN_GRU.__module__,
        'normalization_type':normalization_type,
        'use_ae_data':use_ae_data,
        'stateful':stateful,
    }

    with open(dir_name_ARrnn+dir_sep+'AR_RNN_specific_data.txt', 'w') as f:
        f.write(str(AR_RNN_specific_data))

# %%
rnn_res_dict = create_data_for_RNN(
    latent_states_all,
    dt_rnn,
    T_sample_input,
    T_sample_output,
    T_offset,
    None,
    boundary_idx_arr,
    delta_t,
    params=params,
    return_numsamples=True,
    normalize_dataset=normalize_dataset,
    stddev_multiplier=stddev_multiplier,
    skip_intermediate=skip_intermediate,
    return_OrgDataIdxArr=False,
    normalization_arr_external=normalization_arr,
    normalization_type=normalization_type)
    
data_rnn_input = rnn_res_dict['data_rnn_input']
data_rnn_output = rnn_res_dict['data_rnn_output']
org_data_idx_arr_input = rnn_res_dict['org_data_idx_arr_input']
org_data_idx_arr_output = rnn_res_dict['org_data_idx_arr_output']
num_samples = rnn_res_dict['num_samples']
normalization_arr = rnn_res_dict['normalization_arr']
rnn_data_boundary_idx_arr = rnn_res_dict['rnn_data_boundary_idx_arr']

# %%
temp = np.divide(latent_states_all-normalization_arr[0], normalization_arr[1])
time_stddev = np.std(temp, axis=0)
timeMeanofSpaceRMS = np.mean(np.mean(temp**2, axis=1)**0.5)
del(org_data_idx_arr_input)
del(org_data_idx_arr_output)
del(latent_states_all)
del(temp)

# %%
print(' data_rnn_input.shape :', data_rnn_input.shape)
print('data_rnn_output.shape :', data_rnn_output.shape)
# Out:
#  data_rnn_input.shape : (1623, 77, 16)
# data_rnn_output.shape : (1623, 77, 16)

# %%
# setting up training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_list = [1e-5, 5e-6, 1e-6]
    epochs = 200
    patience = [25, 50, 50] # parameter for early stopping
    min_delta = 1e-6  # parameter for early stopping
    lambda_reg = 1e-6  # weight for regularizer

    if loss_weights is None:
        loss_weights = [1.0]*data_rnn_output.shape[1]
    elif isinstance(loss_weights, list) == False:
        loss_weights = list(loss_weights**np.arange(data_rnn_output.shape[1]))
    
    # saving training params
    training_specific_params = {
        'learning_rate_list':learning_rate_list,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size,
        'fRMS':fRMS,
        'loss_weights':loss_weights,
        'timeMeanofSpaceRMS':timeMeanofSpaceRMS,
        'stddev':stddev,
    }

    with open(dir_name_ARrnn+dir_sep+'training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))
    
    np.savez(
        dir_name_ARrnn+dir_sep+'normalization_data',
        normalization_arr=[normalization_arr],
    )

# %%
# idx = np.arange(data_rnn_input.shape[0])
# np.random.shuffle(idx)
# boundary = int(np.round(train_split*data_rnn_input.shape[0]))

# training_data_rnn_input = data_rnn_input[idx[0:boundary]]
# training_data_rnn_output = data_rnn_output[idx[0:boundary]]

# testing_data_rnn_input = data_rnn_input[idx[boundary:]]
# testing_data_rnn_output = data_rnn_output[idx[boundary:]]

# %%
cum_samples = rnn_data_boundary_idx_arr[-1]
# idx = np.arange(cum_samples)
# np.random.shuffle(idx)
num_train_arr = np.zeros(shape=rnn_data_boundary_idx_arr.shape[0], dtype='int32')
num_val_arr = np.zeros(shape=rnn_data_boundary_idx_arr.shape[0], dtype='int32')
num_test_arr = np.zeros(shape=rnn_data_boundary_idx_arr.shape[0], dtype='int32')
num_samples_arr = np.zeros(shape=rnn_data_boundary_idx_arr.shape[0], dtype='int32')
begin_idx = 0
for i in range(len(rnn_data_boundary_idx_arr)):
    num_samples = rnn_data_boundary_idx_arr[i] - begin_idx
    num_train_arr[i] = batch_size * (int( (1-test_split-val_split)*num_samples )//batch_size)
    num_val_arr[i] = batch_size * (int(val_split*num_samples)//batch_size)
    num_test_arr[i] = batch_size * int((num_samples - num_train_arr[i] - num_val_arr[i])//batch_size)
    num_samples_arr[i] = num_train_arr[i] + num_val_arr[i] + num_test_arr[i]
    begin_idx = rnn_data_boundary_idx_arr[i]

# defining shapes
training_input_shape = [np.sum(num_train_arr)]
training_input_shape.extend(data_rnn_input.shape[1:])

training_output_shape = [np.sum(num_train_arr)]
training_output_shape.extend(data_rnn_output.shape[1:])

val_input_shape = [np.sum(num_val_arr)]
val_input_shape.extend(data_rnn_input.shape[1:])

val_output_shape = [np.sum(num_val_arr)]
val_output_shape.extend(data_rnn_output.shape[1:])

testing_input_shape = [np.sum(num_test_arr)]
testing_input_shape.extend(data_rnn_input.shape[1:])

testing_output_shape = [np.sum(num_test_arr)]
testing_output_shape.extend(data_rnn_output.shape[1:])

# defining required arrays
training_data_rnn_input = np.empty(shape=training_input_shape)
training_data_rnn_output = np.empty(shape=training_output_shape)

val_data_rnn_input = np.empty(shape=val_input_shape)
val_data_rnn_output = np.empty(shape=val_output_shape)

testing_data_rnn_input = np.empty(shape=testing_input_shape)
testing_data_rnn_output = np.empty(shape=testing_output_shape)

begin_idx = 0
training_data_rolling_count = 0
val_data_rolling_count = 0
testing_data_rolling_count = 0
for i in range(len(rnn_data_boundary_idx_arr)):
    idx = np.arange(begin_idx, rnn_data_boundary_idx_arr[i])
    # np.random.shuffle(idx)
    # num_samples = idx.shape[0]
    # num_train = int( (1-test_split-val_split)*num_samples )
    # num_val = int(val_split*num_samples)
    num_samples = num_samples_arr[i]
    num_train = num_train_arr[i]
    num_val = num_val_arr[i]
    num_test = num_test_arr[i]

    for j in range(batch_size):
        training_data_rnn_input[training_data_rolling_count+j:training_data_rolling_count+num_train:batch_size] = data_rnn_input[idx[0:num_train]][j::batch_size]
        training_data_rnn_output[training_data_rolling_count+j:training_data_rolling_count+num_train:batch_size] = data_rnn_output[idx[0:num_train]][j::batch_size]
        
        val_data_rnn_input[val_data_rolling_count+j:val_data_rolling_count+num_val:batch_size] = data_rnn_input[idx[num_train:num_train+num_val]][j::batch_size]
        val_data_rnn_output[val_data_rolling_count+j:val_data_rolling_count+num_val:batch_size] = data_rnn_output[idx[num_train:num_train+num_val]][j::batch_size]

        testing_data_rnn_input[testing_data_rolling_count+j:testing_data_rolling_count+num_test:batch_size] = data_rnn_input[idx[num_train+num_val:num_samples]][j::batch_size]
        testing_data_rnn_output[testing_data_rolling_count+j:testing_data_rolling_count+num_test:batch_size] = data_rnn_output[idx[num_train+num_val:num_samples]][j::batch_size]


    # training_data_rnn_input[training_data_rolling_count:training_data_rolling_count+num_train] = data_rnn_input[idx[0:num_train]]
    # training_data_rnn_output[training_data_rolling_count:training_data_rolling_count+num_train] = data_rnn_output[idx[0:num_train]]
    training_data_rolling_count += num_train

    # val_data_rnn_input[val_data_rolling_count:val_data_rolling_count+num_val] = data_rnn_input[idx[num_train:num_train+num_val]]
    # val_data_rnn_output[val_data_rolling_count:val_data_rolling_count+num_val] = data_rnn_output[idx[num_train:num_train+num_val]]
    val_data_rolling_count += num_val

    # num_test = num_samples-num_train-num_val+1
    # testing_data_rnn_input[testing_data_rolling_count:testing_data_rolling_count+num_test] = data_rnn_input[idx[num_train+num_val:]]
    # testing_data_rnn_output[testing_data_rolling_count:testing_data_rolling_count+num_test] = data_rnn_output[idx[num_train+num_val:]]
    testing_data_rolling_count += num_test

    begin_idx = rnn_data_boundary_idx_arr[i]

# cleaning up
del(data_rnn_input)
del(data_rnn_output)

# further shuffling
if stateful == False:
    idx = np.arange(0, training_data_rnn_input.shape[0])
    np.random.shuffle(idx)
    training_data_rnn_input = training_data_rnn_input[idx]
    training_data_rnn_output = training_data_rnn_output[idx]

    idx = np.arange(0, val_data_rnn_input.shape[0])
    np.random.shuffle(idx)
    val_data_rnn_input = val_data_rnn_input[idx]
    val_data_rnn_output = val_data_rnn_output[idx]

    idx = np.arange(0, testing_data_rnn_input.shape[0])
    np.random.shuffle(idx)
    testing_data_rnn_input = testing_data_rnn_input[idx]
    testing_data_rnn_output = testing_data_rnn_output[idx]

    del(idx)

# %%
print(' training_data_rnn_input.shape : ', training_data_rnn_input.shape)
print('training_data_rnn_output.shape : ', training_data_rnn_output.shape)
print('\n  testing_data_rnn_input.shape : ', testing_data_rnn_input.shape)
print(' testing_data_rnn_output.shape : ', testing_data_rnn_output.shape)
print('\n      val_data_rnn_input.shape : ', val_data_rnn_input.shape)
print('     val_data_rnn_output.shape : ', val_data_rnn_output.shape)
# Out:
#  training_data_rnn_input.shape :  (1280, 77, 16)
# training_data_rnn_output.shape :  (1280, 77, 16)
#
#   testing_data_rnn_input.shape :  (192, 77, 16)
#  testing_data_rnn_output.shape :  (192, 77, 16)
#
#       val_data_rnn_input.shape :  (128, 77, 16)
#      val_data_rnn_output.shape :  (128, 77, 16)

# %%
# Initialize network
if behaviour == 'initialiseAndTrainFromScratch':
    load_file = dir_name_rnn + dir_sep + 'final_net' + dir_sep + 'final_net_class_dict.txt'

    if strategy is not None:
        with strategy.scope():
            rnn_net = AR_RNN_GRU(
                load_file=load_file,
                T_input=T_sample_input,
                T_output=T_sample_output,
                stddev=stddev,
                batch_size=batch_size,
            )
    else:
        rnn_net = AR_RNN_GRU(
            load_file=load_file,
            T_input=T_sample_input,
            T_output=T_sample_output,
            stddev=stddev,
            batch_size=batch_size,
        )
    save_path = dir_name_ARrnn+dir_sep+'final_net'
    if not os.path.isdir(save_path):
        os.makedirs(save_path)
    rnn_net.save_class_dict(save_path+dir_sep+'final_net_class_dict.txt')
    wt_file = dir_name_rnn+dir_sep+'final_net'+dir_sep+'final_net_gru_weights.h5'
    rnn_net.build(input_shape=(batch_size, training_data_rnn_input.shape[1], training_data_rnn_input.shape[2]))
else:
    load_file = dir_name_ARrnn + dir_sep + 'final_net' + dir_sep + 'final_net_class_dict.txt'
    if strategy is not None:
        with strategy.scope():
            rnn_net = AR_RNN_GRU(
                load_file=load_file,
                stddev=stddev
            )
    else:
        rnn_net = AR_RNN_GRU(
            load_file=load_file,
            stddev=stddev
        )
    
    if behaviour == 'loadCheckpointAndContinueTraining':
        wt_file = tf.train.latest_checkpoint(dir_name_ARrnn+dir_sep+'checkpoints')
    elif behaviour == 'loadFinalNetAndPlot':
        wt_file = dir_name_ARrnn+dir_sep+'final_net'+dir_sep+'final_net_gru_weights.h5'
        # wt_file = dir_name_ARrnn+dir_sep+'final_net'+dir_sep+'f2'#+dir_sep+'saved_model.pb'
rnn_net.load_weights_from_file(wt_file)

# %%
# comment this out if not residual RNN
# rnn_net.rnn_cells_list[0].trainable = False

# %%
# compiling the network
rnn_net.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_list[0]),
    loss=losses.MeanSquaredError(),
    run_eagerly=False,
    loss_weights=loss_weights,
    metrics='mse'
)

if behaviour == 'loadCheckpointAndContinueTraining':
    # this loads the weights/attributes of the optimizer as well
    if strategy is not None:
        with strategy.scope():
            rnn_net.load_weights(wt_file)
    else:
        rnn_net.load_weights(wt_file)

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs*len(learning_rate_list))*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
    earlystopping_wait = 0
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt, earlystopping_wait = readAndReturnLossHistories(
        dir_name_ae=dir_name_ARrnn,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=learning_rate_list,
        return_earlystopping_wait=True)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_ARrnn+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    # implementing early stopping
    baseline = None
    if behaviour == 'loadCheckpointAndContinueTraining':
        baseline = np.min(val_loss_hist)

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_ARrnn+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        initial_value_threshold=baseline,
        period=1  # saves every `period` epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=1)

    for i in range(starting_lr_idx, len(learning_rate_list)):
        learning_rate = learning_rate_list[i]
        if type(patience) == type([]):
            if i < len(patience):
                patience_thislr = patience[i]
            else:
                patience_thislr = patience[-1]
        else:
            patience_thislr = patience
            

        K.set_value(rnn_net.optimizer.lr, learning_rate)

        early_stopping_cb = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=patience_thislr,
            restore_best_weights=True,
            verbose=True,
            min_delta=min_delta,
            baseline=baseline
        )
        #** the two lines below are useless because wait is set to 0 in on_train_begin
        # early_stopping_cb.wait = earlystopping_wait
        # print('early_stopping_cb.wait : {}\n'.format(early_stopping_cb.wait))
        
        savelosses_cb.update_lr_idx(i)

        if i == starting_lr_idx:
            EPOCHS = num_epochs_left
            savelosses_cb.update_offset(epochs-num_epochs_left)
        else:
            EPOCHS = epochs
            savelosses_cb.update_offset(0)

        total_s_len = 80
        sep_lr_s = ' LEARNING RATE : {} '.format(learning_rate)
        sep_lr_s = int((total_s_len - len(sep_lr_s))//2)*'-' + sep_lr_s
        sep_lr_s = sep_lr_s + (total_s_len-len(sep_lr_s))*'-'
        print('\n\n' + '-'*len(sep_lr_s))
        print('\n' + sep_lr_s+'\n')
        print('-'*len(sep_lr_s) + '\n\n')
        
        history = rnn_net.fit(training_data_rnn_input, training_data_rnn_output,
            epochs=EPOCHS,
            batch_size=batch_size,
#             validation_split=val_split/train_split,
            validation_data=(val_data_rnn_input, val_data_rnn_output),
            callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb],
            verbose=1
        )

        val_loss_hist.extend(history.history['val_loss'])
        train_loss_hist.extend(history.history['loss'])
        
        if i == starting_lr_idx:
            lr_change[i+1] += len(history.history['val_loss'])
        else:
            lr_change.append(lr_change[i]+len(history.history['val_loss']))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 1e-05 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0336 - mse: 0.0335 - tot_time: 0h 3m 47.3s
#
# Epoch 1: val_loss improved from inf to 0.03471, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 227s 3s/step - loss: 0.0336 - mse: 0.0335 - val_loss: 0.0347 - val_mse: 0.0346
# Epoch 2/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0298 - mse: 0.0297 - tot_time: 0h 4m 5.2s
#
# Epoch 2: val_loss improved from 0.03471 to 0.02912, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0298 - mse: 0.0297 - val_loss: 0.0291 - val_mse: 0.0290
# Epoch 3/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0289 - mse: 0.0288 - tot_time: 0h 4m 23.1s
#
# Epoch 3: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 881ms/step - loss: 0.0289 - mse: 0.0288 - val_loss: 0.0310 - val_mse: 0.0309
# Epoch 4/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0300 - mse: 0.0299 - tot_time: 0h 4m 41.1s
#
# Epoch 4: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0300 - mse: 0.0299 - val_loss: 0.0319 - val_mse: 0.0318
# Epoch 5/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0294 - mse: 0.0293 - tot_time: 0h 4m 59.1s
#
# Epoch 5: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0294 - mse: 0.0293 - val_loss: 0.0326 - val_mse: 0.0325
# Epoch 6/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0304 - mse: 0.0303 - tot_time: 0h 5m 16.9s
#
# Epoch 6: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0304 - mse: 0.0303 - val_loss: 0.0314 - val_mse: 0.0313
# Epoch 7/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0326 - mse: 0.0325 - tot_time: 0h 5m 34.8s
#
# Epoch 7: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0326 - mse: 0.0325 - val_loss: 0.0337 - val_mse: 0.0336
# Epoch 8/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0347 - mse: 0.0346 - tot_time: 0h 5m 52.7s
#
# Epoch 8: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0347 - mse: 0.0346 - val_loss: 0.0358 - val_mse: 0.0357
# Epoch 9/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0357 - mse: 0.0356 - tot_time: 0h 6m 10.3s
#
# Epoch 9: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 880ms/step - loss: 0.0357 - mse: 0.0356 - val_loss: 0.0345 - val_mse: 0.0344
# Epoch 10/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0348 - mse: 0.0347 - tot_time: 0h 6m 28.5s
#
# Epoch 10: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 914ms/step - loss: 0.0348 - mse: 0.0347 - val_loss: 0.0383 - val_mse: 0.0382
# Epoch 11/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0320 - mse: 0.0319 - tot_time: 0h 6m 46.4s
#
# Epoch 11: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0320 - mse: 0.0319 - val_loss: 0.0328 - val_mse: 0.0327
# Epoch 12/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0332 - mse: 0.0330 - tot_time: 0h 7m 4.6s
#
# Epoch 12: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 910ms/step - loss: 0.0332 - mse: 0.0330 - val_loss: 0.0370 - val_mse: 0.0369
# Epoch 13/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0365 - mse: 0.0364 - tot_time: 0h 7m 22.6s
#
# Epoch 13: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0365 - mse: 0.0364 - val_loss: 0.0376 - val_mse: 0.0375
# Epoch 14/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0343 - mse: 0.0342 - tot_time: 0h 7m 40.7s
#
# Epoch 14: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 904ms/step - loss: 0.0343 - mse: 0.0342 - val_loss: 0.0367 - val_mse: 0.0366
# Epoch 15/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0345 - mse: 0.0344 - tot_time: 0h 7m 58.9s
#
# Epoch 15: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 914ms/step - loss: 0.0345 - mse: 0.0344 - val_loss: 0.0344 - val_mse: 0.0343
# Epoch 16/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0311 - mse: 0.0310 - tot_time: 0h 8m 16.8s
#
# Epoch 16: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 899ms/step - loss: 0.0311 - mse: 0.0310 - val_loss: 0.0351 - val_mse: 0.0350
# Epoch 17/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0306 - mse: 0.0304 - tot_time: 0h 8m 34.8s
#
# Epoch 17: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 907ms/step - loss: 0.0306 - mse: 0.0304 - val_loss: 0.0319 - val_mse: 0.0317
# Epoch 18/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0307 - mse: 0.0306 - tot_time: 0h 8m 52.8s
#
# Epoch 18: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0307 - mse: 0.0306 - val_loss: 0.0330 - val_mse: 0.0329
# Epoch 19/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0340 - mse: 0.0339 - tot_time: 0h 9m 10.3s
#
# Epoch 19: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 881ms/step - loss: 0.0340 - mse: 0.0339 - val_loss: 0.0354 - val_mse: 0.0353
# Epoch 20/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0326 - mse: 0.0325 - tot_time: 0h 9m 28.3s
#
# Epoch 20: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0326 - mse: 0.0325 - val_loss: 0.0363 - val_mse: 0.0362
# Epoch 21/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0340 - mse: 0.0339 - tot_time: 0h 9m 46.5s
#
# Epoch 21: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 911ms/step - loss: 0.0340 - mse: 0.0339 - val_loss: 0.0358 - val_mse: 0.0357
# Epoch 22/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0336 - mse: 0.0335 - tot_time: 0h 10m 4.6s
#
# Epoch 22: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0336 - mse: 0.0335 - val_loss: 0.0375 - val_mse: 0.0374
# Epoch 23/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0330 - mse: 0.0329 - tot_time: 0h 10m 22.5s
#
# Epoch 23: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 893ms/step - loss: 0.0330 - mse: 0.0329 - val_loss: 0.0377 - val_mse: 0.0376
# Epoch 24/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0331 - mse: 0.0330 - tot_time: 0h 10m 40.2s
#
# Epoch 24: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 885ms/step - loss: 0.0331 - mse: 0.0330 - val_loss: 0.0355 - val_mse: 0.0354
# Epoch 25/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0338 - mse: 0.0337 - tot_time: 0h 10m 58.6s
#
# Epoch 25: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 921ms/step - loss: 0.0338 - mse: 0.0337 - val_loss: 0.0355 - val_mse: 0.0354
# Epoch 26/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0328 - mse: 0.0327 - tot_time: 0h 11m 16.7s
#
# Epoch 26: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0328 - mse: 0.0327 - val_loss: 0.0395 - val_mse: 0.0394
# Epoch 27/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0368 - mse: 0.0367Restoring model weights from the end of the best epoch: 2.
#  - tot_time: 0h 11m 34.6s
#
# Epoch 27: val_loss did not improve from 0.02912
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0368 - mse: 0.0367 - val_loss: 0.0380 - val_mse: 0.0379
# Epoch 27: early stopping
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 5e-06 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0265 - mse: 0.0264 - tot_time: 0h 11m 53.1s
#
# Epoch 1: val_loss improved from 0.02912 to 0.02657, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 19s 931ms/step - loss: 0.0265 - mse: 0.0264 - val_loss: 0.0266 - val_mse: 0.0265
# Epoch 2/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0251 - mse: 0.0250 - tot_time: 0h 12m 10.8s
#
# Epoch 2: val_loss improved from 0.02657 to 0.02493, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0251 - mse: 0.0250 - val_loss: 0.0249 - val_mse: 0.0248
# Epoch 3/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0228 - mse: 0.0227 - tot_time: 0h 12m 28.8s
#
# Epoch 3: val_loss improved from 0.02493 to 0.02472, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0228 - mse: 0.0227 - val_loss: 0.0247 - val_mse: 0.0246
# Epoch 4/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0228 - mse: 0.0227 - tot_time: 0h 12m 47.0s
#
# Epoch 4: val_loss improved from 0.02472 to 0.02337, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 917ms/step - loss: 0.0228 - mse: 0.0227 - val_loss: 0.0234 - val_mse: 0.0233
# Epoch 5/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0224 - mse: 0.0223 - tot_time: 0h 13m 5.0s
#
# Epoch 5: val_loss improved from 0.02337 to 0.02262, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 892ms/step - loss: 0.0224 - mse: 0.0223 - val_loss: 0.0226 - val_mse: 0.0225
# Epoch 6/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0223 - mse: 0.0222 - tot_time: 0h 13m 22.7s
#
# Epoch 6: val_loss did not improve from 0.02262
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 883ms/step - loss: 0.0223 - mse: 0.0222 - val_loss: 0.0234 - val_mse: 0.0233
# Epoch 7/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0220 - mse: 0.0219 - tot_time: 0h 13m 40.7s
#
# Epoch 7: val_loss did not improve from 0.02262
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0220 - mse: 0.0219 - val_loss: 0.0229 - val_mse: 0.0228
# Epoch 8/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 13m 58.7s
#
# Epoch 8: val_loss improved from 0.02262 to 0.02213, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 909ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 9/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 14m 16.9s
#
# Epoch 9: val_loss did not improve from 0.02213
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0225 - val_mse: 0.0224
# Epoch 10/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0215 - mse: 0.0214 - tot_time: 0h 14m 34.7s
#
# Epoch 10: val_loss did not improve from 0.02213
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0215 - mse: 0.0214 - val_loss: 0.0227 - val_mse: 0.0226
# Epoch 11/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0214 - mse: 0.0213 - tot_time: 0h 14m 52.7s
#
# Epoch 11: val_loss improved from 0.02213 to 0.02201, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 909ms/step - loss: 0.0214 - mse: 0.0213 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 12/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0214 - mse: 0.0213 - tot_time: 0h 15m 10.6s
#
# Epoch 12: val_loss improved from 0.02201 to 0.02183, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0214 - mse: 0.0213 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 13/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0218 - mse: 0.0217 - tot_time: 0h 15m 29.0s
#
# Epoch 13: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0218 - mse: 0.0217 - val_loss: 0.0225 - val_mse: 0.0224
# Epoch 14/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0213 - mse: 0.0212 - tot_time: 0h 15m 47.0s
#
# Epoch 14: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0213 - mse: 0.0212 - val_loss: 0.0228 - val_mse: 0.0227
# Epoch 15/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0210 - mse: 0.0209 - tot_time: 0h 16m 4.7s
#
# Epoch 15: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 887ms/step - loss: 0.0210 - mse: 0.0209 - val_loss: 0.0233 - val_mse: 0.0232
# Epoch 16/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0213 - mse: 0.0212 - tot_time: 0h 16m 22.4s
#
# Epoch 16: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 887ms/step - loss: 0.0213 - mse: 0.0212 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 17/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0214 - mse: 0.0213 - tot_time: 0h 16m 40.6s
#
# Epoch 17: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 912ms/step - loss: 0.0214 - mse: 0.0213 - val_loss: 0.0229 - val_mse: 0.0228
# Epoch 18/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0212 - mse: 0.0211 - tot_time: 0h 16m 58.8s
#
# Epoch 18: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 913ms/step - loss: 0.0212 - mse: 0.0211 - val_loss: 0.0232 - val_mse: 0.0231
# Epoch 19/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0208 - mse: 0.0207 - tot_time: 0h 17m 16.7s
#
# Epoch 19: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0208 - mse: 0.0207 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 20/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0209 - mse: 0.0208 - tot_time: 0h 17m 34.6s
#
# Epoch 20: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 899ms/step - loss: 0.0209 - mse: 0.0208 - val_loss: 0.0232 - val_mse: 0.0231
# Epoch 21/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0212 - mse: 0.0211 - tot_time: 0h 17m 52.7s
#
# Epoch 21: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0212 - mse: 0.0211 - val_loss: 0.0235 - val_mse: 0.0234
# Epoch 22/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0213 - mse: 0.0212 - tot_time: 0h 18m 10.7s
#
# Epoch 22: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0213 - mse: 0.0212 - val_loss: 0.0237 - val_mse: 0.0236
# Epoch 23/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0213 - mse: 0.0212 - tot_time: 0h 18m 28.7s
#
# Epoch 23: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 904ms/step - loss: 0.0213 - mse: 0.0212 - val_loss: 0.0240 - val_mse: 0.0239
# Epoch 24/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0214 - mse: 0.0213 - tot_time: 0h 18m 46.7s
#
# Epoch 24: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 904ms/step - loss: 0.0214 - mse: 0.0213 - val_loss: 0.0238 - val_mse: 0.0237
# Epoch 25/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0216 - mse: 0.0215 - tot_time: 0h 19m 4.7s
#
# Epoch 25: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0216 - mse: 0.0215 - val_loss: 0.0237 - val_mse: 0.0236
# Epoch 26/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 19m 22.6s
#
# Epoch 26: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0240 - val_mse: 0.0239
# Epoch 27/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0218 - mse: 0.0217 - tot_time: 0h 19m 40.4s
#
# Epoch 27: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 889ms/step - loss: 0.0218 - mse: 0.0217 - val_loss: 0.0246 - val_mse: 0.0245
# Epoch 28/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0221 - mse: 0.0220 - tot_time: 0h 19m 58.0s
#
# Epoch 28: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 878ms/step - loss: 0.0221 - mse: 0.0220 - val_loss: 0.0245 - val_mse: 0.0244
# Epoch 29/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0220 - mse: 0.0219 - tot_time: 0h 20m 15.7s
#
# Epoch 29: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 884ms/step - loss: 0.0220 - mse: 0.0219 - val_loss: 0.0228 - val_mse: 0.0226
# Epoch 30/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0216 - mse: 0.0215 - tot_time: 0h 20m 33.8s
#
# Epoch 30: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0216 - mse: 0.0215 - val_loss: 0.0243 - val_mse: 0.0242
# Epoch 31/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0222 - mse: 0.0221 - tot_time: 0h 20m 51.5s
#
# Epoch 31: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 891ms/step - loss: 0.0222 - mse: 0.0221 - val_loss: 0.0241 - val_mse: 0.0240
# Epoch 32/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0220 - mse: 0.0219 - tot_time: 0h 21m 9.4s
#
# Epoch 32: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0220 - mse: 0.0219 - val_loss: 0.0245 - val_mse: 0.0244
# Epoch 33/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0225 - mse: 0.0224 - tot_time: 0h 21m 27.5s
#
# Epoch 33: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0225 - mse: 0.0224 - val_loss: 0.0254 - val_mse: 0.0253
# Epoch 34/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0228 - mse: 0.0227 - tot_time: 0h 21m 45.5s
#
# Epoch 34: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 904ms/step - loss: 0.0228 - mse: 0.0227 - val_loss: 0.0240 - val_mse: 0.0239
# Epoch 35/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0221 - mse: 0.0220 - tot_time: 0h 22m 3.6s
#
# Epoch 35: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 907ms/step - loss: 0.0221 - mse: 0.0220 - val_loss: 0.0256 - val_mse: 0.0255
# Epoch 36/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 22m 21.5s
#
# Epoch 36: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0251 - val_mse: 0.0249
# Epoch 37/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0224 - mse: 0.0223 - tot_time: 0h 22m 39.2s
#
# Epoch 37: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 889ms/step - loss: 0.0224 - mse: 0.0223 - val_loss: 0.0250 - val_mse: 0.0249
# Epoch 38/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 22m 57.0s
#
# Epoch 38: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0235 - val_mse: 0.0234
# Epoch 39/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0220 - mse: 0.0219 - tot_time: 0h 23m 15.1s
#
# Epoch 39: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 905ms/step - loss: 0.0220 - mse: 0.0219 - val_loss: 0.0242 - val_mse: 0.0241
# Epoch 40/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 23m 33.3s
#
# Epoch 40: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 913ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0236 - val_mse: 0.0235
# Epoch 41/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0215 - mse: 0.0214 - tot_time: 0h 23m 51.2s
#
# Epoch 41: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0215 - mse: 0.0214 - val_loss: 0.0251 - val_mse: 0.0250
# Epoch 42/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 24m 9.3s
#
# Epoch 42: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0237 - val_mse: 0.0236
# Epoch 43/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0219 - mse: 0.0218 - tot_time: 0h 24m 27.0s
#
# Epoch 43: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 892ms/step - loss: 0.0219 - mse: 0.0218 - val_loss: 0.0251 - val_mse: 0.0250
# Epoch 44/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0221 - mse: 0.0220 - tot_time: 0h 24m 44.7s
#
# Epoch 44: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 878ms/step - loss: 0.0221 - mse: 0.0220 - val_loss: 0.0256 - val_mse: 0.0255
# Epoch 45/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0225 - mse: 0.0224 - tot_time: 0h 25m 2.5s
#
# Epoch 45: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 896ms/step - loss: 0.0225 - mse: 0.0224 - val_loss: 0.0253 - val_mse: 0.0252
# Epoch 46/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0225 - mse: 0.0224 - tot_time: 0h 25m 20.4s
#
# Epoch 46: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0225 - mse: 0.0224 - val_loss: 0.0251 - val_mse: 0.0249
# Epoch 47/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0226 - mse: 0.0225 - tot_time: 0h 25m 38.0s
#
# Epoch 47: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 878ms/step - loss: 0.0226 - mse: 0.0225 - val_loss: 0.0252 - val_mse: 0.0251
# Epoch 48/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0218 - mse: 0.0217 - tot_time: 0h 25m 56.0s
#
# Epoch 48: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 905ms/step - loss: 0.0218 - mse: 0.0217 - val_loss: 0.0247 - val_mse: 0.0246
# Epoch 49/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0225 - mse: 0.0224 - tot_time: 0h 26m 13.9s
#
# Epoch 49: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0225 - mse: 0.0224 - val_loss: 0.0257 - val_mse: 0.0256
# Epoch 50/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0227 - mse: 0.0226 - tot_time: 0h 26m 31.9s
#
# Epoch 50: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0227 - mse: 0.0226 - val_loss: 0.0264 - val_mse: 0.0263
# Epoch 51/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0227 - mse: 0.0226 - tot_time: 0h 26m 49.5s
#
# Epoch 51: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 884ms/step - loss: 0.0227 - mse: 0.0226 - val_loss: 0.0235 - val_mse: 0.0234
# Epoch 52/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0222 - mse: 0.0221 - tot_time: 0h 27m 7.5s
#
# Epoch 52: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0222 - mse: 0.0221 - val_loss: 0.0238 - val_mse: 0.0237
# Epoch 53/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0217 - mse: 0.0216 - tot_time: 0h 27m 25.5s
#
# Epoch 53: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0217 - mse: 0.0216 - val_loss: 0.0252 - val_mse: 0.0251
# Epoch 54/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0216 - mse: 0.0215 - tot_time: 0h 27m 43.3s
#
# Epoch 54: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0216 - mse: 0.0215 - val_loss: 0.0245 - val_mse: 0.0244
# Epoch 55/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0222 - mse: 0.0221 - tot_time: 0h 28m 1.2s
#
# Epoch 55: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 897ms/step - loss: 0.0222 - mse: 0.0221 - val_loss: 0.0245 - val_mse: 0.0244
# Epoch 56/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0224 - mse: 0.0223 - tot_time: 0h 28m 19.1s
#
# Epoch 56: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0224 - mse: 0.0223 - val_loss: 0.0248 - val_mse: 0.0247
# Epoch 57/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0227 - mse: 0.0226 - tot_time: 0h 28m 36.9s
#
# Epoch 57: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 894ms/step - loss: 0.0227 - mse: 0.0226 - val_loss: 0.0250 - val_mse: 0.0249
# Epoch 58/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0224 - mse: 0.0223 - tot_time: 0h 28m 55.0s
#
# Epoch 58: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0224 - mse: 0.0223 - val_loss: 0.0264 - val_mse: 0.0263
# Epoch 59/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0222 - mse: 0.0221 - tot_time: 0h 29m 12.9s
#
# Epoch 59: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0222 - mse: 0.0221 - val_loss: 0.0251 - val_mse: 0.0250
# Epoch 60/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0226 - mse: 0.0225 - tot_time: 0h 29m 30.8s
#
# Epoch 60: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 899ms/step - loss: 0.0226 - mse: 0.0225 - val_loss: 0.0245 - val_mse: 0.0244
# Epoch 61/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0218 - mse: 0.0217 - tot_time: 0h 29m 48.9s
#
# Epoch 61: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0218 - mse: 0.0217 - val_loss: 0.0258 - val_mse: 0.0257
# Epoch 62/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0223 - mse: 0.0222Restoring model weights from the end of the best epoch: 12.
#  - tot_time: 0h 30m 6.9s
#
# Epoch 62: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0223 - mse: 0.0222 - val_loss: 0.0261 - val_mse: 0.0260
# Epoch 62: early stopping
#
#
# --------------------------------------------------------------------------------
#
# ---------------------------- LEARNING RATE : 1e-06 -----------------------------
#
# --------------------------------------------------------------------------------
#
#
# Epoch 1/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0207 - mse: 0.0206 - tot_time: 0h 30m 25.0s
#
# Epoch 1: val_loss did not improve from 0.02183
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0207 - mse: 0.0206 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 2/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0202 - mse: 0.0201 - tot_time: 0h 30m 42.8s
#
# Epoch 2: val_loss improved from 0.02183 to 0.02181, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0202 - mse: 0.0201 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 3/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0201 - mse: 0.0200 - tot_time: 0h 31m 1.1s
#
# Epoch 3: val_loss improved from 0.02181 to 0.02171, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 916ms/step - loss: 0.0201 - mse: 0.0200 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 4/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0201 - mse: 0.0200 - tot_time: 0h 31m 19.3s
#
# Epoch 4: val_loss did not improve from 0.02171
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 905ms/step - loss: 0.0201 - mse: 0.0200 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 5/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 31m 37.0s
#
# Epoch 5: val_loss improved from 0.02171 to 0.02151, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 6/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0200 - mse: 0.0199 - tot_time: 0h 31m 55.1s
#
# Epoch 6: val_loss improved from 0.02151 to 0.02142, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 912ms/step - loss: 0.0200 - mse: 0.0199 - val_loss: 0.0214 - val_mse: 0.0213
# Epoch 7/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 32m 13.4s
#
# Epoch 7: val_loss did not improve from 0.02142
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 8/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0200 - mse: 0.0198 - tot_time: 0h 32m 31.5s
#
# Epoch 8: val_loss did not improve from 0.02142
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0200 - mse: 0.0198 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 9/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 32m 49.5s
#
# Epoch 9: val_loss did not improve from 0.02142
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 904ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 10/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 33m 7.5s
#
# Epoch 10: val_loss improved from 0.02142 to 0.02131, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 914ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0213 - val_mse: 0.0212
# Epoch 11/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 33m 25.9s
#
# Epoch 11: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 12/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 33m 43.6s
#
# Epoch 12: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 882ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 13/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 34m 1.3s
#
# Epoch 13: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 14/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 34m 19.1s
#
# Epoch 14: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 15/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0200 - mse: 0.0198 - tot_time: 0h 34m 37.2s
#
# Epoch 15: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0200 - mse: 0.0198 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 16/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 34m 55.1s
#
# Epoch 16: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 17/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 35m 13.0s
#
# Epoch 17: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 18/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 35m 30.5s
#
# Epoch 18: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 876ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 19/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 35m 48.5s
#
# Epoch 19: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0213 - val_mse: 0.0212
# Epoch 20/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 36m 6.5s
#
# Epoch 20: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 21/200
# ...
# Epoch 23/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0196 - tot_time: 0h 37m 0.4s
#
# Epoch 23: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 897ms/step - loss: 0.0198 - mse: 0.0196 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 24/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 37m 18.4s
#
# Epoch 24: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 25/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0196 - mse: 0.0195 - tot_time: 0h 37m 36.3s
#
# Epoch 25: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0196 - mse: 0.0195 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 26/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0200 - mse: 0.0199 - tot_time: 0h 37m 54.1s
#
# Epoch 26: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 894ms/step - loss: 0.0200 - mse: 0.0199 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 27/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 38m 12.1s
#
# Epoch 27: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 897ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 28/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0195 - mse: 0.0194 - tot_time: 0h 38m 30.0s
#
# Epoch 28: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 898ms/step - loss: 0.0195 - mse: 0.0194 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 29/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 38m 47.8s
#
# Epoch 29: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 890ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 30/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 39m 6.1s
#
# Epoch 30: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 916ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0216 - val_mse: 0.0215
# Epoch 31/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 39m 24.0s
#
# Epoch 31: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 894ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 32/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 39m 41.8s
#
# Epoch 32: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 891ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0215 - val_mse: 0.0214
# Epoch 33/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 39m 59.9s
#
# Epoch 33: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0217 - val_mse: 0.0216
# Epoch 34/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 40m 17.7s
#
# Epoch 34: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 892ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 35/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 40m 35.5s
#
# Epoch 35: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 892ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 36/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 40m 53.7s
#
# Epoch 36: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 907ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 37/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 41m 11.8s
#
# Epoch 37: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 905ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0219 - val_mse: 0.0217
# Epoch 38/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 41m 29.8s
#
# Epoch 38: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 39/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 41m 47.9s
#
# Epoch 39: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0219 - val_mse: 0.0217
# Epoch 40/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 42m 6.2s
#
# Epoch 40: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 911ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 41/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 42m 24.0s
#
# Epoch 41: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 892ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 42/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 42m 42.1s
#
# Epoch 42: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 906ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 43/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 43m 0.4s
#
# Epoch 43: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 918ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 44/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 43m 18.5s
#
# Epoch 44: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 905ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 45/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 43m 36.3s
#
# Epoch 45: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 46/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0197 - tot_time: 0h 43m 54.2s
#
# Epoch 46: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 900ms/step - loss: 0.0199 - mse: 0.0197 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 47/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0195 - mse: 0.0194 - tot_time: 0h 44m 12.0s
#
# Epoch 47: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 889ms/step - loss: 0.0195 - mse: 0.0194 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 48/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 44m 30.1s
#
# Epoch 48: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 909ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 49/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 44m 48.3s
#
# Epoch 49: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 909ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0222 - val_mse: 0.0221
# Epoch 50/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 45m 6.1s
#
# Epoch 50: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 893ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0224 - val_mse: 0.0223
# Epoch 51/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 45m 24.0s
#
# Epoch 51: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 52/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0196 - mse: 0.0195 - tot_time: 0h 45m 42.2s
#
# Epoch 52: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 911ms/step - loss: 0.0196 - mse: 0.0195 - val_loss: 0.0219 - val_mse: 0.0218
# Epoch 53/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 45m 59.8s
#
# Epoch 53: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 880ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0220 - val_mse: 0.0219
# Epoch 54/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0200 - mse: 0.0199 - tot_time: 0h 46m 17.8s
#
# Epoch 54: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0200 - mse: 0.0199 - val_loss: 0.0218 - val_mse: 0.0217
# Epoch 55/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196 - tot_time: 0h 46m 35.8s
#
# Epoch 55: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 902ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 56/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 46m 53.9s
#
# Epoch 56: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 899ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 57/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0198 - mse: 0.0197 - tot_time: 0h 47m 11.9s
#
# Epoch 57: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 901ms/step - loss: 0.0198 - mse: 0.0197 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 58/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0199 - mse: 0.0198 - tot_time: 0h 47m 30.1s
#
# Epoch 58: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 908ms/step - loss: 0.0199 - mse: 0.0198 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 59/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0196 - mse: 0.0195 - tot_time: 0h 47m 47.9s
#
# Epoch 59: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 895ms/step - loss: 0.0196 - mse: 0.0195 - val_loss: 0.0222 - val_mse: 0.0220
# Epoch 60/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0197 - mse: 0.0196Restoring model weights from the end of the best epoch: 10.
#  - tot_time: 0h 48m 6.0s
#
# Epoch 60: val_loss did not improve from 0.02131
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_AR_rnn/AR_rnn_008/checkpoints/LossHistoriesCheckpoint
# 20/20 [==============================] - 18s 903ms/step - loss: 0.0197 - mse: 0.0196 - val_loss: 0.0221 - val_mse: 0.0220
# Epoch 60: early stopping

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    # test_loss = rnn_net.evaluate(
    #     testing_data_rnn_input, testing_data_rnn_output,
    # )
    for layer in rnn_net.rnn_list:
        if layer.stateful == True:
            layer.reset_states()
    print(testing_data_rnn_input.shape, testing_data_rnn_output.shape)
    
    test_loss = 0.0
    for i in range(int(testing_data_rnn_input.shape[0]//batch_size)):
        # i_test_loss = rnn_net.evaluate(
        #     testing_data_rnn_input[i*batch_size:(i+1)*batch_size, :, :],
        #     testing_data_rnn_output[i*batch_size:(i+1)*batch_size, :, :],
        # )
        temp = rnn_net.call(testing_data_rnn_input[i*batch_size:(i+1)*batch_size, :, :], training=False)
        i_test_loss = np.mean((testing_data_rnn_output[i*batch_size:(i+1)*batch_size, :, :] - temp.numpy())**2)
        test_loss = (i*test_loss + i_test_loss)/(i+1)

    save_path = dir_name_ARrnn+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'lr_change':lr_change,
            'test_loss':test_loss
        }))
        
    if normalize_dataset == True:
        with open(save_path+dir_sep+'rnn_normalization.txt', 'w') as f:
            f.write(str({
                'normalization_arr':normalization_arr
            }))

    rnn_net.save_everything(
        file_name=save_path+dir_sep+'final_net')
# Out:
# (192, 77, 16) (192, 77, 16)

# %%
# plotting losses
dir_name_plot = dir_name_ARrnn+dir_sep+'plots'
if not os.path.isdir(dir_name_plot):
    os.makedirs(dir_name_plot)

# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=learning_rate_list
)

plt.savefig(dir_name_plot+'{ds}loss_history.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()

# %%
# data_type = 'training'
data_type = 'testing'

for layer in rnn_net.rnn_list:
    if layer.stateful == True:
        layer.reset_states()

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 3788
print('data_idx : {}'.format(data_idx))

# data_in = data_in[data_idx]
data_out = data_out[data_idx]

prediction = rnn_net.predict(data_in[data_idx:data_idx+1, :, :])

plot_reconstructed_data_KS(
    [data_out.shape[0]],
    dir_name_ARrnn,
    data_out,
    prediction[0], dt_rnn, 1+np.arange(0, data_out.shape[1]),
    save_figs=False,
    normalization_constant_arr=normalization_arr,
    xticks_snapto=2,
    num_yticks=data_out.shape[1],
    ylabel=r'Latent State Index',
    ax1_title=r'Original Data',
    ax2_title=r'RNN (AR) Predicted Data')
# Out:
# data_idx : 45

# %%
prediction.shape, data_out.shape
# Out:
# ((64, 77, 16), (77, 16))

# %%
def rescale_data(data, normalization_arr):
    '''
    data - [num_batches x num_timesteps x num_states]
    normalization_arr = [2 x num_states]
    '''
    new_data = data.copy()
    shape = new_data.shape
    for i in range(data.shape[-1]):
        new_data[:, i] -= normalization_arr[0, i]
        new_data[:, i] /= normalization_arr[1, i]

    return new_data

def norm_sq_time_average(data):
    data_norm_sq = np.zeros(shape=data.shape[0])
    for i in range(data.shape[1]):
        data_norm_sq[:] += data[:, i]**2
    # integrating using the trapezoidal rule
    norm_sq_time_avg = np.sum(data_norm_sq) - 0.5*(data_norm_sq[0]+data_norm_sq[-1])
    norm_sq_time_avg /= data_norm_sq.shape[0]
    return norm_sq_time_avg

def invert_normalization(data, normalization_arr):
    new_data = data.copy()
    shape = new_data.shape
    for i in range(shape[-1]):
        if len(shape) == 2:
            new_data[:, i] *= normalization_arr[1, i]
            new_data[:, i] += normalization_arr[0, i]
        elif len(shape) == 3:
            new_data[:, :, i] *= normalization_arr[1, i]
            new_data[:, :, i] += normalization_arr[0, i]
    return new_data

# %%
# data_type = 'training'
data_type = 'testing'

for layer in rnn_net.rnn_list:
    if layer.stateful == True:
        layer.reset_states()

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 0
for i in range(len(rnn_data_boundary_idx_arr)):
    if data_idx < rnn_data_boundary_idx_arr[i]:
        case_idx = i
        break
lyap_time = lyapunov_time_arr[case_idx]

print('case {}, data_idx : {}'.format(case_idx+1, data_idx))

# data_in = data_in[data_idx]
data_out = data_out[data_idx]
# data_out = rescale_data(data_out, normalization_arr)
# data_out = invert_normalization(data_out, normalization_arr)

prediction = rnn_net.predict(data_in[data_idx:data_idx+1, :, :])
# prediction = rnn_net(data_in[data_idx:data_idx+1, :, :], training=False)
# prediction = rnn_net.call(data_in[data_idx:data_idx+1, :, :], training=False)
# prediction = invert_normalization(prediction, normalization_arr)

#-- computing KE --#
KE_og = ae_net.decoder_net.predict(invert_normalization(data_out, normalization_arr))
KE_pred = ae_net.decoder_net.predict(invert_normalization(prediction[0, :, :], normalization_arr))

KE_og = np.sum(KE_og**2, axis=1)
KE_pred = np.sum(KE_pred**2, axis=1)
#-- KE computed --#

n = 1
num_latent_states = data_out.shape[-1]
N = data_out.shape[0]

num_cols = 1
num_rows = n*num_latent_states

ax_ylabels = ['$x^*_{' +str(i)+'}$' for i in range(1, num_latent_states+1)]

fig, ax = plt.subplots(num_latent_states+1, 1, sharex=True, figsize=(7.5*num_cols, 2.5*num_rows))
if num_latent_states == 1:
    ax = [ax]
input_time = np.arange(0, N)*dt_rnn/lyap_time

cmap = plt.get_cmap('jet')
colors = [cmap(i) for i in np.linspace(0, 1, 2*n)]

prev_idx = 0

# mpl_ax_artist_list = []
for j in range(num_latent_states):
    for i in range(n):
        obj_in = ax[j].plot(input_time, data_out[:, j], linewidth=1, color=colors[2*i], label='Case {} - actual data'.format(i+1))
        obj_out = ax[j].plot(input_time, prediction[0, :, j], linewidth=1, color=colors[2*i+1], label='Case {} - predicted data'.format(i+1))
        # mpl_ax_artist_list.append(obj_in[0])
        # mpl_ax_artist_list.append(obj_out[0])
    ax[j].set_ylabel(ax_ylabels[j])
    # if xlim is not None:
    #     ax[j].set_xlim(xlim)
    # if ylim is not None:
    #     ax[j].set_ylim(ylim)
    ax[j].grid(True)
    ax[j].set_axisbelow(True)
    # ax[j].set_ylim([-1, 1])

ax[-1].plot(input_time, KE_og, linewidth=1, color=colors[0], label='Case {} - actual KE'.format(i+1))
ax[-1].plot(input_time, KE_pred, linewidth=1, color=colors[1], label='Case {} - predicted KE'.format(i+1))
ax[-1].set_ylabel('$KE$')
ax[-1].grid(True)
ax[-1].set_axisbelow(True)

ax[-1].set_xlabel('Time$^+$')

max_rows = 10
max_rows = float(max_rows)
ncols = int(np.ceil(len(boundary_idx_arr) / max_rows))
ax[0].legend(
    loc='best',
    ncol=ncols,
)
ax[0].set_title(r'Latent States', size=12)
plt.show()
# plt.savefig('AR-GRU.png', dpi=300, bbox_inches='tight')
print('')

### Error and prediction horizon
# error = np.linalg.norm(data_out[:, :] - prediction[0, :, :], axis=1)
error = (data_out[:, :] - prediction[0, :, :])**2
# error /= norm_sq_time_average(data_out)**0.5
error = np.mean(np.divide(error, time_stddev**2), axis=1)**0.5

# print(norm_sq_time_average(data_out)**0.5)

fig2, ax2 = plt.subplots(1, 1, figsize=(7.5, 2.5))
ax2.plot(input_time, error)
ax2.grid(True)
ax2.set_axisbelow(True)
ax2.set_xlabel('Time$^+$')
ax2.set_ylabel('Normalized Error')

error_threshold = 0.5

predhor_idx = np.where(error >= error_threshold)[0][0]
ax2.plot(input_time[predhor_idx], error[predhor_idx], 'o', color='k')
ax2.axhline(error[predhor_idx], linewidth=0.9, linestyle='--', color='k')
ax2.axvline(input_time[predhor_idx], linewidth=0.9, linestyle='--', color='k')

prediction_horizon = predhor_idx*dt_rnn/lyap_time
print(prediction_horizon)

plt.show()
# Out:
# case 1, data_idx : 124
# 0.9827818581204905
