# %%
# enabling 3rd party widgets
# from google.colab import output
# output.enable_custom_widget_manager()
# output.disable_custom_widget_manager()

# interactive 3D plot
# !pip install ipympl
# %matplotlib widget

# %%
import os
import math
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import time as time
import platform as platform

import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import L2
import h5py

tf.keras.backend.set_floatx('float32')

# %%
colab_flag = False
FTYPE = np.float32
ITYPE = np.int32

strategy = None
# strategy = tf.distribute.MirroredStrategy()

# %%
current_sys = platform.system()

if current_sys == 'Windows':
    dir_sep = '\\'
else:
    dir_sep = '/'

# %%
if colab_flag == True:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Github/MLROM/KS/')

# pip install tensorflow-addons
import tensorflow_addons as tfa

# %%
print(os.getcwd())
# Out:
# /home/rkaushik/Documents/Thesis/MLROM/KS

# %%
tf.config.list_physical_devices('GPU')
# Out:
# 2022-11-09 15:04:22.058641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.059131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.140442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.140719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.140943: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.141158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from S
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# ysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
from tools.misc_tools import create_data_for_RNN, mytimecallback, SaveLosses, plot_losses, plot_reconstructed_data_KS, plot_latent_states_KS , readAndReturnLossHistories, sigmoidWarmupAndDecayLRSchedule
from tools.ae_v3 import Autoencoder
# from tools.LSTM_AR_v2 import AR_RNN_LSTM as RNN_LSTM

# %%
behaviour = 'initialiseAndTrainFromScratch'
# behaviour = 'loadCheckpointAndContinueTraining'
# behaviour = 'loadFinalNetAndPlot'

# %%
# setting seed for PRNGs
if behaviour == 'initialiseAndTrainFromScratch':
    prng_seed = 42
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if colab_flag == False:
    if strategy is None:
        if gpus:
            gpu_to_use = 0
            tf.config.set_visible_devices(gpus[gpu_to_use], 'GPU')
    logical_devices = tf.config.list_logical_devices('GPU')
    print(logical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-11-09 15:04:22.451066: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-09 15:04:22.452273: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.452904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:22.453373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:23.052117: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:23.052352: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:23.052551: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-09 15:04:23.052712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3371 MB memory:  -> device: 0, name: Quadro K2200, pci bus id: 0000:02:00.0, compute capability: 5.0

# %%
# print(tf.test.gpu_device_name())
print(tf.config.list_physical_devices())
print(tf.config.list_logical_devices())
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'), LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2.8.1

# %% [markdown]
# # KS System

# %%
# setting up params (and saving, if applicable)
from numpy import *

if behaviour == 'initialiseAndTrainFromScratch':
    # making RNN save directory
    dir_name_rnn = os.getcwd() + dir_sep + 'saved_rnn'
    if not os.path.isdir(dir_name_rnn):
        os.makedirs(dir_name_rnn)

    counter = 0
    while True:
        dir_check = 'rnn_' + str(counter).zfill(3)
        if os.path.isdir(dir_name_rnn + dir_sep + dir_check):
            counter += 1
        else:
            break

    dir_name_rnn = dir_name_rnn + dir_sep + dir_check
    os.makedirs(dir_name_rnn)
    os.makedirs(dir_name_rnn+dir_sep+'plots')

    # autoencoder directory
    ae_idx = '009'
    dir_name_ae = os.getcwd()+'{ds}saved_ae{ds}ae_'.format(ds=dir_sep)+ae_idx
else:
    # RNN directory
    dir_name_rnn = os.getcwd()+'/saved_rnn/rnn_008'

    # reading AE directory
    with open(dir_name_rnn + '/sim_data_AE_params.txt') as f:
        lines = f.readlines()

    params_dict = eval(''.join(lines))

    dir_name_ae = params_dict['dir_name_ae']
    ae_idx = dir_name_ae[-3:]
    dir_name_ae = os.getcwd()+'/saved_ae/ae_'+ae_idx

    # reading RNN paramaters
    with open(dir_name_rnn + '/RNN_specific_data.txt') as f:
        lines = f.readlines()

    params_rnn_dict = eval(''.join(lines))

    dt_rnn = params_rnn_dict['dt_rnn']
    T_sample_input = params_rnn_dict['T_sample_input']
    T_sample_output = params_rnn_dict['T_sample_output']
    T_offset = params_rnn_dict['T_offset']
    return_params_arr = params_rnn_dict['return_params_arr']
    params = params_rnn_dict['params']
    try:
        normalize_dataset = params_rnn_dict['normalize_dataset']
    except:
        print("'normalize_dataset' not present in RNN_specific_data, set to False.")
        normalize_dataset = False
    try:
        stddev_multiplier = params_rnn_dict['stddev_multiplier']
    except:
        print("'stddev_multiplier' not present in RNN_specific_data, set to None.")
        stddev_multiplier = None

# reading simulation parameters
with open(dir_name_ae + dir_sep + 'ae_data.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
data_dir_idx = params_dict['data_dir_idx']
normalizeforae_flag = params_dict['normalizeforae_flag']
normalization_constant_arr_aedata = params_dict['normalization_constant_arr_aedata']

print('dir_name_rnn:', dir_name_rnn)
print('dir_name_ae:', dir_name_ae)
print('data_dir_idx:', data_dir_idx)

# loading data
dir_name_data = os.getcwd() + dir_sep + 'saved_data' + dir_sep + 'data_' + data_dir_idx
    
with open(dir_name_data + dir_sep + 'sim_data_params.txt') as f:
    lines = f.readlines()
params_dict = eval(''.join(lines))
params_mat = params_dict['params_mat']
# init_state = params_dict['init_state']
t0 = params_dict['t0']
T = params_dict['T']
delta_t = params_dict['delta_t']
numpoints_xgrid = params_dict['numpoints_xgrid']
length = params_dict['length']
return_params_arr = params_dict['return_params_arr']
normalize_flag_ogdata = params_dict['normalize_flag']
print('normalize_flag_ogdata:', normalize_flag_ogdata)
alldata_withparams_flag = params_dict['alldata_withparams_flag']

xgrid = length*np.linspace(0, 1, numpoints_xgrid)

fl = np.load(dir_name_data+dir_sep+'data.npz', allow_pickle=True)
all_data = fl['all_data']
boundary_idx_arr = fl['boundary_idx_arr']
normalization_constant_arr_ogdata = fl['normalization_constant_arr'][0]
initial_t0 = fl['initial_t0']
init_state_mat = fl['init_state_mat']

lyapunov_spectrum_mat = fl['lyapunov_spectrum_mat']
# Out:
# dir_name_rnn: /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014
# dir_name_ae: /home/rkaushik/Documents/Thesis/MLROM/KS/saved_ae/ae_009
# data_dir_idx: 001
# normalize_flag_ogdata: False

# %%
lyapunov_time_arr = np.empty(shape=lyapunov_spectrum_mat.shape[0], dtype=FTYPE)
for i in range(lyapunov_spectrum_mat.shape[0]):
    lyapunov_time_arr[i] = 1/lyapunov_spectrum_mat[i, 0]
    print('Case : {}, lyapunov exponent : {}, lyapunov time : {}s'.format(i+1, lyapunov_spectrum_mat[i, 0], lyapunov_time_arr[i]))
# Out:
# Case : 1, lyapunov exponent : 0.07866301843612732, lyapunov time : 12.712453842163086s

# %%
def plot(
        boundary_idx_arr,
        delta_t,
        all_data,
        xgrid,
        xticks_snapto=20,
        num_yticks=11,
    ):

    n = len(boundary_idx_arr)
    # '''
    num_cols = 1
    num_rows = 1
    factor = 1
    # fig = plt.figure(figsize=(7.5*num_cols, 7.5*num_rows))

    num_modes = xgrid.shape[0]

    prev_idx = 0
    for i in range(len(boundary_idx_arr)):
        next_idx = boundary_idx_arr[i]
        fig, ax = plt.subplots(figsize=(factor*7.5*num_cols, factor*5.0*num_rows))
        N = next_idx - prev_idx
        input_time = np.arange(0, N)*delta_t

        im = ax.imshow(all_data[prev_idx:next_idx, 0:num_modes].transpose(), aspect='auto', origin='lower')
        num_xticks = 1 + int((N*delta_t + 0.5*xticks_snapto) // xticks_snapto)
        # xticks = np.linspace(0, N, num_xticks, dtype=np.int32)
        xticks = np.arange(0, N, int((xticks_snapto+0.5*delta_t)//delta_t))
        ax.set_xticks(ticks=xticks)
        ax.set_xticklabels(np.round(xticks*delta_t, 1))
        ax.tick_params(axis='x', rotation=270+45)

        yticks = np.linspace(0, 1, num_yticks)*(len(xgrid)-1)
        yticklabels = np.round(np.linspace(0, 1, yticks.shape[0])*xgrid[-1], 2)
        ax.set_yticks(ticks=yticks)
        ax.set_yticklabels(yticklabels)

        ax.set_xlabel('Time')
        ax.set_ylabel(r'$x$')
        # ax.title.set_text(r'Latent States')

        plt.colorbar(im)
        plt.show()
        print('')

        prev_idx = next_idx

    # '''

# %%
plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    xgrid,
    xticks_snapto=int(40*np.round((T//10)/40))
)

# %%
# delaing with normalizing the data before feeding into autoencoder
if normalizeforae_flag == True:
    for i in range(numpoints_xgrid):
        all_data[:, i] -= normalization_constant_arr_aedata[0, i]
        all_data[:, i] /= normalization_constant_arr_aedata[1, i]

# %%
plot(
    boundary_idx_arr,
    delta_t,
    all_data,
    xgrid,
    xticks_snapto=int(40*np.round((T//10)/40))
)

# %% [markdown]
# # Autoencoder

# %%
# load_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_class_dict.txt'
# wt_file = dir_name_ae+dir_sep+'new_class_data'+dir_sep+'ae_'+ae_idx+'_ae_weights.h5'

# if colab_flag == False:
#     dir_name_ae_og = dir_name_ae
#     dir_name_ae_temp = '/home/rkaushik/Documents/Thesis/MLROM/CDV/saved_ae/ae_'+ae_idx
#     dir_name_ae = dir_name_ae_temp

load_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_class_dict.txt'
wt_file = dir_name_ae+dir_sep+'final_net'+dir_sep+'final_net_ae_weights.h5'

# if colab_flag == False:
#     dir_name_ae = dir_name_ae_og

# %%
ae_net = Autoencoder(all_data.shape[1], load_file=load_file)
ae_net.load_weights_from_file(wt_file)

# %%
# create data
latent_states_all = ae_net.encoder_net.predict(all_data)
num_latent_states = latent_states_all.shape[1]

# %%
plot_latent_states_KS(
    boundary_idx_arr,
    latent_states_all,
    delta_t,
    dir_name_ae,
    xticks_snapto=int(40*np.round((T//10)/40)),
    num_yticks=11,
    save_figs=False)

# %%
# for i in range(ae_net.layers):
#     tf.keras.utils.plot_model(
#         ae_net.layers[i],
#         to_file=dir_name_ae+'/plots/netlayer_{}.png'.format(i),
#         show_shapes=True,
#         dpi=300
# )

# %% [markdown]
# # ESN

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    # RNN data parameters
    num_lyaptimesteps_totrain = 10
    dt_rnn = 0.1
    T_sample_input = num_lyaptimesteps_totrain*np.mean(lyapunov_time_arr)
    T_sample_output = num_lyaptimesteps_totrain*np.mean(lyapunov_time_arr)
    T_offset = dt_rnn
    normalize_dataset = True # whether the data for the RNN should be normalized by the dataset's mean and std
    stddev_multiplier = 3
    if return_params_arr != False:
        params = params_arr
    else:
        params = None

    # saving simulation data
    sim_data = {
        'params_mat':params_mat,
        'init_state_mat':init_state_mat,
        't0':t0,
        'T':T,
        'delta_t':delta_t,
        'return_params_arr':return_params_arr,
        'dir_name_ae':dir_name_ae,
        'normalize_dataset':normalize_dataset,
        'stddev_multiplier':stddev_multiplier,
    }


    with open(dir_name_rnn+dir_sep+'sim_data_AE_params.txt', 'w') as f:
        f.write(str(sim_data))
        
    # saving RNN specific data
    RNN_specific_data = {
        'dt_rnn':dt_rnn,
        'T_sample_input':T_sample_input,
        'T_sample_output':T_sample_output,
        'T_offset':T_offset,
        'boundary_idx_arr':boundary_idx_arr,
        'delta_t':delta_t,
        'params':params,
        'return_params_arr':return_params_arr,
        'normalize_dataset':normalize_dataset,
        'num_lyaptimesteps_totrain':num_lyaptimesteps_totrain,
        'stddev_multiplier':stddev_multiplier,
    }

    with open(dir_name_rnn+dir_sep+'RNN_specific_data.txt', 'w') as f:
        f.write(str(RNN_specific_data))

# %%
rnn_res_dict = create_data_for_RNN(
    latent_states_all,
    dt_rnn,
    T_sample_input,
    T_sample_output,
    T_offset,
    None,
    boundary_idx_arr,
    delta_t,
    params=params,
    return_numsamples=True,
    normalize_dataset=normalize_dataset,
    stddev_multiplier=stddev_multiplier)
    
data_rnn_input = rnn_res_dict['data_rnn_input']
data_rnn_output = rnn_res_dict['data_rnn_output']
org_data_idx_arr_input = rnn_res_dict['org_data_idx_arr_input']
org_data_idx_arr_output = rnn_res_dict['org_data_idx_arr_output']
num_samples = rnn_res_dict['num_samples']
normalization_arr = rnn_res_dict['normalization_arr']
rnn_data_boundary_idx_arr = rnn_res_dict['rnn_data_boundary_idx_arr']

# %%
# setting up training params
if behaviour == 'initialiseAndTrainFromScratch':
    learning_rate_dict = {
        'eta_begin':0.0001,
        'eta_high':0.001,
        'eta_low':0.00001
    }
    epochs = 1000
    patience = 20  # parameter for early stopping
    min_delta = 5e-6  # parameter for early stopping
    lambda_reg = 1e-4  # weight for regularizer
    train_split = 0.8
    val_split = 0.1
    test_split = 1 - train_split - val_split
    batch_size = 64
    fRMS = 0.025

    # saving training params
    training_specific_params = {
        'learning_rate_dict':learning_rate_dict,
        'epochs':epochs,
        'patience':patience,
        'min_delta':min_delta,
        'prng_seed':prng_seed,
        'train_split':train_split,
        'val_split':val_split,
        'batch_size':batch_size,
        'fRMS':fRMS
    }

    with open(dir_name_rnn+dir_sep+'training_specific_params.txt', 'w') as f:
        f.write(str(training_specific_params))
else:
    # dir_name_rnn_og = dir_name_rnn
    # dir_name_rnn_temp = '/home/rkaushik/Documents/Thesis/MLROM/CDV/saved_rnn/rnn_'+dir_name_rnn_og[-3:]
    # dir_name_rnn = dir_name_rnn_temp

    with open(dir_name_rnn + dir_sep + 'training_specific_params.txt') as f:
        lines = f.readlines()


    tparams_dict = eval(''.join(lines))

    learning_rate_dict = tparams_dict['learning_rate_dict']
    epochs = tparams_dict['epochs']
    patience = tparams_dict['patience']
    min_delta = tparams_dict['min_delta']
    prng_seed = tparams_dict['prng_seed']
    train_split = tparams_dict['train_split']
    val_split = tparams_dict['val_split']
    batch_size = tparams_dict['batch_size']

    test_split = 1 - train_split - val_split

    # setting seed for PRNGs
    np.random.seed(prng_seed)
    tf.random.set_seed(prng_seed)

# %%
# idx = np.arange(data_rnn_input.shape[0])
# np.random.shuffle(idx)
# boundary = int(np.round(train_split*data_rnn_input.shape[0]))

# training_data_rnn_input = data_rnn_input[idx[0:boundary]]
# training_data_rnn_output = data_rnn_output[idx[0:boundary]]

# testing_data_rnn_input = data_rnn_input[idx[boundary:]]
# testing_data_rnn_output = data_rnn_output[idx[boundary:]]

# %%
cum_samples = rnn_data_boundary_idx_arr[-1]
# idx = np.arange(cum_samples)
# np.random.shuffle(idx)
num_train = 0
num_val = 0
begin_idx = 0
for i in range(len(boundary_idx_arr)):
    num_samples = rnn_data_boundary_idx_arr[i] - begin_idx
    num_train += int( (1-test_split-val_split)*num_samples )
    num_val += int(val_split*num_samples)
    begin_idx = rnn_data_boundary_idx_arr[i]

# defining shapes
training_input_shape = [num_train]
training_input_shape.extend(data_rnn_input.shape[1:])

training_output_shape = [num_train]
training_output_shape.extend(data_rnn_output.shape[1:])

val_input_shape = [num_val]
val_input_shape.extend(data_rnn_input.shape[1:])

val_output_shape = [num_train]
val_output_shape.extend(data_rnn_output.shape[1:])

testing_input_shape = [cum_samples-num_train-num_val]
testing_input_shape.extend(data_rnn_input.shape[1:])

testing_output_shape = [cum_samples-num_train-num_val]
testing_output_shape.extend(data_rnn_output.shape[1:])

# defining required arrays
training_data_rnn_input = np.empty(shape=training_input_shape)
training_data_rnn_output = np.empty(shape=training_output_shape)

val_data_rnn_input = np.empty(shape=val_input_shape)
val_data_rnn_output = np.empty(shape=val_output_shape)

testing_data_rnn_input = np.empty(shape=testing_input_shape)
testing_data_rnn_output = np.empty(shape=testing_output_shape)

begin_idx = 0
training_data_rolling_count = 0
val_data_rolling_count = 0
testing_data_rolling_count = 0
for i in range(len(boundary_idx_arr)):
    idx = np.arange(begin_idx, rnn_data_boundary_idx_arr[i])
    # np.random.shuffle(idx)
    num_samples = idx.shape[0]
    num_train = int( (1-test_split-val_split)*num_samples )
    num_val = int(val_split*num_samples)

    training_data_rnn_input[training_data_rolling_count:training_data_rolling_count+num_train] = data_rnn_input[idx[0:num_train]]
    training_data_rnn_output[training_data_rolling_count:training_data_rolling_count+num_train] = data_rnn_output[idx[0:num_train]]
    training_data_rolling_count += num_train

    val_data_rnn_input[val_data_rolling_count:val_data_rolling_count+num_val] = data_rnn_input[idx[num_train:num_train+num_val]]
    val_data_rnn_output[val_data_rolling_count:val_data_rolling_count+num_val] = data_rnn_output[idx[num_train:num_train+num_val]]
    val_data_rolling_count += num_val

    num_test = num_samples-num_train-num_val+1
    testing_data_rnn_input[testing_data_rolling_count:testing_data_rolling_count+num_test] = data_rnn_input[idx[num_train+num_val:]]
    testing_data_rnn_output[testing_data_rolling_count:testing_data_rolling_count+num_test] = data_rnn_output[idx[num_train+num_val:]]
    testing_data_rolling_count += num_test

    begin_idx = rnn_data_boundary_idx_arr[i]

# further shuffling
idx = np.arange(0, training_data_rnn_input.shape[0])
np.random.shuffle(idx)
training_data_rnn_input = training_data_rnn_input[idx]
training_data_rnn_output = training_data_rnn_output[idx]

idx = np.arange(0, val_data_rnn_input.shape[0])
np.random.shuffle(idx)
val_data_rnn_input = val_data_rnn_input[idx]
val_data_rnn_output = val_data_rnn_output[idx]

idx = np.arange(0, testing_data_rnn_input.shape[0])
np.random.shuffle(idx)
testing_data_rnn_input = testing_data_rnn_input[idx]
testing_data_rnn_output = testing_data_rnn_output[idx]

# %%
timeMeanofSpaceRMS = np.mean(np.mean(latent_states_all**2, axis=1)**0.5)
stddev = fRMS*timeMeanofSpaceRMS
print('timeMeanofSpaceRMS :', timeMeanofSpaceRMS)
print('stddev :', stddev)

# %%
res_size = 512
spectral_rad = 0.6
degree = 3
connectivity = degree / (res_size - 1.)

ESN_layer = tfa.layers.ESN(
    units=res_size,
    spectral_radius=spectral_rad,
    return_sequences=True,
    connectivity=connectivity
)
ESN_layer.trainable = False

# %%
training_data_rnn_input[0].shape
# Out:
# (1271, 4)

# %%
ESN_input = tf.keras.Input(shape=training_data_rnn_input[0].shape)
ESN_input_with_noise = tf.keras.layers.GaussianNoise(
    stddev,
    seed=prng_seed)(ESN_input)
ESN_output = ESN_layer(ESN_input_with_noise)
ESN_output = tf.concat([ESN_output, tf.math.square(ESN_output)], axis=-1)
ESN_output = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Dense(
        training_data_rnn_output[0].shape[-1],
        activation=None,
        kernel_regularizer=tf.keras.regularizers.L2(lambda_reg)
    )
)(ESN_output)
ESN_output = ESN_output + tf.keras.layers.TimeDistributed(
    tf.keras.layers.Dense(
        training_data_rnn_output[0].shape[-1],
        activation=None,
        kernel_regularizer=tf.keras.regularizers.L2(lambda_reg)
    )
)(ESN_input_with_noise)
ESN_model = Model(ESN_input, ESN_output)

# %%
if behaviour == 'initialiseAndTrainFromScratch':
    val_loss_hist = []
    train_loss_hist = []
    lr_change=[0, 0]
    savelosses_cb_vallossarr = np.ones(shape=epochs)*np.NaN
    savelosses_cb_trainlossarr = np.ones(shape=epochs)*np.NaN
    starting_lr_idx = 0
    num_epochs_left = epochs
    earlystopping_wait = 0
elif behaviour == 'loadCheckpointAndContinueTraining':
    val_loss_hist, train_loss_hist, lr_change, starting_lr_idx, num_epochs_left, val_loss_arr_fromckpt, train_loss_arr_fromckpt, earlystopping_wait = readAndReturnLossHistories(
        dir_name_ae=dir_name_rnn,
        dir_sep=dir_sep,
        epochs=epochs,
        learning_rate_list=[0],
        return_earlystopping_wait=True)
    savelosses_cb_vallossarr = val_loss_arr_fromckpt
    savelosses_cb_trainlossarr = train_loss_arr_fromckpt
elif behaviour == 'loadFinalNetAndPlot':
    with open(dir_name_rnn+'{ds}final_net{ds}losses.txt'.format(ds=dir_sep), 'r') as f:
        lines = f.readlines()
    
    losses_dict = eval(''.join(lines))

    val_loss_hist = losses_dict['val_loss_hist']
    train_loss_hist = losses_dict['train_loss_hist']
    lr_change = losses_dict['lr_change']
    test_loss = losses_dict['test_loss']

# %%
# compiling the network
ESN_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_dict['eta_begin']),
    loss=losses.MeanSquaredError(),
    run_eagerly=False
)

if behaviour == 'loadCheckpointAndContinueTraining':
    # this loads the weights/attributes of the optimizer as well
    if strategy is not None:
        with strategy.scope():
            ESN_model.load_weights(wt_file)
    else:
        ESN_model.load_weights(wt_file)

if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    # implementing early stopping
    baseline = None
    if behaviour == 'loadCheckpointAndContinueTraining':
        baseline = np.min(val_loss_hist)
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=patience,
        restore_best_weights=True,
        verbose=True,
        min_delta=min_delta,
        baseline=baseline
    )
    # the below two lines are useless because wait is set to 0 in on_train_begin
    # early_stopping_cb.wait = earlystopping_wait
    # print('early_stopping_cb.wait : {}\n'.format(early_stopping_cb.wait))

    # time callback for each epoch
    timekeeper_cb = mytimecallback()

    # model checkpoint callback
    dir_name_ckpt = dir_name_rnn+dir_sep+'checkpoints'
    if not os.path.isdir(dir_name_ckpt):
        os.makedirs(dir_name_ckpt)
    checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
        filepath=dir_name_ckpt+dir_sep+'checkpoint',#+'/checkpoint--loss={loss:.4f}--vall_loss={val_loss:.4f}',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=True,
        verbose=2,
        initial_value_threshold=baseline,
        period=1  # saves every `period` epochs
    )

    # save losses callback
    savelosses_cb = SaveLosses(
        filepath=dir_name_ckpt+dir_sep+'LossHistoriesCheckpoint',
        val_loss_arr=savelosses_cb_vallossarr,
        train_loss_arr=savelosses_cb_trainlossarr,
        total_epochs=epochs,
        period=1)
    
    # sigmoid annealing lr schedule
    lrschedule_cb = sigmoidWarmupAndDecayLRSchedule(
        eta_begin=learning_rate_dict['eta_begin'],
        eta_high=learning_rate_dict['eta_high'],
        eta_low=learning_rate_dict['eta_low'],
        warmup=40,
        expected_epochs=100,
        g_star=0.999,
        f_star=0.001
    )

    # training the network
    savelosses_cb.update_offset(epochs - num_epochs_left)
    
    history = ESN_model.fit(training_data_rnn_input, training_data_rnn_output,
        epochs=num_epochs_left,
        batch_size=batch_size,
        # validation_split=val_split/(train_split+val_split),
        validation_data=(val_data_rnn_input, val_data_rnn_output),
        callbacks=[early_stopping_cb, timekeeper_cb, checkpoint_cb, savelosses_cb, lrschedule_cb],
        verbose=1
    )

    val_loss_hist.extend(history.history['val_loss'])
    train_loss_hist.extend(history.history['loss'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 85/85 [==============================] - ETA: 0s - loss: 0.2198 - tot_time: 0h 0m 23.7s
#
# Epoch 1: val_loss improved from inf to 0.19652, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 0.2198 - val_loss: 0.1965
# Epoch 2/200
# 85/85 [==============================] - ETA: 0s - loss: 0.1475 - tot_time: 0h 0m 46.3s
#
# Epoch 2: val_loss improved from 0.19652 to 0.13299, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 0.1475 - val_loss: 0.1330
# Epoch 3/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0961 - tot_time: 0h 1m 8.9s
#
# Epoch 3: val_loss improved from 0.13299 to 0.08693, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 0.0961 - val_loss: 0.0869
# Epoch 4/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0607 - tot_time: 0h 1m 31.6s
#
# Epoch 4: val_loss improved from 0.08693 to 0.05467, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0607 - val_loss: 0.0547
# Epoch 5/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0371 - tot_time: 0h 1m 54.3s
#
# Epoch 5: val_loss improved from 0.05467 to 0.03318, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0371 - val_loss: 0.0332
# Epoch 6/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0220 - tot_time: 0h 2m 17.0s
#
# Epoch 6: val_loss improved from 0.03318 to 0.01945, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0220 - val_loss: 0.0195
# Epoch 7/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0128 - tot_time: 0h 2m 39.5s
#
# Epoch 7: val_loss improved from 0.01945 to 0.01116, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 0.0128 - val_loss: 0.0112
# Epoch 8/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0074 - tot_time: 0h 3m 2.2s
#
# Epoch 8: val_loss improved from 0.01116 to 0.00643, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0074 - val_loss: 0.0064
# Epoch 9/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0044 - tot_time: 0h 3m 24.9s
#
# Epoch 9: val_loss improved from 0.00643 to 0.00387, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0044 - val_loss: 0.0039
# Epoch 10/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0029 - tot_time: 0h 3m 47.5s
#
# Epoch 10: val_loss improved from 0.00387 to 0.00258, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 11/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0021 - tot_time: 0h 4m 10.2s
#
# Epoch 11: val_loss improved from 0.00258 to 0.00195, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 12/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0018 - tot_time: 0h 4m 33.0s
#
# Epoch 12: val_loss improved from 0.00195 to 0.00166, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 13/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0016 - tot_time: 0h 4m 55.7s
#
# Epoch 13: val_loss improved from 0.00166 to 0.00152, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 14/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0015 - tot_time: 0h 5m 18.7s
#
# Epoch 14: val_loss improved from 0.00152 to 0.00145, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 271ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 15/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0014 - tot_time: 0h 5m 41.5s
#
# Epoch 15: val_loss improved from 0.00145 to 0.00141, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 16/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0014 - tot_time: 0h 6m 4.3s
#
# Epoch 16: val_loss improved from 0.00141 to 0.00137, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0014 - tot_time: 0h 6m 27.2s
#
# Epoch 17: val_loss improved from 0.00137 to 0.00134, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 18/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0013 - tot_time: 0h 6m 50.1s
#
# Epoch 18: val_loss improved from 0.00134 to 0.00132, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 19/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0013 - tot_time: 0h 7m 13.0s
#
# Epoch 19: val_loss improved from 0.00132 to 0.00129, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 20/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0013 - tot_time: 0h 7m 35.8s
#
# Epoch 20: val_loss improved from 0.00129 to 0.00127, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 21/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0013 - tot_time: 0h 7m 58.4s
#
# Epoch 21: val_loss improved from 0.00127 to 0.00125, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 22/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0012 - tot_time: 0h 8m 21.1s
#
# Epoch 22: val_loss improved from 0.00125 to 0.00123, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 23/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0012 - tot_time: 0h 8m 43.9s
#
# Epoch 23: val_loss improved from 0.00123 to 0.00120, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 24/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0012 - tot_time: 0h 9m 6.4s
#
# Epoch 24: val_loss improved from 0.00120 to 0.00118, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 265ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 25/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0012 - tot_time: 0h 9m 29.0s
#
# Epoch 25: val_loss improved from 0.00118 to 0.00115, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 26/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0011 - tot_time: 0h 9m 51.8s
#
# Epoch 26: val_loss improved from 0.00115 to 0.00113, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 27/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0011 - tot_time: 0h 10m 14.4s
#
# Epoch 27: val_loss improved from 0.00113 to 0.00110, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 28/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0011 - tot_time: 0h 10m 37.1s
#
# Epoch 28: val_loss improved from 0.00110 to 0.00108, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 29/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0011 - tot_time: 0h 10m 59.8s
#
# Epoch 29: val_loss improved from 0.00108 to 0.00105, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 30/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0010 - tot_time: 0h 11m 22.6s
#
# Epoch 30: val_loss improved from 0.00105 to 0.00103, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 31/200
# 85/85 [==============================] - ETA: 0s - loss: 0.0010 - tot_time: 0h 11m 45.5s
#
# Epoch 31: val_loss improved from 0.00103 to 0.00100, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 32/200
# 85/85 [==============================] - ETA: 0s - loss: 9.9515e-04 - tot_time: 0h 12m 8.3s
#
# Epoch 32: val_loss improved from 0.00100 to 0.00098, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 9.9515e-04 - val_loss: 9.8031e-04
# Epoch 33/200
# 85/85 [==============================] - ETA: 0s - loss: 9.7205e-04 - tot_time: 0h 12m 31.3s
#
# Epoch 33: val_loss improved from 0.00098 to 0.00096, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 271ms/step - loss: 9.7205e-04 - val_loss: 9.5795e-04
# Epoch 34/200
# 85/85 [==============================] - ETA: 0s - loss: 9.4958e-04 - tot_time: 0h 12m 54.0s
#
# Epoch 34: val_loss improved from 0.00096 to 0.00093, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 9.4958e-04 - val_loss: 9.3459e-04
# Epoch 35/200
# 85/85 [==============================] - ETA: 0s - loss: 9.2773e-04 - tot_time: 0h 13m 16.7s
#
# Epoch 35: val_loss improved from 0.00093 to 0.00091, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 9.2773e-04 - val_loss: 9.1439e-04
# Epoch 36/200
# 85/85 [==============================] - ETA: 0s - loss: 9.0650e-04 - tot_time: 0h 13m 39.4s
#
# Epoch 36: val_loss improved from 0.00091 to 0.00089, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 9.0650e-04 - val_loss: 8.9309e-04
# Epoch 37/200
# 85/85 [==============================] - ETA: 0s - loss: 8.8590e-04 - tot_time: 0h 14m 2.3s
#
# Epoch 37: val_loss improved from 0.00089 to 0.00087, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 8.8590e-04 - val_loss: 8.7216e-04
# Epoch 38/200
# 85/85 [==============================] - ETA: 0s - loss: 8.6584e-04 - tot_time: 0h 14m 25.0s
#
# Epoch 38: val_loss improved from 0.00087 to 0.00085, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 8.6584e-04 - val_loss: 8.5315e-04
# Epoch 39/200
# 85/85 [==============================] - ETA: 0s - loss: 8.4633e-04 - tot_time: 0h 14m 47.7s
#
# Epoch 39: val_loss improved from 0.00085 to 0.00083, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 8.4633e-04 - val_loss: 8.3381e-04
# Epoch 40/200
# 85/85 [==============================] - ETA: 0s - loss: 8.2738e-04 - tot_time: 0h 15m 10.7s
#
# Epoch 40: val_loss improved from 0.00083 to 0.00081, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 271ms/step - loss: 8.2738e-04 - val_loss: 8.1445e-04
# Epoch 41/200
# 85/85 [==============================] - ETA: 0s - loss: 8.0893e-04 - tot_time: 0h 15m 33.3s
#
# Epoch 41: val_loss improved from 0.00081 to 0.00080, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 8.0893e-04 - val_loss: 7.9707e-04
# Epoch 42/200
# 85/85 [==============================] - ETA: 0s - loss: 7.9100e-04 - tot_time: 0h 15m 56.1s
#
# Epoch 42: val_loss improved from 0.00080 to 0.00078, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 7.9100e-04 - val_loss: 7.8026e-04
# Epoch 43/200
# 85/85 [==============================] - ETA: 0s - loss: 7.7349e-04 - tot_time: 0h 16m 18.8s
#
# Epoch 43: val_loss improved from 0.00078 to 0.00076, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 7.7349e-04 - val_loss: 7.6226e-04
# Epoch 44/200
# 85/85 [==============================] - ETA: 0s - loss: 7.5646e-04 - tot_time: 0h 16m 41.5s
#
# Epoch 44: val_loss improved from 0.00076 to 0.00075, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 7.5646e-04 - val_loss: 7.4515e-04
# Epoch 45/200
# 85/85 [==============================] - ETA: 0s - loss: 7.3986e-04 - tot_time: 0h 17m 4.4s
#
# Epoch 45: val_loss improved from 0.00075 to 0.00073, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 7.3986e-04 - val_loss: 7.2934e-04
# Epoch 46/200
# 85/85 [==============================] - ETA: 0s - loss: 7.2366e-04 - tot_time: 0h 17m 27.2s
#
# Epoch 46: val_loss improved from 0.00073 to 0.00071, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 7.2366e-04 - val_loss: 7.1277e-04
# Epoch 47/200
# 85/85 [==============================] - ETA: 0s - loss: 7.0788e-04 - tot_time: 0h 17m 49.9s
#
# Epoch 47: val_loss improved from 0.00071 to 0.00070, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 7.0788e-04 - val_loss: 6.9693e-04
# Epoch 48/200
# 85/85 [==============================] - ETA: 0s - loss: 6.9248e-04 - tot_time: 0h 18m 12.7s
#
# Epoch 48: val_loss improved from 0.00070 to 0.00068, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 6.9248e-04 - val_loss: 6.8225e-04
# Epoch 49/200
# 85/85 [==============================] - ETA: 0s - loss: 6.7744e-04 - tot_time: 0h 18m 35.5s
#
# Epoch 49: val_loss improved from 0.00068 to 0.00067, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 6.7744e-04 - val_loss: 6.6688e-04
# Epoch 50/200
# 85/85 [==============================] - ETA: 0s - loss: 6.6276e-04 - tot_time: 0h 18m 58.3s
#
# Epoch 50: val_loss improved from 0.00067 to 0.00065, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 6.6276e-04 - val_loss: 6.5339e-04
# Epoch 51/200
# 85/85 [==============================] - ETA: 0s - loss: 6.4841e-04 - tot_time: 0h 19m 20.9s
#
# Epoch 51: val_loss improved from 0.00065 to 0.00064, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 6.4841e-04 - val_loss: 6.3845e-04
# Epoch 52/200
# 85/85 [==============================] - ETA: 0s - loss: 6.3440e-04 - tot_time: 0h 19m 43.5s
#
# Epoch 52: val_loss improved from 0.00064 to 0.00063, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 6.3440e-04 - val_loss: 6.2511e-04
# Epoch 53/200
# 85/85 [==============================] - ETA: 0s - loss: 6.2069e-04 - tot_time: 0h 20m 6.1s
#
# Epoch 53: val_loss improved from 0.00063 to 0.00061, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 6.2069e-04 - val_loss: 6.1132e-04
# Epoch 54/200
# 85/85 [==============================] - ETA: 0s - loss: 6.0731e-04 - tot_time: 0h 20m 28.9s
#
# Epoch 54: val_loss improved from 0.00061 to 0.00060, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 6.0731e-04 - val_loss: 5.9774e-04
# Epoch 55/200
# 85/85 [==============================] - ETA: 0s - loss: 5.9420e-04 - tot_time: 0h 20m 51.6s
#
# Epoch 55: val_loss improved from 0.00060 to 0.00058, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 5.9420e-04 - val_loss: 5.8438e-04
# Epoch 56/200
# 85/85 [==============================] - ETA: 0s - loss: 5.8140e-04 - tot_time: 0h 21m 14.3s
#
# Epoch 56: val_loss improved from 0.00058 to 0.00057, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 5.8140e-04 - val_loss: 5.7270e-04
# Epoch 57/200
# 85/85 [==============================] - ETA: 0s - loss: 5.6888e-04 - tot_time: 0h 21m 37.1s
#
# Epoch 57: val_loss improved from 0.00057 to 0.00056, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 5.6888e-04 - val_loss: 5.6076e-04
# Epoch 58/200
# 85/85 [==============================] - ETA: 0s - loss: 5.5663e-04 - tot_time: 0h 21m 59.9s
#
# Epoch 58: val_loss improved from 0.00056 to 0.00055, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 5.5663e-04 - val_loss: 5.4826e-04
# Epoch 59/200
# 85/85 [==============================] - ETA: 0s - loss: 5.4459e-04 - tot_time: 0h 22m 22.6s
#
# Epoch 59: val_loss improved from 0.00055 to 0.00054, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 5.4459e-04 - val_loss: 5.3581e-04
# Epoch 60/200
# 85/85 [==============================] - ETA: 0s - loss: 5.3287e-04 - tot_time: 0h 22m 45.5s
#
# Epoch 60: val_loss improved from 0.00054 to 0.00052, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 5.3287e-04 - val_loss: 5.2489e-04
# Epoch 61/200
# 85/85 [==============================] - ETA: 0s - loss: 5.2134e-04 - tot_time: 0h 23m 8.4s
#
# Epoch 61: val_loss improved from 0.00052 to 0.00051, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 5.2134e-04 - val_loss: 5.1371e-04
# Epoch 62/200
# 85/85 [==============================] - ETA: 0s - loss: 5.1006e-04 - tot_time: 0h 23m 31.2s
#
# Epoch 62: val_loss improved from 0.00051 to 0.00050, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 5.1006e-04 - val_loss: 5.0261e-04
# Epoch 63/200
# 85/85 [==============================] - ETA: 0s - loss: 4.9898e-04 - tot_time: 0h 23m 53.9s
#
# Epoch 63: val_loss improved from 0.00050 to 0.00049, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 4.9898e-04 - val_loss: 4.9213e-04
# Epoch 64/200
# 85/85 [==============================] - ETA: 0s - loss: 4.8817e-04 - tot_time: 0h 24m 16.7s
#
# Epoch 64: val_loss improved from 0.00049 to 0.00048, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 4.8817e-04 - val_loss: 4.8160e-04
# Epoch 65/200
# 85/85 [==============================] - ETA: 0s - loss: 4.7757e-04 - tot_time: 0h 24m 39.4s
#
# Epoch 65: val_loss improved from 0.00048 to 0.00047, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 4.7757e-04 - val_loss: 4.6939e-04
# Epoch 66/200
# 85/85 [==============================] - ETA: 0s - loss: 4.6716e-04 - tot_time: 0h 25m 2.2s
#
# Epoch 66: val_loss improved from 0.00047 to 0.00046, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 4.6716e-04 - val_loss: 4.6156e-04
# Epoch 67/200
# 85/85 [==============================] - ETA: 0s - loss: 4.5703e-04 - tot_time: 0h 25m 24.8s
#
# Epoch 67: val_loss improved from 0.00046 to 0.00045, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 4.5703e-04 - val_loss: 4.5020e-04
# Epoch 68/200
# 85/85 [==============================] - ETA: 0s - loss: 4.4702e-04 - tot_time: 0h 25m 47.3s
#
# Epoch 68: val_loss improved from 0.00045 to 0.00044, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 4.4702e-04 - val_loss: 4.4121e-04
# Epoch 69/200
# 85/85 [==============================] - ETA: 0s - loss: 4.3726e-04 - tot_time: 0h 26m 9.8s
#
# Epoch 69: val_loss improved from 0.00044 to 0.00043, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 22s 265ms/step - loss: 4.3726e-04 - val_loss: 4.3069e-04
# Epoch 70/200
# 85/85 [==============================] - ETA: 0s - loss: 4.2774e-04 - tot_time: 0h 26m 32.5s
#
# Epoch 70: val_loss improved from 0.00043 to 0.00042, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 4.2774e-04 - val_loss: 4.2156e-04
# Epoch 71/200
# 85/85 [==============================] - ETA: 0s - loss: 4.1843e-04 - tot_time: 0h 26m 55.2s
#
# Epoch 71: val_loss improved from 0.00042 to 0.00041, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 4.1843e-04 - val_loss: 4.1312e-04
# Epoch 72/200
# 85/85 [==============================] - ETA: 0s - loss: 4.0934e-04 - tot_time: 0h 27m 17.8s
#
# Epoch 72: val_loss improved from 0.00041 to 0.00040, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 4.0934e-04 - val_loss: 4.0318e-04
# Epoch 73/200
# 85/85 [==============================] - ETA: 0s - loss: 4.0038e-04 - tot_time: 0h 27m 40.4s
#
# Epoch 73: val_loss improved from 0.00040 to 0.00039, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 4.0038e-04 - val_loss: 3.9469e-04
# Epoch 74/200
# 85/85 [==============================] - ETA: 0s - loss: 3.9174e-04 - tot_time: 0h 28m 3.0s
#
# Epoch 74: val_loss improved from 0.00039 to 0.00039, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 3.9174e-04 - val_loss: 3.8514e-04
# Epoch 75/200
# 85/85 [==============================] - ETA: 0s - loss: 3.8329e-04 - tot_time: 0h 28m 25.6s
#
# Epoch 75: val_loss improved from 0.00039 to 0.00038, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 3.8329e-04 - val_loss: 3.7731e-04
# Epoch 76/200
# 85/85 [==============================] - ETA: 0s - loss: 3.7506e-04 - tot_time: 0h 28m 48.2s
#
# Epoch 76: val_loss improved from 0.00038 to 0.00037, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 3.7506e-04 - val_loss: 3.6896e-04
# Epoch 77/200
# 85/85 [==============================] - ETA: 0s - loss: 3.6706e-04 - tot_time: 0h 29m 10.8s
#
# Epoch 77: val_loss improved from 0.00037 to 0.00036, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 3.6706e-04 - val_loss: 3.6047e-04
# Epoch 78/200
# 85/85 [==============================] - ETA: 0s - loss: 3.5930e-04 - tot_time: 0h 29m 33.6s
#
# Epoch 78: val_loss improved from 0.00036 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 3.5930e-04 - val_loss: 3.5416e-04
# Epoch 79/200
# 85/85 [==============================] - ETA: 0s - loss: 3.5186e-04 - tot_time: 0h 29m 56.3s
#
# Epoch 79: val_loss improved from 0.00035 to 0.00035, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 3.5186e-04 - val_loss: 3.4654e-04
# Epoch 80/200
# 85/85 [==============================] - ETA: 0s - loss: 3.4460e-04 - tot_time: 0h 30m 18.9s
#
# Epoch 80: val_loss improved from 0.00035 to 0.00034, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 3.4460e-04 - val_loss: 3.4077e-04
# Epoch 81/200
# 85/85 [==============================] - ETA: 0s - loss: 3.3765e-04 - tot_time: 0h 30m 41.6s
#
# Epoch 81: val_loss improved from 0.00034 to 0.00033, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 3.3765e-04 - val_loss: 3.3356e-04
# Epoch 82/200
# 85/85 [==============================] - ETA: 0s - loss: 3.3091e-04 - tot_time: 0h 31m 4.4s
#
# Epoch 82: val_loss improved from 0.00033 to 0.00033, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 3.3091e-04 - val_loss: 3.2604e-04
# Epoch 83/200
# 85/85 [==============================] - ETA: 0s - loss: 3.2447e-04 - tot_time: 0h 31m 27.1s
#
# Epoch 83: val_loss improved from 0.00033 to 0.00032, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 3.2447e-04 - val_loss: 3.1935e-04
# Epoch 84/200
# 85/85 [==============================] - ETA: 0s - loss: 3.1828e-04 - tot_time: 0h 31m 49.8s
#
# Epoch 84: val_loss improved from 0.00032 to 0.00031, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 3.1828e-04 - val_loss: 3.1372e-04
# Epoch 85/200
# 85/85 [==============================] - ETA: 0s - loss: 3.1245e-04 - tot_time: 0h 32m 12.4s
#
# Epoch 85: val_loss improved from 0.00031 to 0.00031, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 3.1245e-04 - val_loss: 3.0848e-04
# Epoch 86/200
# 85/85 [==============================] - ETA: 0s - loss: 3.0675e-04 - tot_time: 0h 32m 35.2s
#
# Epoch 86: val_loss improved from 0.00031 to 0.00030, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 3.0675e-04 - val_loss: 3.0262e-04
# Epoch 87/200
# 85/85 [==============================] - ETA: 0s - loss: 3.0147e-04 - tot_time: 0h 32m 58.0s
#
# Epoch 87: val_loss improved from 0.00030 to 0.00030, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 3.0147e-04 - val_loss: 2.9647e-04
# Epoch 88/200
# 85/85 [==============================] - ETA: 0s - loss: 2.9641e-04 - tot_time: 0h 33m 20.9s
#
# Epoch 88: val_loss improved from 0.00030 to 0.00029, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.9641e-04 - val_loss: 2.9316e-04
# Epoch 89/200
# 85/85 [==============================] - ETA: 0s - loss: 2.9164e-04 - tot_time: 0h 33m 43.9s
#
# Epoch 89: val_loss improved from 0.00029 to 0.00029, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 271ms/step - loss: 2.9164e-04 - val_loss: 2.8766e-04
# Epoch 90/200
# 85/85 [==============================] - ETA: 0s - loss: 2.8719e-04 - tot_time: 0h 34m 6.5s
#
# Epoch 90: val_loss improved from 0.00029 to 0.00028, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.8719e-04 - val_loss: 2.8359e-04
# Epoch 91/200
# 85/85 [==============================] - ETA: 0s - loss: 2.8297e-04 - tot_time: 0h 34m 29.5s
#
# Epoch 91: val_loss improved from 0.00028 to 0.00028, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.8297e-04 - val_loss: 2.7975e-04
# Epoch 92/200
# 85/85 [==============================] - ETA: 0s - loss: 2.7905e-04 - tot_time: 0h 34m 52.4s
#
# Epoch 92: val_loss improved from 0.00028 to 0.00028, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.7905e-04 - val_loss: 2.7545e-04
# Epoch 93/200
# 85/85 [==============================] - ETA: 0s - loss: 2.7541e-04 - tot_time: 0h 35m 15.4s
#
# Epoch 93: val_loss improved from 0.00028 to 0.00027, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.7541e-04 - val_loss: 2.7166e-04
# Epoch 94/200
# 85/85 [==============================] - ETA: 0s - loss: 2.7201e-04 - tot_time: 0h 35m 38.3s
#
# Epoch 94: val_loss improved from 0.00027 to 0.00027, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.7201e-04 - val_loss: 2.6940e-04
# Epoch 95/200
# 85/85 [==============================] - ETA: 0s - loss: 2.6884e-04 - tot_time: 0h 36m 1.3s
#
# Epoch 95: val_loss improved from 0.00027 to 0.00027, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 271ms/step - loss: 2.6884e-04 - val_loss: 2.6600e-04
# Epoch 96/200
# 85/85 [==============================] - ETA: 0s - loss: 2.6594e-04 - tot_time: 0h 36m 24.2s
#
# Epoch 96: val_loss improved from 0.00027 to 0.00026, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.6594e-04 - val_loss: 2.6328e-04
# Epoch 97/200
# 85/85 [==============================] - ETA: 0s - loss: 2.6326e-04 - tot_time: 0h 36m 47.2s
#
# Epoch 97: val_loss improved from 0.00026 to 0.00026, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 271ms/step - loss: 2.6326e-04 - val_loss: 2.6249e-04
# Epoch 98/200
# 85/85 [==============================] - ETA: 0s - loss: 2.6077e-04 - tot_time: 0h 37m 10.2s
#
# Epoch 98: val_loss improved from 0.00026 to 0.00026, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.6077e-04 - val_loss: 2.5896e-04
# Epoch 99/200
# 85/85 [==============================] - ETA: 0s - loss: 2.5846e-04 - tot_time: 0h 37m 33.0s
#
# Epoch 99: val_loss improved from 0.00026 to 0.00026, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.5846e-04 - val_loss: 2.5673e-04
# Epoch 100/200
# 85/85 [==============================] - ETA: 0s - loss: 2.5641e-04 - tot_time: 0h 37m 55.7s
#
# Epoch 100: val_loss improved from 0.00026 to 0.00025, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.5641e-04 - val_loss: 2.5481e-04
# Epoch 101/200
# 85/85 [==============================] - ETA: 0s - loss: 2.5449e-04 - tot_time: 0h 38m 18.4s
#
# Epoch 101: val_loss improved from 0.00025 to 0.00025, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# ...
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.2528e-04 - val_loss: 2.2427e-04
# Epoch 167/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2500e-04 - tot_time: 1h 3m 19.9s
#
# Epoch 167: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.2500e-04 - val_loss: 2.2425e-04
# Epoch 168/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2473e-04 - tot_time: 1h 3m 42.6s
#
# Epoch 168: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.2473e-04 - val_loss: 2.2335e-04
# Epoch 169/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2445e-04 - tot_time: 1h 4m 5.2s
#
# Epoch 169: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 2.2445e-04 - val_loss: 2.2361e-04
# Epoch 170/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2418e-04 - tot_time: 1h 4m 27.9s
#
# Epoch 170: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.2418e-04 - val_loss: 2.2282e-04
# Epoch 171/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2390e-04 - tot_time: 1h 4m 50.8s
#
# Epoch 171: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.2390e-04 - val_loss: 2.2288e-04
# Epoch 172/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2363e-04 - tot_time: 1h 5m 13.5s
#
# Epoch 172: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.2363e-04 - val_loss: 2.2261e-04
# Epoch 173/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2335e-04 - tot_time: 1h 5m 36.3s
#
# Epoch 173: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.2335e-04 - val_loss: 2.2213e-04
# Epoch 174/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2308e-04 - tot_time: 1h 5m 59.0s
#
# Epoch 174: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.2308e-04 - val_loss: 2.2219e-04
# Epoch 175/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2281e-04 - tot_time: 1h 6m 21.8s
#
# Epoch 175: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.2281e-04 - val_loss: 2.2165e-04
# Epoch 176/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2253e-04 - tot_time: 1h 6m 44.7s
#
# Epoch 176: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.2253e-04 - val_loss: 2.2158e-04
# Epoch 177/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2226e-04 - tot_time: 1h 7m 7.6s
#
# Epoch 177: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.2226e-04 - val_loss: 2.2139e-04
# Epoch 178/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2199e-04 - tot_time: 1h 7m 30.2s
#
# Epoch 178: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 2.2199e-04 - val_loss: 2.2083e-04
# Epoch 179/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2172e-04 - tot_time: 1h 7m 53.1s
#
# Epoch 179: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.2172e-04 - val_loss: 2.2108e-04
# Epoch 180/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2144e-04 - tot_time: 1h 8m 15.7s
#
# Epoch 180: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 2.2144e-04 - val_loss: 2.2036e-04
# Epoch 181/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2118e-04 - tot_time: 1h 8m 38.4s
#
# Epoch 181: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.2118e-04 - val_loss: 2.1994e-04
# Epoch 182/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2091e-04 - tot_time: 1h 9m 1.1s
#
# Epoch 182: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.2091e-04 - val_loss: 2.1993e-04
# Epoch 183/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2064e-04 - tot_time: 1h 9m 23.8s
#
# Epoch 183: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.2064e-04 - val_loss: 2.1959e-04
# Epoch 184/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2037e-04 - tot_time: 1h 9m 46.5s
#
# Epoch 184: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.2037e-04 - val_loss: 2.1964e-04
# Epoch 185/200
# 85/85 [==============================] - ETA: 0s - loss: 2.2011e-04 - tot_time: 1h 10m 9.1s
#
# Epoch 185: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 266ms/step - loss: 2.2011e-04 - val_loss: 2.1920e-04
# Epoch 186/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1984e-04 - tot_time: 1h 10m 31.8s
#
# Epoch 186: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1984e-04 - val_loss: 2.1909e-04
# Epoch 187/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1958e-04 - tot_time: 1h 10m 54.5s
#
# Epoch 187: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.1958e-04 - val_loss: 2.1871e-04
# Epoch 188/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1931e-04 - tot_time: 1h 11m 17.2s
#
# Epoch 188: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 267ms/step - loss: 2.1931e-04 - val_loss: 2.1873e-04
# Epoch 189/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1905e-04 - tot_time: 1h 11m 39.9s
#
# Epoch 189: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1905e-04 - val_loss: 2.1805e-04
# Epoch 190/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1879e-04 - tot_time: 1h 12m 2.6s
#
# Epoch 190: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1879e-04 - val_loss: 2.1763e-04
# Epoch 191/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1853e-04 - tot_time: 1h 12m 25.5s
#
# Epoch 191: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.1853e-04 - val_loss: 2.1755e-04
# Epoch 192/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1827e-04 - tot_time: 1h 12m 48.2s
#
# Epoch 192: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1827e-04 - val_loss: 2.1738e-04
# Epoch 193/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1801e-04 - tot_time: 1h 13m 11.0s
#
# Epoch 193: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1801e-04 - val_loss: 2.1722e-04
# Epoch 194/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1776e-04 - tot_time: 1h 13m 33.7s
#
# Epoch 194: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1776e-04 - val_loss: 2.1703e-04
# Epoch 195/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1751e-04 - tot_time: 1h 13m 56.5s
#
# Epoch 195: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1751e-04 - val_loss: 2.1636e-04
# Epoch 196/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1725e-04 - tot_time: 1h 14m 19.3s
#
# Epoch 196: val_loss did not improve from 0.00022
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 268ms/step - loss: 2.1725e-04 - val_loss: 2.1664e-04
# Epoch 197/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1699e-04 - tot_time: 1h 14m 42.1s
#
# Epoch 197: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 269ms/step - loss: 2.1699e-04 - val_loss: 2.1590e-04
# Epoch 198/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1673e-04 - tot_time: 1h 15m 5.0s
#
# Epoch 198: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.1673e-04 - val_loss: 2.1564e-04
# Epoch 199/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1649e-04 - tot_time: 1h 15m 27.9s
#
# Epoch 199: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.1649e-04 - val_loss: 2.1554e-04
# Epoch 200/200
# 85/85 [==============================] - ETA: 0s - loss: 2.1624e-04Restoring model weights from the end of the best epoch: 180.
#  - tot_time: 1h 15m 50.9s
#
# Epoch 200: val_loss improved from 0.00022 to 0.00022, saving model to /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/checkpoint
#  - saving loss histories at /home/rkaushik/Documents/Thesis/MLROM/KS/saved_rnn/rnn_014/checkpoints/LossHistoriesCheckpoint
# 85/85 [==============================] - 23s 270ms/step - loss: 2.1624e-04 - val_loss: 2.1541e-04
# Epoch 200: early stopping

# %%
if behaviour == 'initialiseAndTrainFromScratch' or behaviour == 'loadCheckpointAndContinueTraining':
    test_loss = ESN_model.evaluate(
        testing_data_rnn_input, testing_data_rnn_output,
    )

    save_path = dir_name_rnn+dir_sep+'final_net'

    if not os.path.isdir(save_path):
        os.makedirs(save_path)


    with open(save_path+dir_sep+'losses.txt', 'w') as f:
        f.write(str({
            'val_loss_hist':val_loss_hist,
            'train_loss_hist':train_loss_hist,
            'lr_change':lr_change,
            'test_loss':test_loss
        }))
        
    if normalize_dataset == True:
        with open(save_path+dir_sep+'rnn_normalization.txt', 'w') as f:
            f.write(str({
                'normalization_arr':normalization_arr
            }))

    ESN_model.save_weights(
        save_path+dir_sep+'final_net.h5')
# Out:
# 22/22 [==============================] - 3s 151ms/step - loss: 2.2263e-04

# %%
# plotting losses
dir_name_plot = dir_name_rnn+dir_sep+'plots'
if not os.path.isdir(dir_name_plot):
    os.makedirs(dir_name_plot)

# Visualize loss history
fig, ax = plot_losses(
    training_loss=train_loss_hist,
    val_loss=val_loss_hist,
    lr_change=lr_change,
    learning_rate_list=None
)

plt.savefig(dir_name_rnn+'{ds}plots{ds}loss_history.png'.format(ds=dir_sep), dpi=300, bbox_inches='tight')
plt.show()

# %%
# data_type = 'training'
data_type = 'testing'

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
print('data_idx : {}'.format(data_idx))

# data_in = data_in[data_idx]
data_out = data_out[data_idx]

prediction = ESN_model.predict(data_in[data_idx:data_idx+1, :, :])

n = 1
num_latent_states = data_out.shape[-1]
N = data_out.shape[0]

num_cols = 1
num_rows = n*num_latent_states

ax_ylabels = ['$x^*_1$', '$x^*_2$', '$x^*_3$', '$x^*_4$', '$x^*_5$', '$x^*_6$']

fig, ax = plt.subplots(num_latent_states, 1, sharex=True, figsize=(7.5*num_cols, 2.5*num_rows))
if num_latent_states == 1:
    ax = [ax]
input_time = np.arange(0, N)*dt_rnn

cmap = plt.get_cmap('jet')
colors = [cmap(i) for i in np.linspace(0, 1, 2*n)]

prev_idx = 0

mpl_ax_artist_list = []
for j in range(num_latent_states):
    for i in range(n):
        obj_in = ax[j].plot(input_time, data_out[:, j], linewidth=1, color=colors[2*i], label='Case {} - actual data'.format(i+1))
        obj_out = ax[j].plot(input_time, prediction[0, :, j], linewidth=1, color=colors[2*i+1], label='Case {} - predicted data'.format(i+1))
        mpl_ax_artist_list.append(obj_in[0])
        mpl_ax_artist_list.append(obj_out[0])
    ax[j].set_ylabel(ax_ylabels[j])
    # if xlim is not None:
    #     ax[j].set_xlim(xlim)
    # if ylim is not None:
    #     ax[j].set_ylim(ylim)
    ax[j].grid(True)
    ax[j].set_axisbelow(True)


ax[-1].set_xlabel('Time$^+$')

max_rows = 10
max_rows = float(max_rows)
ncols = int(np.ceil(len(boundary_idx_arr) / max_rows))
# plt.figlegend(
#     handles=mpl_ax_artist_list[0:n],
#     # bbox_to_anchor=[1.1,0.85],
#     loc=legend_loc,
#     bbox_to_anchor=legend_bbox_to_anchor,
#     ncol=ncols,
#     markerscale=legend_markerscale
# )
ax[0].legend(
    # handles=mpl_ax_artist_list[0:n],
    # bbox_to_anchor=[1.1,0.85],
    loc='best',
    # bbox_to_anchor=legend_bbox_to_anchor,
    ncol=ncols,
    # markerscale=legend_markerscale
)
# fig.suptitle(r'Latent States', size=12)
ax[0].set_title(r'Latent States', size=12)
# Out:
# data_idx : 399
# Text(0.5, 1.0, 'Latent States')

# %%
# data_type = 'training'
data_type = 'testing'

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 3788
print('data_idx : {}'.format(data_idx))

# data_in = data_in[data_idx]
data_out = data_out[data_idx]

prediction = ESN_model.predict(data_in[data_idx:data_idx+1, :, :])

plot_reconstructed_data_KS(
    [data_out.shape[0]],
    dir_name_ae,
    data_out,
    prediction[0], delta_t, 1+np.arange(0, data_out.shape[1]),
    save_figs=False,
    normalization_constant_arr=normalization_arr,
    xticks_snapto=int(10*np.round((T_sample_output//10)/10)),
    num_yticks=data_out.shape[1],
    ylabel=r'Latent State Index',
    ax1_title=r'Original Data',
    ax2_title=r'RNN (Teacher Forced) Predicted Data')
# Out:
# data_idx : 418

# %%
# data_type = 'training'
data_type = 'testing'

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 10
print('data_idx : {}'.format(data_idx))

### initial point
# plt.plot(data_in[data_idx, :, 0], data_in[data_idx, :, 1], 'o')

### actual trajectory
plt.plot(data_out[data_idx, 0, 0], data_out[data_idx, 0, 1], 'o', color='C1')
plt.plot(data_out[data_idx, :, 0], data_out[data_idx, :, 1], 'C1')

### predicted trajectory
prediction = ESN_model.predict(data_in[data_idx:data_idx+1, :, :])
# plt.plot([data_in[data_idx, :, 0], ].extend(prediction[0, :, 0]), [data_in[data_idx, :, 1], ].extend(prediction[0, :, 1]))
plt.plot(prediction[0, :, 0], prediction[0, :, 1], color='C2')
plt.plot(prediction[0, 0, 0], prediction[0, 0, 1], 'o', color='C2')

plt.grid(True)
plt.show()
# Out:
# data_idx : 628

# %% [markdown]
# # AutoRegressive ESN

# %%
num_input_timesteps = 121
num_output_timesteps = 1000

# %%
AR_ESN_layer = tfa.layers.ESN(
    units=res_size,
    spectral_radius=spectral_rad,
    return_sequences=False,
    connectivity=connectivity
)
AR_ESN_layer.trainable = False
AR_ESN_layer.return_state = True

# %%
AR_ESN_input = tf.keras.Input(shape=training_data_rnn_input[0, 0:1].shape)
AR_ESN_output, ESN_state = AR_ESN_layer(AR_ESN_input)
AR_ESN_output = tf.concat([AR_ESN_output, tf.math.square(AR_ESN_output)], axis=-1)
AR_ESN_output = tf.keras.layers.Dense(
        training_data_rnn_input[0, 0:1].shape[-1],
        activation=None,
        kernel_regularizer=tf.keras.regularizers.L2(lambda_reg)
)(AR_ESN_output)
AR_ESN_output = AR_ESN_output + tf.keras.layers.Dense(
    training_data_rnn_input[0, 0:1].shape[-1],
    activation=None,
    kernel_regularizer=tf.keras.regularizers.L2(lambda_reg)
)(AR_ESN_input)
AR_ESN_model = Model(AR_ESN_input, [AR_ESN_output, ESN_state])

# %%
AR_ESN_model.set_weights(ESN_model.get_weights())

# %%
AR_ESN_layer.states
# Out:
# [None]

# %%
og_get_initial_state = AR_ESN_model.layers[1].cell.get_initial_state

# %%
# AR_ESN_model.layers[1].return_state = True

# %%
AR_ESN_model.layers[1]

# %%
# data_type = 'training'
data_type = 'testing'

data_in = eval(data_type+'_data_rnn_input')
data_out = eval(data_type+'_data_rnn_output')

data_idx = np.arange(data_in.shape[0])
np.random.shuffle(data_idx)
data_idx = data_idx[0]
# data_idx = 0
print('data_idx : {}'.format(data_idx))
data_out = data_out[data_idx, num_input_timesteps-1:num_input_timesteps-1+num_output_timesteps]
print('data_out.shape :', data_out.shape)

plt.plot(data_in[data_idx, 0:num_input_timesteps, 0])
plt.plot(np.arange(data_out.shape[0])+num_input_timesteps, data_out[:, 0])
plt.grid(True)
plt.show()
# Out:
# data_idx : 253
# data_out.shape : (1000, 4)

# %%
prediction_lst = []
input_pred_lst = []
# print('\ni=0 : state = ', AR_ESN_model.layers[1].states)
AR_ESN_model.layers[1].cell.get_initial_state = og_get_initial_state
prediction, state = AR_ESN_model(data_in[data_idx:data_idx+1, 0:1, :], training=None)
# state = AR_ESN_model.layers[1].states
input_pred_lst.append(prediction[0])
# print('i=0 : state = ', state)
# print('')
print(data_in[data_idx:data_idx+1, 0:1, :].shape)

for i in range(1, num_input_timesteps):
#     AR_ESN_model.layers[1].states = state
#     print('\ni={} : state = '.format(i), state)
    AR_ESN_model.layers[1].cell.get_initial_state = lambda **kwargs:state
    prediction, state = AR_ESN_model(data_in[data_idx:data_idx+1, i:i+1, :], training=None)#, state=state)
#     state = AR_ESN_model.layers[1].states
    input_pred_lst.append(prediction[0])
#     print('i={} : state = '.format(i), AR_ESN_model.layers[1].states)
#     print('')
print(len(input_pred_lst[0]))
input_pred_lst = tf.stack(input_pred_lst)
print(input_pred_lst.shape)
print(prediction.shape)
input_pred_lst = tf.transpose(input_pred_lst, [1, 0, 2])

prediction_lst.append(prediction[0])
for i in range(1, num_output_timesteps):
#     AR_ESN_model.layers[1].states = state
    AR_ESN_model.layers[1].cell.get_initial_state = lambda **kwargs:state
    prediction, state = AR_ESN_model(tf.stack([prediction[0]]), training=None)#, state=state)
#     state = AR_ESN_model.layers[1].states
    prediction_lst.append(prediction[0])
    
predictions = tf.stack(prediction_lst)
prediction = tf.transpose(predictions, [1, 0, 2])
# Out:
# (1, 1, 4)
# 1
# (121, 1, 4)
# (1, 1, 4)

# %%
input_pred_lst.shape
# Out:
# TensorShape([1, 121, 4])

# %%
n = 1
num_latent_states = data_out.shape[-1]
N = data_out.shape[0]#num_output_timesteps
print(data_out.shape)
print(prediction.shape)

num_cols = 1
num_rows = n*num_latent_states

ax_ylabels = ['$x^*_1$', '$x^*_2$', '$x^*_3$', '$x^*_4$', '$x^*_5$', '$x^*_6$']

fig, ax = plt.subplots(num_latent_states, 1, sharex=True, figsize=(7.5*num_cols, 2.5*num_rows))
if num_latent_states == 1:
    ax = [ax]
input_time = np.arange(input_pred_lst.shape[1], input_pred_lst.shape[1]+N)*dt_rnn

cmap = plt.get_cmap('jet')
colors = [cmap(i) for i in np.linspace(0, 1, 2*n)]

prev_idx = 0

time_arr_warmup = np.arange(0, input_pred_lst.shape[1])*dt_rnn

for j in range(num_latent_states):
    for i in range(n):
        ax[j].plot(time_arr_warmup, data_in[data_idx, 0:num_input_timesteps, j], linestyle='--', linewidth=1, color=colors[2*i], label='Case {} - actual warmup data'.format(i+1))
        ax[j].plot(time_arr_warmup+dt_rnn, input_pred_lst[0, :, j], linestyle='--', linewidth=1, color=colors[2*i+1], label='Case {} - predicted warmup data'.format(i+1))
        ax[j].plot(input_time, data_out[:, j], linewidth=1, color=colors[2*i], label='Case {} - actual data'.format(i+1))
        ax[j].plot(input_time, prediction[0, :, j], linewidth=1, color=colors[2*i+1], label='Case {} - predicted data'.format(i+1))
    ax[j].set_ylabel(ax_ylabels[j])
    ax[j].grid(True)
    ax[j].set_axisbelow(True)


ax[-1].set_xlabel('Time$^+$')

max_rows = 10
max_rows = float(max_rows)
ncols = int(np.ceil(len(boundary_idx_arr) / max_rows))
ax[0].legend(
    loc='best',
    ncol=ncols,
)
ax[0].set_title(r'Latent States', size=12)
# Out:
# (1000, 4)
# (1, 1000, 4)
# Text(0.5, 1.0, 'Latent States')

# %%
training_data_rnn_input[0, 0].shape
# Out:
# (4,)

# %%
data_out[data_idx].shape
# Out:
# (4,)
